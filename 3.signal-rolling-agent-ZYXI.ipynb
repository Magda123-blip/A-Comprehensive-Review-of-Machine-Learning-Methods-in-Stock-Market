# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../agent/cleaned_data/ZYXI.csv')
df.head()
# Out:
#        Date  Open  High   Low  Close  Adj Close  Volume
# 0  1/2/2013  0.70  0.70  0.70   0.70   0.380843       0
# 1  1/3/2013  0.70  0.70  0.70   0.70   0.380843       0
# 2  1/4/2013  0.65  0.65  0.65   0.65   0.353640   17900
# 3  1/7/2013  0.65  0.65  0.65   0.65   0.353640    3100
# 4  1/8/2013  0.63  0.65  0.63   0.65   0.353640    9800

# %%
def buy_stock(
    real_movement,
    delay = 5,
    initial_state = 1,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    delay_change_decision = delay
    current_decision = 0
    state = initial_state
    current_val = real_movement[0]
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    if state == 1:
        initial_money, current_inventory = buy(
            0, initial_money, current_inventory
        )

    for i in range(1, real_movement.shape[0], 1):
        if real_movement[i] < current_val and state == 0:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 1
                initial_money, current_inventory = buy(
                    i, initial_money, current_inventory
                )
                current_decision = 0
                states_buy.append(i)
        if real_movement[i] > current_val and state == 1:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 0

                if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
                else:
                    if current_inventory > max_sell:
                        sell_units = max_sell
                    else:
                        sell_units = current_inventory
                    current_inventory -= sell_units
                    total_sell = sell_units * real_movement[i]
                    initial_money += total_sell
                    try:
                        invest = (
                            (real_movement[i] - real_movement[states_buy[-1]])
                            / real_movement[states_buy[-1]]
                        ) * 100
                    except:
                        invest = 0
                    print(
                        'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                        % (i, sell_units, total_sell, invest, initial_money)
                    )

                current_decision = 0
                states_sell.append(i)
        current_val = real_movement[i]
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, initial_state = 1, 
                                                         delay = 4, initial_money = 10000)
# Out:
# day 0: buy 1 units at price 0.700000, total balance 9999.300000
# day 27, sell 1 units at price 0.600000, investment -14.285709 %, total balance 9999.900000,
# day 39: buy 1 units at price 0.510000, total balance 9999.390000
# day 58, sell 1 units at price 0.580000, investment 13.725489 %, total balance 9999.970000,
# day 70: buy 1 units at price 0.530000, total balance 9999.440000
# day 88, sell 1 units at price 0.500000, investment -5.660372 %, total balance 9999.940000,
# day 99: buy 1 units at price 0.420000, total balance 9999.520000
# day 121, sell 1 units at price 0.480000, investment 14.285715 %, total balance 10000.000000,
# day 145: buy 1 units at price 0.440000, total balance 9999.560000
# day 166, sell 1 units at price 0.300000, investment -31.818179 %, total balance 9999.860000,
# day 183: buy 1 units at price 0.260000, total balance 9999.600000
# day 205, sell 1 units at price 0.250000, investment -3.846150 %, total balance 9999.850000,
# day 217: buy 1 units at price 0.220000, total balance 9999.630000
# day 230, sell 1 units at price 0.310000, investment 40.909092 %, total balance 9999.940000,
# day 242: buy 1 units at price 0.310000, total balance 9999.630000
# day 251, sell 1 units at price 0.370000, investment 19.354840 %, total balance 10000.000000,
# day 261: buy 1 units at price 0.300000, total balance 9999.700000
# day 285, sell 1 units at price 0.360000, investment 20.000000 %, total balance 10000.060000,
# day 301: buy 1 units at price 0.410000, total balance 9999.650000
# day 315, sell 1 units at price 0.500000, investment 21.951221 %, total balance 10000.150000,
# day 329: buy 1 units at price 0.400000, total balance 9999.750000
# day 354, sell 1 units at price 0.300000, investment -24.999998 %, total balance 10000.050000,
# day 372: buy 1 units at price 0.250000, total balance 9999.800000
# day 384, sell 1 units at price 0.250000, investment 0.000000 %, total balance 10000.050000,
# day 399: buy 1 units at price 0.210000, total balance 9999.840000
# day 415, sell 1 units at price 0.220000, investment 4.761908 %, total balance 10000.060000,
# day 428: buy 1 units at price 0.150000, total balance 9999.910000
# day 441, sell 1 units at price 0.140000, investment -6.666670 %, total balance 10000.050000,
# day 459: buy 1 units at price 0.090000, total balance 9999.960000
# day 468, sell 1 units at price 0.180000, investment 99.999999 %, total balance 10000.140000,
# day 482: buy 1 units at price 0.170000, total balance 9999.970000
# day 501, sell 1 units at price 0.170000, investment 0.000000 %, total balance 10000.140000,
# day 514: buy 1 units at price 0.180000, total balance 9999.960000
# day 556, sell 1 units at price 0.140000, investment -22.222225 %, total balance 10000.100000,
# day 588: buy 1 units at price 0.210000, total balance 9999.890000
# day 631, sell 1 units at price 0.200000, investment -4.761900 %, total balance 10000.090000,
# day 655: buy 1 units at price 0.160000, total balance 9999.930000
# day 688, sell 1 units at price 0.190000, investment 18.750002 %, total balance 10000.120000,
# day 730: buy 1 units at price 0.200000, total balance 9999.920000
# day 747, sell 1 units at price 0.350000, investment 74.999994 %, total balance 10000.270000,
# day 760: buy 1 units at price 0.380000, total balance 9999.890000
# day 772, sell 1 units at price 0.360000, investment -5.263153 %, total balance 10000.250000,
# day 800: buy 1 units at price 0.340000, total balance 9999.910000
# day 840, sell 1 units at price 0.330000, investment -2.941174 %, total balance 10000.240000,
# day 863: buy 1 units at price 0.250000, total balance 9999.990000
# day 891, sell 1 units at price 0.210000, investment -16.000003 %, total balance 10000.200000,
# day 913: buy 1 units at price 0.160000, total balance 10000.040000
# day 919, sell 1 units at price 0.260000, investment 62.499998 %, total balance 10000.300000,
# day 970: buy 1 units at price 0.270000, total balance 10000.030000
# day 990, sell 1 units at price 0.320000, investment 18.518511 %, total balance 10000.350000,
# day 1011: buy 1 units at price 0.320000, total balance 10000.030000
# day 1036, sell 1 units at price 0.320000, investment 0.000000 %, total balance 10000.350000,
# day 1061: buy 1 units at price 0.320000, total balance 10000.030000
# day 1087, sell 1 units at price 0.330000, investment 3.125006 %, total balance 10000.360000,
# day 1105: buy 1 units at price 0.350000, total balance 10000.010000
# day 1117, sell 1 units at price 0.420000, investment 19.999998 %, total balance 10000.430000,
# day 1136: buy 1 units at price 0.710000, total balance 9999.720000
# day 1144, sell 1 units at price 0.900000, investment 26.760564 %, total balance 10000.620000,
# day 1151: buy 1 units at price 0.710000, total balance 9999.910000
# day 1160, sell 1 units at price 0.790000, investment 11.267612 %, total balance 10000.700000,
# day 1179: buy 1 units at price 1.540000, total balance 9999.160000
# day 1188, sell 1 units at price 1.830000, investment 18.831175 %, total balance 10000.990000,
# day 1198: buy 1 units at price 1.820000, total balance 9999.170000
# day 1205, sell 1 units at price 1.940000, investment 6.593407 %, total balance 10001.110000,
# day 1218: buy 1 units at price 2.740000, total balance 9998.370000
# day 1227, sell 1 units at price 3.050000, investment 11.313866 %, total balance 10001.420000,
# day 1237: buy 1 units at price 2.790000, total balance 9998.630000
# day 1247, sell 1 units at price 2.690000, investment -3.584226 %, total balance 10001.320000,
# day 1260: buy 1 units at price 3.300000, total balance 9998.020000
# day 1267, sell 1 units at price 3.650000, investment 10.606065 %, total balance 10001.670000,
# day 1288: buy 1 units at price 5.000000, total balance 9996.670000
# day 1303, sell 1 units at price 3.800000, investment -24.000001 %, total balance 10000.470000,
# day 1311: buy 1 units at price 3.820000, total balance 9996.650000
# day 1329, sell 1 units at price 3.500000, investment -8.376962 %, total balance 10000.150000,
# day 1335: buy 1 units at price 3.110000, total balance 9997.040001
# day 1342, sell 1 units at price 3.300000, investment 6.109327 %, total balance 10000.340000,
# day 1352: buy 1 units at price 3.050000, total balance 9997.290001
# day 1361, sell 1 units at price 3.120000, investment 2.295080 %, total balance 10000.410000,
# day 1373: buy 1 units at price 3.360000, total balance 9997.050001
# day 1388, sell 1 units at price 3.000000, investment -10.714283 %, total balance 10000.050001,
# day 1396: buy 1 units at price 2.790000, total balance 9997.260001
# day 1412, sell 1 units at price 2.900000, investment 3.942657 %, total balance 10000.160001,
# day 1427: buy 1 units at price 3.080000, total balance 9997.080001
# day 1434, sell 1 units at price 3.350000, investment 8.766233 %, total balance 10000.430001,
# day 1444: buy 1 units at price 3.130000, total balance 9997.300001
# day 1459, sell 1 units at price 3.120000, investment -0.319496 %, total balance 10000.420000,
# day 1468: buy 1 units at price 3.050000, total balance 9997.370000
# day 1473, sell 1 units at price 3.440000, investment 12.786889 %, total balance 10000.810001,
# day 1481: buy 1 units at price 3.100000, total balance 9997.710001
# day 1495, sell 1 units at price 3.150000, investment 1.612909 %, total balance 10000.860001,
# day 1502: buy 1 units at price 2.970000, total balance 9997.890001
# day 1515, sell 1 units at price 3.000000, investment 1.010100 %, total balance 10000.890001,
# day 1533: buy 1 units at price 3.650000, total balance 9997.240001
# day 1539, sell 1 units at price 4.860000, investment 33.150685 %, total balance 10002.100001,
# day 1553: buy 1 units at price 4.430000, total balance 9997.670001
# day 1562, sell 1 units at price 4.400000, investment -0.677195 %, total balance 10002.070001,
# day 1578: buy 1 units at price 5.020000, total balance 9997.050001
# day 1584, sell 1 units at price 5.310000, investment 5.776892 %, total balance 10002.360001,
# day 1603: buy 1 units at price 7.520000, total balance 9994.840001
# day 1614, sell 1 units at price 7.350000, investment -2.260639 %, total balance 10002.190001,
# day 1630: buy 1 units at price 10.500000, total balance 9991.690001
# day 1647, sell 1 units at price 7.730000, investment -26.380952 %, total balance 9999.420001,
# day 1659: buy 1 units at price 8.570000, total balance 9990.850001
# day 1667, sell 1 units at price 10.620000, investment 23.920657 %, total balance 10001.470001,
# day 1673: buy 1 units at price 8.740000, total balance 9992.730001
# day 1683, sell 1 units at price 9.220000, investment 5.491997 %, total balance 10001.950002,
# day 1693: buy 1 units at price 9.720000, total balance 9992.230001
# day 1701, sell 1 units at price 12.510000, investment 28.703703 %, total balance 10004.740002,
# day 1707: buy 1 units at price 11.510000, total balance 9993.230001
# day 1720, sell 1 units at price 9.240000, investment -19.721984 %, total balance 10002.470001,
# day 1736: buy 1 units at price 8.920000, total balance 9993.550001
# day 1750, sell 1 units at price 9.310000, investment 4.372201 %, total balance 10002.860001,
# day 1758: buy 1 units at price 8.040000, total balance 9994.820001

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
