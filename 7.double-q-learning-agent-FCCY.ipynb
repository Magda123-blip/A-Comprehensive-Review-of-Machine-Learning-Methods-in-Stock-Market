# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../agent/cleaned_data/FCCY.csv')
df.head()
# Out:
#        Date      Open      High       Low     Close  Adj Close  Volume
# 0  1/2/2013  7.981859  7.981859  7.981859  7.981859   7.603687     400
# 1  1/3/2013  7.981859  8.036282  7.981859  8.036282   7.655531    1300
# 2  1/4/2013  8.045351  8.235827  8.045351  8.217687   7.828341     500
# 3  1/7/2013  8.136054  8.244898  8.136054  8.235827   7.845623     900
# 4  1/8/2013  8.235827  8.235827  8.208617  8.208617   7.819701    1000

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B6A571C88>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B6A571C88>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B6A571C88>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B6A571C88>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B6A571C88>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B6A571C88>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B6A571C88>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B6A571C88>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B147C0188>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B147C0188>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B147C0188>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B147C0188>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B14951308>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B14951308>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B14951308>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000027B14951308>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: 89.736275.3, cost: 0.001295, total money: 9765.666277
# epoch: 20, total rewards: 49.181960.3, cost: 0.000313, total money: 9983.881961
# epoch: 30, total rewards: 47.900458.3, cost: 0.000144, total money: 10047.900458
# epoch: 40, total rewards: 21.723266.3, cost: 0.001258, total money: 10021.723266
# epoch: 50, total rewards: 41.228699.3, cost: 0.000658, total money: 9934.008698
# epoch: 60, total rewards: 80.499583.3, cost: 0.000021, total money: 10058.779584
# epoch: 70, total rewards: 6.487217.3, cost: 0.000525, total money: 9876.407219
# epoch: 80, total rewards: 6.400462.3, cost: 0.000472, total money: 10006.400462
# epoch: 90, total rewards: 18.500403.3, cost: 0.000112, total money: 9953.180406
# epoch: 100, total rewards: 18.224862.3, cost: 0.000186, total money: 9996.444861
# epoch: 110, total rewards: 42.273692.3, cost: 0.000045, total money: 10020.553693
# epoch: 120, total rewards: 3.883652.3, cost: 0.000120, total money: 9938.633654
# epoch: 130, total rewards: 25.408041.3, cost: 0.000282, total money: 10025.408041
# epoch: 140, total rewards: 10.670471.3, cost: 0.000188, total money: 9988.870472
# epoch: 150, total rewards: 29.208062.3, cost: 0.000186, total money: 10007.408063
# epoch: 160, total rewards: 16.074587.3, cost: 0.000307, total money: 10016.074587
# epoch: 170, total rewards: 3.487109.3, cost: 0.000077, total money: 10003.487109
# epoch: 180, total rewards: 16.893399.3, cost: 0.000114, total money: 10016.893399
# epoch: 190, total rewards: 13.702863.3, cost: 0.000015, total money: 9991.902863
# epoch: 200, total rewards: 34.172864.3, cost: 0.000305, total money: 10034.172864

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 6: buy 1 unit at price 8.571428, total balance 9991.428572
# day 7, sell 1 unit at price 8.552381, investment -0.222224 %, total balance 9999.980952,
# day 17: buy 1 unit at price 8.590476, total balance 9991.390476
# day 18, sell 1 unit at price 8.485714, investment -1.219514 %, total balance 9999.876190,
# day 21: buy 1 unit at price 8.476191, total balance 9991.400000
# day 22, sell 1 unit at price 8.619047, investment 1.685387 %, total balance 10000.019047,
# day 35: buy 1 unit at price 8.619047, total balance 9991.400000
# day 36, sell 1 unit at price 8.619047, investment 0.000000 %, total balance 10000.019047,
# day 51: buy 1 unit at price 8.342857, total balance 9991.676189
# day 52: buy 1 unit at price 8.361905, total balance 9983.314284
# day 53, sell 1 unit at price 8.361905, investment 0.228312 %, total balance 9991.676189,
# day 54, sell 1 unit at price 8.361905, investment 0.000000 %, total balance 10000.038095,
# day 62: buy 1 unit at price 8.390476, total balance 9991.647618
# day 63: buy 1 unit at price 8.419047, total balance 9983.228571
# day 64, sell 1 unit at price 8.352381, investment -0.454032 %, total balance 9991.580952,
# day 65, sell 1 unit at price 8.371428, investment -0.565609 %, total balance 9999.952380,
# day 67: buy 1 unit at price 8.438095, total balance 9991.514285
# day 68: buy 1 unit at price 8.342857, total balance 9983.171428
# day 69, sell 1 unit at price 8.361905, investment -0.902929 %, total balance 9991.533333,
# day 70, sell 1 unit at price 8.371428, investment 0.342462 %, total balance 9999.904761,
# day 74: buy 1 unit at price 8.333333, total balance 9991.571428
# day 75, sell 1 unit at price 8.304762, investment -0.342854 %, total balance 9999.876190,
# day 76: buy 1 unit at price 8.238095, total balance 9991.638095
# day 77, sell 1 unit at price 8.238095, investment 0.000000 %, total balance 9999.876190,
# day 80: buy 1 unit at price 8.190476, total balance 9991.685714
# day 81, sell 1 unit at price 8.257143, investment 0.813953 %, total balance 9999.942857,
# day 82: buy 1 unit at price 8.238095, total balance 9991.704762
# day 84: buy 1 unit at price 8.352381, total balance 9983.352381
# day 85, sell 1 unit at price 8.514286, investment 3.352605 %, total balance 9991.866667,
# day 86: buy 1 unit at price 8.514286, total balance 9983.352381
# day 87, sell 1 unit at price 8.514286, investment 1.938433 %, total balance 9991.866667,
# day 88: buy 1 unit at price 8.542857, total balance 9983.323810
# day 89: buy 1 unit at price 8.647619, total balance 9974.676190
# day 90, sell 1 unit at price 8.628572, investment 1.342279 %, total balance 9983.304762,
# day 92, sell 1 unit at price 8.571428, investment 0.334445 %, total balance 9991.876190,
# day 93, sell 1 unit at price 8.476191, investment -1.982380 %, total balance 10000.352381,
# day 94: buy 1 unit at price 8.447619, total balance 9991.904761
# day 95, sell 1 unit at price 8.476191, investment 0.338215 %, total balance 10000.380952,
# day 103: buy 1 unit at price 8.761905, total balance 9991.619047
# day 104, sell 1 unit at price 8.685715, investment -0.869560 %, total balance 10000.304762,
# day 108: buy 1 unit at price 8.800000, total balance 9991.504762
# day 112: buy 1 unit at price 8.761905, total balance 9982.742857
# day 115, sell 1 unit at price 8.847619, investment 0.541123 %, total balance 9991.590476,
# day 116, sell 1 unit at price 9.019048, investment 2.934784 %, total balance 10000.609524,
# day 117: buy 1 unit at price 8.914286, total balance 9991.695238
# day 118, sell 1 unit at price 9.047619, investment 1.495725 %, total balance 10000.742857,
# day 119: buy 1 unit at price 8.809524, total balance 9991.933333
# day 121: buy 1 unit at price 8.819048, total balance 9983.114285
# day 122, sell 1 unit at price 8.819048, investment 0.108114 %, total balance 9991.933333,
# day 123, sell 1 unit at price 9.047619, investment 2.591787 %, total balance 10000.980952,
# day 127: buy 1 unit at price 9.200000, total balance 9991.780952
# day 128, sell 1 unit at price 9.314285, investment 1.242233 %, total balance 10001.095238,
# day 133: buy 1 unit at price 9.085714, total balance 9992.009523
# day 134: buy 1 unit at price 9.066667, total balance 9982.942857
# day 135: buy 1 unit at price 9.057143, total balance 9973.885714
# day 136, sell 1 unit at price 9.171429, investment 0.943397 %, total balance 9983.057142,
# day 137: buy 1 unit at price 9.171429, total balance 9973.885714
# day 138, sell 1 unit at price 9.247619, investment 1.995795 %, total balance 9983.133332,
# day 139, sell 1 unit at price 9.038095, investment -0.210306 %, total balance 9992.171428,
# day 140, sell 1 unit at price 9.095238, investment -0.830742 %, total balance 10001.266665,
# day 141: buy 1 unit at price 9.161904, total balance 9992.104761
# day 143: buy 1 unit at price 9.142858, total balance 9982.961904
# day 144, sell 1 unit at price 9.142858, investment -0.207891 %, total balance 9992.104761,
# day 145, sell 1 unit at price 9.142858, investment 0.000000 %, total balance 10001.247619,
# day 149: buy 1 unit at price 9.295238, total balance 9991.952380
# day 150, sell 1 unit at price 9.323810, investment 0.307374 %, total balance 10001.276190,
# day 152: buy 1 unit at price 9.428572, total balance 9991.847618
# day 153, sell 1 unit at price 9.190476, investment -2.525253 %, total balance 10001.038095,
# day 154: buy 1 unit at price 9.190476, total balance 9991.847618
# day 155, sell 1 unit at price 9.285714, investment 1.036265 %, total balance 10001.133332,
# day 157: buy 1 unit at price 9.428572, total balance 9991.704761
# day 159, sell 1 unit at price 9.571428, investment 1.515146 %, total balance 10001.276189,
# day 170: buy 1 unit at price 9.466666, total balance 9991.809523
# day 171, sell 1 unit at price 9.476191, investment 0.100609 %, total balance 10001.285713,
# day 175: buy 1 unit at price 9.895238, total balance 9991.390475
# day 176, sell 1 unit at price 10.419047, investment 5.293551 %, total balance 10001.809523,
# day 180: buy 1 unit at price 10.400000, total balance 9991.409523
# day 181, sell 1 unit at price 10.447619, investment 0.457883 %, total balance 10001.857142,
# day 184: buy 1 unit at price 10.009523, total balance 9991.847619
# day 185: buy 1 unit at price 9.914286, total balance 9981.933333
# day 186, sell 1 unit at price 10.076191, investment 0.666041 %, total balance 9992.009524,
# day 187: buy 1 unit at price 10.076191, total balance 9981.933333
# day 188: buy 1 unit at price 10.076191, total balance 9971.857142
# day 189, sell 1 unit at price 9.942857, investment 0.288181 %, total balance 9981.799999,
# day 190, sell 1 unit at price 9.761905, investment -3.119098 %, total balance 9991.561904,
# day 191, sell 1 unit at price 9.761905, investment -3.119098 %, total balance 10001.323809,
# day 202: buy 1 unit at price 10.361905, total balance 9990.961904
# day 203, sell 1 unit at price 10.304762, investment -0.551474 %, total balance 10001.266665,
# day 210: buy 1 unit at price 9.714286, total balance 9991.552380
# day 211: buy 1 unit at price 9.638095, total balance 9981.914285
# day 212, sell 1 unit at price 9.619047, investment -0.980398 %, total balance 9991.533332,
# day 214: buy 1 unit at price 9.685715, total balance 9981.847617
# day 215, sell 1 unit at price 9.923809, investment 2.964426 %, total balance 9991.771426,
# day 216, sell 1 unit at price 10.009523, investment 3.343157 %, total balance 10001.780950,
# day 224: buy 1 unit at price 9.523809, total balance 9992.257140
# day 225, sell 1 unit at price 9.523809, investment 0.000000 %, total balance 10001.780950,
# day 230: buy 1 unit at price 9.571428, total balance 9992.209521
# day 231: buy 1 unit at price 10.476191, total balance 9981.733331
# day 232: buy 1 unit at price 10.476191, total balance 9971.257140
# day 233, sell 1 unit at price 10.714286, investment 11.940303 %, total balance 9981.971426,
# day 235, sell 1 unit at price 10.857142, investment 3.636359 %, total balance 9992.828568,
# day 236, sell 1 unit at price 10.476191, investment 0.000000 %, total balance 10003.304759,
# day 246: buy 1 unit at price 10.133333, total balance 9993.171426
# day 247, sell 1 unit at price 10.133333, investment 0.000000 %, total balance 10003.304759,
# day 259: buy 1 unit at price 10.409524, total balance 9992.895235
# day 260, sell 1 unit at price 10.200000, investment -2.012812 %, total balance 10003.095235,
# day 262: buy 1 unit at price 10.409524, total balance 9992.685711
# day 263, sell 1 unit at price 10.409524, investment 0.000000 %, total balance 10003.095235,
# day 278: buy 1 unit at price 9.904762, total balance 9993.190473
# day 279, sell 1 unit at price 10.247619, investment 3.461531 %, total balance 10003.438091,
# day 283: buy 1 unit at price 9.952381, total balance 9993.485710
# day 284, sell 1 unit at price 9.780952, investment -1.722489 %, total balance 10003.266663,
# day 286: buy 1 unit at price 9.580953, total balance 9993.685710
# day 287, sell 1 unit at price 9.885715, investment 3.180914 %, total balance 10003.571424,
# day 290: buy 1 unit at price 9.752381, total balance 9993.819043
# day 292: buy 1 unit at price 9.828571, total balance 9983.990472
# day 293, sell 1 unit at price 9.809524, investment 0.585931 %, total balance 9993.799995,
# day 294, sell 1 unit at price 9.780952, investment -0.484494 %, total balance 10003.580948,
# day 319: buy 1 unit at price 9.666667, total balance 9993.914281
# day 321, sell 1 unit at price 9.742857, investment 0.788172 %, total balance 10003.657138,
# day 328: buy 1 unit at price 9.780952, total balance 9993.876185
# day 329, sell 1 unit at price 9.828571, investment 0.486853 %, total balance 10003.704757,
# day 332: buy 1 unit at price 10.238095, total balance 9993.466661
# day 333, sell 1 unit at price 9.923809, investment -3.069772 %, total balance 10003.390471,
# day 334: buy 1 unit at price 10.152381, total balance 9993.238090
# day 335, sell 1 unit at price 10.152381, investment 0.000000 %, total balance 10003.390471,
# day 340: buy 1 unit at price 9.847619, total balance 9993.542851
# day 341, sell 1 unit at price 9.857142, investment 0.096708 %, total balance 10003.399994,
# day 348: buy 1 unit at price 10.000000, total balance 9993.399994
# day 349, sell 1 unit at price 10.000000, investment 0.000000 %, total balance 10003.399994,
# day 357: buy 1 unit at price 9.952381, total balance 9993.447613
# day 358, sell 1 unit at price 9.895238, investment -0.574166 %, total balance 10003.342851,
# day 359: buy 1 unit at price 9.961905, total balance 9993.380946
# day 360, sell 1 unit at price 9.904762, investment -0.573608 %, total balance 10003.285708,
# day 367: buy 1 unit at price 10.085714, total balance 9993.199994
# day 369: buy 1 unit at price 9.885715, total balance 9983.314280
# day 370, sell 1 unit at price 9.800000, investment -2.832860 %, total balance 9993.114280,
# day 371, sell 1 unit at price 9.800000, investment -0.867053 %, total balance 10002.914280,
# day 379: buy 1 unit at price 9.714286, total balance 9993.199994
# day 380, sell 1 unit at price 9.723809, investment 0.098035 %, total balance 10002.923803,
# day 394: buy 1 unit at price 9.761905, total balance 9993.161899
# day 395, sell 1 unit at price 9.761905, investment 0.000000 %, total balance 10002.923803,
# day 397: buy 1 unit at price 9.542857, total balance 9993.380946
# day 398, sell 1 unit at price 9.533334, investment -0.099796 %, total balance 10002.914280,
# day 403: buy 1 unit at price 9.676190, total balance 9993.238090
# day 404, sell 1 unit at price 9.561905, investment -1.181100 %, total balance 10002.799994,
# day 407: buy 1 unit at price 9.590476, total balance 9993.209518
# day 408: buy 1 unit at price 9.561905, total balance 9983.647614
# day 409, sell 1 unit at price 9.561905, investment -0.297911 %, total balance 9993.209518,
# day 410, sell 1 unit at price 9.628572, investment 0.697210 %, total balance 10002.838090,
# day 429: buy 1 unit at price 9.695238, total balance 9993.142852
# day 430, sell 1 unit at price 9.800000, investment 1.080552 %, total balance 10002.942852,
# day 458: buy 1 unit at price 10.466666, total balance 9992.476186
# day 460: buy 1 unit at price 10.476191, total balance 9981.999995
# day 461, sell 1 unit at price 10.266666, investment -1.910826 %, total balance 9992.266662,
# day 462: buy 1 unit at price 10.266666, total balance 9981.999995
# day 463, sell 1 unit at price 10.761905, investment 2.727271 %, total balance 9992.761900,
# day 464, sell 1 unit at price 10.361905, investment 0.927650 %, total balance 10003.123805,
# day 488: buy 1 unit at price 10.200000, total balance 9992.923805
# day 491, sell 1 unit at price 10.285714, investment 0.840337 %, total balance 10003.209519,
# day 493: buy 1 unit at price 10.457143, total balance 9992.752377
# day 494, sell 1 unit at price 10.333333, investment -1.183974 %, total balance 10003.085710,
# day 502: buy 1 unit at price 10.380953, total balance 9992.704757
# day 503, sell 1 unit at price 10.371428, investment -0.091748 %, total balance 10003.076185,
# day 511: buy 1 unit at price 10.523809, total balance 9992.552376
# day 512, sell 1 unit at price 10.504762, investment -0.180997 %, total balance 10003.057138,
# day 517: buy 1 unit at price 10.523809, total balance 9992.533328
# day 518, sell 1 unit at price 10.638095, investment 1.085971 %, total balance 10003.171423,
# day 520: buy 1 unit at price 10.495238, total balance 9992.676185
# day 521, sell 1 unit at price 10.590476, investment 0.907438 %, total balance 10003.266661,
# day 525: buy 1 unit at price 10.619047, total balance 9992.647614
# day 526: buy 1 unit at price 10.571428, total balance 9982.076185
# day 527, sell 1 unit at price 10.580953, investment -0.358738 %, total balance 9992.657138,
# day 528, sell 1 unit at price 10.523809, investment -0.450449 %, total balance 10003.180947,
# day 529: buy 1 unit at price 10.571428, total balance 9992.609519
# day 530, sell 1 unit at price 10.571428, investment 0.000000 %, total balance 10003.180947,
# day 532: buy 1 unit at price 10.571428, total balance 9992.609519
# day 533, sell 1 unit at price 10.657143, investment 0.810811 %, total balance 10003.266662,
# day 547: buy 1 unit at price 11.133333, total balance 9992.133328
# day 548, sell 1 unit at price 11.238095, investment 0.940977 %, total balance 10003.371424,
# day 549: buy 1 unit at price 11.276191, total balance 9992.095233
# day 554, sell 1 unit at price 11.760000, investment 4.290540 %, total balance 10003.855233,
# day 570: buy 1 unit at price 11.520000, total balance 9992.335233
# day 571, sell 1 unit at price 11.390000, investment -1.128473 %, total balance 10003.725233,
# day 580: buy 1 unit at price 11.460000, total balance 9992.265233
# day 581, sell 1 unit at price 11.680000, investment 1.919723 %, total balance 10003.945233,
# day 582: buy 1 unit at price 11.480000, total balance 9992.465234
# day 583, sell 1 unit at price 11.480000, investment 0.000000 %, total balance 10003.945233,
# day 601: buy 1 unit at price 11.430000, total balance 9992.515233
# day 603, sell 1 unit at price 11.530000, investment 0.874886 %, total balance 10004.045233,
# day 612: buy 1 unit at price 11.560000, total balance 9992.485232
# day 613, sell 1 unit at price 11.650000, investment 0.778540 %, total balance 10004.135232,
# day 614: buy 1 unit at price 11.980000, total balance 9992.155232
# day 615: buy 1 unit at price 11.400000, total balance 9980.755233
# day 616, sell 1 unit at price 12.030000, investment 0.417364 %, total balance 9992.785233,
# day 617, sell 1 unit at price 12.850000, investment 12.719305 %, total balance 10005.635233,
# day 626: buy 1 unit at price 11.350000, total balance 9994.285233
# day 627, sell 1 unit at price 11.350000, investment 0.000000 %, total balance 10005.635233,
# day 638: buy 1 unit at price 11.750000, total balance 9993.885233
# day 639, sell 1 unit at price 11.600000, investment -1.276593 %, total balance 10005.485233,
# day 649: buy 1 unit at price 11.500000, total balance 9993.985233
# day 650, sell 1 unit at price 11.630000, investment 1.130436 %, total balance 10005.615233,
# day 677: buy 1 unit at price 11.550000, total balance 9994.065233
# day 679, sell 1 unit at price 11.400000, investment -1.298706 %, total balance 10005.465233,
# day 690: buy 1 unit at price 11.350000, total balance 9994.115232
# day 691, sell 1 unit at price 11.630000, investment 2.466958 %, total balance 10005.745233,
# day 693: buy 1 unit at price 11.550000, total balance 9994.195232
# day 694, sell 1 unit at price 11.550000, investment 0.000000 %, total balance 10005.745233,
# day 701: buy 1 unit at price 11.730000, total balance 9994.015233
# day 702: buy 1 unit at price 11.790000, total balance 9982.225233
# day 703, sell 1 unit at price 11.700000, investment -0.255752 %, total balance 9993.925233,
# day 704: buy 1 unit at price 11.550000, total balance 9982.375233
# day 705: buy 1 unit at price 11.490000, total balance 9970.885233
# day 706, sell 1 unit at price 11.570000, investment -1.865990 %, total balance 9982.455233,
# day 707, sell 1 unit at price 11.510000, investment -0.346320 %, total balance 9993.965233,
# day 708, sell 1 unit at price 11.630000, investment 1.218454 %, total balance 10005.595233,
# day 716: buy 1 unit at price 12.400000, total balance 9993.195233
# day 717, sell 1 unit at price 12.460000, investment 0.483874 %, total balance 10005.655233,
# day 718: buy 1 unit at price 12.330000, total balance 9993.325233
# day 719, sell 1 unit at price 12.390000, investment 0.486621 %, total balance 10005.715234,
# day 731: buy 1 unit at price 12.640000, total balance 9993.075233
# day 732: buy 1 unit at price 12.500000, total balance 9980.575233
# day 733, sell 1 unit at price 12.580000, investment -0.474687 %, total balance 9993.155233,
# day 734, sell 1 unit at price 12.430000, investment -0.559998 %, total balance 10005.585234,
# day 739: buy 1 unit at price 12.600000, total balance 9992.985233
# day 741, sell 1 unit at price 12.450000, investment -1.190481 %, total balance 10005.435233,
# day 758: buy 1 unit at price 13.260000, total balance 9992.175233
# day 759, sell 1 unit at price 12.990000, investment -2.036203 %, total balance 10005.165233,
# day 769: buy 1 unit at price 11.760000, total balance 9993.405232
# day 770, sell 1 unit at price 11.510000, investment -2.125850 %, total balance 10004.915233,
# day 776: buy 1 unit at price 11.480000, total balance 9993.435233
# day 777, sell 1 unit at price 11.580000, investment 0.871083 %, total balance 10005.015233,
# day 800: buy 1 unit at price 12.430000, total balance 9992.585233
# day 801: buy 1 unit at price 12.700000, total balance 9979.885233
# day 802: buy 1 unit at price 12.800000, total balance 9967.085233
# day 803, sell 1 unit at price 13.030000, investment 4.827027 %, total balance 9980.115232,
# day 804, sell 1 unit at price 12.790000, investment 0.708663 %, total balance 9992.905232,
# day 807, sell 1 unit at price 12.180000, investment -4.843749 %, total balance 10005.085233,
# day 817: buy 1 unit at price 12.570000, total balance 9992.515233
# day 818, sell 1 unit at price 12.640000, investment 0.556887 %, total balance 10005.155233,
# day 828: buy 1 unit at price 12.600000, total balance 9992.555233
# day 829, sell 1 unit at price 12.650000, investment 0.396819 %, total balance 10005.205233,
# day 833: buy 1 unit at price 12.840000, total balance 9992.365232
# day 834, sell 1 unit at price 12.850000, investment 0.077883 %, total balance 10005.215233,
# day 835: buy 1 unit at price 12.850000, total balance 9992.365232
# day 837, sell 1 unit at price 12.540000, investment -2.412455 %, total balance 10004.905232,
# day 853: buy 1 unit at price 12.570000, total balance 9992.335233
# day 854, sell 1 unit at price 12.490000, investment -0.636435 %, total balance 10004.825233,
# day 862: buy 1 unit at price 12.490000, total balance 9992.335233
# day 863, sell 1 unit at price 12.480000, investment -0.080066 %, total balance 10004.815232,
# day 867: buy 1 unit at price 12.310000, total balance 9992.505232
# day 869, sell 1 unit at price 12.170000, investment -1.137289 %, total balance 10004.675232,
# day 890: buy 1 unit at price 12.500000, total balance 9992.175232
# day 891, sell 1 unit at price 12.450000, investment -0.400002 %, total balance 10004.625232,
# day 893: buy 1 unit at price 12.460000, total balance 9992.165232
# day 894, sell 1 unit at price 12.550000, investment 0.722313 %, total balance 10004.715232,
# day 900: buy 1 unit at price 12.500000, total balance 9992.215232
# day 901, sell 1 unit at price 12.400000, investment -0.800003 %, total balance 10004.615232,
# day 903: buy 1 unit at price 12.680000, total balance 9991.935231
# day 905, sell 1 unit at price 12.590000, investment -0.709780 %, total balance 10004.525231,
# day 914: buy 1 unit at price 12.810000, total balance 9991.715231
# day 917, sell 1 unit at price 13.000000, investment 1.483213 %, total balance 10004.715231,
# day 942: buy 1 unit at price 13.350000, total balance 9991.365231
# day 943, sell 1 unit at price 13.400000, investment 0.374526 %, total balance 10004.765230,
# day 949: buy 1 unit at price 13.780000, total balance 9990.985230
# day 950: buy 1 unit at price 13.650000, total balance 9977.335231
# day 951, sell 1 unit at price 13.650000, investment -0.943397 %, total balance 9990.985230,
# day 953, sell 1 unit at price 13.310000, investment -2.490837 %, total balance 10004.295231,
# day 957: buy 1 unit at price 13.450000, total balance 9990.845231
# day 958, sell 1 unit at price 13.550000, investment 0.743497 %, total balance 10004.395231,
# day 973: buy 1 unit at price 13.350000, total balance 9991.045231
# day 974, sell 1 unit at price 13.580000, investment 1.722843 %, total balance 10004.625231,
# day 975: buy 1 unit at price 13.750000, total balance 9990.875231
# day 976, sell 1 unit at price 13.650000, investment -0.727275 %, total balance 10004.525230,
# day 978: buy 1 unit at price 13.700000, total balance 9990.825231
# day 979: buy 1 unit at price 13.700000, total balance 9977.125231
# day 980, sell 1 unit at price 14.150000, investment 3.284670 %, total balance 9991.275230,
# day 981, sell 1 unit at price 14.850000, investment 8.394165 %, total balance 10006.125231,
# day 985: buy 1 unit at price 15.900000, total balance 9990.225231
# day 986, sell 1 unit at price 15.900000, investment 0.000000 %, total balance 10006.125231,
# day 987: buy 1 unit at price 16.200001, total balance 9989.925230
# day 988, sell 1 unit at price 15.750000, investment -2.777782 %, total balance 10005.675230,
# day 989: buy 1 unit at price 16.100000, total balance 9989.575230
# day 990, sell 1 unit at price 16.299999, investment 1.242229 %, total balance 10005.875229,
# day 993: buy 1 unit at price 17.600000, total balance 9988.275229
# day 994, sell 1 unit at price 16.950001, investment -3.693180 %, total balance 10005.225229,
# day 995: buy 1 unit at price 16.950001, total balance 9988.275229
# day 996, sell 1 unit at price 16.799999, investment -0.884965 %, total balance 10005.075228,
# day 1004: buy 1 unit at price 18.100000, total balance 9986.975227
# day 1005, sell 1 unit at price 18.250000, investment 0.828727 %, total balance 10005.225227,
# day 1008: buy 1 unit at price 18.650000, total balance 9986.575228
# day 1009, sell 1 unit at price 18.700001, investment 0.268103 %, total balance 10005.275229,
# day 1018: buy 1 unit at price 16.700001, total balance 9988.575228
# day 1019, sell 1 unit at price 17.000000, investment 1.796403 %, total balance 10005.575228,
# day 1021: buy 1 unit at price 16.549999, total balance 9989.025229
# day 1022, sell 1 unit at price 16.350000, investment -1.208452 %, total balance 10005.375229,
# day 1025: buy 1 unit at price 16.850000, total balance 9988.525229
# day 1026, sell 1 unit at price 16.549999, investment -1.780422 %, total balance 10005.075228,
# day 1028: buy 1 unit at price 16.700001, total balance 9988.375227
# day 1029, sell 1 unit at price 17.150000, investment 2.694604 %, total balance 10005.525227,
# day 1034: buy 1 unit at price 18.500000, total balance 9987.025227
# day 1035: buy 1 unit at price 18.850000, total balance 9968.175226
# day 1036, sell 1 unit at price 18.850000, investment 1.891894 %, total balance 9987.025227,
# day 1038, sell 1 unit at price 19.000000, investment 0.795754 %, total balance 10006.025227,
# day 1040: buy 1 unit at price 19.100000, total balance 9986.925226
# day 1041, sell 1 unit at price 19.049999, investment -0.261786 %, total balance 10005.975225,
# day 1043: buy 1 unit at price 18.950001, total balance 9987.025225
# day 1044, sell 1 unit at price 18.600000, investment -1.846968 %, total balance 10005.625225,
# day 1048: buy 1 unit at price 18.600000, total balance 9987.025225
# day 1049: buy 1 unit at price 18.650000, total balance 9968.375225
# day 1050, sell 1 unit at price 18.700001, investment 0.537636 %, total balance 9987.075226,
# day 1051, sell 1 unit at price 18.500000, investment -0.804288 %, total balance 10005.575226,
# day 1057: buy 1 unit at price 18.200001, total balance 9987.375225
# day 1058, sell 1 unit at price 18.400000, investment 1.098895 %, total balance 10005.775225,
# day 1064: buy 1 unit at price 18.350000, total balance 9987.425224
# day 1065: buy 1 unit at price 18.400000, total balance 9969.025225
# day 1066, sell 1 unit at price 18.150000, investment -1.089922 %, total balance 9987.175224,
# day 1068, sell 1 unit at price 18.049999, investment -1.902176 %, total balance 10005.225224,
# day 1069: buy 1 unit at price 18.450001, total balance 9986.775223
# day 1070, sell 1 unit at price 18.400000, investment -0.271009 %, total balance 10005.175222,
# day 1071: buy 1 unit at price 18.400000, total balance 9986.775223
# day 1073, sell 1 unit at price 18.450001, investment 0.271745 %, total balance 10005.225224,
# day 1074: buy 1 unit at price 18.549999, total balance 9986.675224
# day 1075, sell 1 unit at price 18.049999, investment -2.695418 %, total balance 10004.725224,
# day 1078: buy 1 unit at price 18.049999, total balance 9986.675224
# day 1079, sell 1 unit at price 17.850000, investment -1.108027 %, total balance 10004.525225,
# day 1084: buy 1 unit at price 18.549999, total balance 9985.975225
# day 1085, sell 1 unit at price 18.150000, investment -2.156332 %, total balance 10004.125225,
# day 1086: buy 1 unit at price 18.450001, total balance 9985.675224
# day 1087, sell 1 unit at price 18.100000, investment -1.897021 %, total balance 10003.775225,
# day 1098: buy 1 unit at price 17.400000, total balance 9986.375225
# day 1099: buy 1 unit at price 17.250000, total balance 9969.125225
# day 1100: buy 1 unit at price 17.250000, total balance 9951.875225
# day 1102: buy 1 unit at price 17.100000, total balance 9934.775225
# day 1103: buy 1 unit at price 17.200001, total balance 9917.575224
# day 1104, sell 1 unit at price 17.150000, investment -1.436782 %, total balance 9934.725224,
# day 1106, sell 1 unit at price 17.150000, investment -0.579712 %, total balance 9951.875223,
# day 1110, sell 1 unit at price 17.299999, investment 0.289851 %, total balance 9969.175222,
# day 1111, sell 1 unit at price 17.250000, investment 0.877191 %, total balance 9986.425222,
# day 1112, sell 1 unit at price 17.350000, investment 0.872091 %, total balance 10003.775223,
# day 1115: buy 1 unit at price 17.250000, total balance 9986.525223
# day 1116, sell 1 unit at price 17.100000, investment -0.869563 %, total balance 10003.625223,
# day 1128: buy 1 unit at price 17.000000, total balance 9986.625223
# day 1129: buy 1 unit at price 17.270000, total balance 9969.355223
# day 1130, sell 1 unit at price 17.500000, investment 2.941176 %, total balance 9986.855223,
# day 1131, sell 1 unit at price 17.500000, investment 1.331787 %, total balance 10004.355223,
# day 1136: buy 1 unit at price 17.250000, total balance 9987.105223
# day 1137, sell 1 unit at price 17.450001, investment 1.159425 %, total balance 10004.555223,
# day 1143: buy 1 unit at price 17.250000, total balance 9987.305223
# day 1144, sell 1 unit at price 17.299999, investment 0.289851 %, total balance 10004.605223,
# day 1146: buy 1 unit at price 17.150000, total balance 9987.455223
# day 1148, sell 1 unit at price 17.150000, investment 0.000000 %, total balance 10004.605223,
# day 1164: buy 1 unit at price 16.950001, total balance 9987.655222
# day 1165, sell 1 unit at price 16.850000, investment -0.589973 %, total balance 10004.505222,
# day 1170: buy 1 unit at price 17.100000, total balance 9987.405222
# day 1171, sell 1 unit at price 17.150000, investment 0.292393 %, total balance 10004.555222,
# day 1173: buy 1 unit at price 17.200001, total balance 9987.355221
# day 1174, sell 1 unit at price 17.299999, investment 0.581386 %, total balance 10004.655220,
# day 1179: buy 1 unit at price 17.250000, total balance 9987.405220
# day 1180, sell 1 unit at price 17.200001, investment -0.289851 %, total balance 10004.605221,
# day 1184: buy 1 unit at price 17.350000, total balance 9987.255220
# day 1185, sell 1 unit at price 17.500000, investment 0.864551 %, total balance 10004.755220,
# day 1191: buy 1 unit at price 18.200001, total balance 9986.555220
# day 1192, sell 1 unit at price 18.500000, investment 1.648347 %, total balance 10005.055220,
# day 1198: buy 1 unit at price 17.750000, total balance 9987.305220
# day 1199, sell 1 unit at price 17.950001, investment 1.126765 %, total balance 10005.255220,
# day 1223: buy 1 unit at price 17.700001, total balance 9987.555220
# day 1224, sell 1 unit at price 17.700001, investment 0.000000 %, total balance 10005.255220,
# day 1233: buy 1 unit at price 18.100000, total balance 9987.155220
# day 1234, sell 1 unit at price 18.350000, investment 1.381215 %, total balance 10005.505220,
# day 1256: buy 1 unit at price 18.200001, total balance 9987.305220
# day 1257: buy 1 unit at price 18.200001, total balance 9969.105219
# day 1258, sell 1 unit at price 18.299999, investment 0.549442 %, total balance 9987.405218,
# day 1259: buy 1 unit at price 18.299999, total balance 9969.105219
# day 1261, sell 1 unit at price 18.200001, investment 0.000000 %, total balance 9987.305220,
# day 1262, sell 1 unit at price 18.200001, investment -0.546440 %, total balance 10005.505220,
# day 1266: buy 1 unit at price 18.500000, total balance 9987.005220
# day 1267, sell 1 unit at price 18.600000, investment 0.540543 %, total balance 10005.605221,
# day 1282: buy 1 unit at price 19.200001, total balance 9986.405220
# day 1283: buy 1 unit at price 19.250000, total balance 9967.155220
# day 1284: buy 1 unit at price 19.250000, total balance 9947.905220
# day 1285, sell 1 unit at price 19.150000, investment -0.260423 %, total balance 9967.055220,
# day 1286, sell 1 unit at price 19.200001, investment -0.259736 %, total balance 9986.255220,
# day 1287, sell 1 unit at price 19.100000, investment -0.779219 %, total balance 10005.355221,
# day 1300: buy 1 unit at price 19.600000, total balance 9985.755220
# day 1301, sell 1 unit at price 19.299999, investment -1.530618 %, total balance 10005.055220,
# day 1302: buy 1 unit at price 19.299999, total balance 9985.755220
# day 1303, sell 1 unit at price 19.500000, investment 1.036273 %, total balance 10005.255220,
# day 1306: buy 1 unit at price 19.600000, total balance 9985.655220
# day 1307, sell 1 unit at price 19.600000, investment 0.000000 %, total balance 10005.255220,
# day 1309: buy 1 unit at price 20.150000, total balance 9985.105221
# day 1310, sell 1 unit at price 20.049999, investment -0.496280 %, total balance 10005.155220,
# day 1319: buy 1 unit at price 21.750000, total balance 9983.405220
# day 1320: buy 1 unit at price 21.500000, total balance 9961.905220
# day 1321, sell 1 unit at price 21.450001, investment -1.379307 %, total balance 9983.355221,
# day 1322, sell 1 unit at price 21.400000, investment -0.465118 %, total balance 10004.755220,
# day 1323: buy 1 unit at price 21.799999, total balance 9982.955221
# day 1325: buy 1 unit at price 21.799999, total balance 9961.155222
# day 1326: buy 1 unit at price 22.000000, total balance 9939.155222
# day 1327, sell 1 unit at price 22.000000, investment 0.917435 %, total balance 9961.155222,
# day 1329, sell 1 unit at price 21.750000, investment -0.229354 %, total balance 9982.905222,
# day 1330, sell 1 unit at price 21.900000, investment -0.454547 %, total balance 10004.805222,
# day 1332: buy 1 unit at price 21.700001, total balance 9983.105221
# day 1333, sell 1 unit at price 22.000000, investment 1.382485 %, total balance 10005.105221,
# day 1344: buy 1 unit at price 21.850000, total balance 9983.255220
# day 1345: buy 1 unit at price 21.850000, total balance 9961.405220
# day 1346, sell 1 unit at price 21.600000, investment -1.144165 %, total balance 9983.005220,
# day 1347, sell 1 unit at price 21.799999, investment -0.228838 %, total balance 10004.805220,
# day 1353: buy 1 unit at price 21.100000, total balance 9983.705219
# day 1354, sell 1 unit at price 21.100000, investment 0.000000 %, total balance 10004.805220,
# day 1362: buy 1 unit at price 21.600000, total balance 9983.205219
# day 1364, sell 1 unit at price 21.600000, investment 0.000000 %, total balance 10004.805220,
# day 1372: buy 1 unit at price 22.000000, total balance 9982.805220
# day 1373, sell 1 unit at price 22.150000, investment 0.681816 %, total balance 10004.955219,
# day 1385: buy 1 unit at price 21.299999, total balance 9983.655220
# day 1386, sell 1 unit at price 21.799999, investment 2.347418 %, total balance 10005.455219,
# day 1390: buy 1 unit at price 21.700001, total balance 9983.755219
# day 1391: buy 1 unit at price 21.650000, total balance 9962.105219
# day 1392, sell 1 unit at price 21.299999, investment -1.843325 %, total balance 9983.405218,
# day 1393, sell 1 unit at price 21.450001, investment -0.923782 %, total balance 10004.855219,
# day 1400: buy 1 unit at price 22.350000, total balance 9982.505219
# day 1401: buy 1 unit at price 22.200001, total balance 9960.305218
# day 1402, sell 1 unit at price 21.950001, investment -1.789707 %, total balance 9982.255219,
# day 1403, sell 1 unit at price 21.350000, investment -3.828830 %, total balance 10003.605219,
# day 1410: buy 1 unit at price 21.950001, total balance 9981.655218
# day 1411, sell 1 unit at price 21.900000, investment -0.227796 %, total balance 10003.555218,
# day 1424: buy 1 unit at price 21.299999, total balance 9982.255219
# day 1425, sell 1 unit at price 21.250000, investment -0.234738 %, total balance 10003.505219,
# day 1428: buy 1 unit at price 21.100000, total balance 9982.405218
# day 1429, sell 1 unit at price 20.600000, investment -2.369668 %, total balance 10003.005219,
# day 1431: buy 1 unit at price 20.850000, total balance 9982.155218
# day 1432, sell 1 unit at price 20.900000, investment 0.239805 %, total balance 10003.055218,
# day 1434: buy 1 unit at price 20.150000, total balance 9982.905218
# day 1436, sell 1 unit at price 20.600000, investment 2.233254 %, total balance 10003.505219,
# day 1443: buy 1 unit at price 20.650000, total balance 9982.855219
# day 1444, sell 1 unit at price 20.200001, investment -2.179171 %, total balance 10003.055220,
# day 1447: buy 1 unit at price 20.480000, total balance 9982.575220
# day 1448, sell 1 unit at price 20.139999, investment -1.660157 %, total balance 10002.715220,
# day 1449: buy 1 unit at price 20.150000, total balance 9982.565220
# day 1450, sell 1 unit at price 20.080000, investment -0.347393 %, total balance 10002.645220,
# day 1451: buy 1 unit at price 19.770000, total balance 9982.875219
# day 1452, sell 1 unit at price 20.040001, investment 1.365708 %, total balance 10002.915220,
# day 1467: buy 1 unit at price 19.250000, total balance 9983.665220
# day 1468, sell 1 unit at price 19.690001, investment 2.285717 %, total balance 10003.355221,
# day 1469: buy 1 unit at price 20.219999, total balance 9983.135222
# day 1470, sell 1 unit at price 20.129999, investment -0.445105 %, total balance 10003.265221,
# day 1480: buy 1 unit at price 20.049999, total balance 9983.215221
# day 1481, sell 1 unit at price 19.830000, investment -1.097254 %, total balance 10003.045221,
# day 1483: buy 1 unit at price 19.650000, total balance 9983.395222
# day 1484, sell 1 unit at price 19.930000, investment 1.424940 %, total balance 10003.325222,
# day 1493: buy 1 unit at price 19.770000, total balance 9983.555222
# day 1494, sell 1 unit at price 19.990000, investment 1.112794 %, total balance 10003.545221,
# day 1496: buy 1 unit at price 19.160000, total balance 9984.385222
# day 1497, sell 1 unit at price 19.490000, investment 1.722338 %, total balance 10003.875221,
# day 1500: buy 1 unit at price 19.010000, total balance 9984.865221
# day 1501, sell 1 unit at price 19.400000, investment 2.051549 %, total balance 10004.265221,
# day 1502: buy 1 unit at price 19.129999, total balance 9985.135222
# day 1503, sell 1 unit at price 19.100000, investment -0.156815 %, total balance 10004.235222,
# day 1508: buy 1 unit at price 19.750000, total balance 9984.485222
# day 1509, sell 1 unit at price 19.930000, investment 0.911394 %, total balance 10004.415222,
# day 1520: buy 1 unit at price 19.750000, total balance 9984.665222
# day 1522, sell 1 unit at price 19.430000, investment -1.620252 %, total balance 10004.095223,
# day 1523: buy 1 unit at price 19.410000, total balance 9984.685223
# day 1524, sell 1 unit at price 19.650000, investment 1.236475 %, total balance 10004.335222,
# day 1529: buy 1 unit at price 19.660000, total balance 9984.675222
# day 1530: buy 1 unit at price 19.420000, total balance 9965.255222
# day 1531, sell 1 unit at price 19.320000, investment -1.729401 %, total balance 9984.575222,
# day 1533, sell 1 unit at price 19.040001, investment -1.956741 %, total balance 10003.615223,
# day 1539: buy 1 unit at price 18.850000, total balance 9984.765223
# day 1540: buy 1 unit at price 18.309999, total balance 9966.455223
# day 1541, sell 1 unit at price 18.340000, investment -2.705571 %, total balance 9984.795223,
# day 1542: buy 1 unit at price 18.780001, total balance 9966.015223
# day 1543, sell 1 unit at price 18.670000, investment 1.966142 %, total balance 9984.685223,
# day 1544, sell 1 unit at price 18.510000, investment -1.437702 %, total balance 10003.195223,
# day 1556: buy 1 unit at price 18.750000, total balance 9984.445223
# day 1557, sell 1 unit at price 18.650000, investment -0.533335 %, total balance 10003.095223,
# day 1568: buy 1 unit at price 17.600000, total balance 9985.495222
# day 1569, sell 1 unit at price 18.059999, investment 2.613631 %, total balance 10003.555222,
# day 1571: buy 1 unit at price 17.900000, total balance 9985.655222
# day 1572, sell 1 unit at price 18.070000, investment 0.949721 %, total balance 10003.725222,
# day 1573: buy 1 unit at price 18.290001, total balance 9985.435221
# day 1575, sell 1 unit at price 18.379999, investment 0.492063 %, total balance 10003.815220,
# day 1576: buy 1 unit at price 18.309999, total balance 9985.505220
# day 1578, sell 1 unit at price 18.379999, investment 0.382303 %, total balance 10003.885220,
# day 1588: buy 1 unit at price 18.600000, total balance 9985.285219
# day 1589, sell 1 unit at price 18.610001, investment 0.053765 %, total balance 10003.895220,
# day 1594: buy 1 unit at price 19.360001, total balance 9984.535219
# day 1595, sell 1 unit at price 18.820000, investment -2.789261 %, total balance 10003.355219,
# day 1599: buy 1 unit at price 18.950001, total balance 9984.405218
# day 1600, sell 1 unit at price 18.740000, investment -1.108185 %, total balance 10003.145218,
# day 1617: buy 1 unit at price 18.930000, total balance 9984.215218
# day 1620, sell 1 unit at price 18.850000, investment -0.422609 %, total balance 10003.065218,
# day 1621: buy 1 unit at price 18.969999, total balance 9984.095219
# day 1622, sell 1 unit at price 19.030001, investment 0.316296 %, total balance 10003.125219,
# day 1624: buy 1 unit at price 18.930000, total balance 9984.195219
# day 1625, sell 1 unit at price 18.730000, investment -1.056528 %, total balance 10002.925219,
# day 1632: buy 1 unit at price 18.090000, total balance 9984.835218
# day 1633: buy 1 unit at price 18.469999, total balance 9966.365219
# day 1634, sell 1 unit at price 17.950001, investment -0.773905 %, total balance 9984.315220,
# day 1635, sell 1 unit at price 18.209999, investment -1.407689 %, total balance 10002.525219,
# day 1637: buy 1 unit at price 18.240000, total balance 9984.285219
# day 1639, sell 1 unit at price 18.290001, investment 0.274129 %, total balance 10002.575220,
# day 1647: buy 1 unit at price 18.200001, total balance 9984.375219
# day 1650, sell 1 unit at price 18.070000, investment -0.714292 %, total balance 10002.445219,
# day 1658: buy 1 unit at price 17.010000, total balance 9985.435219
# day 1659, sell 1 unit at price 17.100000, investment 0.529101 %, total balance 10002.535219,
# day 1661: buy 1 unit at price 17.049999, total balance 9985.485220
# day 1662, sell 1 unit at price 17.030001, investment -0.117294 %, total balance 10002.515221,
# day 1680: buy 1 unit at price 17.309999, total balance 9985.205221
# day 1681, sell 1 unit at price 17.330000, investment 0.115543 %, total balance 10002.535221,
# day 1682: buy 1 unit at price 17.860001, total balance 9984.675220
# day 1683, sell 1 unit at price 18.400000, investment 3.023511 %, total balance 10003.075220,
# day 1685: buy 1 unit at price 19.139999, total balance 9983.935221
# day 1686: buy 1 unit at price 18.840000, total balance 9965.095221
# day 1688, sell 1 unit at price 18.860001, investment -1.462899 %, total balance 9983.955221,
# day 1690: buy 1 unit at price 18.420000, total balance 9965.535221
# day 1691, sell 1 unit at price 18.360001, investment -2.547768 %, total balance 9983.895222,
# day 1692, sell 1 unit at price 18.219999, investment -1.085781 %, total balance 10002.115221,
# day 1719: buy 1 unit at price 19.100000, total balance 9983.015221
# day 1720, sell 1 unit at price 18.990000, investment -0.575919 %, total balance 10002.005220,
# day 1721: buy 1 unit at price 19.090000, total balance 9982.915220
# day 1723, sell 1 unit at price 19.350000, investment 1.361971 %, total balance 10002.265221,
# day 1727: buy 1 unit at price 19.330000, total balance 9982.935221
# day 1728, sell 1 unit at price 19.500000, investment 0.879462 %, total balance 10002.435221,
# day 1732: buy 1 unit at price 19.590000, total balance 9982.845221
# day 1734: buy 1 unit at price 19.559999, total balance 9963.285221
# day 1735, sell 1 unit at price 19.500000, investment -0.459419 %, total balance 9982.785221,
# day 1736, sell 1 unit at price 19.590000, investment 0.153378 %, total balance 10002.375221,
# day 1739: buy 1 unit at price 20.219999, total balance 9982.155222
# day 1740, sell 1 unit at price 20.379999, investment 0.791295 %, total balance 10002.535221,
# day 1741: buy 1 unit at price 20.280001, total balance 9982.255220
# day 1742, sell 1 unit at price 19.910000, investment -1.824462 %, total balance 10002.165220,
# day 1754: buy 1 unit at price 21.850000, total balance 9980.315220
# day 1755, sell 1 unit at price 21.780001, investment -0.320365 %, total balance 10002.095221,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
