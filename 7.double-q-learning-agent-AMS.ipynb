# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../agent/cleaned_data/AMS.csv')
df.head()
# Out:
#        Date  Open  High   Low  Close  Adj Close  Volume
# 0  1/2/2013  2.70  2.80  2.70    2.8        2.8    5600
# 1  1/3/2013  2.75  2.81  2.74    2.8        2.8    4500
# 2  1/4/2013  2.80  2.80  2.80    2.8        2.8       0
# 3  1/7/2013  2.75  2.75  2.70    2.7        2.7     400
# 4  1/8/2013  2.70  2.70  2.60    2.6        2.6     500

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D493DE4448>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D493DE4448>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D493DE4448>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D493DE4448>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D493DE4448>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D493DE4448>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D493DE4448>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D493DE4448>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D4BDE44788>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D4BDE44788>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D4BDE44788>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D4BDE44788>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D4BDE44788>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D4BDE44788>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D4BDE44788>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002D4BDE44788>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: -23.509996.3, cost: 0.000213, total money: 9899.560004
# epoch: 20, total rewards: 6.490001.3, cost: 0.000056, total money: 9983.750001
# epoch: 30, total rewards: -11.469999.3, cost: 0.000093, total money: 9929.450001
# epoch: 40, total rewards: -2.449995.3, cost: 0.000061, total money: 9994.870005
# epoch: 50, total rewards: 12.600000.3, cost: 0.000012, total money: 10007.270000
# epoch: 60, total rewards: 0.439999.3, cost: 0.000027, total money: 9984.990000
# epoch: 70, total rewards: -5.159997.3, cost: 0.000033, total money: 9989.830003
# epoch: 80, total rewards: -9.179998.3, cost: 0.000007, total money: 9990.820002
# epoch: 90, total rewards: 6.790002.3, cost: 0.000008, total money: 9988.800002
# epoch: 100, total rewards: -1.480003.3, cost: 0.000004, total money: 9998.519997
# epoch: 110, total rewards: 18.079996.3, cost: 0.000017, total money: 10010.489996
# epoch: 120, total rewards: 23.120001.3, cost: 0.000001, total money: 10023.120001
# epoch: 130, total rewards: -2.160000.3, cost: 0.000001, total money: 9997.840000
# epoch: 140, total rewards: 10.920003.3, cost: 0.000028, total money: 10010.920003
# epoch: 150, total rewards: -2.780004.3, cost: 0.000027, total money: 9979.429996
# epoch: 160, total rewards: -3.980002.3, cost: 0.000001, total money: 9996.019998
# epoch: 170, total rewards: 4.740003.3, cost: 0.000050, total money: 10004.740003
# epoch: 180, total rewards: -1.219998.3, cost: 0.000001, total money: 9998.780002
# epoch: 190, total rewards: 1.729998.3, cost: 0.000040, total money: 9991.649998
# epoch: 200, total rewards: 16.990000.3, cost: 0.000174, total money: 10016.990000

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 19: buy 1 unit at price 2.230000, total balance 9997.770000
# day 20, sell 1 unit at price 2.250000, investment 0.896860 %, total balance 10000.020000,
# day 22: buy 1 unit at price 2.200000, total balance 9997.820000
# day 23, sell 1 unit at price 2.250000, investment 2.272725 %, total balance 10000.070000,
# day 25: buy 1 unit at price 2.180000, total balance 9997.890000
# day 26, sell 1 unit at price 2.180000, investment 0.000000 %, total balance 10000.070000,
# day 31: buy 1 unit at price 2.150000, total balance 9997.920000
# day 32: buy 1 unit at price 2.170000, total balance 9995.750000
# day 33: buy 1 unit at price 2.260000, total balance 9993.490000
# day 34, sell 1 unit at price 2.150000, investment 0.000000 %, total balance 9995.640000,
# day 35, sell 1 unit at price 2.110000, investment -2.764985 %, total balance 9997.750000,
# day 36: buy 1 unit at price 2.080000, total balance 9995.670000
# day 37, sell 1 unit at price 2.080000, investment -7.964605 %, total balance 9997.750000,
# day 39: buy 1 unit at price 2.100000, total balance 9995.650000
# day 40: buy 1 unit at price 2.100000, total balance 9993.550000
# day 41: buy 1 unit at price 2.040000, total balance 9991.510000
# day 42, sell 1 unit at price 1.970000, investment -5.288457 %, total balance 9993.480000,
# day 43, sell 1 unit at price 1.870000, investment -10.952377 %, total balance 9995.350000,
# day 46, sell 1 unit at price 2.020000, investment -3.809520 %, total balance 9997.370000,
# day 47, sell 1 unit at price 2.010000, investment -1.470587 %, total balance 9999.380000,
# day 48: buy 1 unit at price 2.000000, total balance 9997.380000
# day 49, sell 1 unit at price 2.000000, investment 0.000000 %, total balance 9999.380000,
# day 54: buy 1 unit at price 2.070000, total balance 9997.310000
# day 55, sell 1 unit at price 1.980000, investment -4.347822 %, total balance 9999.290000,
# day 66: buy 1 unit at price 1.740000, total balance 9997.550000
# day 67, sell 1 unit at price 1.700000, investment -2.298848 %, total balance 9999.250000,
# day 75: buy 1 unit at price 1.640000, total balance 9997.610000
# day 76, sell 1 unit at price 1.600000, investment -2.439022 %, total balance 9999.210000,
# day 89: buy 1 unit at price 1.740000, total balance 9997.470000
# day 91, sell 1 unit at price 1.610000, investment -7.471264 %, total balance 9999.080000,
# day 108: buy 1 unit at price 1.990000, total balance 9997.090000
# day 109, sell 1 unit at price 2.100000, investment 5.527633 %, total balance 9999.190000,
# day 111: buy 1 unit at price 2.130000, total balance 9997.060000
# day 112, sell 1 unit at price 2.220000, investment 4.225348 %, total balance 9999.280000,
# day 116: buy 1 unit at price 2.270000, total balance 9997.010000
# day 117, sell 1 unit at price 2.250000, investment -0.881056 %, total balance 9999.260000,
# day 121: buy 1 unit at price 2.310000, total balance 9996.950000
# day 122, sell 1 unit at price 2.110000, investment -8.658011 %, total balance 9999.060000,
# day 128: buy 1 unit at price 2.140000, total balance 9996.920000
# day 129, sell 1 unit at price 2.190000, investment 2.336446 %, total balance 9999.110000,
# day 136: buy 1 unit at price 2.790000, total balance 9996.320000
# day 137, sell 1 unit at price 2.870000, investment 2.867381 %, total balance 9999.190000,
# day 169: buy 1 unit at price 2.650000, total balance 9996.540000
# day 172, sell 1 unit at price 2.700000, investment 1.886791 %, total balance 9999.240000,
# day 178: buy 1 unit at price 2.610000, total balance 9996.630000
# day 179, sell 1 unit at price 2.690000, investment 3.065140 %, total balance 9999.320000,
# day 189: buy 1 unit at price 2.540000, total balance 9996.780000
# day 190, sell 1 unit at price 2.530000, investment -0.393700 %, total balance 9999.310000,
# day 194: buy 1 unit at price 2.530000, total balance 9996.780000
# day 195, sell 1 unit at price 2.530000, investment 0.000000 %, total balance 9999.310000,
# day 213: buy 1 unit at price 2.470000, total balance 9996.840000
# day 214, sell 1 unit at price 2.460000, investment -0.404858 %, total balance 9999.300000,
# day 218: buy 1 unit at price 2.360000, total balance 9996.940000
# day 220: buy 1 unit at price 2.450000, total balance 9994.490000
# day 221, sell 1 unit at price 2.380000, investment 0.847467 %, total balance 9996.870000,
# day 222, sell 1 unit at price 2.350000, investment -4.081638 %, total balance 9999.220000,
# day 242: buy 1 unit at price 2.680000, total balance 9996.540000
# day 243, sell 1 unit at price 2.680000, investment 0.000000 %, total balance 9999.220000,
# day 248: buy 1 unit at price 2.790000, total balance 9996.430000
# day 249, sell 1 unit at price 2.630000, investment -5.734762 %, total balance 9999.060000,
# day 253: buy 1 unit at price 2.740000, total balance 9996.320000
# day 254, sell 1 unit at price 2.850000, investment 4.014595 %, total balance 9999.170000,
# day 263: buy 1 unit at price 2.950000, total balance 9996.220000
# day 264, sell 1 unit at price 2.990000, investment 1.355931 %, total balance 9999.210000,
# day 269: buy 1 unit at price 2.960000, total balance 9996.250000
# day 270: buy 1 unit at price 2.960000, total balance 9993.290000
# day 271, sell 1 unit at price 2.850000, investment -3.716221 %, total balance 9996.140000,
# day 272, sell 1 unit at price 2.890000, investment -2.364863 %, total balance 9999.030000,
# day 276: buy 1 unit at price 2.940000, total balance 9996.090000
# day 277, sell 1 unit at price 3.100000, investment 5.442172 %, total balance 9999.190000,
# day 281: buy 1 unit at price 3.120000, total balance 9996.070000
# day 282, sell 1 unit at price 3.090000, investment -0.961538 %, total balance 9999.160000,
# day 287: buy 1 unit at price 3.210000, total balance 9995.950000
# day 288, sell 1 unit at price 3.110000, investment -3.115269 %, total balance 9999.060000,
# day 296: buy 1 unit at price 3.270000, total balance 9995.790000
# day 297, sell 1 unit at price 3.290000, investment 0.611620 %, total balance 9999.080000,
# day 309: buy 1 unit at price 3.110000, total balance 9995.970000
# day 310, sell 1 unit at price 3.160000, investment 1.607723 %, total balance 9999.130000,
# day 323: buy 1 unit at price 2.800000, total balance 9996.330000
# day 324, sell 1 unit at price 2.800000, investment 0.000000 %, total balance 9999.130000,
# day 332: buy 1 unit at price 2.800000, total balance 9996.330000
# day 333, sell 1 unit at price 2.780000, investment -0.714285 %, total balance 9999.110000,
# day 335: buy 1 unit at price 2.760000, total balance 9996.350000
# day 336: buy 1 unit at price 2.770000, total balance 9993.580000
# day 337, sell 1 unit at price 2.730000, investment -1.086955 %, total balance 9996.310000,
# day 338, sell 1 unit at price 2.760000, investment -0.361011 %, total balance 9999.070000,
# day 342: buy 1 unit at price 2.790000, total balance 9996.280000
# day 343, sell 1 unit at price 2.720000, investment -2.508958 %, total balance 9999.000000,
# day 347: buy 1 unit at price 2.700000, total balance 9996.300000
# day 348, sell 1 unit at price 2.600000, investment -3.703709 %, total balance 9998.900000,
# day 354: buy 1 unit at price 2.410000, total balance 9996.490000
# day 355, sell 1 unit at price 2.500000, investment 3.734436 %, total balance 9998.990000,
# day 357: buy 1 unit at price 2.570000, total balance 9996.420000
# day 358, sell 1 unit at price 2.550000, investment -0.778209 %, total balance 9998.970000,
# day 363: buy 1 unit at price 2.500000, total balance 9996.470000
# day 364, sell 1 unit at price 2.550000, investment 1.999998 %, total balance 9999.020000,
# day 365: buy 1 unit at price 2.540000, total balance 9996.480000
# day 366, sell 1 unit at price 2.690000, investment 5.905516 %, total balance 9999.170000,
# day 372: buy 1 unit at price 2.650000, total balance 9996.520000
# day 373: buy 1 unit at price 2.700000, total balance 9993.820000
# day 374: buy 1 unit at price 2.600000, total balance 9991.220000
# day 375: buy 1 unit at price 2.600000, total balance 9988.620000
# day 377, sell 1 unit at price 2.610000, investment -1.509441 %, total balance 9991.230000,
# day 378: buy 1 unit at price 2.630000, total balance 9988.600000
# day 379, sell 1 unit at price 2.670000, investment -1.111110 %, total balance 9991.270000,
# day 380, sell 1 unit at price 2.540000, investment -2.307690 %, total balance 9993.810000,
# day 382, sell 1 unit at price 2.520000, investment -3.076920 %, total balance 9996.330000,
# day 383, sell 1 unit at price 2.840000, investment 7.984783 %, total balance 9999.170000,
# day 385: buy 1 unit at price 2.880000, total balance 9996.289999
# day 386, sell 1 unit at price 3.000000, investment 4.166663 %, total balance 9999.289999,
# day 387: buy 1 unit at price 2.960000, total balance 9996.329999
# day 388, sell 1 unit at price 2.700000, investment -8.783783 %, total balance 9999.029999,
# day 394: buy 1 unit at price 2.870000, total balance 9996.160000
# day 395, sell 1 unit at price 2.790000, investment -2.787454 %, total balance 9998.950000,
# day 418: buy 1 unit at price 2.300000, total balance 9996.650000
# day 419, sell 1 unit at price 2.260000, investment -1.739129 %, total balance 9998.910000,
# day 425: buy 1 unit at price 2.130000, total balance 9996.779999
# day 426, sell 1 unit at price 2.150000, investment 0.938966 %, total balance 9998.930000,
# day 429: buy 1 unit at price 2.160000, total balance 9996.770000
# day 430: buy 1 unit at price 2.120000, total balance 9994.650000
# day 431, sell 1 unit at price 2.150000, investment -0.462963 %, total balance 9996.800000,
# day 432, sell 1 unit at price 2.240000, investment 5.660384 %, total balance 9999.040000,
# day 433: buy 1 unit at price 2.240000, total balance 9996.800000
# day 434, sell 1 unit at price 2.240000, investment 0.000000 %, total balance 9999.040000,
# day 437: buy 1 unit at price 2.250000, total balance 9996.790000
# day 439, sell 1 unit at price 2.200000, investment -2.222220 %, total balance 9998.990000,
# day 444: buy 1 unit at price 2.100000, total balance 9996.890000
# day 445, sell 1 unit at price 2.010000, investment -4.285710 %, total balance 9998.900000,
# day 448: buy 1 unit at price 2.120000, total balance 9996.780000
# day 449, sell 1 unit at price 2.190000, investment 3.301895 %, total balance 9998.970000,
# day 450: buy 1 unit at price 2.170000, total balance 9996.800000
# day 451, sell 1 unit at price 2.160000, investment -0.460829 %, total balance 9998.960000,
# day 452: buy 1 unit at price 2.140000, total balance 9996.820000
# day 453, sell 1 unit at price 2.180000, investment 1.869157 %, total balance 9999.000000,
# day 458: buy 1 unit at price 2.180000, total balance 9996.820000
# day 459, sell 1 unit at price 2.190000, investment 0.458715 %, total balance 9999.010000,
# day 474: buy 1 unit at price 2.530000, total balance 9996.480000
# day 475, sell 1 unit at price 2.590000, investment 2.371539 %, total balance 9999.070000,
# day 477: buy 1 unit at price 2.600000, total balance 9996.470000
# day 478, sell 1 unit at price 2.490000, investment -4.230765 %, total balance 9998.960000,
# day 479: buy 1 unit at price 2.490000, total balance 9996.470000
# day 480, sell 1 unit at price 2.490000, investment 0.000000 %, total balance 9998.960000,
# day 487: buy 1 unit at price 2.600000, total balance 9996.360000
# day 488, sell 1 unit at price 2.600000, investment 0.000000 %, total balance 9998.960000,
# day 490: buy 1 unit at price 2.510000, total balance 9996.450000
# day 491, sell 1 unit at price 2.430000, investment -3.187248 %, total balance 9998.880000,
# day 498: buy 1 unit at price 2.520000, total balance 9996.360000
# day 499, sell 1 unit at price 2.500000, investment -0.793650 %, total balance 9998.860000,
# day 512: buy 1 unit at price 2.550000, total balance 9996.310000
# day 514, sell 1 unit at price 2.350000, investment -7.843139 %, total balance 9998.660000,
# day 518: buy 1 unit at price 2.590000, total balance 9996.070000
# day 519, sell 1 unit at price 2.420000, investment -6.563701 %, total balance 9998.490000,
# day 523: buy 1 unit at price 2.490000, total balance 9996.000000
# day 524: buy 1 unit at price 2.540000, total balance 9993.460000
# day 525, sell 1 unit at price 2.620000, investment 5.220879 %, total balance 9996.080000,
# day 526: buy 1 unit at price 2.660000, total balance 9993.420000
# day 527, sell 1 unit at price 2.650000, investment 4.330714 %, total balance 9996.070000,
# day 528, sell 1 unit at price 2.650000, investment -0.375939 %, total balance 9998.720000,
# day 529: buy 1 unit at price 2.600000, total balance 9996.120000
# day 530: buy 1 unit at price 2.540000, total balance 9993.580000
# day 532: buy 1 unit at price 2.480000, total balance 9991.100000
# day 533, sell 1 unit at price 2.480000, investment -4.615380 %, total balance 9993.580000,
# day 534, sell 1 unit at price 2.570000, investment 1.181101 %, total balance 9996.150000,
# day 535, sell 1 unit at price 2.600000, investment 4.838705 %, total balance 9998.750000,
# day 537: buy 1 unit at price 2.650000, total balance 9996.100000
# day 539, sell 1 unit at price 2.520000, investment -4.905665 %, total balance 9998.620000,
# day 542: buy 1 unit at price 2.400000, total balance 9996.220000
# day 543, sell 1 unit at price 2.400000, investment 0.000000 %, total balance 9998.620000,
# day 544: buy 1 unit at price 2.380000, total balance 9996.240000
# day 545, sell 1 unit at price 2.470000, investment 3.781509 %, total balance 9998.710000,
# day 551: buy 1 unit at price 2.260000, total balance 9996.450000
# day 552, sell 1 unit at price 2.340000, investment 3.539820 %, total balance 9998.790000,
# day 558: buy 1 unit at price 2.370000, total balance 9996.420000
# day 559, sell 1 unit at price 2.500000, investment 5.485237 %, total balance 9998.920000,
# day 563: buy 1 unit at price 2.550000, total balance 9996.370000
# day 564, sell 1 unit at price 2.540000, investment -0.392156 %, total balance 9998.910000,
# day 576: buy 1 unit at price 2.830000, total balance 9996.080000
# day 577, sell 1 unit at price 2.700000, investment -4.593635 %, total balance 9998.780000,
# day 578: buy 1 unit at price 2.740000, total balance 9996.040000
# day 579, sell 1 unit at price 2.740000, investment 0.000000 %, total balance 9998.780000,
# day 597: buy 1 unit at price 2.660000, total balance 9996.120000
# day 598, sell 1 unit at price 2.580000, investment -3.007525 %, total balance 9998.700000,
# day 609: buy 1 unit at price 2.400000, total balance 9996.300000
# day 610, sell 1 unit at price 2.360000, investment -1.666675 %, total balance 9998.660000,
# day 627: buy 1 unit at price 2.530000, total balance 9996.130000
# day 628, sell 1 unit at price 2.530000, investment 0.000000 %, total balance 9998.660000,
# day 652: buy 1 unit at price 2.630000, total balance 9996.030000
# day 653, sell 1 unit at price 2.500000, investment -4.942970 %, total balance 9998.530000,
# day 660: buy 1 unit at price 2.500000, total balance 9996.030000
# day 661, sell 1 unit at price 2.570000, investment 2.799997 %, total balance 9998.600000,
# day 680: buy 1 unit at price 2.040000, total balance 9996.560000
# day 681, sell 1 unit at price 2.040000, investment 0.000000 %, total balance 9998.600000,
# day 686: buy 1 unit at price 1.870000, total balance 9996.730000
# day 687, sell 1 unit at price 1.870000, investment 0.000000 %, total balance 9998.600000,
# day 691: buy 1 unit at price 1.920000, total balance 9996.680000
# day 692, sell 1 unit at price 1.920000, investment 0.000000 %, total balance 9998.600000,
# day 703: buy 1 unit at price 1.850000, total balance 9996.750000
# day 704, sell 1 unit at price 1.740000, investment -5.945947 %, total balance 9998.490000,
# day 705: buy 1 unit at price 1.740000, total balance 9996.750000
# day 706, sell 1 unit at price 1.740000, investment 0.000000 %, total balance 9998.490000,
# day 712: buy 1 unit at price 1.650000, total balance 9996.840000
# day 713: buy 1 unit at price 1.670000, total balance 9995.170000
# day 714, sell 1 unit at price 1.800000, investment 9.090908 %, total balance 9996.970000,
# day 715, sell 1 unit at price 1.740000, investment 4.191620 %, total balance 9998.710000,
# day 723: buy 1 unit at price 1.960000, total balance 9996.750000
# day 724, sell 1 unit at price 1.840000, investment -6.122449 %, total balance 9998.590000,
# day 728: buy 1 unit at price 1.950000, total balance 9996.640000
# day 729: buy 1 unit at price 1.950000, total balance 9994.690000
# day 730, sell 1 unit at price 1.950000, investment 0.000000 %, total balance 9996.640000,
# day 731, sell 1 unit at price 2.050000, investment 5.128200 %, total balance 9998.690000,
# day 733: buy 1 unit at price 1.860000, total balance 9996.830000
# day 734, sell 1 unit at price 1.840000, investment -1.075268 %, total balance 9998.670000,
# day 750: buy 1 unit at price 1.570000, total balance 9997.100000
# day 751: buy 1 unit at price 1.510000, total balance 9995.590000
# day 754, sell 1 unit at price 1.730000, investment 10.191080 %, total balance 9997.320000,
# day 755, sell 1 unit at price 1.840000, investment 21.854308 %, total balance 9999.160000,
# day 768: buy 1 unit at price 1.910000, total balance 9997.250000
# day 769, sell 1 unit at price 1.860000, investment -2.617799 %, total balance 9999.110000,
# day 771: buy 1 unit at price 1.650000, total balance 9997.460000
# day 772, sell 1 unit at price 1.570000, investment -4.848480 %, total balance 9999.030000,
# day 779: buy 1 unit at price 1.810000, total balance 9997.220000
# day 781, sell 1 unit at price 1.630000, investment -9.944749 %, total balance 9998.850000,
# day 783: buy 1 unit at price 1.720000, total balance 9997.130000
# day 784, sell 1 unit at price 1.720000, investment 0.000000 %, total balance 9998.850000,
# day 790: buy 1 unit at price 1.880000, total balance 9996.970000
# day 792: buy 1 unit at price 1.900000, total balance 9995.070000
# day 794, sell 1 unit at price 1.830000, investment -2.659572 %, total balance 9996.900000,
# day 795, sell 1 unit at price 1.870000, investment -1.578946 %, total balance 9998.770000,
# day 797: buy 1 unit at price 1.830000, total balance 9996.940000
# day 798: buy 1 unit at price 1.900000, total balance 9995.040000
# day 799, sell 1 unit at price 1.880000, investment 2.732238 %, total balance 9996.920000,
# day 800, sell 1 unit at price 1.900000, investment 0.000000 %, total balance 9998.820000,
# day 808: buy 1 unit at price 1.910000, total balance 9996.910000
# day 809, sell 1 unit at price 1.890000, investment -1.047119 %, total balance 9998.800000,
# day 835: buy 1 unit at price 1.910000, total balance 9996.890000
# day 836, sell 1 unit at price 1.930000, investment 1.047119 %, total balance 9998.820000,
# day 842: buy 1 unit at price 1.960000, total balance 9996.860000
# day 843, sell 1 unit at price 2.110000, investment 7.653054 %, total balance 9998.970000,
# day 844: buy 1 unit at price 2.090000, total balance 9996.880000
# day 845, sell 1 unit at price 2.120000, investment 1.435405 %, total balance 9999.000000,
# day 865: buy 1 unit at price 2.140000, total balance 9996.860000
# day 866, sell 1 unit at price 2.200000, investment 2.803736 %, total balance 9999.060000,
# day 867: buy 1 unit at price 2.170000, total balance 9996.890000
# day 868, sell 1 unit at price 2.300000, investment 5.990777 %, total balance 9999.189999,
# day 869: buy 1 unit at price 2.330000, total balance 9996.860000
# day 871, sell 1 unit at price 2.250000, investment -3.433473 %, total balance 9999.110000,
# day 873: buy 1 unit at price 2.250000, total balance 9996.860000
# day 874, sell 1 unit at price 2.210000, investment -1.777776 %, total balance 9999.070000,
# day 887: buy 1 unit at price 2.090000, total balance 9996.980000
# day 888, sell 1 unit at price 2.070000, investment -0.956937 %, total balance 9999.050000,
# day 895: buy 1 unit at price 2.010000, total balance 9997.040000
# day 896, sell 1 unit at price 2.170000, investment 7.960203 %, total balance 9999.210000,
# day 925: buy 1 unit at price 2.670000, total balance 9996.540000
# day 926, sell 1 unit at price 2.580000, investment -3.370792 %, total balance 9999.120000,
# day 954: buy 1 unit at price 2.800000, total balance 9996.320000
# day 955, sell 1 unit at price 2.770000, investment -1.071428 %, total balance 9999.090000,
# day 957: buy 1 unit at price 3.000000, total balance 9996.090000
# day 958, sell 1 unit at price 2.930000, investment -2.333331 %, total balance 9999.020000,
# day 964: buy 1 unit at price 3.000000, total balance 9996.020000
# day 965, sell 1 unit at price 3.000000, investment 0.000000 %, total balance 9999.020000,
# day 984: buy 1 unit at price 3.300000, total balance 9995.720000
# day 985, sell 1 unit at price 3.300000, investment 0.000000 %, total balance 9999.020000,
# day 986: buy 1 unit at price 3.400000, total balance 9995.620000
# day 987, sell 1 unit at price 3.400000, investment 0.000000 %, total balance 9999.020000,
# day 1009: buy 1 unit at price 3.350000, total balance 9995.670000
# day 1010, sell 1 unit at price 3.450000, investment 2.985079 %, total balance 9999.120000,
# day 1013: buy 1 unit at price 4.100000, total balance 9995.020000
# day 1014, sell 1 unit at price 4.000000, investment -2.439022 %, total balance 9999.020000,
# day 1018: buy 1 unit at price 3.900000, total balance 9995.120000
# day 1019, sell 1 unit at price 3.850000, investment -1.282056 %, total balance 9998.970000,
# day 1027: buy 1 unit at price 4.500000, total balance 9994.470000
# day 1028, sell 1 unit at price 4.340000, investment -3.555552 %, total balance 9998.810000,
# day 1038: buy 1 unit at price 4.100000, total balance 9994.710000
# day 1039, sell 1 unit at price 4.050000, investment -1.219505 %, total balance 9998.760000,
# day 1048: buy 1 unit at price 4.100000, total balance 9994.660000
# day 1051, sell 1 unit at price 4.000000, investment -2.439022 %, total balance 9998.660000,
# day 1058: buy 1 unit at price 3.850000, total balance 9994.810000
# day 1059, sell 1 unit at price 3.990000, investment 3.636366 %, total balance 9998.800000,
# day 1061: buy 1 unit at price 3.950000, total balance 9994.850000
# day 1062, sell 1 unit at price 4.000000, investment 1.265822 %, total balance 9998.850000,
# day 1067: buy 1 unit at price 4.250000, total balance 9994.600000
# day 1068, sell 1 unit at price 4.200000, investment -1.176475 %, total balance 9998.800000,
# day 1079: buy 1 unit at price 4.500000, total balance 9994.300000
# day 1080, sell 1 unit at price 4.400000, investment -2.222220 %, total balance 9998.700000,
# day 1082: buy 1 unit at price 4.500000, total balance 9994.200000
# day 1083, sell 1 unit at price 4.350000, investment -3.333335 %, total balance 9998.550000,
# day 1085: buy 1 unit at price 4.550000, total balance 9994.000000
# day 1086: buy 1 unit at price 4.500000, total balance 9989.500000
# day 1087, sell 1 unit at price 4.350000, investment -4.395610 %, total balance 9993.850000,
# day 1088, sell 1 unit at price 4.350000, investment -3.333335 %, total balance 9998.200000,
# day 1110: buy 1 unit at price 4.150000, total balance 9994.050000
# day 1111: buy 1 unit at price 4.050000, total balance 9989.999999
# day 1112: buy 1 unit at price 4.000000, total balance 9985.999999
# day 1113, sell 1 unit at price 4.200000, investment 1.204812 %, total balance 9990.199999,
# day 1114, sell 1 unit at price 4.150000, investment 2.469133 %, total balance 9994.349999,
# day 1115, sell 1 unit at price 4.150000, investment 3.750002 %, total balance 9998.499999,
# day 1123: buy 1 unit at price 3.990000, total balance 9994.509999
# day 1124, sell 1 unit at price 3.900000, investment -2.255637 %, total balance 9998.409999,
# day 1125: buy 1 unit at price 3.850000, total balance 9994.560000
# day 1126, sell 1 unit at price 3.800000, investment -1.298700 %, total balance 9998.360000,
# day 1132: buy 1 unit at price 3.900000, total balance 9994.459999
# day 1133, sell 1 unit at price 3.920000, investment 0.512820 %, total balance 9998.380000,
# day 1138: buy 1 unit at price 3.950000, total balance 9994.429999
# day 1139, sell 1 unit at price 3.950000, investment 0.000000 %, total balance 9998.380000,
# day 1140: buy 1 unit at price 4.050000, total balance 9994.329999
# day 1142, sell 1 unit at price 4.000000, investment -1.234573 %, total balance 9998.329999,
# day 1151: buy 1 unit at price 3.800000, total balance 9994.529999
# day 1152, sell 1 unit at price 3.750000, investment -1.315788 %, total balance 9998.279999,
# day 1156: buy 1 unit at price 3.400000, total balance 9994.879999
# day 1157, sell 1 unit at price 3.500000, investment 2.941174 %, total balance 9998.379999,
# day 1162: buy 1 unit at price 2.950000, total balance 9995.429999
# day 1163, sell 1 unit at price 2.950000, investment 0.000000 %, total balance 9998.379999,
# day 1164: buy 1 unit at price 2.950000, total balance 9995.429999
# day 1165, sell 1 unit at price 2.900000, investment -1.694914 %, total balance 9998.329999,
# day 1167: buy 1 unit at price 2.860000, total balance 9995.469999
# day 1168, sell 1 unit at price 2.800000, investment -2.097900 %, total balance 9998.269999,
# day 1171: buy 1 unit at price 2.800000, total balance 9995.469999
# day 1173, sell 1 unit at price 2.850000, investment 1.785713 %, total balance 9998.319999,
# day 1176: buy 1 unit at price 2.900000, total balance 9995.419999
# day 1177, sell 1 unit at price 2.900000, investment 0.000000 %, total balance 9998.319999,
# day 1180: buy 1 unit at price 2.900000, total balance 9995.419999
# day 1181, sell 1 unit at price 2.850000, investment -1.724144 %, total balance 9998.269999,
# day 1190: buy 1 unit at price 3.000000, total balance 9995.269999
# day 1191, sell 1 unit at price 2.950000, investment -1.666665 %, total balance 9998.219999,
# day 1199: buy 1 unit at price 2.950000, total balance 9995.269999
# day 1200: buy 1 unit at price 2.950000, total balance 9992.319999
# day 1201, sell 1 unit at price 2.940000, investment -0.338983 %, total balance 9995.259999,
# day 1202, sell 1 unit at price 2.950000, investment 0.000000 %, total balance 9998.209999,
# day 1208: buy 1 unit at price 3.060000, total balance 9995.149999
# day 1209, sell 1 unit at price 3.000000, investment -1.960782 %, total balance 9998.149999,
# day 1210: buy 1 unit at price 3.100000, total balance 9995.049999
# day 1211, sell 1 unit at price 3.150000, investment 1.612909 %, total balance 9998.199999,
# day 1229: buy 1 unit at price 2.750000, total balance 9995.449999
# day 1230, sell 1 unit at price 2.700000, investment -1.818180 %, total balance 9998.149999,
# day 1237: buy 1 unit at price 2.540000, total balance 9995.610000
# day 1238, sell 1 unit at price 2.550000, investment 0.393700 %, total balance 9998.159999,
# day 1250: buy 1 unit at price 2.550000, total balance 9995.610000
# day 1251: buy 1 unit at price 2.500000, total balance 9993.110000
# day 1252, sell 1 unit at price 2.500000, investment -1.960782 %, total balance 9995.610000,
# day 1253, sell 1 unit at price 2.750000, investment 10.000000 %, total balance 9998.360000,
# day 1261: buy 1 unit at price 2.800000, total balance 9995.560000
# day 1262, sell 1 unit at price 2.850000, investment 1.785713 %, total balance 9998.409999,
# day 1266: buy 1 unit at price 2.750000, total balance 9995.659999
# day 1267, sell 1 unit at price 2.700000, investment -1.818180 %, total balance 9998.360000,
# day 1275: buy 1 unit at price 2.850000, total balance 9995.510000
# day 1276, sell 1 unit at price 2.750000, investment -3.508769 %, total balance 9998.260000,
# day 1278: buy 1 unit at price 2.680000, total balance 9995.580000
# day 1279, sell 1 unit at price 2.700000, investment 0.746268 %, total balance 9998.280000,
# day 1285: buy 1 unit at price 2.500000, total balance 9995.780000
# day 1286, sell 1 unit at price 2.550000, investment 1.999998 %, total balance 9998.330000,
# day 1289: buy 1 unit at price 2.600000, total balance 9995.730000
# day 1290, sell 1 unit at price 2.600000, investment 0.000000 %, total balance 9998.330000,
# day 1291: buy 1 unit at price 2.600000, total balance 9995.730000
# day 1292, sell 1 unit at price 2.600000, investment 0.000000 %, total balance 9998.330000,
# day 1303: buy 1 unit at price 2.550000, total balance 9995.780000
# day 1304, sell 1 unit at price 2.550000, investment 0.000000 %, total balance 9998.330000,
# day 1305: buy 1 unit at price 2.600000, total balance 9995.730000
# day 1306, sell 1 unit at price 2.600000, investment 0.000000 %, total balance 9998.330000,
# day 1307: buy 1 unit at price 2.550000, total balance 9995.780000
# day 1308: buy 1 unit at price 2.600000, total balance 9993.180000
# day 1309: buy 1 unit at price 2.600000, total balance 9990.580000
# day 1310, sell 1 unit at price 2.550000, investment 0.000000 %, total balance 9993.130000,
# day 1312, sell 1 unit at price 2.600000, investment 0.000000 %, total balance 9995.730000,
# day 1314: buy 1 unit at price 2.700000, total balance 9993.030000
# day 1315, sell 1 unit at price 2.700000, investment 3.846159 %, total balance 9995.730000,
# day 1316, sell 1 unit at price 2.750000, investment 1.851850 %, total balance 9998.480000,
# day 1327: buy 1 unit at price 2.500000, total balance 9995.980000
# day 1328, sell 1 unit at price 2.400000, investment -3.999996 %, total balance 9998.380000,
# day 1334: buy 1 unit at price 2.430000, total balance 9995.950000
# day 1335, sell 1 unit at price 2.380000, investment -2.057611 %, total balance 9998.330000,
# day 1348: buy 1 unit at price 2.890000, total balance 9995.440000
# day 1349, sell 1 unit at price 2.780000, investment -3.806233 %, total balance 9998.220000,
# day 1351: buy 1 unit at price 2.690000, total balance 9995.530000
# day 1352, sell 1 unit at price 2.700000, investment 0.371747 %, total balance 9998.230000,
# day 1361: buy 1 unit at price 2.750000, total balance 9995.480000
# day 1362, sell 1 unit at price 2.780000, investment 1.090908 %, total balance 9998.260000,
# day 1369: buy 1 unit at price 2.650000, total balance 9995.610000
# day 1370, sell 1 unit at price 2.750000, investment 3.773581 %, total balance 9998.360000,
# day 1381: buy 1 unit at price 2.550000, total balance 9995.810000
# day 1382, sell 1 unit at price 2.650000, investment 3.921574 %, total balance 9998.460000,
# day 1394: buy 1 unit at price 2.830000, total balance 9995.630000
# day 1395, sell 1 unit at price 2.850000, investment 0.706713 %, total balance 9998.480000,
# day 1398: buy 1 unit at price 2.950000, total balance 9995.530000
# day 1399, sell 1 unit at price 3.060000, investment 3.728810 %, total balance 9998.590000,
# day 1400: buy 1 unit at price 3.100000, total balance 9995.490000
# day 1401, sell 1 unit at price 3.050000, investment -1.612902 %, total balance 9998.540000,
# day 1402: buy 1 unit at price 2.950000, total balance 9995.590000
# day 1403, sell 1 unit at price 2.950000, investment 0.000000 %, total balance 9998.540000,
# day 1408: buy 1 unit at price 3.020000, total balance 9995.520000
# day 1409, sell 1 unit at price 3.010000, investment -0.331126 %, total balance 9998.530000,
# day 1411: buy 1 unit at price 2.780000, total balance 9995.750000
# day 1412, sell 1 unit at price 2.800000, investment 0.719424 %, total balance 9998.550000,
# day 1424: buy 1 unit at price 3.100000, total balance 9995.450000
# day 1426, sell 1 unit at price 3.100000, investment 0.000000 %, total balance 9998.550000,
# day 1429: buy 1 unit at price 3.040000, total balance 9995.510000
# day 1430, sell 1 unit at price 3.000000, investment -1.315788 %, total balance 9998.510000,
# day 1433: buy 1 unit at price 3.050000, total balance 9995.460000
# day 1435, sell 1 unit at price 3.200000, investment 4.918036 %, total balance 9998.660000,
# day 1436: buy 1 unit at price 3.150000, total balance 9995.510000
# day 1438: buy 1 unit at price 3.100000, total balance 9992.410000
# day 1439, sell 1 unit at price 3.050000, investment -3.174608 %, total balance 9995.460000,
# day 1440: buy 1 unit at price 3.000000, total balance 9992.460000
# day 1442, sell 1 unit at price 3.030000, investment -2.258062 %, total balance 9995.490000,
# day 1443: buy 1 unit at price 3.050000, total balance 9992.440000
# day 1444, sell 1 unit at price 3.150000, investment 5.000003 %, total balance 9995.590000,
# day 1445: buy 1 unit at price 3.150000, total balance 9992.440000
# day 1447, sell 1 unit at price 3.740000, investment 22.622953 %, total balance 9996.180000,
# day 1448, sell 1 unit at price 3.780000, investment 19.999995 %, total balance 9999.960000,
# day 1450: buy 1 unit at price 3.500000, total balance 9996.460000
# day 1452: buy 1 unit at price 3.790000, total balance 9992.670000
# day 1453, sell 1 unit at price 3.850000, investment 9.999997 %, total balance 9996.520000,
# day 1454, sell 1 unit at price 3.580000, investment -5.540898 %, total balance 10000.100000,
# day 1455: buy 1 unit at price 3.410000, total balance 9996.689999
# day 1456, sell 1 unit at price 3.370000, investment -1.173026 %, total balance 10000.059999,
# day 1458: buy 1 unit at price 3.400000, total balance 9996.659999
# day 1459, sell 1 unit at price 3.580000, investment 5.294112 %, total balance 10000.239999,
# day 1469: buy 1 unit at price 3.150000, total balance 9997.089999
# day 1470, sell 1 unit at price 3.170000, investment 0.634920 %, total balance 10000.259999,
# day 1493: buy 1 unit at price 2.370000, total balance 9997.889999
# day 1494, sell 1 unit at price 2.420000, investment 2.109713 %, total balance 10000.309999,
# day 1496: buy 1 unit at price 2.530000, total balance 9997.779999
# day 1497, sell 1 unit at price 2.480000, investment -1.976283 %, total balance 10000.259999,
# day 1499: buy 1 unit at price 2.500000, total balance 9997.759999
# day 1500, sell 1 unit at price 2.510000, investment 0.400000 %, total balance 10000.269999,
# day 1505: buy 1 unit at price 2.390000, total balance 9997.879999
# day 1506, sell 1 unit at price 2.350000, investment -1.673648 %, total balance 10000.229999,
# day 1517: buy 1 unit at price 2.380000, total balance 9997.849999
# day 1518, sell 1 unit at price 2.400000, investment 0.840335 %, total balance 10000.249999,
# day 1525: buy 1 unit at price 2.360000, total balance 9997.889999
# day 1526, sell 1 unit at price 2.520000, investment 6.779665 %, total balance 10000.409999,
# day 1535: buy 1 unit at price 2.510000, total balance 9997.899999
# day 1536, sell 1 unit at price 2.560000, investment 1.992030 %, total balance 10000.459999,
# day 1546: buy 1 unit at price 2.880000, total balance 9997.579999
# day 1547, sell 1 unit at price 2.950000, investment 2.430553 %, total balance 10000.529999,
# day 1556: buy 1 unit at price 2.750000, total balance 9997.779999
# day 1558, sell 1 unit at price 2.730000, investment -0.727272 %, total balance 10000.509999,
# day 1569: buy 1 unit at price 2.840000, total balance 9997.669999
# day 1570, sell 1 unit at price 2.780000, investment -2.112674 %, total balance 10000.449999,
# day 1574: buy 1 unit at price 2.720000, total balance 9997.729999
# day 1575, sell 1 unit at price 2.710000, investment -0.367647 %, total balance 10000.439999,
# day 1582: buy 1 unit at price 2.680000, total balance 9997.759999
# day 1583, sell 1 unit at price 2.650000, investment -1.119402 %, total balance 10000.409999,
# day 1584: buy 1 unit at price 2.660000, total balance 9997.749999
# day 1585, sell 1 unit at price 2.710000, investment 1.879697 %, total balance 10000.459999,
# day 1593: buy 1 unit at price 2.780000, total balance 9997.679999
# day 1594: buy 1 unit at price 2.760000, total balance 9994.919999
# day 1596: buy 1 unit at price 2.780000, total balance 9992.139999
# day 1598, sell 1 unit at price 2.820000, investment 1.438848 %, total balance 9994.959999,
# day 1599, sell 1 unit at price 2.840000, investment 2.898548 %, total balance 9997.799999,
# day 1601, sell 1 unit at price 2.870000, investment 3.237407 %, total balance 10000.669999,
# day 1618: buy 1 unit at price 2.830000, total balance 9997.839999
# day 1620: buy 1 unit at price 2.840000, total balance 9994.999999
# day 1621, sell 1 unit at price 2.840000, investment 0.353357 %, total balance 9997.839999,
# day 1622, sell 1 unit at price 2.870000, investment 1.056337 %, total balance 10000.709999,
# day 1624: buy 1 unit at price 3.030000, total balance 9997.679999
# day 1625, sell 1 unit at price 2.950000, investment -2.640262 %, total balance 10000.629999,
# day 1631: buy 1 unit at price 2.950000, total balance 9997.679999
# day 1632: buy 1 unit at price 2.960000, total balance 9994.719999
# day 1633, sell 1 unit at price 2.870000, investment -2.711870 %, total balance 9997.589999,
# day 1635, sell 1 unit at price 3.020000, investment 2.027025 %, total balance 10000.609999,
# day 1646: buy 1 unit at price 2.920000, total balance 9997.689999
# day 1647, sell 1 unit at price 2.890000, investment -1.027396 %, total balance 10000.579999,
# day 1666: buy 1 unit at price 2.620000, total balance 9997.959999
# day 1667, sell 1 unit at price 2.570000, investment -1.908395 %, total balance 10000.529999,
# day 1677: buy 1 unit at price 2.570000, total balance 9997.959999
# day 1679, sell 1 unit at price 2.570000, investment 0.000000 %, total balance 10000.529999,
# day 1686: buy 1 unit at price 2.550000, total balance 9997.979999
# day 1687, sell 1 unit at price 2.520000, investment -1.176469 %, total balance 10000.499999,
# day 1690: buy 1 unit at price 2.440000, total balance 9998.059999
# day 1691, sell 1 unit at price 2.630000, investment 7.786887 %, total balance 10000.689999,
# day 1697: buy 1 unit at price 2.510000, total balance 9998.179999
# day 1698, sell 1 unit at price 2.510000, investment 0.000000 %, total balance 10000.689999,
# day 1728: buy 1 unit at price 2.460000, total balance 9998.229999
# day 1730, sell 1 unit at price 2.340000, investment -4.878054 %, total balance 10000.569999,
# day 1734: buy 1 unit at price 2.340000, total balance 9998.229999
# day 1735, sell 1 unit at price 2.460000, investment 5.128211 %, total balance 10000.689999,
# day 1740: buy 1 unit at price 2.530000, total balance 9998.159999
# day 1741, sell 1 unit at price 2.360000, investment -6.719371 %, total balance 10000.519999,
# day 1747: buy 1 unit at price 2.600000, total balance 9997.919999
# day 1749, sell 1 unit at price 2.540000, investment -2.307690 %, total balance 10000.459999,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
