# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../Kaggle_dataset/ACWI3.csv')
df.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close   Volume
# 0  1/2/2013  48.919998  49.070000  48.709999  49.040001  41.957142  2298300
# 1  1/3/2013  48.810001  49.080002  48.720001  48.830002  41.777470  1567500
# 2  1/4/2013  48.840000  49.099998  48.750000  49.040001  41.957142  1400200
# 3  1/7/2013  48.790001  48.889999  48.669998  48.840000  41.786026  1497400
# 4  1/8/2013  48.709999  48.750000  48.430000  48.599998  41.580692   306300

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6EF5C848>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6EF5C848>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6EF5C848>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6EF5C848>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6EF5C848>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6EF5C848>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6EF5C848>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6EF5C848>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6E4D0148>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6E4D0148>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6E4D0148>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6E4D0148>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6E4D0148>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6E4D0148>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6E4D0148>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001CA6E4D0148>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: 70.339966.3, cost: 0.015538, total money: 9291.269951
# epoch: 20, total rewards: 305.729927.3, cost: 0.085641, total money: 8472.589912
# epoch: 30, total rewards: 121.089958.3, cost: 0.001799, total money: 10121.089958
# epoch: 40, total rewards: -2.479946.3, cost: 0.002132, total money: 9918.450054
# epoch: 50, total rewards: 505.830010.3, cost: 0.141045, total money: 8769.740006
# epoch: 60, total rewards: 10.940029.3, cost: 0.001480, total money: 9851.890026
# epoch: 70, total rewards: 86.639908.3, cost: 0.000660, total money: 10086.639908
# epoch: 80, total rewards: 36.140106.3, cost: 0.016237, total money: 10036.140106
# epoch: 90, total rewards: 32.489952.3, cost: 0.006868, total money: 10032.489952
# epoch: 100, total rewards: 27.809990.3, cost: 0.000852, total money: 10027.809990
# epoch: 110, total rewards: 71.110031.3, cost: 0.001271, total money: 10071.110031
# epoch: 120, total rewards: 11.140007.3, cost: 0.002236, total money: 9852.520004
# epoch: 130, total rewards: -0.089958.3, cost: 0.002842, total money: 9841.970039
# epoch: 140, total rewards: 33.920044.3, cost: 0.001576, total money: 10033.920044
# epoch: 150, total rewards: 28.670063.3, cost: 0.000081, total money: 10028.670063
# epoch: 160, total rewards: -6.889999.3, cost: 0.000238, total money: 9993.110001
# epoch: 170, total rewards: 60.839939.3, cost: 0.001448, total money: 9981.769939
# epoch: 180, total rewards: -14.650024.3, cost: 0.001517, total money: 9985.349976
# epoch: 190, total rewards: 9.610050.3, cost: 0.001644, total money: 10009.610050
# epoch: 200, total rewards: 18.040020.3, cost: 0.000288, total money: 9938.970020

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 9: buy 1 unit at price 49.240002, total balance 9950.759998
# day 10, sell 1 unit at price 49.180000, investment -0.121855 %, total balance 9999.939999,
# day 22: buy 1 unit at price 49.630001, total balance 9950.309998
# day 23, sell 1 unit at price 49.959999, investment 0.664916 %, total balance 10000.269997,
# day 28: buy 1 unit at price 50.169998, total balance 9950.099998
# day 29, sell 1 unit at price 50.279999, investment 0.219256 %, total balance 10000.379997,
# day 33: buy 1 unit at price 49.939999, total balance 9950.439999
# day 36, sell 1 unit at price 49.029999, investment -1.822186 %, total balance 9999.469997,
# day 45: buy 1 unit at price 50.900002, total balance 9948.569996
# day 46: buy 1 unit at price 51.020000, total balance 9897.549995
# day 47: buy 1 unit at price 50.779999, total balance 9846.769997
# day 49, sell 1 unit at price 51.029999, investment 0.255397 %, total balance 9897.799995,
# day 50, sell 1 unit at price 51.009998, investment -0.019604 %, total balance 9948.809994,
# day 51, sell 1 unit at price 50.570000, investment -0.413547 %, total balance 9999.379993,
# day 68: buy 1 unit at price 51.650002, total balance 9947.729992
# day 69: buy 1 unit at price 51.450001, total balance 9896.279991
# day 70: buy 1 unit at price 50.259998, total balance 9846.019993
# day 71, sell 1 unit at price 51.009998, investment -1.239116 %, total balance 9897.029991,
# day 73, sell 1 unit at price 49.910000, investment -2.993199 %, total balance 9946.939991,
# day 74, sell 1 unit at price 50.389999, investment 0.258657 %, total balance 9997.329990,
# day 84: buy 1 unit at price 52.650002, total balance 9944.679989
# day 85, sell 1 unit at price 52.720001, investment 0.132953 %, total balance 9997.399990,
# day 89: buy 1 unit at price 53.119999, total balance 9944.279991
# day 90: buy 1 unit at price 53.099998, total balance 9891.179993
# day 92, sell 1 unit at price 53.630001, investment 0.960094 %, total balance 9944.809994,
# day 93: buy 1 unit at price 53.330002, total balance 9891.479992
# day 94, sell 1 unit at price 53.759998, investment 1.242938 %, total balance 9945.239990,
# day 95, sell 1 unit at price 53.910000, investment 1.087564 %, total balance 9999.149990,
# day 97: buy 1 unit at price 53.500000, total balance 9945.649990
# day 98, sell 1 unit at price 53.169998, investment -0.616826 %, total balance 9998.819988,
# day 114: buy 1 unit at price 52.020000, total balance 9946.799988
# day 115, sell 1 unit at price 52.360001, investment 0.653595 %, total balance 9999.159988,
# day 116: buy 1 unit at price 51.470001, total balance 9947.689987
# day 117: buy 1 unit at price 49.919998, total balance 9897.769989
# day 118, sell 1 unit at price 50.070000, investment -2.720034 %, total balance 9947.839989,
# day 120, sell 1 unit at price 49.820000, investment -0.200317 %, total balance 9997.659988,
# day 124: buy 1 unit at price 50.320000, total balance 9947.339989
# day 126, sell 1 unit at price 50.110001, investment -0.417327 %, total balance 9997.449989,
# day 130: buy 1 unit at price 51.080002, total balance 9946.369987
# day 131, sell 1 unit at price 52.209999, investment 2.212211 %, total balance 9998.579987,
# day 138: buy 1 unit at price 52.759998, total balance 9945.819988
# day 139: buy 1 unit at price 52.820000, total balance 9892.999989
# day 142, sell 1 unit at price 52.660000, investment -0.189535 %, total balance 9945.659988,
# day 143, sell 1 unit at price 52.380001, investment -0.833015 %, total balance 9998.039989,
# day 147: buy 1 unit at price 53.180000, total balance 9944.859989
# day 148: buy 1 unit at price 53.099998, total balance 9891.759991
# day 149, sell 1 unit at price 52.790001, investment -0.733357 %, total balance 9944.549992,
# day 150, sell 1 unit at price 52.570000, investment -0.998114 %, total balance 9997.119991,
# day 153: buy 1 unit at price 52.939999, total balance 9944.179993
# day 155, sell 1 unit at price 53.070000, investment 0.245563 %, total balance 9997.249992,
# day 157: buy 1 unit at price 52.430000, total balance 9944.819992
# day 158, sell 1 unit at price 52.000000, investment -0.820142 %, total balance 9996.819992,
# day 159: buy 1 unit at price 52.060001, total balance 9944.759991
# day 160, sell 1 unit at price 51.560001, investment -0.960430 %, total balance 9996.319992,
# day 162: buy 1 unit at price 52.349998, total balance 9943.969994
# day 163, sell 1 unit at price 52.099998, investment -0.477555 %, total balance 9996.069992,
# day 166: buy 1 unit at price 51.369999, total balance 9944.699993
# day 167, sell 1 unit at price 51.090000, investment -0.545063 %, total balance 9995.789993,
# day 183: buy 1 unit at price 54.430000, total balance 9941.359993
# day 184, sell 1 unit at price 54.340000, investment -0.165350 %, total balance 9995.699993,
# day 198: buy 1 unit at price 54.639999, total balance 9941.059994
# day 199, sell 1 unit at price 55.189999, investment 1.006587 %, total balance 9996.249992,
# day 202: buy 1 unit at price 56.070000, total balance 9940.179993
# day 205, sell 1 unit at price 56.270000, investment 0.356698 %, total balance 9996.449993,
# day 209: buy 1 unit at price 56.360001, total balance 9940.089993
# day 211, sell 1 unit at price 56.040001, investment -0.567778 %, total balance 9996.129993,
# day 222: buy 1 unit at price 56.770000, total balance 9939.359993
# day 223, sell 1 unit at price 56.619999, investment -0.264227 %, total balance 9995.979992,
# day 226: buy 1 unit at price 56.889999, total balance 9939.089993
# day 227, sell 1 unit at price 56.720001, investment -0.298819 %, total balance 9995.809994,
# day 230: buy 1 unit at price 56.919998, total balance 9938.889996
# day 231, sell 1 unit at price 56.590000, investment -0.579758 %, total balance 9995.479996,
# day 243: buy 1 unit at price 56.130001, total balance 9939.349995
# day 244, sell 1 unit at price 56.060001, investment -0.124710 %, total balance 9995.409996,
# day 262: buy 1 unit at price 57.330002, total balance 9938.079994
# day 263, sell 1 unit at price 57.130001, investment -0.348859 %, total balance 9995.209995,
# day 265: buy 1 unit at price 57.360001, total balance 9937.849995
# day 266, sell 1 unit at price 56.849998, investment -0.889125 %, total balance 9994.699993,
# day 271: buy 1 unit at price 55.480000, total balance 9939.219994
# day 275, sell 1 unit at price 54.250000, investment -2.217014 %, total balance 9993.469994,
# day 283: buy 1 unit at price 57.259998, total balance 9936.209995
# day 284, sell 1 unit at price 56.910000, investment -0.611244 %, total balance 9993.119995,
# day 286: buy 1 unit at price 57.209999, total balance 9935.909996
# day 287, sell 1 unit at price 57.610001, investment 0.699181 %, total balance 9993.519997,
# day 289: buy 1 unit at price 57.369999, total balance 9936.149998
# day 290, sell 1 unit at price 57.689999, investment 0.557782 %, total balance 9993.839996,
# day 292: buy 1 unit at price 57.020000, total balance 9936.819996
# day 293, sell 1 unit at price 57.970001, investment 1.666083 %, total balance 9994.789997,
# day 300: buy 1 unit at price 56.689999, total balance 9938.099998
# day 301: buy 1 unit at price 56.509998, total balance 9881.590000
# day 302, sell 1 unit at price 57.139999, investment 0.793792 %, total balance 9938.730000,
# day 303: buy 1 unit at price 57.520000, total balance 9881.209999
# day 304, sell 1 unit at price 56.980000, investment 0.831713 %, total balance 9938.189999,
# day 306, sell 1 unit at price 56.980000, investment -0.938805 %, total balance 9995.169998,
# day 310: buy 1 unit at price 57.320000, total balance 9937.849998
# day 312, sell 1 unit at price 58.139999, investment 1.430565 %, total balance 9995.989998,
# day 314: buy 1 unit at price 58.700001, total balance 9937.289997
# day 316: buy 1 unit at price 58.150002, total balance 9879.139996
# day 317, sell 1 unit at price 57.740002, investment -1.635433 %, total balance 9936.879997,
# day 319, sell 1 unit at price 58.599998, investment 0.773855 %, total balance 9995.479996,
# day 323: buy 1 unit at price 57.419998, total balance 9938.059998
# day 324, sell 1 unit at price 58.119999, investment 1.219089 %, total balance 9996.179996,
# day 327: buy 1 unit at price 58.650002, total balance 9937.529995
# day 328, sell 1 unit at price 58.480000, investment -0.289858 %, total balance 9996.009994,
# day 337: buy 1 unit at price 58.500000, total balance 9937.509994
# day 338, sell 1 unit at price 58.730000, investment 0.393162 %, total balance 9996.239994,
# day 352: buy 1 unit at price 59.680000, total balance 9936.559994
# day 353, sell 1 unit at price 60.009998, investment 0.552946 %, total balance 9996.569992,
# day 360: buy 1 unit at price 60.880001, total balance 9935.689991
# day 361, sell 1 unit at price 60.919998, investment 0.065698 %, total balance 9996.609989,
# day 370: buy 1 unit at price 61.150002, total balance 9935.459988
# day 371, sell 1 unit at price 60.730000, investment -0.686839 %, total balance 9996.189987,
# day 372: buy 1 unit at price 60.040001, total balance 9936.149986
# day 374, sell 1 unit at price 60.220001, investment 0.299801 %, total balance 9996.369987,
# day 377: buy 1 unit at price 60.840000, total balance 9935.529987
# day 378, sell 1 unit at price 61.139999, investment 0.493095 %, total balance 9996.669987,
# day 381: buy 1 unit at price 60.610001, total balance 9936.059986
# day 382, sell 1 unit at price 60.200001, investment -0.676456 %, total balance 9996.259987,
# day 389: buy 1 unit at price 60.459999, total balance 9935.799988
# day 390, sell 1 unit at price 60.750000, investment 0.479657 %, total balance 9996.549988,
# day 401: buy 1 unit at price 58.810001, total balance 9937.739986
# day 402, sell 1 unit at price 58.419998, investment -0.663158 %, total balance 9996.159985,
# day 403: buy 1 unit at price 58.990002, total balance 9937.169983
# day 404, sell 1 unit at price 59.200001, investment 0.355991 %, total balance 9996.369984,
# day 407: buy 1 unit at price 59.799999, total balance 9936.569984
# day 408, sell 1 unit at price 59.810001, investment 0.016726 %, total balance 9996.379986,
# day 413: buy 1 unit at price 60.450001, total balance 9935.929985
# day 417: buy 1 unit at price 60.810001, total balance 9875.119984
# day 418, sell 1 unit at price 60.919998, investment 0.777498 %, total balance 9936.039982,
# day 419, sell 1 unit at price 60.880001, investment 0.115112 %, total balance 9996.919983,
# day 421: buy 1 unit at price 60.889999, total balance 9936.029983
# day 422, sell 1 unit at price 61.150002, investment 0.427003 %, total balance 9997.179985,
# day 432: buy 1 unit at price 60.450001, total balance 9936.729984
# day 433, sell 1 unit at price 59.959999, investment -0.810590 %, total balance 9996.689983,
# day 450: buy 1 unit at price 55.689999, total balance 9940.999985
# day 451, sell 1 unit at price 55.529999, investment -0.287304 %, total balance 9996.529983,
# day 453: buy 1 unit at price 56.709999, total balance 9939.819984
# day 454, sell 1 unit at price 57.549999, investment 1.481221 %, total balance 9997.369984,
# day 461: buy 1 unit at price 58.830002, total balance 9938.539982
# day 462, sell 1 unit at price 59.610001, investment 1.325852 %, total balance 9998.149982,
# day 474: buy 1 unit at price 60.060001, total balance 9938.089981
# day 476, sell 1 unit at price 59.919998, investment -0.233106 %, total balance 9998.009979,
# day 478: buy 1 unit at price 60.590000, total balance 9937.419979
# day 479, sell 1 unit at price 60.560001, investment -0.049511 %, total balance 9997.979980,
# day 491: buy 1 unit at price 57.790001, total balance 9940.189980
# day 492, sell 1 unit at price 57.160000, investment -1.090156 %, total balance 9997.349979,
# day 495: buy 1 unit at price 58.709999, total balance 9938.639980
# day 496, sell 1 unit at price 58.869999, investment 0.272526 %, total balance 9997.509979,
# day 500: buy 1 unit at price 59.549999, total balance 9937.959980
# day 501, sell 1 unit at price 59.419998, investment -0.218306 %, total balance 9997.379978,
# day 515: buy 1 unit at price 58.009998, total balance 9939.369980
# day 516, sell 1 unit at price 58.439999, investment 0.741252 %, total balance 9997.809978,
# day 524: buy 1 unit at price 58.480000, total balance 9939.329979
# day 525, sell 1 unit at price 59.389999, investment 1.556087 %, total balance 9998.719978,
# day 558: buy 1 unit at price 61.180000, total balance 9937.539978
# day 559, sell 1 unit at price 61.000000, investment -0.294214 %, total balance 9998.539978,
# day 570: buy 1 unit at price 61.590000, total balance 9936.949978
# day 572: buy 1 unit at price 61.529999, total balance 9875.419979
# day 573, sell 1 unit at price 61.759998, investment 0.276016 %, total balance 9937.179977,
# day 576: buy 1 unit at price 61.419998, total balance 9875.759979
# day 577, sell 1 unit at price 61.750000, investment 0.357551 %, total balance 9937.509979,
# day 578, sell 1 unit at price 61.930000, investment 0.830352 %, total balance 9999.439980,
# day 586: buy 1 unit at price 62.299999, total balance 9937.139980
# day 587, sell 1 unit at price 62.439999, investment 0.224718 %, total balance 9999.579979,
# day 614: buy 1 unit at price 61.740002, total balance 9937.839977
# day 615, sell 1 unit at price 61.310001, investment -0.696470 %, total balance 9999.149979,
# day 616: buy 1 unit at price 60.990002, total balance 9938.159977
# day 617: buy 1 unit at price 61.139999, total balance 9877.019978
# day 618, sell 1 unit at price 61.180000, investment 0.311524 %, total balance 9938.199978,
# day 619, sell 1 unit at price 61.790001, investment 1.063136 %, total balance 9999.989979,
# day 621: buy 1 unit at price 62.160000, total balance 9937.829979
# day 622: buy 1 unit at price 62.299999, total balance 9875.529980
# day 623, sell 1 unit at price 61.860001, investment -0.482624 %, total balance 9937.389980,
# day 624, sell 1 unit at price 60.959999, investment -2.150883 %, total balance 9998.349979,
# day 626: buy 1 unit at price 59.349998, total balance 9938.999981
# day 627, sell 1 unit at price 59.450001, investment 0.168496 %, total balance 9998.449982,
# day 633: buy 1 unit at price 58.480000, total balance 9939.969982
# day 634, sell 1 unit at price 59.720001, investment 2.120386 %, total balance 9999.689983,
# day 636: buy 1 unit at price 60.549999, total balance 9939.139984
# day 637, sell 1 unit at price 60.389999, investment -0.264244 %, total balance 9999.529983,
# day 644: buy 1 unit at price 59.380001, total balance 9940.149982
# day 645: buy 1 unit at price 58.830002, total balance 9881.319981
# day 646: buy 1 unit at price 59.529999, total balance 9821.789982
# day 647, sell 1 unit at price 59.900002, investment 0.875716 %, total balance 9881.689983,
# day 648, sell 1 unit at price 59.860001, investment 1.750805 %, total balance 9941.549984,
# day 649, sell 1 unit at price 59.939999, investment 0.688728 %, total balance 10001.489983,
# day 654: buy 1 unit at price 59.439999, total balance 9942.049984
# day 657, sell 1 unit at price 59.209999, investment -0.386944 %, total balance 10001.259983,
# day 673: buy 1 unit at price 55.090000, total balance 9946.169983
# day 674, sell 1 unit at price 54.049999, investment -1.887822 %, total balance 10000.219982,
# day 679: buy 1 unit at price 55.150002, total balance 9945.069981
# day 680, sell 1 unit at price 55.700001, investment 0.997279 %, total balance 10000.769981,
# day 695: buy 1 unit at price 55.990002, total balance 9944.779980
# day 696, sell 1 unit at price 56.610001, investment 1.107339 %, total balance 10001.389980,
# day 700: buy 1 unit at price 56.570000, total balance 9944.819981
# day 701, sell 1 unit at price 56.630001, investment 0.106066 %, total balance 10001.449982,
# day 704: buy 1 unit at price 57.490002, total balance 9943.959980
# day 705, sell 1 unit at price 57.389999, investment -0.173947 %, total balance 10001.349979,
# day 714: buy 1 unit at price 58.730000, total balance 9942.619980
# day 715, sell 1 unit at price 58.910000, investment 0.306488 %, total balance 10001.529980,
# day 719: buy 1 unit at price 57.750000, total balance 9943.779980
# day 720, sell 1 unit at price 57.799999, investment 0.086579 %, total balance 10001.579979,
# day 726: buy 1 unit at price 57.860001, total balance 9943.719978
# day 727, sell 1 unit at price 58.009998, investment 0.259242 %, total balance 10001.729977,
# day 730: buy 1 unit at price 57.959999, total balance 9943.769978
# day 731, sell 1 unit at price 58.009998, investment 0.086265 %, total balance 10001.779976,
# day 738: buy 1 unit at price 57.419998, total balance 9944.359978
# day 739, sell 1 unit at price 56.849998, investment -0.992685 %, total balance 10001.209976,
# day 743: buy 1 unit at price 55.619999, total balance 9945.589977
# day 744, sell 1 unit at price 56.169998, investment 0.988852 %, total balance 10001.759975,
# day 748: buy 1 unit at price 55.310001, total balance 9946.449974
# day 749, sell 1 unit at price 55.740002, investment 0.777437 %, total balance 10002.189976,
# day 772: buy 1 unit at price 51.470001, total balance 9950.719974
# day 773: buy 1 unit at price 51.750000, total balance 9898.969974
# day 774, sell 1 unit at price 52.860001, investment 2.700601 %, total balance 9951.829975,
# day 775: buy 1 unit at price 52.759998, total balance 9899.069977
# day 776, sell 1 unit at price 51.639999, investment -0.212562 %, total balance 9950.709976,
# day 777, sell 1 unit at price 52.040001, investment -1.364665 %, total balance 10002.749977,
# day 784: buy 1 unit at price 50.389999, total balance 9952.359978
# day 785, sell 1 unit at price 51.400002, investment 2.004370 %, total balance 10003.759979,
# day 796: buy 1 unit at price 53.820000, total balance 9949.939980
# day 797, sell 1 unit at price 54.220001, investment 0.743221 %, total balance 10004.159981,
# day 799: buy 1 unit at price 54.599998, total balance 9949.559982
# day 801, sell 1 unit at price 54.299999, investment -0.549449 %, total balance 10003.859982,
# day 802: buy 1 unit at price 54.270000, total balance 9949.589981
# day 803, sell 1 unit at price 55.360001, investment 2.008476 %, total balance 10004.949982,
# day 815: buy 1 unit at price 56.330002, total balance 9948.619980
# day 817, sell 1 unit at price 56.020000, investment -0.550331 %, total balance 10004.639980,
# day 841: buy 1 unit at price 55.820000, total balance 9948.819981
# day 842, sell 1 unit at price 55.980000, investment 0.286635 %, total balance 10004.799980,
# day 862: buy 1 unit at price 57.689999, total balance 9947.109982
# day 863, sell 1 unit at price 57.919998, investment 0.398682 %, total balance 10005.029980,
# day 885: buy 1 unit at price 56.459999, total balance 9948.569981
# day 886, sell 1 unit at price 56.950001, investment 0.867874 %, total balance 10005.519981,
# day 890: buy 1 unit at price 57.709999, total balance 9947.809982
# day 891, sell 1 unit at price 57.889999, investment 0.311905 %, total balance 10005.699982,
# day 892: buy 1 unit at price 57.619999, total balance 9948.079983
# day 893, sell 1 unit at price 57.950001, investment 0.572721 %, total balance 10006.029984,
# day 901: buy 1 unit at price 58.160000, total balance 9947.869984
# day 902, sell 1 unit at price 57.799999, investment -0.618983 %, total balance 10005.669983,
# day 910: buy 1 unit at price 59.119999, total balance 9946.549984
# day 911, sell 1 unit at price 59.369999, investment 0.422869 %, total balance 10005.919983,
# day 914: buy 1 unit at price 59.389999, total balance 9946.529984
# day 915, sell 1 unit at price 59.169998, investment -0.370435 %, total balance 10005.699982,
# day 916: buy 1 unit at price 59.099998, total balance 9946.599983
# day 917, sell 1 unit at price 59.220001, investment 0.203050 %, total balance 10005.819984,
# day 921: buy 1 unit at price 58.889999, total balance 9946.929985
# day 922, sell 1 unit at price 58.779999, investment -0.186790 %, total balance 10005.709984,
# day 934: buy 1 unit at price 57.830002, total balance 9947.879982
# day 936, sell 1 unit at price 58.189999, investment 0.622509 %, total balance 10006.069981,
# day 971: buy 1 unit at price 58.220001, total balance 9947.849979
# day 972, sell 1 unit at price 58.400002, investment 0.309173 %, total balance 10006.249981,
# day 977: buy 1 unit at price 58.020000, total balance 9948.229980
# day 978, sell 1 unit at price 58.299999, investment 0.482590 %, total balance 10006.529980,
# day 982: buy 1 unit at price 58.570000, total balance 9947.959980
# day 985, sell 1 unit at price 58.720001, investment 0.256106 %, total balance 10006.679981,
# day 987: buy 1 unit at price 58.290001, total balance 9948.389980
# day 989, sell 1 unit at price 58.790001, investment 0.857780 %, total balance 10007.179981,
# day 998: buy 1 unit at price 59.840000, total balance 9947.339981
# day 999, sell 1 unit at price 59.910000, investment 0.116978 %, total balance 10007.249981,
# day 1005: buy 1 unit at price 59.150002, total balance 9948.099979
# day 1007, sell 1 unit at price 59.169998, investment 0.033807 %, total balance 10007.269978,
# day 1037: buy 1 unit at price 62.150002, total balance 9945.119976
# day 1038: buy 1 unit at price 62.450001, total balance 9882.669975
# day 1039, sell 1 unit at price 62.459999, investment 0.498789 %, total balance 9945.129974,
# day 1040: buy 1 unit at price 62.419998, total balance 9882.709976
# day 1041, sell 1 unit at price 62.689999, investment 0.384304 %, total balance 9945.399975,
# day 1042, sell 1 unit at price 62.709999, investment 0.464596 %, total balance 10008.109974,
# day 1052: buy 1 unit at price 62.400002, total balance 9945.709972
# day 1053: buy 1 unit at price 62.439999, total balance 9883.269974
# day 1054: buy 1 unit at price 62.779999, total balance 9820.489975
# day 1055: buy 1 unit at price 63.020000, total balance 9757.469975
# day 1056, sell 1 unit at price 62.660000, investment 0.416664 %, total balance 9820.129974,
# day 1057, sell 1 unit at price 63.410000, investment 1.553493 %, total balance 9883.539974,
# day 1058, sell 1 unit at price 63.540001, investment 1.210580 %, total balance 9947.079975,
# day 1059, sell 1 unit at price 63.509998, investment 0.777528 %, total balance 10010.589973,
# day 1064: buy 1 unit at price 63.080002, total balance 9947.509972
# day 1065, sell 1 unit at price 63.130001, investment 0.079263 %, total balance 10010.639973,
# day 1091: buy 1 unit at price 64.449997, total balance 9946.189976
# day 1092: buy 1 unit at price 64.589996, total balance 9881.599979
# day 1093, sell 1 unit at price 65.019997, investment 0.884406 %, total balance 9946.619976,
# day 1094, sell 1 unit at price 64.889999, investment 0.464473 %, total balance 10011.509975,
# day 1099: buy 1 unit at price 65.370003, total balance 9946.139973
# day 1100, sell 1 unit at price 65.489998, investment 0.183563 %, total balance 10011.629971,
# day 1103: buy 1 unit at price 65.250000, total balance 9946.379971
# day 1104, sell 1 unit at price 65.510002, investment 0.398471 %, total balance 10011.889973,
# day 1108: buy 1 unit at price 65.830002, total balance 9946.059971
# day 1109, sell 1 unit at price 65.800003, investment -0.045570 %, total balance 10011.859974,
# day 1120: buy 1 unit at price 66.389999, total balance 9945.469975
# day 1121, sell 1 unit at price 66.029999, investment -0.542251 %, total balance 10011.499973,
# day 1124: buy 1 unit at price 65.410004, total balance 9946.089970
# day 1125, sell 1 unit at price 65.440002, investment 0.045863 %, total balance 10011.529972,
# day 1130: buy 1 unit at price 65.930000, total balance 9945.599972
# day 1131, sell 1 unit at price 65.330002, investment -0.910054 %, total balance 10010.929974,
# day 1137: buy 1 unit at price 65.500000, total balance 9945.429974
# day 1139, sell 1 unit at price 66.180000, investment 1.038168 %, total balance 10011.609974,
# day 1141: buy 1 unit at price 66.720001, total balance 9944.889973
# day 1143: buy 1 unit at price 66.760002, total balance 9878.129971
# day 1144: buy 1 unit at price 67.129997, total balance 9810.999973
# day 1145, sell 1 unit at price 67.199997, investment 0.719418 %, total balance 9878.199970,
# day 1146: buy 1 unit at price 67.110001, total balance 9811.089970
# day 1147, sell 1 unit at price 67.059998, investment 0.449364 %, total balance 9878.149967,
# day 1148, sell 1 unit at price 67.199997, investment 0.104275 %, total balance 9945.349964,
# day 1150, sell 1 unit at price 67.269997, investment 0.238409 %, total balance 10012.619961,
# day 1164: buy 1 unit at price 67.160004, total balance 9945.459957
# day 1165, sell 1 unit at price 66.279999, investment -1.310311 %, total balance 10011.739956,
# day 1174: buy 1 unit at price 67.139999, total balance 9944.599957
# day 1175, sell 1 unit at price 67.550003, investment 0.610670 %, total balance 10012.149960,
# day 1180: buy 1 unit at price 67.690002, total balance 9944.459957
# day 1181, sell 1 unit at price 68.309998, investment 0.915933 %, total balance 10012.769955,
# day 1187: buy 1 unit at price 68.839996, total balance 9943.929958
# day 1188, sell 1 unit at price 68.870003, investment 0.043589 %, total balance 10012.799961,
# day 1191: buy 1 unit at price 68.400002, total balance 9944.399960
# day 1192, sell 1 unit at price 68.260002, investment -0.204677 %, total balance 10012.659962,
# day 1196: buy 1 unit at price 68.900002, total balance 9943.759960
# day 1197, sell 1 unit at price 69.169998, investment 0.391867 %, total balance 10012.929958,
# day 1198: buy 1 unit at price 69.220001, total balance 9943.709957
# day 1199, sell 1 unit at price 69.489998, investment 0.390056 %, total balance 10013.199955,
# day 1218: buy 1 unit at price 70.419998, total balance 9942.779957
# day 1219, sell 1 unit at price 70.519997, investment 0.142003 %, total balance 10013.299953,
# day 1221: buy 1 unit at price 70.790001, total balance 9942.509953
# day 1222, sell 1 unit at price 70.699997, investment -0.127142 %, total balance 10013.209949,
# day 1224: buy 1 unit at price 70.500000, total balance 9942.709949
# day 1225, sell 1 unit at price 70.379997, investment -0.170217 %, total balance 10013.089947,
# day 1230: buy 1 unit at price 70.379997, total balance 9942.709949
# day 1231, sell 1 unit at price 70.519997, investment 0.198919 %, total balance 10013.229946,
# day 1237: buy 1 unit at price 71.379997, total balance 9941.849949
# day 1238, sell 1 unit at price 71.720001, investment 0.476329 %, total balance 10013.569950,
# day 1240: buy 1 unit at price 71.360001, total balance 9942.209949
# day 1241, sell 1 unit at price 71.150002, investment -0.294281 %, total balance 10013.359951,
# day 1244: buy 1 unit at price 71.610001, total balance 9941.749950
# day 1245, sell 1 unit at price 71.879997, investment 0.377038 %, total balance 10013.629948,
# day 1249: buy 1 unit at price 71.970001, total balance 9941.659946
# day 1250, sell 1 unit at price 72.629997, investment 0.917043 %, total balance 10014.289944,
# day 1253: buy 1 unit at price 71.919998, total balance 9942.369946
# day 1254, sell 1 unit at price 72.000000, investment 0.111237 %, total balance 10014.369946,
# day 1265: buy 1 unit at price 74.120003, total balance 9940.249943
# day 1266, sell 1 unit at price 74.629997, investment 0.688066 %, total balance 10014.879940,
# day 1271: buy 1 unit at price 75.919998, total balance 9938.959942
# day 1272, sell 1 unit at price 76.470001, investment 0.724451 %, total balance 10015.429943,
# day 1278: buy 1 unit at price 76.120003, total balance 9939.309940
# day 1279, sell 1 unit at price 76.199997, investment 0.105090 %, total balance 10015.509937,
# day 1287: buy 1 unit at price 71.620003, total balance 9943.889935
# day 1288, sell 1 unit at price 71.750000, investment 0.181510 %, total balance 10015.639935,
# day 1290: buy 1 unit at price 73.790001, total balance 9941.849934
# day 1291, sell 1 unit at price 73.870003, investment 0.108418 %, total balance 10015.719936,
# day 1293: buy 1 unit at price 72.930000, total balance 9942.789936
# day 1294, sell 1 unit at price 73.080002, investment 0.205679 %, total balance 10015.869938,
# day 1313: buy 1 unit at price 73.040001, total balance 9942.829937
# day 1314, sell 1 unit at price 71.309998, investment -2.368570 %, total balance 10014.139935,
# day 1315: buy 1 unit at price 70.089996, total balance 9944.049938
# day 1316, sell 1 unit at price 71.730003, investment 2.339859 %, total balance 10015.779942,
# day 1318: buy 1 unit at price 70.750000, total balance 9945.029942
# day 1319, sell 1 unit at price 71.699997, investment 1.342752 %, total balance 10016.729938,
# day 1320: buy 1 unit at price 70.260002, total balance 9946.469936
# day 1321, sell 1 unit at price 71.010002, investment 1.067464 %, total balance 10017.479938,
# day 1336: buy 1 unit at price 71.669998, total balance 9945.809940
# day 1337, sell 1 unit at price 71.680000, investment 0.013956 %, total balance 10017.489941,
# day 1343: buy 1 unit at price 71.620003, total balance 9945.869938
# day 1344, sell 1 unit at price 72.220001, investment 0.837753 %, total balance 10018.089939,
# day 1351: buy 1 unit at price 73.160004, total balance 9944.929935
# day 1352, sell 1 unit at price 73.489998, investment 0.451058 %, total balance 10018.419933,
# day 1355: buy 1 unit at price 73.620003, total balance 9944.799931
# day 1356, sell 1 unit at price 73.540001, investment -0.108669 %, total balance 10018.339931,
# day 1370: buy 1 unit at price 74.089996, total balance 9944.249935
# day 1371, sell 1 unit at price 73.940002, investment -0.202448 %, total balance 10018.189938,
# day 1375: buy 1 unit at price 72.010002, total balance 9946.179935
# day 1376, sell 1 unit at price 72.180000, investment 0.236076 %, total balance 10018.359936,
# day 1383: buy 1 unit at price 71.120003, total balance 9947.239933
# day 1384, sell 1 unit at price 70.910004, investment -0.295274 %, total balance 10018.149937,
# day 1386: buy 1 unit at price 71.360001, total balance 9946.789936
# day 1387, sell 1 unit at price 71.879997, investment 0.728695 %, total balance 10018.669933,
# day 1404: buy 1 unit at price 73.300003, total balance 9945.369930
# day 1405: buy 1 unit at price 73.139999, total balance 9872.229931
# day 1407, sell 1 unit at price 73.370003, investment 0.095498 %, total balance 9945.599934,
# day 1408, sell 1 unit at price 73.360001, investment 0.300795 %, total balance 10018.959934,
# day 1413: buy 1 unit at price 72.220001, total balance 9946.739933
# day 1414, sell 1 unit at price 72.550003, investment 0.456940 %, total balance 10019.289936,
# day 1415: buy 1 unit at price 71.690002, total balance 9947.599934
# day 1416, sell 1 unit at price 72.230003, investment 0.753244 %, total balance 10019.829937,
# day 1417: buy 1 unit at price 72.559998, total balance 9947.269939
# day 1418, sell 1 unit at price 72.830002, investment 0.372112 %, total balance 10020.099941,
# day 1429: buy 1 unit at price 73.000000, total balance 9947.099941
# day 1430, sell 1 unit at price 72.739998, investment -0.356167 %, total balance 10019.839939,
# day 1433: buy 1 unit at price 72.779999, total balance 9947.059940
# day 1434, sell 1 unit at price 72.919998, investment 0.192360 %, total balance 10019.979938,
# day 1440: buy 1 unit at price 74.650002, total balance 9945.329937
# day 1441: buy 1 unit at price 74.690002, total balance 9870.639935
# day 1442, sell 1 unit at price 74.339996, investment -0.415278 %, total balance 9944.979931,
# day 1443, sell 1 unit at price 74.489998, investment -0.267780 %, total balance 10019.469929,
# day 1454: buy 1 unit at price 70.580002, total balance 9948.889927
# day 1455, sell 1 unit at price 69.389999, investment -1.686033 %, total balance 10018.279926,
# day 1468: buy 1 unit at price 67.989998, total balance 9950.289928
# day 1469, sell 1 unit at price 68.739998, investment 1.103103 %, total balance 10019.029926,
# day 1479: buy 1 unit at price 68.739998, total balance 9950.289928
# day 1480, sell 1 unit at price 69.400002, investment 0.960145 %, total balance 10019.689930,
# day 1485: buy 1 unit at price 67.449997, total balance 9952.239933
# day 1486, sell 1 unit at price 68.440002, investment 1.467762 %, total balance 10020.679935,
# day 1495: buy 1 unit at price 66.940002, total balance 9953.739933
# day 1497, sell 1 unit at price 67.739998, investment 1.195093 %, total balance 10021.479931,
# day 1509: buy 1 unit at price 64.160004, total balance 9957.319927
# day 1510, sell 1 unit at price 64.139999, investment -0.031179 %, total balance 10021.459927,
# day 1530: buy 1 unit at price 69.320000, total balance 9952.139927
# day 1531, sell 1 unit at price 69.239998, investment -0.115409 %, total balance 10021.379925,
# day 1532: buy 1 unit at price 69.639999, total balance 9951.739925
# day 1533, sell 1 unit at price 70.050003, investment 0.588747 %, total balance 10021.789928,
# day 1563: buy 1 unit at price 72.339996, total balance 9949.449932
# day 1564, sell 1 unit at price 72.849998, investment 0.705007 %, total balance 10022.299931,
# day 1566: buy 1 unit at price 71.330002, total balance 9950.969929
# day 1567, sell 1 unit at price 71.820000, investment 0.686945 %, total balance 10022.789928,
# day 1588: buy 1 unit at price 74.089996, total balance 9948.699932
# day 1589: buy 1 unit at price 74.370003, total balance 9874.329929
# day 1591, sell 1 unit at price 74.620003, investment 0.715355 %, total balance 9948.949932,
# day 1593: buy 1 unit at price 73.940002, total balance 9875.009930
# day 1594, sell 1 unit at price 74.720001, investment 0.470618 %, total balance 9949.729931,
# day 1595, sell 1 unit at price 74.099998, investment 0.216386 %, total balance 10023.829929,
# day 1602: buy 1 unit at price 72.000000, total balance 9951.829929
# day 1603, sell 1 unit at price 72.540001, investment 0.750001 %, total balance 10024.369930,
# day 1610: buy 1 unit at price 70.879997, total balance 9953.489933
# day 1611, sell 1 unit at price 70.470001, investment -0.578437 %, total balance 10023.959934,
# day 1614: buy 1 unit at price 70.220001, total balance 9953.739933
# day 1615, sell 1 unit at price 71.360001, investment 1.623468 %, total balance 10025.099934,
# day 1618: buy 1 unit at price 72.750000, total balance 9952.349934
# day 1619, sell 1 unit at price 73.059998, investment 0.426113 %, total balance 10025.409931,
# day 1622: buy 1 unit at price 73.099998, total balance 9952.309933
# day 1623, sell 1 unit at price 72.779999, investment -0.437756 %, total balance 10025.089931,
# day 1630: buy 1 unit at price 73.070000, total balance 9952.019932
# day 1631, sell 1 unit at price 73.120003, investment 0.068432 %, total balance 10025.139935,
# day 1635: buy 1 unit at price 74.470001, total balance 9950.669933
# day 1636: buy 1 unit at price 74.940002, total balance 9875.729931
# day 1637, sell 1 unit at price 74.589996, investment 0.161132 %, total balance 9950.319927,
# day 1638, sell 1 unit at price 74.199997, investment -0.987464 %, total balance 10024.519924,
# day 1649: buy 1 unit at price 74.809998, total balance 9949.709927
# day 1650, sell 1 unit at price 75.050003, investment 0.320820 %, total balance 10024.759930,
# day 1661: buy 1 unit at price 72.470001, total balance 9952.289928
# day 1662, sell 1 unit at price 71.980003, investment -0.676139 %, total balance 10024.269932,
# day 1672: buy 1 unit at price 70.440002, total balance 9953.829929
# day 1673, sell 1 unit at price 71.089996, investment 0.922762 %, total balance 10024.919926,
# day 1682: buy 1 unit at price 73.680000, total balance 9951.239925
# day 1683, sell 1 unit at price 73.690002, investment 0.013575 %, total balance 10024.929928,
# day 1690: buy 1 unit at price 74.510002, total balance 9950.419926
# day 1691: buy 1 unit at price 74.230003, total balance 9876.189922
# day 1692: buy 1 unit at price 74.129997, total balance 9802.059925
# day 1693: buy 1 unit at price 73.690002, total balance 9728.369923
# day 1694, sell 1 unit at price 73.889999, investment -0.832107 %, total balance 9802.259922,
# day 1695, sell 1 unit at price 73.809998, investment -0.565817 %, total balance 9876.069920,
# day 1696, sell 1 unit at price 73.400002, investment -0.984751 %, total balance 9949.469921,
# day 1699, sell 1 unit at price 71.680000, investment -2.727646 %, total balance 10021.149921,
# day 1701: buy 1 unit at price 73.040001, total balance 9948.109920
# day 1702, sell 1 unit at price 72.750000, investment -0.397044 %, total balance 10020.859920,
# day 1704: buy 1 unit at price 72.410004, total balance 9948.449917
# day 1705, sell 1 unit at price 72.980003, investment 0.787184 %, total balance 10021.429920,
# day 1706: buy 1 unit at price 73.970001, total balance 9947.459919
# day 1708, sell 1 unit at price 74.510002, investment 0.730027 %, total balance 10021.969921,
# day 1710: buy 1 unit at price 74.709999, total balance 9947.259922
# day 1712, sell 1 unit at price 75.000000, investment 0.388169 %, total balance 10022.259922,
# day 1715: buy 1 unit at price 75.199997, total balance 9947.059925
# day 1716, sell 1 unit at price 75.410004, investment 0.279264 %, total balance 10022.469929,
# day 1720: buy 1 unit at price 75.769997, total balance 9946.699932
# day 1721, sell 1 unit at price 76.540001, investment 1.016239 %, total balance 10023.239933,
# day 1746: buy 1 unit at price 77.620003, total balance 9945.619930
# day 1748, sell 1 unit at price 77.940002, investment 0.412264 %, total balance 10023.559933,
# day 1754: buy 1 unit at price 78.730003, total balance 9944.829929
# day 1756, sell 1 unit at price 79.050003, investment 0.406452 %, total balance 10023.879932,
# day 1757: buy 1 unit at price 79.070000, total balance 9944.809933
# day 1759, sell 1 unit at price 79.550003, investment 0.607061 %, total balance 10024.359936,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
