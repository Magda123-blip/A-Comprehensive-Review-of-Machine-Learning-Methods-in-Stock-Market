# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../agent/cleaned_data/AAP.csv')
df.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close   Volume
# 0  1/2/2013  73.489998  73.760002  71.690002  72.489998  71.357033   800500
# 1  1/3/2013  72.849998  73.440002  72.129997  72.489998  71.357033   520600
# 2  1/4/2013  72.750000  73.639999  72.389999  73.620003  72.469398   615000
# 3  1/7/2013  73.150002  73.800003  73.150002  73.370003  72.223305  1054400
# 4  1/8/2013  73.169998  73.660004  72.139999  72.169998  71.042053   840000

# %%
from collections import deque
import random
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.X = tf.placeholder(tf.float32, (None, None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, self.OUTPUT_SIZE))
        cell = tf.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
        self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * self.LAYER_SIZE))
        self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
        self.logits = tf.layers.dense(self.rnn[:,-1], self.OUTPUT_SIZE)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.logits, feed_dict={self.X:states, self.hidden_layer:init_values})
        Q_new = self.sess.run(self.logits, feed_dict={self.X:new_states, self.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * np.amax(Q_new[i])
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.logits,self.last_state],
                                                feed_dict={self.X:[self.INITIAL_FEATURES],
                                                            self.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.logits,
                                                  self.last_state],
                                                  feed_dict={self.X:[self.INITIAL_FEATURES],
                                                             self.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.cost, self.optimizer], 
                                        feed_dict={self.X: X, self.Y:Y,
                                                  self.hidden_layer: INIT_VAL})
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
                
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-deb04c5fc6f6>:27: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000001C867EB7488>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:From <ipython-input-3-deb04c5fc6f6>:31: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py:961: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000001C867EB7488>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000001C867EB7488>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000001C867EB7488>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000001C867EB7488>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From <ipython-input-3-deb04c5fc6f6>:32: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C86A307A88>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C86A307A88>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C86A307A88>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C86A307A88>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: -448.789963.3, cost: 0.455947, total money: 9390.640030
# epoch: 20, total rewards: 1331.360137.3, cost: 0.285897, total money: 6858.120162
# epoch: 30, total rewards: 521.479912.3, cost: 38.560532, total money: 10203.089912
# epoch: 40, total rewards: 85.910087.3, cost: 0.203609, total money: 10085.910087
# epoch: 50, total rewards: -15.459869.3, cost: 0.127664, total money: 8584.140138
# epoch: 60, total rewards: 1264.309945.3, cost: 1.565286, total money: 11264.309945
# epoch: 70, total rewards: 817.459855.3, cost: 0.276395, total money: 10030.899858
# epoch: 80, total rewards: 27.780097.3, cost: 0.062793, total money: 9393.940101
# epoch: 90, total rewards: 929.370132.3, cost: 61.319942, total money: 10929.370132
# epoch: 100, total rewards: 39.149819.3, cost: 0.087307, total money: 10039.149819
# epoch: 110, total rewards: 1031.769891.3, cost: 0.374251, total money: 7345.459878
# epoch: 120, total rewards: 289.430121.3, cost: 6.993474, total money: 9976.810126
# epoch: 130, total rewards: -737.310112.3, cost: 5.612540, total money: 7511.609887
# epoch: 140, total rewards: -100.970247.3, cost: 1.686721, total money: 9423.579756
# epoch: 150, total rewards: 890.830125.3, cost: 721.451294, total money: 10414.320130
# epoch: 160, total rewards: 3197.410057.3, cost: 1.148793, total money: 909.920128
# epoch: 170, total rewards: -241.420091.3, cost: 0.030066, total money: 9758.579909
# epoch: 180, total rewards: 550.939994.3, cost: 10.861208, total money: 10550.939994
# epoch: 190, total rewards: 76.319947.3, cost: 0.092187, total money: 10076.319947
# epoch: 200, total rewards: 4852.199973.3, cost: 7.977774, total money: 13260.729972

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 72.489998, total balance 9927.510002
# day 2, sell 1 unit at price 73.620003, investment 1.558842 %, total balance 10001.130005,
# day 8: buy 1 unit at price 72.580002, total balance 9928.550003
# day 9: buy 1 unit at price 73.639999, total balance 9854.910004
# day 10: buy 1 unit at price 73.360001, total balance 9781.550003
# day 11: buy 1 unit at price 73.419998, total balance 9708.130005
# day 12: buy 1 unit at price 73.750000, total balance 9634.380005
# day 13: buy 1 unit at price 74.080002, total balance 9560.300003
# day 14: buy 1 unit at price 74.750000, total balance 9485.550003
# day 15: buy 1 unit at price 75.010002, total balance 9410.540001
# day 16: buy 1 unit at price 75.250000, total balance 9335.290001
# day 17: buy 1 unit at price 75.940002, total balance 9259.349998
# day 18: buy 1 unit at price 74.570000, total balance 9184.779999
# day 19: buy 1 unit at price 73.529999, total balance 9111.250000
# day 20: buy 1 unit at price 73.519997, total balance 9037.730003
# day 21: buy 1 unit at price 73.660004, total balance 8964.070000
# day 22: buy 1 unit at price 72.230003, total balance 8891.839996
# day 23: buy 1 unit at price 73.269997, total balance 8818.570000
# day 24: buy 1 unit at price 72.900002, total balance 8745.669998
# day 25: buy 1 unit at price 77.139999, total balance 8668.529999
# day 26: buy 1 unit at price 78.900002, total balance 8589.629997
# day 27: buy 1 unit at price 78.389999, total balance 8511.239998
# day 28: buy 1 unit at price 78.599998, total balance 8432.639999
# day 29: buy 1 unit at price 78.970001, total balance 8353.669998
# day 30: buy 1 unit at price 78.839996, total balance 8274.830002
# day 31: buy 1 unit at price 79.000000, total balance 8195.830002
# day 32: buy 1 unit at price 80.720001, total balance 8115.110001
# day 33: buy 1 unit at price 79.500000, total balance 8035.610001
# day 34: buy 1 unit at price 79.059998, total balance 7956.550003
# day 35: buy 1 unit at price 79.209999, total balance 7877.340004
# day 36: buy 1 unit at price 78.360001, total balance 7798.980003
# day 37: buy 1 unit at price 77.150002, total balance 7721.830002
# day 38: buy 1 unit at price 77.300003, total balance 7644.529999
# day 39: buy 1 unit at price 76.339996, total balance 7568.190002
# day 40: buy 1 unit at price 76.370003, total balance 7491.820000
# day 41: buy 1 unit at price 77.019997, total balance 7414.800003
# day 42: buy 1 unit at price 76.949997, total balance 7337.850006
# day 43: buy 1 unit at price 76.180000, total balance 7261.670006
# day 44: buy 1 unit at price 76.220001, total balance 7185.450005
# day 45: buy 1 unit at price 76.839996, total balance 7108.610008
# day 46: buy 1 unit at price 77.529999, total balance 7031.080009
# day 47: buy 1 unit at price 77.360001, total balance 6953.720009
# day 48: buy 1 unit at price 78.769997, total balance 6874.950012
# day 49: buy 1 unit at price 77.669998, total balance 6797.280014
# day 50: buy 1 unit at price 79.570000, total balance 6717.710014
# day 51: buy 1 unit at price 80.699997, total balance 6637.010017
# day 52: buy 1 unit at price 80.070000, total balance 6556.940018
# day 53: buy 1 unit at price 80.220001, total balance 6476.720016
# day 54: buy 1 unit at price 80.029999, total balance 6396.690018
# day 55: buy 1 unit at price 79.809998, total balance 6316.880020
# day 56: buy 1 unit at price 80.529999, total balance 6236.350021
# day 57: buy 1 unit at price 81.599998, total balance 6154.750023
# day 58: buy 1 unit at price 81.639999, total balance 6073.110024
# day 59: buy 1 unit at price 82.650002, total balance 5990.460022
# day 60: buy 1 unit at price 82.339996, total balance 5908.120026
# day 61: buy 1 unit at price 82.830002, total balance 5825.290024
# day 62: buy 1 unit at price 82.120003, total balance 5743.170021
# day 63: buy 1 unit at price 82.199997, total balance 5660.970024
# day 64: buy 1 unit at price 80.949997, total balance 5580.020027
# day 65: buy 1 unit at price 80.629997, total balance 5499.390030
# day 66: buy 1 unit at price 78.709999, total balance 5420.680031
# day 67: buy 1 unit at price 81.230003, total balance 5339.450027
# day 68: buy 1 unit at price 83.010002, total balance 5256.440025
# day 69: buy 1 unit at price 81.989998, total balance 5174.450027
# day 70: buy 1 unit at price 80.269997, total balance 5094.180031
# day 71: buy 1 unit at price 80.470001, total balance 5013.710030
# day 72: buy 1 unit at price 79.820000, total balance 4933.890030
# day 73: buy 1 unit at price 78.919998, total balance 4854.970032
# day 74: buy 1 unit at price 79.930000, total balance 4775.040031
# day 75: buy 1 unit at price 79.070000, total balance 4695.970032
# day 76: buy 1 unit at price 80.550003, total balance 4615.420029
# day 77: buy 1 unit at price 81.180000, total balance 4534.240028
# day 78: buy 1 unit at price 83.000000, total balance 4451.240028
# day 79: buy 1 unit at price 82.940002, total balance 4368.300026
# day 80: buy 1 unit at price 83.019997, total balance 4285.280029
# day 81: buy 1 unit at price 83.879997, total balance 4201.400032
# day 82: buy 1 unit at price 84.339996, total balance 4117.060036
# day 83: buy 1 unit at price 84.589996, total balance 4032.470039
# day 84: buy 1 unit at price 84.559998, total balance 3947.910042
# day 85: buy 1 unit at price 84.910004, total balance 3863.000038
# day 86: buy 1 unit at price 85.580002, total balance 3777.420036
# day 87: buy 1 unit at price 85.120003, total balance 3692.300034
# day 88: buy 1 unit at price 84.720001, total balance 3607.580032
# day 89: buy 1 unit at price 85.430000, total balance 3522.150032
# day 90: buy 1 unit at price 85.000000, total balance 3437.150032
# day 91: buy 1 unit at price 86.120003, total balance 3351.030029
# day 92: buy 1 unit at price 86.400002, total balance 3264.630028
# day 93: buy 1 unit at price 85.419998, total balance 3179.210030
# day 94: buy 1 unit at price 86.160004, total balance 3093.050026
# day 95: buy 1 unit at price 86.519997, total balance 3006.530029
# day 96: buy 1 unit at price 87.180000, total balance 2919.350029
# day 97: buy 1 unit at price 85.800003, total balance 2833.550026
# day 98: buy 1 unit at price 84.080002, total balance 2749.470024
# day 99: buy 1 unit at price 83.389999, total balance 2666.080025
# day 100: buy 1 unit at price 83.629997, total balance 2582.450027
# day 101: buy 1 unit at price 82.160004, total balance 2500.290024
# day 102: buy 1 unit at price 82.070000, total balance 2418.220024
# day 103: buy 1 unit at price 81.519997, total balance 2336.700027
# day 104: buy 1 unit at price 82.550003, total balance 2254.150024
# day 105: buy 1 unit at price 81.989998, total balance 2172.160027
# day 106: buy 1 unit at price 81.550003, total balance 2090.610024
# day 107: buy 1 unit at price 83.230003, total balance 2007.380020
# day 108: buy 1 unit at price 84.320000, total balance 1923.060020
# day 109: buy 1 unit at price 83.620003, total balance 1839.440018
# day 110: buy 1 unit at price 82.690002, total balance 1756.750015
# day 111: buy 1 unit at price 82.349998, total balance 1674.400017
# day 112: buy 1 unit at price 82.750000, total balance 1591.650017
# day 113: buy 1 unit at price 82.480003, total balance 1509.170013
# day 114: buy 1 unit at price 82.480003, total balance 1426.690010
# day 115: buy 1 unit at price 83.690002, total balance 1343.000008
# day 116: buy 1 unit at price 84.070000, total balance 1258.930008
# day 117: buy 1 unit at price 82.879997, total balance 1176.050011
# day 118: buy 1 unit at price 80.739998, total balance 1095.310013
# day 119: buy 1 unit at price 80.220001, total balance 1015.090012
# day 120: buy 1 unit at price 81.389999, total balance 933.700012
# day 121: buy 1 unit at price 79.750000, total balance 853.950012
# day 122: buy 1 unit at price 80.019997, total balance 773.930016
# day 123: buy 1 unit at price 81.169998, total balance 692.760017
# day 124: buy 1 unit at price 81.889999, total balance 610.870018
# day 125: buy 1 unit at price 81.470001, total balance 529.400017
# day 126: buy 1 unit at price 81.989998, total balance 447.410019
# day 127: buy 1 unit at price 82.580002, total balance 364.830017
# day 128: buy 1 unit at price 83.720001, total balance 281.110016
# day 129: buy 1 unit at price 83.199997, total balance 197.910019
# day 130: buy 1 unit at price 82.750000, total balance 115.160019
# day 131: buy 1 unit at price 82.760002, total balance 32.400017
# day 730, sell 1 unit at price 163.190002, investment 124.841552 %, total balance 195.590019,
# day 731, sell 1 unit at price 164.300003, investment 123.112445 %, total balance 359.890022,
# day 732: buy 1 unit at price 164.839996, total balance 195.050026
# day 738: buy 1 unit at price 151.220001, total balance 43.830025
# day 995, sell 1 unit at price 171.869995, investment 134.282979 %, total balance 215.700020,
# day 999: buy 1 unit at price 173.820007, total balance 41.880013
# day 1172, sell 1 unit at price 94.660004, investment 28.929455 %, total balance 136.540016,
# day 1179: buy 1 unit at price 93.529999, total balance 43.010018

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
