# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../agent/cleaned_data/REED.csv')
df.head()
# Out:
#        Date  Open  High   Low  Close  Adj Close  Volume
# 0  1/2/2013  5.76  6.05  5.76   5.90       5.90  159600
# 1  1/3/2013  5.93  6.10  5.83   6.06       6.06   73600
# 2  1/4/2013  6.02  6.50  6.02   6.47       6.47  110700
# 3  1/7/2013  6.50  6.50  6.24   6.37       6.37   71900
# 4  1/8/2013  6.44  6.45  6.33   6.37       6.37   45200

# %%
def buy_stock(
    real_movement,
    delay = 5,
    initial_state = 1,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    delay_change_decision = delay
    current_decision = 0
    state = initial_state
    current_val = real_movement[0]
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    if state == 1:
        initial_money, current_inventory = buy(
            0, initial_money, current_inventory
        )

    for i in range(1, real_movement.shape[0], 1):
        if real_movement[i] < current_val and state == 0:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 1
                initial_money, current_inventory = buy(
                    i, initial_money, current_inventory
                )
                current_decision = 0
                states_buy.append(i)
        if real_movement[i] > current_val and state == 1:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 0

                if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
                else:
                    if current_inventory > max_sell:
                        sell_units = max_sell
                    else:
                        sell_units = current_inventory
                    current_inventory -= sell_units
                    total_sell = sell_units * real_movement[i]
                    initial_money += total_sell
                    try:
                        invest = (
                            (real_movement[i] - real_movement[states_buy[-1]])
                            / real_movement[states_buy[-1]]
                        ) * 100
                    except:
                        invest = 0
                    print(
                        'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                        % (i, sell_units, total_sell, invest, initial_money)
                    )

                current_decision = 0
                states_sell.append(i)
        current_val = real_movement[i]
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, initial_state = 1, 
                                                         delay = 4, initial_money = 10000)
# Out:
# day 0: buy 1 units at price 5.900000, total balance 9994.100000
# day 14, sell 1 units at price 5.270000, investment -10.677968 %, total balance 9999.370000,
# day 24: buy 1 units at price 5.840000, total balance 9993.530000
# day 38, sell 1 units at price 4.330000, investment -25.856168 %, total balance 9997.860000,
# day 49: buy 1 units at price 4.420000, total balance 9993.440000
# day 64, sell 1 units at price 4.060000, investment -8.144799 %, total balance 9997.500000,
# day 73: buy 1 units at price 4.070000, total balance 9993.429999
# day 83, sell 1 units at price 4.090000, investment 0.491400 %, total balance 9997.520000,
# day 95: buy 1 units at price 4.910000, total balance 9992.610000
# day 111, sell 1 units at price 4.710000, investment -4.073316 %, total balance 9997.320000,
# day 125: buy 1 units at price 5.210000, total balance 9992.110000
# day 133, sell 1 units at price 5.590000, investment 7.293668 %, total balance 9997.700000,
# day 141: buy 1 units at price 5.410000, total balance 9992.290000
# day 146, sell 1 units at price 5.750000, investment 6.284661 %, total balance 9998.040000,
# day 155: buy 1 units at price 6.240000, total balance 9991.800000
# day 163, sell 1 units at price 5.520000, investment -11.538459 %, total balance 9997.320000,
# day 174: buy 1 units at price 5.810000, total balance 9991.510000
# day 188, sell 1 units at price 5.680000, investment -2.237524 %, total balance 9997.190000,
# day 193: buy 1 units at price 5.090000, total balance 9992.100000
# day 204, sell 1 units at price 5.210000, investment 2.357562 %, total balance 9997.310000,
# day 221: buy 1 units at price 6.870000, total balance 9990.440000
# day 231, sell 1 units at price 6.850000, investment -0.291121 %, total balance 9997.290000,
# day 237: buy 1 units at price 6.520000, total balance 9990.770000
# day 243, sell 1 units at price 6.920000, investment 6.134971 %, total balance 9997.690000,
# day 257: buy 1 units at price 8.280000, total balance 9989.410000
# day 272, sell 1 units at price 7.280000, investment -12.077289 %, total balance 9996.690001,
# day 282: buy 1 units at price 7.070000, total balance 9989.620000
# day 289, sell 1 units at price 7.700000, investment 8.910886 %, total balance 9997.320000,
# day 304: buy 1 units at price 7.680000, total balance 9989.640000
# day 315, sell 1 units at price 5.710000, investment -25.651040 %, total balance 9995.350000,
# day 320: buy 1 units at price 5.050000, total balance 9990.300000
# day 326, sell 1 units at price 5.460000, investment 8.118809 %, total balance 9995.760000,
# day 335: buy 1 units at price 5.300000, total balance 9990.460000
# day 351, sell 1 units at price 5.010000, investment -5.471697 %, total balance 9995.470000,
# day 361: buy 1 units at price 4.590000, total balance 9990.880000
# day 370, sell 1 units at price 4.620000, investment 0.653589 %, total balance 9995.500000,
# day 380: buy 1 units at price 5.080000, total balance 9990.420000
# day 390, sell 1 units at price 5.080000, investment 0.000000 %, total balance 9995.500000,
# day 398: buy 1 units at price 5.000000, total balance 9990.500000
# day 407, sell 1 units at price 5.880000, investment 17.600002 %, total balance 9996.380000,
# day 417: buy 1 units at price 6.050000, total balance 9990.330000
# day 429, sell 1 units at price 6.100000, investment 0.826442 %, total balance 9996.430000,
# day 439: buy 1 units at price 5.900000, total balance 9990.530000
# day 448, sell 1 units at price 5.870000, investment -0.508478 %, total balance 9996.400000,
# day 464: buy 1 units at price 7.350000, total balance 9989.050000
# day 477, sell 1 units at price 6.480000, investment -11.836733 %, total balance 9995.530000,
# day 484: buy 1 units at price 6.260000, total balance 9989.270000
# day 497, sell 1 units at price 6.190000, investment -1.118214 %, total balance 9995.460000,
# day 503: buy 1 units at price 5.910000, total balance 9989.550000
# day 516, sell 1 units at price 5.520000, investment -6.598983 %, total balance 9995.070000,
# day 522: buy 1 units at price 5.320000, total balance 9989.750000
# day 531, sell 1 units at price 5.420000, investment 1.879697 %, total balance 9995.170000,
# day 542: buy 1 units at price 5.400000, total balance 9989.770000
# day 550, sell 1 units at price 6.370000, investment 17.962959 %, total balance 9996.139999,
# day 560: buy 1 units at price 6.590000, total balance 9989.549999
# day 574, sell 1 units at price 5.300000, investment -19.575113 %, total balance 9994.849999,
# day 582: buy 1 units at price 5.160000, total balance 9989.690000
# day 592, sell 1 units at price 6.020000, investment 16.666670 %, total balance 9995.710000,
# day 606: buy 1 units at price 6.040000, total balance 9989.670000
# day 615, sell 1 units at price 6.490000, investment 7.450328 %, total balance 9996.159999,
# day 623: buy 1 units at price 6.370000, total balance 9989.789999
# day 632, sell 1 units at price 6.050000, investment -5.023543 %, total balance 9995.840000,
# day 642: buy 1 units at price 6.280000, total balance 9989.559999
# day 651, sell 1 units at price 6.280000, investment 0.000000 %, total balance 9995.840000,
# day 657: buy 1 units at price 5.640000, total balance 9990.200000
# day 668, sell 1 units at price 5.300000, investment -6.028363 %, total balance 9995.500000,
# day 676: buy 1 units at price 5.000000, total balance 9990.500000
# day 687, sell 1 units at price 4.800000, investment -3.999996 %, total balance 9995.300000,
# day 702: buy 1 units at price 4.850000, total balance 9990.450000
# day 707, sell 1 units at price 5.140000, investment 5.979381 %, total balance 9995.590000,
# day 716: buy 1 units at price 4.900000, total balance 9990.690000
# day 725, sell 1 units at price 4.610000, investment -5.918366 %, total balance 9995.300000,
# day 740: buy 1 units at price 5.440000, total balance 9989.860000
# day 751, sell 1 units at price 5.650000, investment 3.860295 %, total balance 9995.510000,
# day 757: buy 1 units at price 5.330000, total balance 9990.180000
# day 771, sell 1 units at price 4.770000, investment -10.506566 %, total balance 9994.950000,
# day 779: buy 1 units at price 4.740000, total balance 9990.210001
# day 788, sell 1 units at price 4.910000, investment 3.586500 %, total balance 9995.120000,
# day 798: buy 1 units at price 5.040000, total balance 9990.080000
# day 806, sell 1 units at price 5.210000, investment 3.373017 %, total balance 9995.290000,
# day 813: buy 1 units at price 4.850000, total balance 9990.440001
# day 822, sell 1 units at price 4.850000, investment 0.000000 %, total balance 9995.290000,
# day 830: buy 1 units at price 4.570000, total balance 9990.720000
# day 841, sell 1 units at price 4.500000, investment -1.531732 %, total balance 9995.220000,
# day 851: buy 1 units at price 3.840000, total balance 9991.380000
# day 868, sell 1 units at price 2.460000, investment -35.937498 %, total balance 9993.840000,
# day 879: buy 1 units at price 2.430000, total balance 9991.410000
# day 885, sell 1 units at price 2.620000, investment 7.818922 %, total balance 9994.030000,
# day 896: buy 1 units at price 2.590000, total balance 9991.440000
# day 905, sell 1 units at price 2.610000, investment 0.772200 %, total balance 9994.050000,
# day 915: buy 1 units at price 2.640000, total balance 9991.410000
# day 920, sell 1 units at price 3.120000, investment 18.181809 %, total balance 9994.530000,
# day 929: buy 1 units at price 3.530000, total balance 9991.000000
# day 938, sell 1 units at price 3.510000, investment -0.566572 %, total balance 9994.510000,
# day 956: buy 1 units at price 4.200000, total balance 9990.310000
# day 964, sell 1 units at price 4.550000, investment 8.333343 %, total balance 9994.860000,
# day 972: buy 1 units at price 4.150000, total balance 9990.710000
# day 993, sell 1 units at price 4.000000, investment -3.614460 %, total balance 9994.710000,
# day 1006: buy 1 units at price 4.000000, total balance 9990.710000
# day 1016, sell 1 units at price 4.200000, investment 4.999995 %, total balance 9994.910000,
# day 1028: buy 1 units at price 4.150000, total balance 9990.760000
# day 1039, sell 1 units at price 4.050000, investment -2.409636 %, total balance 9994.810000,
# day 1050: buy 1 units at price 3.750000, total balance 9991.060000
# day 1058, sell 1 units at price 4.000000, investment 6.666667 %, total balance 9995.060000,
# day 1070: buy 1 units at price 3.950000, total balance 9991.110000
# day 1078, sell 1 units at price 4.300000, investment 8.860763 %, total balance 9995.410000,
# day 1087: buy 1 units at price 3.500000, total balance 9991.910000
# day 1101, sell 1 units at price 3.250000, investment -7.142857 %, total balance 9995.160000,
# day 1114: buy 1 units at price 2.950000, total balance 9992.210000
# day 1127, sell 1 units at price 2.550000, investment -13.559325 %, total balance 9994.760000,
# day 1137: buy 1 units at price 2.350000, total balance 9992.410000
# day 1160, sell 1 units at price 1.600000, investment -31.914890 %, total balance 9994.010000,
# day 1172: buy 1 units at price 1.700000, total balance 9992.310000
# day 1182, sell 1 units at price 2.250000, investment 32.352937 %, total balance 9994.560000,
# day 1192: buy 1 units at price 2.190000, total balance 9992.370000
# day 1214, sell 1 units at price 1.750000, investment -20.091326 %, total balance 9994.120000,
# day 1233: buy 1 units at price 2.000000, total balance 9992.120000
# day 1243, sell 1 units at price 1.700000, investment -14.999998 %, total balance 9993.820000,
# day 1258: buy 1 units at price 1.550000, total balance 9992.270000
# day 1267, sell 1 units at price 1.700000, investment 9.677426 %, total balance 9993.970000,
# day 1278: buy 1 units at price 1.530000, total balance 9992.440000
# day 1291, sell 1 units at price 1.600000, investment 4.575167 %, total balance 9994.040000,
# day 1301: buy 1 units at price 1.500000, total balance 9992.540000
# day 1317, sell 1 units at price 1.650000, investment 9.999998 %, total balance 9994.190000,
# day 1330: buy 1 units at price 2.200000, total balance 9991.990000
# day 1346, sell 1 units at price 2.200000, investment 0.000000 %, total balance 9994.190000,
# day 1361: buy 1 units at price 2.750000, total balance 9991.440000
# day 1369, sell 1 units at price 3.000000, investment 9.090909 %, total balance 9994.440000,
# day 1379: buy 1 units at price 2.900000, total balance 9991.540000
# day 1400, sell 1 units at price 2.700000, investment -6.896553 %, total balance 9994.240000,
# day 1412: buy 1 units at price 2.760000, total balance 9991.480000
# day 1424, sell 1 units at price 3.250000, investment 17.753624 %, total balance 9994.730000,
# day 1435: buy 1 units at price 3.180000, total balance 9991.550000
# day 1445, sell 1 units at price 3.130000, investment -1.572326 %, total balance 9994.680000,
# day 1454: buy 1 units at price 2.560000, total balance 9992.120000
# day 1466, sell 1 units at price 2.570000, investment 0.390625 %, total balance 9994.690000,
# day 1478: buy 1 units at price 2.650000, total balance 9992.040000
# day 1489, sell 1 units at price 2.540000, investment -4.150948 %, total balance 9994.580000,
# day 1498: buy 1 units at price 2.250000, total balance 9992.330000
# day 1508, sell 1 units at price 2.130000, investment -5.333328 %, total balance 9994.460000,
# day 1520: buy 1 units at price 2.660000, total balance 9991.800000
# day 1539, sell 1 units at price 2.690000, investment 1.127818 %, total balance 9994.490000,
# day 1550: buy 1 units at price 2.870000, total balance 9991.620000
# day 1564, sell 1 units at price 3.040000, investment 5.923348 %, total balance 9994.660000,
# day 1575: buy 1 units at price 3.110000, total balance 9991.550001
# day 1584, sell 1 units at price 3.400000, investment 9.324766 %, total balance 9994.950001,
# day 1594: buy 1 units at price 3.610000, total balance 9991.340001
# day 1606, sell 1 units at price 3.670000, investment 1.662055 %, total balance 9995.010001,
# day 1613: buy 1 units at price 3.310000, total balance 9991.700001
# day 1622, sell 1 units at price 3.620000, investment 9.365557 %, total balance 9995.320001,
# day 1630: buy 1 units at price 3.320000, total balance 9992.000001
# day 1641, sell 1 units at price 3.360000, investment 1.204818 %, total balance 9995.360001,
# day 1649: buy 1 units at price 3.250000, total balance 9992.110001
# day 1671, sell 1 units at price 1.960000, investment -39.692307 %, total balance 9994.070001,
# day 1680: buy 1 units at price 1.760000, total balance 9992.310001
# day 1695, sell 1 units at price 1.260000, investment -28.409091 %, total balance 9993.570001,
# day 1703: buy 1 units at price 0.770000, total balance 9992.800001
# day 1715, sell 1 units at price 0.700000, investment -9.090908 %, total balance 9993.500001,
# day 1728: buy 1 units at price 0.670000, total balance 9992.830001
# day 1740, sell 1 units at price 0.660000, investment -1.492536 %, total balance 9993.490001,
# day 1754: buy 1 units at price 0.850000, total balance 9992.640001

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
