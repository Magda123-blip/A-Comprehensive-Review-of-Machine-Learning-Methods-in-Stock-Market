# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../agent/cleaned_data/HCCI.csv')
df.head()
# Out:
#        Date       Open       High    Low      Close  Adj Close  Volume
# 0  1/2/2013  15.500000  16.200001  15.19  16.030001  16.030001   29300
# 1  1/3/2013  16.120001  16.260000  15.21  16.040001  16.040001   12900
# 2  1/4/2013  16.090000  16.780001  15.99  16.370001  16.370001   24300
# 3  1/7/2013  16.370001  16.450001  15.88  15.880000  15.880000   28400
# 4  1/8/2013  15.930000  16.469999  15.59  16.180000  16.180000   47800

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCCEE54188>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCCEE54188>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCCEE54188>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCCEE54188>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCCEE5DB48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCCEE5DB48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCCEE5DB48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCCEE5DB48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCD6E48808>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCD6E48808>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCD6E48808>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCD6E48808>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCD6E48808>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCD6E48808>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCD6E48808>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001BCD6E48808>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: 131.230017.3, cost: 0.008095, total money: 9212.740015
# epoch: 20, total rewards: 273.310002.3, cost: 0.007524, total money: 9261.520005
# epoch: 30, total rewards: 67.809967.3, cost: 0.010236, total money: 10067.809967
# epoch: 40, total rewards: 114.720009.3, cost: 0.000730, total money: 10083.160009
# epoch: 50, total rewards: 77.209996.3, cost: 0.000930, total money: 10046.389996
# epoch: 60, total rewards: 98.059992.3, cost: 0.000547, total money: 9787.769992
# epoch: 70, total rewards: 34.760017.3, cost: 0.000414, total money: 10003.940017
# epoch: 80, total rewards: -11.219984.3, cost: 0.000164, total money: 9988.780016
# epoch: 90, total rewards: -34.260008.3, cost: 0.000208, total money: 9934.179993
# epoch: 100, total rewards: -4.410013.3, cost: 0.000706, total money: 9900.629986
# epoch: 110, total rewards: 38.229998.3, cost: 0.000267, total money: 9912.629998
# epoch: 120, total rewards: -11.120008.3, cost: 0.000360, total money: 9956.429991
# epoch: 130, total rewards: -7.690016.3, cost: 0.000110, total money: 9992.309984
# epoch: 140, total rewards: -6.979995.3, cost: 0.000158, total money: 9961.450005
# epoch: 150, total rewards: -7.809994.3, cost: 0.000100, total money: 9992.190006
# epoch: 160, total rewards: 37.729983.3, cost: 0.000794, total money: 9882.149983
# epoch: 170, total rewards: -17.549999.3, cost: 0.000259, total money: 9982.450001
# epoch: 180, total rewards: -13.639984.3, cost: 0.000077, total money: 9986.360016
# epoch: 190, total rewards: 15.040002.3, cost: 0.000143, total money: 9982.590002
# epoch: 200, total rewards: -10.169989.3, cost: 0.000016, total money: 9989.830011

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 16.040001, total balance 9983.959999
# day 4, sell 1 unit at price 16.180000, investment 0.872814 %, total balance 10000.139999,
# day 5: buy 1 unit at price 15.500000, total balance 9984.639999
# day 8, sell 1 unit at price 14.710000, investment -5.096774 %, total balance 9999.349999,
# day 10: buy 1 unit at price 14.670000, total balance 9984.679999
# day 11, sell 1 unit at price 14.900000, investment 1.567822 %, total balance 9999.579999,
# day 12: buy 1 unit at price 14.650000, total balance 9984.929999
# day 17: buy 1 unit at price 15.560000, total balance 9969.369999
# day 20: buy 1 unit at price 15.730000, total balance 9953.639999
# day 23, sell 1 unit at price 15.810000, investment 7.918094 %, total balance 9969.450000,
# day 28: buy 1 unit at price 15.540000, total balance 9953.910000
# day 29: buy 1 unit at price 15.480000, total balance 9938.430000
# day 34: buy 1 unit at price 15.020000, total balance 9923.410000
# day 38: buy 1 unit at price 14.900000, total balance 9908.510000
# day 41: buy 1 unit at price 14.790000, total balance 9893.720000
# day 45, sell 1 unit at price 15.100000, investment -2.956298 %, total balance 9908.820001,
# day 46, sell 1 unit at price 15.150000, investment -3.687221 %, total balance 9923.970000,
# day 47: buy 1 unit at price 15.340000, total balance 9908.630000
# day 48, sell 1 unit at price 16.209999, investment 4.311449 %, total balance 9924.839999,
# day 49: buy 1 unit at price 16.000000, total balance 9908.839999
# day 51: buy 1 unit at price 15.290000, total balance 9893.549999
# day 53: buy 1 unit at price 15.720000, total balance 9877.829999
# day 56: buy 1 unit at price 15.490000, total balance 9862.339999
# day 63: buy 1 unit at price 14.640000, total balance 9847.699999
# day 64, sell 1 unit at price 14.070000, investment -9.108526 %, total balance 9861.769999,
# day 68: buy 1 unit at price 14.700000, total balance 9847.069999
# day 71, sell 1 unit at price 14.350000, investment -4.460719 %, total balance 9861.419999,
# day 73: buy 1 unit at price 13.160000, total balance 9848.259999
# day 79: buy 1 unit at price 15.240000, total balance 9833.020000
# day 80: buy 1 unit at price 15.390000, total balance 9817.629999
# day 90: buy 1 unit at price 14.520000, total balance 9803.109999
# day 92: buy 1 unit at price 14.350000, total balance 9788.759998
# day 95: buy 1 unit at price 14.590000, total balance 9774.169998
# day 98, sell 1 unit at price 14.530000, investment -2.483221 %, total balance 9788.699998,
# day 99, sell 1 unit at price 14.500000, investment -1.960784 %, total balance 9803.199998,
# day 101: buy 1 unit at price 14.850000, total balance 9788.349998
# day 105: buy 1 unit at price 15.140000, total balance 9773.209997
# day 114: buy 1 unit at price 14.680000, total balance 9758.529997
# day 116: buy 1 unit at price 15.100000, total balance 9743.429996
# day 118, sell 1 unit at price 15.260000, investment -0.521512 %, total balance 9758.689997,
# day 121: buy 1 unit at price 14.780000, total balance 9743.909997
# day 122, sell 1 unit at price 14.750000, investment -7.812500 %, total balance 9758.659997,
# day 123, sell 1 unit at price 14.610000, investment -4.447353 %, total balance 9773.269997,
# day 126: buy 1 unit at price 14.480000, total balance 9758.789997
# day 129: buy 1 unit at price 14.050000, total balance 9744.739997
# day 133, sell 1 unit at price 14.100000, investment -10.305343 %, total balance 9758.839997,
# day 144, sell 1 unit at price 15.440000, investment -0.322790 %, total balance 9774.279997,
# day 147: buy 1 unit at price 15.210000, total balance 9759.069997
# day 152, sell 1 unit at price 15.260000, investment 4.234972 %, total balance 9774.329997,
# day 158, sell 1 unit at price 15.230000, investment 3.605440 %, total balance 9789.559997,
# day 161: buy 1 unit at price 15.250000, total balance 9774.309997
# day 162, sell 1 unit at price 15.250000, investment 15.881460 %, total balance 9789.559997,
# day 163: buy 1 unit at price 15.220000, total balance 9774.339996
# day 165, sell 1 unit at price 15.240000, investment 0.000000 %, total balance 9789.579996,
# day 168: buy 1 unit at price 15.450000, total balance 9774.129996
# day 171, sell 1 unit at price 15.840000, investment 2.923975 %, total balance 9789.969996,
# day 172: buy 1 unit at price 16.340000, total balance 9773.629996
# day 176, sell 1 unit at price 16.629999, investment 14.531671 %, total balance 9790.259995,
# day 180, sell 1 unit at price 17.860001, investment 24.459931 %, total balance 9808.119996,
# day 187, sell 1 unit at price 18.000000, investment 23.372171 %, total balance 9826.119996,
# day 189: buy 1 unit at price 17.969999, total balance 9808.149997
# day 190: buy 1 unit at price 18.100000, total balance 9790.049996
# day 196, sell 1 unit at price 18.139999, investment 22.154875 %, total balance 9808.189996,
# day 197: buy 1 unit at price 18.100000, total balance 9790.089995
# day 199: buy 1 unit at price 18.120001, total balance 9771.969995
# day 203, sell 1 unit at price 18.219999, investment 20.343454 %, total balance 9790.189994,
# day 205, sell 1 unit at price 18.030001, investment 22.820166 %, total balance 9808.219995,
# day 206, sell 1 unit at price 18.430000, investment 22.052979 %, total balance 9826.649995,
# day 209: buy 1 unit at price 17.799999, total balance 9808.849996
# day 211, sell 1 unit at price 17.520000, investment 18.538571 %, total balance 9826.369996,
# day 216: buy 1 unit at price 17.820000, total balance 9808.549996
# day 218: buy 1 unit at price 18.190001, total balance 9790.359996
# day 221: buy 1 unit at price 17.610001, total balance 9772.749995
# day 223, sell 1 unit at price 17.719999, investment 22.375690 %, total balance 9790.469995,
# day 224: buy 1 unit at price 17.540001, total balance 9772.929994
# day 230: buy 1 unit at price 18.610001, total balance 9754.319993
# day 240: buy 1 unit at price 18.540001, total balance 9735.779992
# day 243, sell 1 unit at price 18.889999, investment 34.448392 %, total balance 9754.669992,
# day 249: buy 1 unit at price 19.840000, total balance 9734.829991
# day 250: buy 1 unit at price 20.520000, total balance 9714.309991
# day 255: buy 1 unit at price 19.020000, total balance 9695.289990
# day 260: buy 1 unit at price 18.260000, total balance 9677.029990
# day 262, sell 1 unit at price 17.299999, investment 13.740955 %, total balance 9694.329989,
# day 265, sell 1 unit at price 17.469999, investment 14.557373 %, total balance 9711.799989,
# day 266: buy 1 unit at price 17.400000, total balance 9694.399989
# day 281, sell 1 unit at price 17.200001, investment 13.009201 %, total balance 9711.599990,
# day 285: buy 1 unit at price 16.809999, total balance 9694.789990
# day 287: buy 1 unit at price 19.139999, total balance 9675.649991
# day 296: buy 1 unit at price 18.799999, total balance 9656.849992
# day 303, sell 1 unit at price 18.100000, investment 17.152107 %, total balance 9674.949992,
# day 308: buy 1 unit at price 18.129999, total balance 9656.819993
# day 312: buy 1 unit at price 18.129999, total balance 9638.689994
# day 314, sell 1 unit at price 17.959999, investment 9.914314 %, total balance 9656.649993,
# day 318, sell 1 unit at price 17.600000, investment -2.058981 %, total balance 9674.249993,
# day 319: buy 1 unit at price 17.490000, total balance 9656.759994
# day 320: buy 1 unit at price 17.500000, total balance 9639.259994
# day 321, sell 1 unit at price 17.040001, investment -5.856350 %, total balance 9656.299994,
# day 322: buy 1 unit at price 16.660000, total balance 9639.639995
# day 323, sell 1 unit at price 17.309999, investment -4.364646 %, total balance 9656.949994,
# day 327, sell 1 unit at price 17.200001, investment -5.077263 %, total balance 9674.149995,
# day 334, sell 1 unit at price 16.040001, investment -9.887631 %, total balance 9690.189996,
# day 335, sell 1 unit at price 15.840000, investment -11.111109 %, total balance 9706.029996,
# day 336, sell 1 unit at price 15.650000, investment -13.963721 %, total balance 9721.679996,
# day 337, sell 1 unit at price 15.000000, investment -14.821127 %, total balance 9736.679996,
# day 341, sell 1 unit at price 15.220000, investment -13.226913 %, total balance 9751.899996,
# day 345, sell 1 unit at price 15.240000, investment -18.108548 %, total balance 9767.139996,
# day 346, sell 1 unit at price 15.420000, investment -16.828483 %, total balance 9782.559996,
# day 348: buy 1 unit at price 15.750000, total balance 9766.809996
# day 355: buy 1 unit at price 16.969999, total balance 9749.839996
# day 360, sell 1 unit at price 17.290001, investment -12.852819 %, total balance 9767.129997,
# day 364: buy 1 unit at price 17.080000, total balance 9750.049997
# day 369: buy 1 unit at price 17.570000, total balance 9732.479998
# day 379, sell 1 unit at price 18.379999, investment -10.428856 %, total balance 9750.859997,
# day 380, sell 1 unit at price 17.709999, investment -6.887494 %, total balance 9768.569996,
# day 381, sell 1 unit at price 17.530001, investment -3.997807 %, total balance 9786.099997,
# day 382, sell 1 unit at price 17.170000, investment -1.321836 %, total balance 9803.269997,
# day 384, sell 1 unit at price 17.309999, investment 2.974420 %, total balance 9820.579996,
# day 388: buy 1 unit at price 17.129999, total balance 9803.449997
# day 396: buy 1 unit at price 17.549999, total balance 9785.899998
# day 397: buy 1 unit at price 16.959999, total balance 9768.939999
# day 400, sell 1 unit at price 17.139999, investment -10.449321 %, total balance 9786.079998,
# day 402, sell 1 unit at price 16.820000, investment -10.531913 %, total balance 9802.899998,
# day 404, sell 1 unit at price 16.670000, investment -8.052946 %, total balance 9819.569998,
# day 409, sell 1 unit at price 15.990000, investment -11.803638 %, total balance 9835.559998,
# day 412: buy 1 unit at price 15.540000, total balance 9820.019998
# day 414: buy 1 unit at price 15.020000, total balance 9804.999997
# day 415, sell 1 unit at price 15.200000, investment -13.093196 %, total balance 9820.199997,
# day 418, sell 1 unit at price 16.010000, investment -8.514284 %, total balance 9836.209997,
# day 422: buy 1 unit at price 16.889999, total balance 9819.319998
# day 423, sell 1 unit at price 16.670000, investment 0.060025 %, total balance 9835.989998,
# day 426, sell 1 unit at price 16.240000, investment 3.111110 %, total balance 9852.229998,
# day 430, sell 1 unit at price 15.460000, investment -8.898051 %, total balance 9867.689998,
# day 432, sell 1 unit at price 15.630000, investment -8.489460 %, total balance 9883.319998,
# day 438: buy 1 unit at price 14.530000, total balance 9868.789998
# day 442: buy 1 unit at price 14.700000, total balance 9854.089998
# day 443, sell 1 unit at price 14.300000, investment -18.611267 %, total balance 9868.389998,
# day 446, sell 1 unit at price 14.270000, investment -16.695848 %, total balance 9882.659999,
# day 447: buy 1 unit at price 14.180000, total balance 9868.479999
# day 448: buy 1 unit at price 14.620000, total balance 9853.859999
# day 460: buy 1 unit at price 18.330000, total balance 9835.529999
# day 461: buy 1 unit at price 18.559999, total balance 9816.969999
# day 468: buy 1 unit at price 18.559999, total balance 9798.410000
# day 474, sell 1 unit at price 17.600000, investment 0.284907 %, total balance 9816.010000,
# day 475: buy 1 unit at price 17.650000, total balance 9798.360001
# day 479: buy 1 unit at price 17.520000, total balance 9780.840000
# day 484, sell 1 unit at price 15.190000, investment -10.436318 %, total balance 9796.030000,
# day 485: buy 1 unit at price 14.210000, total balance 9781.820000
# day 487, sell 1 unit at price 13.620000, investment -12.355213 %, total balance 9795.440000,
# day 490, sell 1 unit at price 10.900000, investment -27.430098 %, total balance 9806.339999,
# day 491, sell 1 unit at price 9.730000, investment -42.391949 %, total balance 9816.069999,
# day 492: buy 1 unit at price 10.090000, total balance 9805.979999
# day 497: buy 1 unit at price 11.900000, total balance 9794.079999
# day 500: buy 1 unit at price 12.030000, total balance 9782.049999
# day 505, sell 1 unit at price 12.040000, investment -17.136957 %, total balance 9794.089999,
# day 506: buy 1 unit at price 12.200000, total balance 9781.889999
# day 509, sell 1 unit at price 12.380000, investment -15.782311 %, total balance 9794.270000,
# day 512, sell 1 unit at price 12.540000, investment -11.565588 %, total balance 9806.809999,
# day 513, sell 1 unit at price 12.570000, investment -14.021889 %, total balance 9819.379999,
# day 523: buy 1 unit at price 12.750000, total balance 9806.629999
# day 524, sell 1 unit at price 12.910000, investment -29.569013 %, total balance 9819.539999,
# day 526, sell 1 unit at price 12.410000, investment -33.135775 %, total balance 9831.949999,
# day 527: buy 1 unit at price 12.860000, total balance 9819.089999
# day 530, sell 1 unit at price 12.730000, investment -31.411638 %, total balance 9831.819999,
# day 532: buy 1 unit at price 12.190000, total balance 9819.629999
# day 537, sell 1 unit at price 12.500000, investment -29.178469 %, total balance 9832.129999,
# day 541, sell 1 unit at price 12.600000, investment -28.082192 %, total balance 9844.730000,
# day 551: buy 1 unit at price 13.040000, total balance 9831.690000
# day 553, sell 1 unit at price 13.110000, investment -7.741030 %, total balance 9844.799999,
# day 554, sell 1 unit at price 13.040000, investment 29.236866 %, total balance 9857.839999,
# day 557: buy 1 unit at price 12.130000, total balance 9845.709999
# day 563, sell 1 unit at price 12.080000, investment 1.512608 %, total balance 9857.789999,
# day 568: buy 1 unit at price 12.940000, total balance 9844.849999
# day 570, sell 1 unit at price 13.340000, investment 10.889447 %, total balance 9858.190000,
# day 576: buy 1 unit at price 12.810000, total balance 9845.379999
# day 577: buy 1 unit at price 12.740000, total balance 9832.639999
# day 578, sell 1 unit at price 12.270000, investment 0.573776 %, total balance 9844.910000,
# day 583: buy 1 unit at price 12.030000, total balance 9832.880000
# day 587: buy 1 unit at price 11.510000, total balance 9821.370000
# day 594, sell 1 unit at price 12.990000, investment 1.882351 %, total balance 9834.360000,
# day 595: buy 1 unit at price 13.160000, total balance 9821.200000
# day 600, sell 1 unit at price 13.780000, investment 7.153967 %, total balance 9834.980000,
# day 603, sell 1 unit at price 13.850000, investment 13.617726 %, total balance 9848.830000,
# day 609: buy 1 unit at price 15.320000, total balance 9833.510000
# day 614: buy 1 unit at price 15.360000, total balance 9818.150001
# day 628: buy 1 unit at price 14.710000, total balance 9803.440001
# day 630: buy 1 unit at price 14.190000, total balance 9789.250001
# day 633: buy 1 unit at price 13.410000, total balance 9775.840001
# day 639, sell 1 unit at price 14.170000, investment 8.665645 %, total balance 9790.010001,
# day 646: buy 1 unit at price 12.760000, total balance 9777.250001
# day 648, sell 1 unit at price 12.630000, investment 4.122012 %, total balance 9789.880001,
# day 649: buy 1 unit at price 12.850000, total balance 9777.030001
# day 655: buy 1 unit at price 12.390000, total balance 9764.640000
# day 657: buy 1 unit at price 12.680000, total balance 9751.960000
# day 659, sell 1 unit at price 12.700000, investment -1.854712 %, total balance 9764.660000,
# day 660: buy 1 unit at price 12.850000, total balance 9751.809999
# day 662, sell 1 unit at price 12.110000, investment -5.464487 %, total balance 9763.919999,
# day 663, sell 1 unit at price 11.760000, investment -7.692304 %, total balance 9775.679999,
# day 666, sell 1 unit at price 10.490000, investment -12.801330 %, total balance 9786.169999,
# day 667, sell 1 unit at price 11.000000, investment -4.430932 %, total balance 9797.169999,
# day 673: buy 1 unit at price 11.720000, total balance 9785.449999
# day 674: buy 1 unit at price 11.570000, total balance 9773.879999
# day 679: buy 1 unit at price 11.360000, total balance 9762.520000
# day 681: buy 1 unit at price 11.870000, total balance 9750.650000
# day 682, sell 1 unit at price 11.930000, investment -9.346501 %, total balance 9762.580000,
# day 685, sell 1 unit at price 11.210000, investment -26.827674 %, total balance 9773.790000,
# day 686: buy 1 unit at price 11.230000, total balance 9762.560000
# day 689, sell 1 unit at price 10.600000, investment -30.989579 %, total balance 9773.160001,
# day 695, sell 1 unit at price 10.040000, investment -31.747111 %, total balance 9783.200001,
# day 708, sell 1 unit at price 12.490000, investment -11.980267 %, total balance 9795.690001,
# day 711, sell 1 unit at price 11.990000, investment -10.589113 %, total balance 9807.680000,
# day 712, sell 1 unit at price 11.960000, investment -6.269594 %, total balance 9819.640000,
# day 716, sell 1 unit at price 11.940000, investment -7.081718 %, total balance 9831.580000,
# day 719: buy 1 unit at price 11.330000, total balance 9820.250000
# day 724: buy 1 unit at price 10.900000, total balance 9809.350000
# day 728: buy 1 unit at price 10.490000, total balance 9798.860001
# day 739, sell 1 unit at price 10.020000, investment -19.128328 %, total balance 9808.880001,
# day 742: buy 1 unit at price 9.810000, total balance 9799.070001
# day 746, sell 1 unit at price 9.520000, investment -24.921134 %, total balance 9808.590001,
# day 753: buy 1 unit at price 10.370000, total balance 9798.220001
# day 755: buy 1 unit at price 10.600000, total balance 9787.620001
# day 756: buy 1 unit at price 10.270000, total balance 9777.350000
# day 757, sell 1 unit at price 10.400000, investment -19.066153 %, total balance 9787.750000,
# day 761, sell 1 unit at price 9.540000, investment -18.600685 %, total balance 9797.290000,
# day 762, sell 1 unit at price 8.800000, investment -23.941224 %, total balance 9806.090000,
# day 763: buy 1 unit at price 8.390000, total balance 9797.700000
# day 766, sell 1 unit at price 8.530000, investment -24.911972 %, total balance 9806.230000,
# day 767, sell 1 unit at price 9.040000, investment -23.841617 %, total balance 9815.270000,
# day 768, sell 1 unit at price 9.110000, investment -18.878005 %, total balance 9824.379999,
# day 771: buy 1 unit at price 9.680000, total balance 9814.699999
# day 776: buy 1 unit at price 8.860000, total balance 9805.839999
# day 777, sell 1 unit at price 8.670000, investment -23.477492 %, total balance 9814.509999,
# day 779: buy 1 unit at price 8.180000, total balance 9806.329999
# day 781: buy 1 unit at price 8.090000, total balance 9798.239999
# day 786: buy 1 unit at price 8.010000, total balance 9790.229999
# day 792, sell 1 unit at price 7.450000, investment -31.651376 %, total balance 9797.679998,
# day 795: buy 1 unit at price 8.010000, total balance 9789.669998
# day 802: buy 1 unit at price 8.480000, total balance 9781.189999
# day 813, sell 1 unit at price 9.080000, investment -13.441372 %, total balance 9790.269999,
# day 815: buy 1 unit at price 9.730000, total balance 9780.539999
# day 816: buy 1 unit at price 9.940000, total balance 9770.599999
# day 819: buy 1 unit at price 10.050000, total balance 9760.549999
# day 828, sell 1 unit at price 10.780000, investment 9.887862 %, total balance 9771.329999,
# day 831: buy 1 unit at price 10.790000, total balance 9760.539999
# day 834, sell 1 unit at price 10.860000, investment 4.725167 %, total balance 9771.399999,
# day 838: buy 1 unit at price 10.590000, total balance 9760.809999
# day 839: buy 1 unit at price 10.570000, total balance 9750.239999
# day 850, sell 1 unit at price 10.090000, investment -4.811323 %, total balance 9760.329999,
# day 855, sell 1 unit at price 11.530000, investment 12.268736 %, total balance 9771.859999,
# day 857: buy 1 unit at price 11.470000, total balance 9760.389998
# day 863, sell 1 unit at price 12.050000, investment 43.623358 %, total balance 9772.439999,
# day 864, sell 1 unit at price 12.430000, investment 28.409090 %, total balance 9784.869999,
# day 873, sell 1 unit at price 13.100000, investment 47.855540 %, total balance 9797.969999,
# day 882: buy 1 unit at price 12.000000, total balance 9785.969999
# day 884: buy 1 unit at price 12.300000, total balance 9773.669999
# day 885: buy 1 unit at price 12.500000, total balance 9761.169999
# day 895, sell 1 unit at price 12.430000, investment 51.955988 %, total balance 9773.599999,
# day 900: buy 1 unit at price 12.610000, total balance 9760.990000
# day 903: buy 1 unit at price 12.710000, total balance 9748.280000
# day 906: buy 1 unit at price 12.840000, total balance 9735.440000
# day 907: buy 1 unit at price 12.800000, total balance 9722.639999
# day 912: buy 1 unit at price 12.480000, total balance 9710.160000
# day 916, sell 1 unit at price 12.310000, investment 52.163167 %, total balance 9722.470000,
# day 929: buy 1 unit at price 12.750000, total balance 9709.720000
# day 932, sell 1 unit at price 13.020000, investment 62.546818 %, total balance 9722.740001,
# day 934: buy 1 unit at price 13.210000, total balance 9709.530001
# day 941, sell 1 unit at price 13.170000, investment 64.419472 %, total balance 9722.700001,
# day 945: buy 1 unit at price 13.420000, total balance 9709.280001
# day 946, sell 1 unit at price 13.300000, investment 56.839633 %, total balance 9722.580001,
# day 955: buy 1 unit at price 13.000000, total balance 9709.580001
# day 956: buy 1 unit at price 13.000000, total balance 9696.580001
# day 957, sell 1 unit at price 13.100000, investment 34.635159 %, total balance 9709.680001,
# day 959: buy 1 unit at price 12.650000, total balance 9697.030002
# day 960, sell 1 unit at price 13.350000, investment 34.305845 %, total balance 9710.380002,
# day 965, sell 1 unit at price 13.100000, investment 30.348260 %, total balance 9723.480002,
# day 967, sell 1 unit at price 13.000000, investment 20.481928 %, total balance 9736.480002,
# day 970, sell 1 unit at price 13.250000, investment 25.118034 %, total balance 9749.730002,
# day 971: buy 1 unit at price 13.400000, total balance 9736.330003
# day 977: buy 1 unit at price 15.000000, total balance 9721.330003
# day 978, sell 1 unit at price 14.950000, investment 41.438035 %, total balance 9736.280003,
# day 981: buy 1 unit at price 15.400000, total balance 9720.880003
# day 982: buy 1 unit at price 15.950000, total balance 9704.930003
# day 984, sell 1 unit at price 16.400000, investment 42.981685 %, total balance 9721.330003,
# day 987, sell 1 unit at price 16.049999, investment 33.749994 %, total balance 9737.380002,
# day 988, sell 1 unit at price 14.800000, investment 20.325203 %, total balance 9752.180002,
# day 991, sell 1 unit at price 15.900000, investment 27.199997 %, total balance 9768.080002,
# day 994: buy 1 unit at price 15.450000, total balance 9752.630002
# day 995, sell 1 unit at price 15.400000, investment 22.125298 %, total balance 9768.030002,
# day 997, sell 1 unit at price 14.650000, investment 15.263569 %, total balance 9782.680001,
# day 1002, sell 1 unit at price 15.800000, investment 23.052960 %, total balance 9798.480001,
# day 1004: buy 1 unit at price 15.800000, total balance 9782.680001
# day 1005, sell 1 unit at price 15.850000, investment 23.828126 %, total balance 9798.530002,
# day 1006, sell 1 unit at price 15.600000, investment 25.000008 %, total balance 9814.130002,
# day 1009: buy 1 unit at price 15.500000, total balance 9798.630002
# day 1010, sell 1 unit at price 15.400000, investment 20.784311 %, total balance 9814.030002,
# day 1011, sell 1 unit at price 15.100000, investment 14.307345 %, total balance 9829.130002,
# day 1017: buy 1 unit at price 14.500000, total balance 9814.630002
# day 1018, sell 1 unit at price 14.500000, investment 8.047689 %, total balance 9829.130002,
# day 1022: buy 1 unit at price 15.150000, total balance 9813.980002
# day 1028, sell 1 unit at price 15.000000, investment 15.384615 %, total balance 9828.980002,
# day 1030, sell 1 unit at price 15.050000, investment 15.769232 %, total balance 9844.030003,
# day 1040: buy 1 unit at price 15.400000, total balance 9828.630003
# day 1042, sell 1 unit at price 15.100000, investment 19.367596 %, total balance 9843.730003,
# day 1044, sell 1 unit at price 15.050000, investment 12.313437 %, total balance 9858.780004,
# day 1047, sell 1 unit at price 15.750000, investment 5.000000 %, total balance 9874.530004,
# day 1048: buy 1 unit at price 14.700000, total balance 9859.830004
# day 1052: buy 1 unit at price 13.750000, total balance 9846.080004
# day 1055, sell 1 unit at price 13.900000, investment -9.740260 %, total balance 9859.980003,
# day 1061, sell 1 unit at price 13.200000, investment -17.241380 %, total balance 9873.180003,
# day 1062, sell 1 unit at price 13.100000, investment -15.210352 %, total balance 9886.280004,
# day 1081: buy 1 unit at price 14.600000, total balance 9871.680003
# day 1082, sell 1 unit at price 14.350000, investment -9.177214 %, total balance 9886.030004,
# day 1083: buy 1 unit at price 14.400000, total balance 9871.630004
# day 1084: buy 1 unit at price 15.650000, total balance 9855.980004
# day 1086, sell 1 unit at price 15.850000, investment 2.258067 %, total balance 9871.830005,
# day 1087, sell 1 unit at price 15.700000, investment 8.275861 %, total balance 9887.530004,
# day 1091, sell 1 unit at price 15.300000, investment 0.990103 %, total balance 9902.830005,
# day 1096: buy 1 unit at price 15.750000, total balance 9887.080005
# day 1097, sell 1 unit at price 16.000000, investment 3.896106 %, total balance 9903.080005,
# day 1100: buy 1 unit at price 15.600000, total balance 9887.480004
# day 1101, sell 1 unit at price 15.600000, investment 6.122453 %, total balance 9903.080005,
# day 1105: buy 1 unit at price 16.000000, total balance 9887.080005
# day 1107: buy 1 unit at price 15.550000, total balance 9871.530004
# day 1117, sell 1 unit at price 15.500000, investment 12.727273 %, total balance 9887.030004,
# day 1123: buy 1 unit at price 15.000000, total balance 9872.030004
# day 1126, sell 1 unit at price 15.250000, investment 4.452052 %, total balance 9887.280004,
# day 1127, sell 1 unit at price 15.300000, investment 6.250004 %, total balance 9902.580005,
# day 1128: buy 1 unit at price 15.350000, total balance 9887.230004
# day 1129, sell 1 unit at price 15.550000, investment -0.638974 %, total balance 9902.780004,
# day 1130: buy 1 unit at price 16.000000, total balance 9886.780004
# day 1138: buy 1 unit at price 16.250000, total balance 9870.530004
# day 1144, sell 1 unit at price 16.000000, investment 1.587302 %, total balance 9886.530004,
# day 1145, sell 1 unit at price 16.100000, investment 3.205128 %, total balance 9902.630005,
# day 1146: buy 1 unit at price 16.200001, total balance 9886.430004
# day 1154, sell 1 unit at price 18.900000, investment 18.124998 %, total balance 9905.330004,
# day 1155, sell 1 unit at price 18.750000, investment 20.578777 %, total balance 9924.080004,
# day 1156, sell 1 unit at price 18.700001, investment 24.666672 %, total balance 9942.780004,
# day 1160: buy 1 unit at price 18.549999, total balance 9924.230005
# day 1162: buy 1 unit at price 18.850000, total balance 9905.380005
# day 1166, sell 1 unit at price 18.299999, investment 19.218233 %, total balance 9923.680004,
# day 1167: buy 1 unit at price 18.200001, total balance 9905.480003
# day 1168: buy 1 unit at price 18.150000, total balance 9887.330004
# day 1176, sell 1 unit at price 20.250000, investment 26.562500 %, total balance 9907.580004,
# day 1179, sell 1 unit at price 20.500000, investment 26.153846 %, total balance 9928.080004,
# day 1184, sell 1 unit at price 20.049999, investment 23.765422 %, total balance 9948.130003,
# day 1185: buy 1 unit at price 20.250000, total balance 9927.880003
# day 1188, sell 1 unit at price 20.650000, investment 11.320757 %, total balance 9948.530003,
# day 1189, sell 1 unit at price 20.500000, investment 8.753313 %, total balance 9969.030003,
# day 1190: buy 1 unit at price 20.500000, total balance 9948.530003
# day 1192, sell 1 unit at price 20.799999, investment 14.285705 %, total balance 9969.330002,
# day 1194: buy 1 unit at price 21.750000, total balance 9947.580002
# day 1195: buy 1 unit at price 21.750000, total balance 9925.830002
# day 1196, sell 1 unit at price 21.850000, investment 20.385680 %, total balance 9947.680002,
# day 1198: buy 1 unit at price 21.549999, total balance 9926.130003
# day 1200: buy 1 unit at price 21.250000, total balance 9904.880003
# day 1202, sell 1 unit at price 21.450001, investment 5.925930 %, total balance 9926.330004,
# day 1204, sell 1 unit at price 21.549999, investment 5.121948 %, total balance 9947.880003,
# day 1212: buy 1 unit at price 19.400000, total balance 9928.480003
# day 1213: buy 1 unit at price 19.200001, total balance 9909.280003
# day 1215, sell 1 unit at price 19.200001, investment -11.724134 %, total balance 9928.480003,
# day 1220: buy 1 unit at price 20.000000, total balance 9908.480003
# day 1225, sell 1 unit at price 19.250000, investment -11.494253 %, total balance 9927.730003,
# day 1227, sell 1 unit at price 19.200001, investment -10.904866 %, total balance 9946.930004,
# day 1229, sell 1 unit at price 18.400000, investment -13.411766 %, total balance 9965.330004,
# day 1233: buy 1 unit at price 18.950001, total balance 9946.380003
# day 1246: buy 1 unit at price 19.799999, total balance 9926.580004
# day 1250, sell 1 unit at price 21.549999, investment 11.082472 %, total balance 9948.130003,
# day 1251, sell 1 unit at price 21.150000, investment 10.156244 %, total balance 9969.280003,
# day 1259: buy 1 unit at price 21.900000, total balance 9947.380003
# day 1262, sell 1 unit at price 22.549999, investment 12.749996 %, total balance 9969.930002,
# day 1264: buy 1 unit at price 22.400000, total balance 9947.530003
# day 1272, sell 1 unit at price 22.850000, investment 20.580472 %, total balance 9970.380003,
# day 1276, sell 1 unit at price 22.750000, investment 14.898994 %, total balance 9993.130003,
# day 1280: buy 1 unit at price 21.799999, total balance 9971.330004
# day 1283: buy 1 unit at price 20.650000, total balance 9950.680004
# day 1285: buy 1 unit at price 19.950001, total balance 9930.730003
# day 1288: buy 1 unit at price 19.900000, total balance 9910.830004
# day 1290: buy 1 unit at price 20.500000, total balance 9890.330004
# day 1308: buy 1 unit at price 23.350000, total balance 9866.980003
# day 1309, sell 1 unit at price 23.200001, investment 5.936078 %, total balance 9890.180004,
# day 1310: buy 1 unit at price 23.799999, total balance 9866.380005
# day 1315, sell 1 unit at price 22.799999, investment 1.785713 %, total balance 9889.180004,
# day 1316: buy 1 unit at price 23.350000, total balance 9865.830004
# day 1319, sell 1 unit at price 23.549999, investment 8.027523 %, total balance 9889.380003,
# day 1330, sell 1 unit at price 22.200001, investment 7.506059 %, total balance 9911.580004,
# day 1337: buy 1 unit at price 22.650000, total balance 9888.930004
# day 1342: buy 1 unit at price 20.650000, total balance 9868.280004
# day 1345: buy 1 unit at price 19.750000, total balance 9848.530004
# day 1346: buy 1 unit at price 20.400000, total balance 9828.130005
# day 1352: buy 1 unit at price 19.700001, total balance 9808.430004
# day 1355, sell 1 unit at price 20.400000, investment 2.255633 %, total balance 9828.830004,
# day 1358, sell 1 unit at price 20.250000, investment 1.758796 %, total balance 9849.080004,
# day 1364, sell 1 unit at price 20.600000, investment 0.487807 %, total balance 9869.680004,
# day 1366: buy 1 unit at price 20.750000, total balance 9848.930004
# day 1370: buy 1 unit at price 20.250000, total balance 9828.680004
# day 1373, sell 1 unit at price 19.150000, investment -17.987155 %, total balance 9847.830004,
# day 1375: buy 1 unit at price 19.750000, total balance 9828.080004
# day 1381: buy 1 unit at price 20.000000, total balance 9808.080004
# day 1384: buy 1 unit at price 20.350000, total balance 9787.730003
# day 1387: buy 1 unit at price 20.150000, total balance 9767.580004
# day 1396: buy 1 unit at price 19.350000, total balance 9748.230003
# day 1398, sell 1 unit at price 19.200001, investment -19.327725 %, total balance 9767.430004,
# day 1401, sell 1 unit at price 23.900000, investment 2.355457 %, total balance 9791.330004,
# day 1404: buy 1 unit at price 24.100000, total balance 9767.230003
# day 1409: buy 1 unit at price 23.799999, total balance 9743.430004
# day 1421, sell 1 unit at price 23.600000, investment 4.194264 %, total balance 9767.030004,
# day 1424: buy 1 unit at price 22.750000, total balance 9744.280004
# day 1426: buy 1 unit at price 23.500000, total balance 9720.780004
# day 1427, sell 1 unit at price 23.299999, investment 12.832928 %, total balance 9744.080004,
# day 1430, sell 1 unit at price 23.000000, investment 16.455696 %, total balance 9767.080004,
# day 1438, sell 1 unit at price 21.000000, investment 2.941178 %, total balance 9788.080004,
# day 1442: buy 1 unit at price 20.500000, total balance 9767.580004
# day 1448: buy 1 unit at price 20.549999, total balance 9747.030004
# day 1453, sell 1 unit at price 20.440001, investment 3.756344 %, total balance 9767.470005,
# day 1463: buy 1 unit at price 22.850000, total balance 9744.620005
# day 1465, sell 1 unit at price 22.959999, investment 10.650598 %, total balance 9767.580004,
# day 1473: buy 1 unit at price 22.719999, total balance 9744.860004
# day 1475, sell 1 unit at price 23.700001, investment 17.037041 %, total balance 9768.560005,
# day 1479: buy 1 unit at price 24.650000, total balance 9743.910006
# day 1490, sell 1 unit at price 28.010000, investment 41.822786 %, total balance 9771.920006,
# day 1493: buy 1 unit at price 25.969999, total balance 9745.950006
# day 1494: buy 1 unit at price 25.620001, total balance 9720.330006
# day 1495: buy 1 unit at price 24.900000, total balance 9695.430006
# day 1500: buy 1 unit at price 25.000000, total balance 9670.430006
# day 1507, sell 1 unit at price 21.910000, investment 9.549999 %, total balance 9692.340006,
# day 1528: buy 1 unit at price 25.620001, total balance 9666.720005
# day 1536: buy 1 unit at price 24.620001, total balance 9642.100004
# day 1537, sell 1 unit at price 25.010000, investment 22.899262 %, total balance 9667.110004,
# day 1539, sell 1 unit at price 25.510000, investment 26.600500 %, total balance 9692.620005,
# day 1540, sell 1 unit at price 25.379999, investment 31.162784 %, total balance 9718.000004,
# day 1541: buy 1 unit at price 26.030001, total balance 9691.970003
# day 1542, sell 1 unit at price 26.379999, investment 9.460576 %, total balance 9718.350002,
# day 1549: buy 1 unit at price 24.160000, total balance 9694.190002
# day 1550: buy 1 unit at price 25.030001, total balance 9669.160002
# day 1551: buy 1 unit at price 25.160000, total balance 9644.000002
# day 1554: buy 1 unit at price 25.250000, total balance 9618.750002
# day 1555, sell 1 unit at price 24.290001, investment 2.058831 %, total balance 9643.040003,
# day 1556: buy 1 unit at price 24.209999, total balance 9618.830004
# day 1558, sell 1 unit at price 23.820000, investment 4.703295 %, total balance 9642.650003,
# day 1559, sell 1 unit at price 24.340000, investment 3.574469 %, total balance 9666.990004,
# day 1566, sell 1 unit at price 26.240000, investment 27.999999 %, total balance 9693.230003,
# day 1570, sell 1 unit at price 27.450001, investment 33.576651 %, total balance 9720.680004,
# day 1571, sell 1 unit at price 27.540001, investment 20.525166 %, total balance 9748.220005,
# day 1572: buy 1 unit at price 26.190001, total balance 9722.030004
# day 1574: buy 1 unit at price 26.410000, total balance 9695.620005
# day 1576, sell 1 unit at price 26.150000, investment 15.096833 %, total balance 9721.770004,
# day 1577: buy 1 unit at price 25.719999, total balance 9696.050005
# day 1579, sell 1 unit at price 26.410000, investment 7.139960 %, total balance 9722.460005,
# day 1583: buy 1 unit at price 27.270000, total balance 9695.190004
# day 1589, sell 1 unit at price 27.930000, investment 7.547174 %, total balance 9723.120005,
# day 1592, sell 1 unit at price 28.750000, investment 12.217014 %, total balance 9751.870005,
# day 1598, sell 1 unit at price 27.680000, investment 11.164662 %, total balance 9779.550005,
# day 1599: buy 1 unit at price 28.110001, total balance 9751.440004
# day 1604: buy 1 unit at price 27.840000, total balance 9723.600004
# day 1605, sell 1 unit at price 27.879999, investment 11.519997 %, total balance 9751.480003,
# day 1606, sell 1 unit at price 27.860001, investment 8.743168 %, total balance 9779.340004,
# day 1610, sell 1 unit at price 26.379999, investment 7.148653 %, total balance 9805.720003,
# day 1613: buy 1 unit at price 25.000000, total balance 9780.720003
# day 1614, sell 1 unit at price 25.389999, investment -2.458706 %, total balance 9806.110003,
# day 1615, sell 1 unit at price 25.440001, investment 5.298016 %, total balance 9831.550003,
# day 1627, sell 1 unit at price 26.440001, investment 5.633239 %, total balance 9857.990004,
# day 1630: buy 1 unit at price 25.680000, total balance 9832.310003
# day 1631, sell 1 unit at price 24.940001, investment -0.874401 %, total balance 9857.250004,
# day 1632, sell 1 unit at price 26.160000, investment 3.603960 %, total balance 9883.410004,
# day 1647: buy 1 unit at price 27.370001, total balance 9856.040003
# day 1648, sell 1 unit at price 27.629999, investment 14.126395 %, total balance 9883.670002,
# day 1650: buy 1 unit at price 28.510000, total balance 9855.160002
# day 1653, sell 1 unit at price 28.040001, investment 7.063766 %, total balance 9883.200003,
# day 1655, sell 1 unit at price 28.049999, investment 6.209767 %, total balance 9911.250002,
# day 1656, sell 1 unit at price 28.000000, investment 8.864700 %, total balance 9939.250002,
# day 1664, sell 1 unit at price 25.930000, investment -4.913825 %, total balance 9965.180002,
# day 1665: buy 1 unit at price 25.090000, total balance 9940.090002
# day 1666: buy 1 unit at price 25.340000, total balance 9914.750002
# day 1667: buy 1 unit at price 26.340000, total balance 9888.410002
# day 1669, sell 1 unit at price 25.100000, investment -10.707934 %, total balance 9913.510002,
# day 1672: buy 1 unit at price 24.709999, total balance 9888.800003
# day 1674, sell 1 unit at price 24.240000, investment -12.931036 %, total balance 9913.040003,
# day 1677: buy 1 unit at price 24.500000, total balance 9888.540003
# day 1691: buy 1 unit at price 26.059999, total balance 9862.480003
# day 1693: buy 1 unit at price 25.650000, total balance 9836.830004
# day 1695: buy 1 unit at price 26.180000, total balance 9810.650003
# day 1696, sell 1 unit at price 26.270000, investment 5.080002 %, total balance 9836.920004,
# day 1698, sell 1 unit at price 26.110001, investment 1.674456 %, total balance 9863.030004,
# day 1700, sell 1 unit at price 25.270000, investment -7.672635 %, total balance 9888.300005,
# day 1706, sell 1 unit at price 25.740000, investment -9.715891 %, total balance 9914.040005,
# day 1713: buy 1 unit at price 26.969999, total balance 9887.070005
# day 1715: buy 1 unit at price 25.740000, total balance 9861.330006
# day 1717, sell 1 unit at price 25.990000, investment 3.587085 %, total balance 9887.320005,
# day 1718: buy 1 unit at price 26.090000, total balance 9861.230005
# day 1720, sell 1 unit at price 26.540001, investment 4.735599 %, total balance 9887.770006,
# day 1721: buy 1 unit at price 27.219999, total balance 9860.550007
# day 1722, sell 1 unit at price 27.959999, investment 6.150338 %, total balance 9888.510006,
# day 1724: buy 1 unit at price 27.840000, total balance 9860.670006
# day 1725: buy 1 unit at price 27.980000, total balance 9832.690006
# day 1727, sell 1 unit at price 28.120001, investment 13.800089 %, total balance 9860.810007,
# day 1730, sell 1 unit at price 27.930000, investment 14.000001 %, total balance 9888.740007,
# day 1735, sell 1 unit at price 28.340000, investment 8.749043 %, total balance 9917.080008,
# day 1737: buy 1 unit at price 30.170000, total balance 9886.910007
# day 1740, sell 1 unit at price 30.930000, investment 20.584798 %, total balance 9917.840008,
# day 1742: buy 1 unit at price 30.549999, total balance 9887.290009

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
