# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../agent/cleaned_data/LUNA.csv')
df.head()
# Out:
#        Date  Open  High   Low  Close  Adj Close  Volume
# 0  1/2/2013  1.18  1.32  1.18   1.25       1.25   11700
# 1  1/3/2013  1.22  1.24  1.16   1.17       1.17   15800
# 2  1/4/2013  1.18  1.23  1.18   1.22       1.22    5600
# 3  1/7/2013  1.22  1.22  1.20   1.22       1.22    2500
# 4  1/8/2013  1.24  1.32  1.20   1.30       1.30    8500

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2BE510988>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2BE510988>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2BE510988>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2BE510988>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2BE510988>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2BE510988>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2BE510988>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2BE510988>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2E84B91C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2E84B91C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2E84B91C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2E84B91C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2E0B43D08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2E0B43D08>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2E0B43D08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001D2E0B43D08>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: 106.859999.3, cost: 0.000022, total money: 9989.019999
# epoch: 20, total rewards: 138.120000.3, cost: 0.000121, total money: 10048.560000
# epoch: 30, total rewards: 42.630000.3, cost: 0.000240, total money: 9909.890000
# epoch: 40, total rewards: 110.129997.3, cost: 0.000043, total money: 10030.919998
# epoch: 50, total rewards: 18.739998.3, cost: 0.000048, total money: 10018.739998
# epoch: 60, total rewards: 121.969999.3, cost: 0.000069, total money: 10072.259999
# epoch: 70, total rewards: 10.900000.3, cost: 0.000096, total money: 9996.170000
# epoch: 80, total rewards: 6.990003.3, cost: 0.000025, total money: 10006.990003
# epoch: 90, total rewards: -12.070000.3, cost: 0.000003, total money: 9973.150000
# epoch: 100, total rewards: 15.000001.3, cost: 0.000068, total money: 10015.000001
# epoch: 110, total rewards: 58.600001.3, cost: 0.000130, total money: 10016.970001
# epoch: 120, total rewards: 13.579998.3, cost: 0.000033, total money: 10006.229998
# epoch: 130, total rewards: 5.729997.3, cost: 0.000016, total money: 9998.439997
# epoch: 140, total rewards: 5.570000.3, cost: 0.000004, total money: 10005.570000
# epoch: 150, total rewards: 45.100000.3, cost: 0.000023, total money: 10037.670000
# epoch: 160, total rewards: 14.590000.3, cost: 0.000066, total money: 10000.100000
# epoch: 170, total rewards: -0.239999.3, cost: 0.000002, total money: 9999.760001
# epoch: 180, total rewards: 20.010002.3, cost: 0.000038, total money: 10005.240002
# epoch: 190, total rewards: 0.229997.3, cost: 0.000013, total money: 9992.939997
# epoch: 200, total rewards: 12.130001.3, cost: 0.000071, total money: 9990.050001

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 10: buy 1 unit at price 1.270000, total balance 9998.730000
# day 17, sell 1 unit at price 1.320000, investment 3.937014 %, total balance 10000.050000,
# day 25: buy 1 unit at price 1.220000, total balance 9998.830000
# day 28: buy 1 unit at price 1.270000, total balance 9997.560000
# day 31, sell 1 unit at price 1.210000, investment -0.819671 %, total balance 9998.770000,
# day 37: buy 1 unit at price 1.190000, total balance 9997.580000
# day 39, sell 1 unit at price 1.170000, investment -7.874018 %, total balance 9998.750000,
# day 41: buy 1 unit at price 1.250000, total balance 9997.500000
# day 47, sell 1 unit at price 1.330000, investment 11.764704 %, total balance 9998.830000,
# day 54: buy 1 unit at price 1.350000, total balance 9997.480000
# day 58: buy 1 unit at price 1.300000, total balance 9996.180000
# day 59, sell 1 unit at price 1.260000, investment 0.799999 %, total balance 9997.440000,
# day 60: buy 1 unit at price 1.190000, total balance 9996.250000
# day 62, sell 1 unit at price 1.210000, investment -10.370369 %, total balance 9997.460000,
# day 64, sell 1 unit at price 1.250000, investment -3.846150 %, total balance 9998.710000,
# day 66, sell 1 unit at price 1.230000, investment 3.361341 %, total balance 9999.940000,
# day 102: buy 1 unit at price 1.210000, total balance 9998.730000
# day 103: buy 1 unit at price 1.230000, total balance 9997.500000
# day 104: buy 1 unit at price 1.230000, total balance 9996.270000
# day 105: buy 1 unit at price 1.300000, total balance 9994.970000
# day 106: buy 1 unit at price 1.280000, total balance 9993.690000
# day 107: buy 1 unit at price 1.340000, total balance 9992.350000
# day 110: buy 1 unit at price 1.300000, total balance 9991.050000
# day 111: buy 1 unit at price 1.260000, total balance 9989.790000
# day 131, sell 1 unit at price 1.650000, investment 36.363630 %, total balance 9991.440000,
# day 136, sell 1 unit at price 1.460000, investment 18.699188 %, total balance 9992.900000,
# day 137, sell 1 unit at price 1.460000, investment 18.699188 %, total balance 9994.360000,
# day 138: buy 1 unit at price 1.430000, total balance 9992.930000
# day 139, sell 1 unit at price 1.440000, investment 10.769239 %, total balance 9994.370000,
# day 140: buy 1 unit at price 1.440000, total balance 9992.930000
# day 142, sell 1 unit at price 1.460000, investment 14.062506 %, total balance 9994.390000,
# day 143: buy 1 unit at price 1.390000, total balance 9993.000000
# day 150: buy 1 unit at price 1.320000, total balance 9991.680000
# day 153: buy 1 unit at price 1.290000, total balance 9990.390000
# day 155: buy 1 unit at price 1.250000, total balance 9989.140000
# day 157, sell 1 unit at price 1.240000, investment -7.462688 %, total balance 9990.380000,
# day 158, sell 1 unit at price 1.230000, investment -5.384610 %, total balance 9991.610000,
# day 161, sell 1 unit at price 1.200000, investment -4.761900 %, total balance 9992.810000,
# day 162: buy 1 unit at price 1.200000, total balance 9991.610000
# day 163: buy 1 unit at price 1.170000, total balance 9990.440000
# day 165: buy 1 unit at price 1.220000, total balance 9989.220000
# day 166, sell 1 unit at price 1.250000, investment -12.587409 %, total balance 9990.470000,
# day 167, sell 1 unit at price 1.190000, investment -17.361110 %, total balance 9991.660000,
# day 176: buy 1 unit at price 1.270000, total balance 9990.390000
# day 187, sell 1 unit at price 1.350000, investment -2.877695 %, total balance 9991.740000,
# day 190: buy 1 unit at price 1.320000, total balance 9990.420000
# day 191, sell 1 unit at price 1.340000, investment 1.515150 %, total balance 9991.760000,
# day 198, sell 1 unit at price 1.350000, investment 4.651168 %, total balance 9993.110000,
# day 199, sell 1 unit at price 1.390000, investment 11.199999 %, total balance 9994.500000,
# day 200: buy 1 unit at price 1.350000, total balance 9993.150000
# day 202: buy 1 unit at price 1.390000, total balance 9991.760000
# day 203, sell 1 unit at price 1.430000, investment 19.166658 %, total balance 9993.190000,
# day 209, sell 1 unit at price 1.430000, investment 22.222222 %, total balance 9994.620000,
# day 211: buy 1 unit at price 1.420000, total balance 9993.200000
# day 212: buy 1 unit at price 1.480000, total balance 9991.720000
# day 215: buy 1 unit at price 1.350000, total balance 9990.370000
# day 219: buy 1 unit at price 1.290000, total balance 9989.080000
# day 220: buy 1 unit at price 1.250000, total balance 9987.830000
# day 224: buy 1 unit at price 1.210000, total balance 9986.620000
# day 230: buy 1 unit at price 1.210000, total balance 9985.410000
# day 232, sell 1 unit at price 1.420000, investment 16.393436 %, total balance 9986.830000,
# day 235: buy 1 unit at price 1.280000, total balance 9985.550000
# day 243: buy 1 unit at price 1.230000, total balance 9984.320000
# day 248: buy 1 unit at price 1.540000, total balance 9982.780000
# day 254, sell 1 unit at price 1.390000, investment 9.448819 %, total balance 9984.170000,
# day 256: buy 1 unit at price 1.380000, total balance 9982.790000
# day 260: buy 1 unit at price 1.500000, total balance 9981.290000
# day 261: buy 1 unit at price 1.430000, total balance 9979.860000
# day 265, sell 1 unit at price 2.500000, investment 89.393932 %, total balance 9982.360000,
# day 267: buy 1 unit at price 1.620000, total balance 9980.740000
# day 270: buy 1 unit at price 1.430000, total balance 9979.310000
# day 273, sell 1 unit at price 1.410000, investment 4.444440 %, total balance 9980.720000,
# day 275: buy 1 unit at price 1.450000, total balance 9979.270000
# day 279, sell 1 unit at price 1.400000, investment 0.719424 %, total balance 9980.670000,
# day 280, sell 1 unit at price 1.720000, investment 21.126766 %, total balance 9982.390000,
# day 282, sell 1 unit at price 1.600000, investment 8.108108 %, total balance 9983.990000,
# day 289, sell 1 unit at price 1.490000, investment 10.370369 %, total balance 9985.480000,
# day 299: buy 1 unit at price 1.720000, total balance 9983.760000
# day 300, sell 1 unit at price 1.730000, investment 34.108533 %, total balance 9985.490000,
# day 305, sell 1 unit at price 1.670000, investment 33.599997 %, total balance 9987.160000,
# day 307, sell 1 unit at price 1.590000, investment 31.404957 %, total balance 9988.750000,
# day 311, sell 1 unit at price 1.460000, investment 20.661156 %, total balance 9990.210000,
# day 313, sell 1 unit at price 1.490000, investment 16.406253 %, total balance 9991.700000,
# day 317: buy 1 unit at price 1.490000, total balance 9990.210000
# day 318, sell 1 unit at price 1.510000, investment 22.764225 %, total balance 9991.720000,
# day 319: buy 1 unit at price 1.480000, total balance 9990.240000
# day 324: buy 1 unit at price 1.500000, total balance 9988.740000
# day 330: buy 1 unit at price 1.500000, total balance 9987.240000
# day 333, sell 1 unit at price 1.440000, investment -6.493500 %, total balance 9988.680000,
# day 334: buy 1 unit at price 1.440000, total balance 9987.240000
# day 348, sell 1 unit at price 1.360000, investment -1.449274 %, total balance 9988.600000,
# day 349: buy 1 unit at price 1.370000, total balance 9987.230000
# day 354: buy 1 unit at price 1.420000, total balance 9985.810000
# day 355: buy 1 unit at price 1.420000, total balance 9984.390000
# day 356, sell 1 unit at price 1.400000, investment -6.666668 %, total balance 9985.790000,
# day 365: buy 1 unit at price 1.460000, total balance 9984.330000
# day 367, sell 1 unit at price 1.410000, investment -1.398600 %, total balance 9985.740000,
# day 369, sell 1 unit at price 1.380000, investment -14.814815 %, total balance 9987.120000,
# day 370: buy 1 unit at price 1.390000, total balance 9985.730000
# day 372: buy 1 unit at price 1.370000, total balance 9984.360000
# day 373, sell 1 unit at price 1.360000, investment -4.895100 %, total balance 9985.720000,
# day 376: buy 1 unit at price 1.380000, total balance 9984.340000
# day 379, sell 1 unit at price 1.370000, investment -5.517244 %, total balance 9985.710000,
# day 383, sell 1 unit at price 1.320000, investment -23.255812 %, total balance 9987.030000,
# day 385: buy 1 unit at price 1.360000, total balance 9985.670000
# day 387: buy 1 unit at price 1.360000, total balance 9984.310000
# day 391: buy 1 unit at price 1.400000, total balance 9982.910000
# day 393, sell 1 unit at price 1.430000, investment -4.026850 %, total balance 9984.340000,
# day 394: buy 1 unit at price 1.450000, total balance 9982.890000
# day 396: buy 1 unit at price 1.480000, total balance 9981.410000
# day 401: buy 1 unit at price 1.330000, total balance 9980.080000
# day 402, sell 1 unit at price 1.270000, investment -14.189192 %, total balance 9981.350000,
# day 403: buy 1 unit at price 1.250000, total balance 9980.100000
# day 407, sell 1 unit at price 1.310000, investment -12.666670 %, total balance 9981.410000,
# day 410, sell 1 unit at price 1.330000, investment -11.333330 %, total balance 9982.740000,
# day 422, sell 1 unit at price 1.360000, investment -5.555558 %, total balance 9984.100000,
# day 426: buy 1 unit at price 1.660000, total balance 9982.440000
# day 434: buy 1 unit at price 1.400000, total balance 9981.040000
# day 437: buy 1 unit at price 1.370000, total balance 9979.670000
# day 439: buy 1 unit at price 1.390000, total balance 9978.280000
# day 440, sell 1 unit at price 1.350000, investment -1.459853 %, total balance 9979.630000,
# day 445: buy 1 unit at price 1.390000, total balance 9978.240000
# day 465: buy 1 unit at price 1.310000, total balance 9976.930000
# day 466, sell 1 unit at price 1.380000, investment -2.816899 %, total balance 9978.310000,
# day 468, sell 1 unit at price 1.440000, investment 1.408458 %, total balance 9979.750000,
# day 472: buy 1 unit at price 1.440000, total balance 9978.310000
# day 475: buy 1 unit at price 1.400000, total balance 9976.910000
# day 479, sell 1 unit at price 1.430000, investment -2.054801 %, total balance 9978.340000,
# day 482, sell 1 unit at price 1.440000, investment 3.597127 %, total balance 9979.780000,
# day 486: buy 1 unit at price 1.460000, total balance 9978.320000
# day 488, sell 1 unit at price 1.510000, investment 10.218977 %, total balance 9979.830000,
# day 494: buy 1 unit at price 1.430000, total balance 9978.400000
# day 495, sell 1 unit at price 1.450000, investment 5.072468 %, total balance 9979.850000,
# day 502, sell 1 unit at price 1.400000, investment 2.941174 %, total balance 9981.250000,
# day 507: buy 1 unit at price 1.460000, total balance 9979.790000
# day 512, sell 1 unit at price 1.580000, investment 16.176473 %, total balance 9981.370000,
# day 517: buy 1 unit at price 1.650000, total balance 9979.720000
# day 519, sell 1 unit at price 1.650000, investment 17.857143 %, total balance 9981.370000,
# day 526: buy 1 unit at price 1.510000, total balance 9979.860000
# day 527: buy 1 unit at price 1.520000, total balance 9978.340000
# day 529, sell 1 unit at price 1.540000, investment 6.206890 %, total balance 9979.880000,
# day 531: buy 1 unit at price 1.520000, total balance 9978.360000
# day 534: buy 1 unit at price 1.430000, total balance 9976.930000
# day 539: buy 1 unit at price 1.440000, total balance 9975.490000
# day 540: buy 1 unit at price 1.450000, total balance 9974.040000
# day 542: buy 1 unit at price 1.420000, total balance 9972.620000
# day 552: buy 1 unit at price 1.310000, total balance 9971.310000
# day 559: buy 1 unit at price 1.350000, total balance 9969.960000
# day 560, sell 1 unit at price 1.370000, investment -7.432433 %, total balance 9971.330000,
# day 562: buy 1 unit at price 1.350000, total balance 9969.980000
# day 564, sell 1 unit at price 1.350000, investment 1.503758 %, total balance 9971.330000,
# day 565, sell 1 unit at price 1.340000, investment 7.200003 %, total balance 9972.670000,
# day 566: buy 1 unit at price 1.450000, total balance 9971.220000
# day 567: buy 1 unit at price 1.380000, total balance 9969.840000
# day 571: buy 1 unit at price 1.370000, total balance 9968.470000
# day 573: buy 1 unit at price 1.360000, total balance 9967.110000
# day 576: buy 1 unit at price 1.370000, total balance 9965.740000
# day 578: buy 1 unit at price 1.360000, total balance 9964.380000
# day 585: buy 1 unit at price 1.370000, total balance 9963.010000
# day 587, sell 1 unit at price 1.350000, investment -18.674696 %, total balance 9964.360000,
# day 595, sell 1 unit at price 1.220000, investment -12.857139 %, total balance 9965.580000,
# day 596: buy 1 unit at price 1.280000, total balance 9964.300000
# day 597, sell 1 unit at price 1.270000, investment -7.299272 %, total balance 9965.570000,
# day 600: buy 1 unit at price 1.150000, total balance 9964.420000
# day 602, sell 1 unit at price 1.150000, investment -17.266188 %, total balance 9965.570000,
# day 603: buy 1 unit at price 1.130000, total balance 9964.440000
# day 605: buy 1 unit at price 1.150000, total balance 9963.290000
# day 611, sell 1 unit at price 1.140000, investment -17.985612 %, total balance 9964.430000,
# day 614, sell 1 unit at price 1.110000, investment -15.267171 %, total balance 9965.540000,
# day 615: buy 1 unit at price 1.090000, total balance 9964.450000
# day 620, sell 1 unit at price 1.050000, investment -27.083340 %, total balance 9965.500000,
# day 622, sell 1 unit at price 1.010000, investment -27.857142 %, total balance 9966.510000,
# day 627: buy 1 unit at price 1.030000, total balance 9965.480000
# day 628, sell 1 unit at price 1.010000, investment -30.821920 %, total balance 9966.490000,
# day 631: buy 1 unit at price 1.040000, total balance 9965.450000
# day 635: buy 1 unit at price 1.020000, total balance 9964.430000
# day 636: buy 1 unit at price 1.010000, total balance 9963.420000
# day 639, sell 1 unit at price 1.070000, investment -25.174819 %, total balance 9964.490000,
# day 643, sell 1 unit at price 1.060000, investment -27.397266 %, total balance 9965.550000,
# day 648, sell 1 unit at price 1.110000, investment -32.727271 %, total balance 9966.660000,
# day 654, sell 1 unit at price 1.120000, investment -25.827814 %, total balance 9967.780000,
# day 656, sell 1 unit at price 1.160000, investment -23.684212 %, total balance 9968.940000,
# day 658, sell 1 unit at price 1.200000, investment -21.052627 %, total balance 9970.140000,
# day 660, sell 1 unit at price 1.260000, investment -11.888109 %, total balance 9971.400000,
# day 661, sell 1 unit at price 1.210000, investment -15.972223 %, total balance 9972.610000,
# day 663, sell 1 unit at price 1.180000, investment -18.620696 %, total balance 9973.790000,
# day 664, sell 1 unit at price 1.160000, investment -18.309859 %, total balance 9974.950000,
# day 666: buy 1 unit at price 1.090000, total balance 9973.860000
# day 668, sell 1 unit at price 1.110000, investment -15.267171 %, total balance 9974.970000,
# day 671: buy 1 unit at price 1.110000, total balance 9973.860000
# day 672, sell 1 unit at price 1.090000, investment -19.259258 %, total balance 9974.950000,
# day 673: buy 1 unit at price 1.060000, total balance 9973.890000
# day 675: buy 1 unit at price 1.030000, total balance 9972.860000
# day 676: buy 1 unit at price 1.080000, total balance 9971.780000
# day 678, sell 1 unit at price 1.020000, investment -24.444447 %, total balance 9972.800000,
# day 679: buy 1 unit at price 1.000000, total balance 9971.800000
# day 683, sell 1 unit at price 1.100000, investment -24.137932 %, total balance 9972.900000,
# day 687, sell 1 unit at price 1.010000, investment -26.811595 %, total balance 9973.910000,
# day 688, sell 1 unit at price 0.980000, investment -28.467152 %, total balance 9974.890000,
# day 690, sell 1 unit at price 0.920000, investment -32.352941 %, total balance 9975.810000,
# day 691: buy 1 unit at price 0.940000, total balance 9974.870000
# day 697: buy 1 unit at price 0.940000, total balance 9973.930000
# day 705: buy 1 unit at price 1.000000, total balance 9972.930000
# day 706: buy 1 unit at price 0.970000, total balance 9971.960000
# day 707, sell 1 unit at price 1.020000, investment -25.547447 %, total balance 9972.980000,
# day 708: buy 1 unit at price 0.980000, total balance 9972.000000
# day 715, sell 1 unit at price 1.190000, investment -12.499997 %, total balance 9973.190000,
# day 716, sell 1 unit at price 1.170000, investment -14.598544 %, total balance 9974.360000,
# day 725: buy 1 unit at price 1.150000, total balance 9973.210000
# day 734, sell 1 unit at price 1.050000, investment -17.968752 %, total balance 9974.260000,
# day 736, sell 1 unit at price 1.020000, investment -11.304348 %, total balance 9975.280000,
# day 737, sell 1 unit at price 1.020000, investment -9.734515 %, total balance 9976.300000,
# day 743: buy 1 unit at price 1.030000, total balance 9975.270000
# day 744, sell 1 unit at price 1.010000, investment -12.173912 %, total balance 9976.280000,
# day 750, sell 1 unit at price 1.140000, investment 4.587152 %, total balance 9977.420000,
# day 755, sell 1 unit at price 1.080000, investment 4.854376 %, total balance 9978.500000,
# day 756, sell 1 unit at price 1.060000, investment 1.923075 %, total balance 9979.560000,
# day 760, sell 1 unit at price 1.000000, investment -1.960782 %, total balance 9980.560000,
# day 762, sell 1 unit at price 1.000000, investment -0.990098 %, total balance 9981.560000,
# day 773, sell 1 unit at price 0.900000, investment -17.431197 %, total balance 9982.460000,
# day 775, sell 1 unit at price 0.920000, investment -17.117117 %, total balance 9983.380000,
# day 780: buy 1 unit at price 0.880000, total balance 9982.500000
# day 783: buy 1 unit at price 0.840000, total balance 9981.660000
# day 785: buy 1 unit at price 0.840000, total balance 9980.820000
# day 787: buy 1 unit at price 0.900000, total balance 9979.920000
# day 790: buy 1 unit at price 0.990000, total balance 9978.930000
# day 795: buy 1 unit at price 0.920000, total balance 9978.010000
# day 797: buy 1 unit at price 0.870000, total balance 9977.140000
# day 805, sell 1 unit at price 0.910000, investment -14.150936 %, total balance 9978.050000,
# day 811: buy 1 unit at price 1.170000, total balance 9976.880000
# day 815, sell 1 unit at price 1.120000, investment 8.737868 %, total balance 9978.000000,
# day 816: buy 1 unit at price 1.050000, total balance 9976.950001
# day 817, sell 1 unit at price 1.070000, investment -0.925925 %, total balance 9978.020001,
# day 819: buy 1 unit at price 1.080000, total balance 9976.940001
# day 820, sell 1 unit at price 1.070000, investment 7.000005 %, total balance 9978.010001,
# day 825: buy 1 unit at price 1.080000, total balance 9976.930001
# day 826: buy 1 unit at price 1.100000, total balance 9975.830001
# day 829: buy 1 unit at price 1.060000, total balance 9974.770001
# day 833, sell 1 unit at price 1.050000, investment 11.702123 %, total balance 9975.820001,
# day 835: buy 1 unit at price 1.030000, total balance 9974.790001
# day 837: buy 1 unit at price 1.010000, total balance 9973.780001
# day 838, sell 1 unit at price 0.980000, investment 4.255321 %, total balance 9974.760001,
# day 842, sell 1 unit at price 1.030000, investment 2.999997 %, total balance 9975.790001,
# day 845, sell 1 unit at price 1.060000, investment 9.278341 %, total balance 9976.850000,
# day 846: buy 1 unit at price 1.040000, total balance 9975.810001
# day 850, sell 1 unit at price 1.040000, investment 6.122443 %, total balance 9976.850000,
# day 855: buy 1 unit at price 1.080000, total balance 9975.770000
# day 856: buy 1 unit at price 1.090000, total balance 9974.680000
# day 859: buy 1 unit at price 1.080000, total balance 9973.600000
# day 867: buy 1 unit at price 1.120000, total balance 9972.480000
# day 868, sell 1 unit at price 1.180000, investment 2.608693 %, total balance 9973.660000,
# day 869, sell 1 unit at price 1.240000, investment 20.388354 %, total balance 9974.900000,
# day 872: buy 1 unit at price 1.200000, total balance 9973.700000
# day 873, sell 1 unit at price 1.150000, investment 30.681816 %, total balance 9974.850000,
# day 875, sell 1 unit at price 1.200000, investment 42.857153 %, total balance 9976.050000,
# day 877: buy 1 unit at price 1.130000, total balance 9974.920000
# day 881, sell 1 unit at price 1.240000, investment 47.619053 %, total balance 9976.160000,
# day 886, sell 1 unit at price 1.240000, investment 37.777783 %, total balance 9977.400000,
# day 887: buy 1 unit at price 1.250000, total balance 9976.150000
# day 898: buy 1 unit at price 1.350000, total balance 9974.800000
# day 903, sell 1 unit at price 1.340000, investment 35.353537 %, total balance 9976.140000,
# day 905, sell 1 unit at price 1.390000, investment 51.086952 %, total balance 9977.530000,
# day 909, sell 1 unit at price 1.180000, investment 35.632177 %, total balance 9978.710000,
# day 913, sell 1 unit at price 1.090000, investment -6.837601 %, total balance 9979.800000,
# day 917: buy 1 unit at price 1.200000, total balance 9978.600000
# day 918: buy 1 unit at price 1.170000, total balance 9977.430000
# day 923, sell 1 unit at price 1.200000, investment 14.285724 %, total balance 9978.630000,
# day 924: buy 1 unit at price 1.190000, total balance 9977.440000
# day 925: buy 1 unit at price 1.140000, total balance 9976.300000
# day 931: buy 1 unit at price 1.440000, total balance 9974.860000
# day 932, sell 1 unit at price 1.430000, investment 32.407397 %, total balance 9976.290000,
# day 934, sell 1 unit at price 1.450000, investment 34.259258 %, total balance 9977.740000,
# day 938, sell 1 unit at price 1.560000, investment 41.818174 %, total balance 9979.300000,
# day 949: buy 1 unit at price 1.430000, total balance 9977.870000
# day 954: buy 1 unit at price 1.350000, total balance 9976.520000
# day 972: buy 1 unit at price 1.270000, total balance 9975.250000
# day 973: buy 1 unit at price 1.310000, total balance 9973.940000
# day 975, sell 1 unit at price 1.300000, investment 22.641512 %, total balance 9975.240000,
# day 979: buy 1 unit at price 1.520000, total balance 9973.720000
# day 980: buy 1 unit at price 1.440000, total balance 9972.280000
# day 981: buy 1 unit at price 1.440000, total balance 9970.840000
# day 986, sell 1 unit at price 1.440000, investment 39.805835 %, total balance 9972.280000,
# day 989: buy 1 unit at price 1.360000, total balance 9970.920000
# day 992: buy 1 unit at price 1.340000, total balance 9969.580000
# day 995, sell 1 unit at price 1.360000, investment 34.653468 %, total balance 9970.940000,
# day 996, sell 1 unit at price 1.330000, investment 27.884624 %, total balance 9972.270000,
# day 999: buy 1 unit at price 1.450000, total balance 9970.820000
# day 1000, sell 1 unit at price 1.460000, investment 35.185183 %, total balance 9972.280000,
# day 1001, sell 1 unit at price 1.400000, investment 28.440361 %, total balance 9973.680000,
# day 1002: buy 1 unit at price 1.430000, total balance 9972.250000
# day 1011, sell 1 unit at price 1.580000, investment 46.296294 %, total balance 9973.830000,
# day 1012, sell 1 unit at price 1.550000, investment 38.392852 %, total balance 9975.380000,
# day 1013, sell 1 unit at price 1.560000, investment 29.999990 %, total balance 9976.940000,
# day 1016: buy 1 unit at price 1.530000, total balance 9975.410000
# day 1018, sell 1 unit at price 1.780000, investment 57.522122 %, total balance 9977.190000,
# day 1023: buy 1 unit at price 1.990000, total balance 9975.200000
# day 1024, sell 1 unit at price 2.270000, investment 81.599998 %, total balance 9977.470000,
# day 1025: buy 1 unit at price 1.950000, total balance 9975.520000
# day 1026: buy 1 unit at price 1.980000, total balance 9973.540000
# day 1028: buy 1 unit at price 1.960000, total balance 9971.580000
# day 1033: buy 1 unit at price 2.010000, total balance 9969.570000
# day 1035, sell 1 unit at price 1.990000, investment 47.407406 %, total balance 9971.560000,
# day 1036: buy 1 unit at price 1.980000, total balance 9969.580000
# day 1039, sell 1 unit at price 1.950000, investment 62.499998 %, total balance 9971.530000,
# day 1050: buy 1 unit at price 1.890000, total balance 9969.640000
# day 1051: buy 1 unit at price 1.970000, total balance 9967.670000
# day 1055, sell 1 unit at price 1.850000, investment 58.119666 %, total balance 9969.520000,
# day 1056, sell 1 unit at price 1.790000, investment 50.420158 %, total balance 9971.310000,
# day 1061: buy 1 unit at price 1.660000, total balance 9969.650000
# day 1064: buy 1 unit at price 1.700000, total balance 9967.950000
# day 1067, sell 1 unit at price 1.730000, investment 51.754389 %, total balance 9969.680000,
# day 1069, sell 1 unit at price 1.730000, investment 20.138885 %, total balance 9971.410000,
# day 1075: buy 1 unit at price 1.740000, total balance 9969.670000
# day 1076, sell 1 unit at price 1.710000, investment 19.580427 %, total balance 9971.380000,
# day 1077: buy 1 unit at price 1.690000, total balance 9969.690000
# day 1083, sell 1 unit at price 1.470000, investment 8.888889 %, total balance 9971.160000,
# day 1092: buy 1 unit at price 1.470000, total balance 9969.690000
# day 1096, sell 1 unit at price 1.480000, investment 16.535436 %, total balance 9971.170000,
# day 1099: buy 1 unit at price 1.380000, total balance 9969.790000
# day 1103: buy 1 unit at price 1.500000, total balance 9968.290000
# day 1108: buy 1 unit at price 1.510000, total balance 9966.780000
# day 1113: buy 1 unit at price 1.490000, total balance 9965.290000
# day 1116, sell 1 unit at price 1.680000, investment 28.244276 %, total balance 9966.970000,
# day 1118: buy 1 unit at price 1.560000, total balance 9965.410000
# day 1121: buy 1 unit at price 1.580000, total balance 9963.830000
# day 1122: buy 1 unit at price 1.510000, total balance 9962.320000
# day 1129: buy 1 unit at price 1.450000, total balance 9960.870000
# day 1130, sell 1 unit at price 1.500000, investment -1.315788 %, total balance 9962.370000,
# day 1132: buy 1 unit at price 1.510000, total balance 9960.860000
# day 1140, sell 1 unit at price 1.470000, investment 2.083331 %, total balance 9962.330000,
# day 1152: buy 1 unit at price 1.320000, total balance 9961.010000
# day 1153: buy 1 unit at price 1.350000, total balance 9959.660000
# day 1158, sell 1 unit at price 1.220000, investment -15.277779 %, total balance 9960.880000,
# day 1161: buy 1 unit at price 1.440000, total balance 9959.440000
# day 1167, sell 1 unit at price 1.460000, investment 7.352943 %, total balance 9960.900000,
# day 1168: buy 1 unit at price 1.410000, total balance 9959.490000
# day 1171: buy 1 unit at price 1.440000, total balance 9958.050000
# day 1181, sell 1 unit at price 1.540000, investment 14.925367 %, total balance 9959.590000,
# day 1183: buy 1 unit at price 1.580000, total balance 9958.010000
# day 1186: buy 1 unit at price 1.580000, total balance 9956.430000
# day 1187, sell 1 unit at price 1.590000, investment 9.655171 %, total balance 9958.020000,
# day 1189: buy 1 unit at price 1.630000, total balance 9956.390000
# day 1191: buy 1 unit at price 1.680000, total balance 9954.710000
# day 1200: buy 1 unit at price 1.630000, total balance 9953.080000
# day 1206, sell 1 unit at price 1.610000, investment 12.587418 %, total balance 9954.690000,
# day 1207: buy 1 unit at price 1.570000, total balance 9953.120000
# day 1219: buy 1 unit at price 1.640000, total balance 9951.480000
# day 1222, sell 1 unit at price 1.660000, investment 8.496732 %, total balance 9953.140000,
# day 1223: buy 1 unit at price 1.660000, total balance 9951.480000
# day 1224, sell 1 unit at price 1.640000, investment -17.587941 %, total balance 9953.120000,
# day 1227, sell 1 unit at price 1.770000, investment -9.230772 %, total balance 9954.890000,
# day 1228: buy 1 unit at price 1.800000, total balance 9953.090000
# day 1231: buy 1 unit at price 2.060000, total balance 9951.030000
# day 1236: buy 1 unit at price 2.380000, total balance 9948.650000
# day 1238, sell 1 unit at price 2.350000, investment 18.686863 %, total balance 9951.000000,
# day 1242, sell 1 unit at price 2.330000, investment 18.877545 %, total balance 9953.330000,
# day 1247, sell 1 unit at price 2.290000, investment 13.930347 %, total balance 9955.620000,
# day 1250, sell 1 unit at price 2.400000, investment 21.212125 %, total balance 9958.020000,
# day 1251, sell 1 unit at price 2.490000, investment 31.746033 %, total balance 9960.510000,
# day 1253, sell 1 unit at price 2.500000, investment 26.903551 %, total balance 9963.010000,
# day 1254: buy 1 unit at price 2.510000, total balance 9960.500000
# day 1259, sell 1 unit at price 2.500000, investment 50.602413 %, total balance 9963.000000,
# day 1262, sell 1 unit at price 2.730000, investment 60.588232 %, total balance 9965.730000,
# day 1263, sell 1 unit at price 2.610000, investment 49.999993 %, total balance 9968.340000,
# day 1264, sell 1 unit at price 2.590000, investment 53.254428 %, total balance 9970.930000,
# day 1276, sell 1 unit at price 2.300000, investment 56.462579 %, total balance 9973.230000,
# day 1278: buy 1 unit at price 2.180000, total balance 9971.049999
# day 1281: buy 1 unit at price 2.120000, total balance 9968.930000
# day 1282, sell 1 unit at price 2.200000, investment 59.420294 %, total balance 9971.130000,
# day 1283: buy 1 unit at price 2.100000, total balance 9969.030000
# day 1286: buy 1 unit at price 2.200000, total balance 9966.830000
# day 1294: buy 1 unit at price 2.430000, total balance 9964.400000
# day 1301: buy 1 unit at price 2.560000, total balance 9961.840000
# day 1302: buy 1 unit at price 2.560000, total balance 9959.280000
# day 1305, sell 1 unit at price 2.630000, investment 75.333341 %, total balance 9961.910000,
# day 1306, sell 1 unit at price 2.570000, investment 70.198672 %, total balance 9964.480000,
# day 1307, sell 1 unit at price 2.570000, investment 72.483216 %, total balance 9967.050000,
# day 1315, sell 1 unit at price 3.090000, investment 98.076925 %, total balance 9970.140000,
# day 1316, sell 1 unit at price 3.100000, investment 96.202520 %, total balance 9973.240000,
# day 1321, sell 1 unit at price 3.210000, investment 112.582785 %, total balance 9976.450000,
# day 1324: buy 1 unit at price 3.170000, total balance 9973.279999
# day 1325, sell 1 unit at price 3.400000, investment 134.482757 %, total balance 9976.680000,
# day 1329: buy 1 unit at price 3.230000, total balance 9973.450000
# day 1335: buy 1 unit at price 3.250000, total balance 9970.200000
# day 1339, sell 1 unit at price 3.210000, investment 112.582785 %, total balance 9973.410000,
# day 1342, sell 1 unit at price 3.310000, investment 150.757562 %, total balance 9976.720000,
# day 1345, sell 1 unit at price 3.330000, investment 146.666657 %, total balance 9980.049999,
# day 1348, sell 1 unit at price 2.960000, investment 105.555550 %, total balance 9983.010000,
# day 1349: buy 1 unit at price 2.960000, total balance 9980.049999
# day 1352: buy 1 unit at price 3.300000, total balance 9976.750000
# day 1353, sell 1 unit at price 3.380000, investment 139.716326 %, total balance 9980.130000,
# day 1357, sell 1 unit at price 3.260000, investment 126.388879 %, total balance 9983.390000,
# day 1360, sell 1 unit at price 3.360000, investment 112.658215 %, total balance 9986.750000,
# day 1377: buy 1 unit at price 2.950000, total balance 9983.799999
# day 1378, sell 1 unit at price 2.970000, investment 87.974680 %, total balance 9986.770000,
# day 1379: buy 1 unit at price 2.950000, total balance 9983.819999
# day 1380: buy 1 unit at price 2.950000, total balance 9980.869999
# day 1383, sell 1 unit at price 2.980000, investment 82.822088 %, total balance 9983.849999,
# day 1384: buy 1 unit at price 3.190000, total balance 9980.659999
# day 1386: buy 1 unit at price 3.350000, total balance 9977.309999
# day 1387, sell 1 unit at price 3.370000, investment 100.595238 %, total balance 9980.679999,
# day 1405, sell 1 unit at price 3.930000, investment 141.104299 %, total balance 9984.609999,
# day 1408: buy 1 unit at price 3.690000, total balance 9980.919999
# day 1413: buy 1 unit at price 3.760000, total balance 9977.159999
# day 1416, sell 1 unit at price 3.680000, investment 134.394901 %, total balance 9980.839999,
# day 1418, sell 1 unit at price 3.600000, investment 119.512191 %, total balance 9984.439999,
# day 1419, sell 1 unit at price 3.540000, investment 113.253014 %, total balance 9987.979999,
# day 1421, sell 1 unit at price 3.650000, investment 102.777788 %, total balance 9991.629999,
# day 1425: buy 1 unit at price 3.740000, total balance 9987.889999
# day 1426: buy 1 unit at price 3.680000, total balance 9984.209999
# day 1427, sell 1 unit at price 3.720000, investment 80.582531 %, total balance 9987.929999,
# day 1430: buy 1 unit at price 3.730000, total balance 9984.199999
# day 1434, sell 1 unit at price 3.570000, investment 49.999990 %, total balance 9987.769999,
# day 1439, sell 1 unit at price 3.410000, investment 35.856578 %, total balance 9991.179999,
# day 1449: buy 1 unit at price 3.250000, total balance 9987.929999
# day 1452: buy 1 unit at price 3.380000, total balance 9984.549999
# day 1453: buy 1 unit at price 3.220000, total balance 9981.329999
# day 1457, sell 1 unit at price 3.040000, investment 39.449535 %, total balance 9984.369999,
# day 1458, sell 1 unit at price 3.270000, investment 54.245290 %, total balance 9987.639999,
# day 1459, sell 1 unit at price 3.260000, investment 55.238102 %, total balance 9990.899999,
# day 1461: buy 1 unit at price 3.210000, total balance 9987.689999
# day 1468: buy 1 unit at price 3.260000, total balance 9984.429999
# day 1473, sell 1 unit at price 3.150000, investment 43.181819 %, total balance 9987.579999,
# day 1475: buy 1 unit at price 3.500000, total balance 9984.079999
# day 1478, sell 1 unit at price 3.570000, investment 46.913573 %, total balance 9987.649999,
# day 1491, sell 1 unit at price 3.450000, investment 34.765630 %, total balance 9991.099999,
# day 1493, sell 1 unit at price 3.420000, investment 33.593756 %, total balance 9994.519999,
# day 1498, sell 1 unit at price 3.100000, investment -2.208207 %, total balance 9997.619999,
# day 1501, sell 1 unit at price 2.960000, investment -8.359132 %, total balance 10000.579999,
# day 1502, sell 1 unit at price 3.000000, investment -7.692308 %, total balance 10003.579999,
# day 1506, sell 1 unit at price 2.920000, investment -1.351350 %, total balance 10006.499999,
# day 1508: buy 1 unit at price 3.180000, total balance 10003.319999
# day 1510, sell 1 unit at price 3.350000, investment 1.515150 %, total balance 10006.669999,
# day 1516: buy 1 unit at price 3.400000, total balance 10003.269999
# day 1520: buy 1 unit at price 3.400000, total balance 9999.869999
# day 1533, sell 1 unit at price 3.290000, investment 11.525421 %, total balance 10003.159999,
# day 1535, sell 1 unit at price 3.170000, investment 7.457628 %, total balance 10006.329999,
# day 1542, sell 1 unit at price 3.170000, investment 7.457628 %, total balance 10009.499999,
# day 1549: buy 1 unit at price 3.210000, total balance 10006.289999
# day 1554: buy 1 unit at price 3.880000, total balance 10002.409999
# day 1566: buy 1 unit at price 4.380000, total balance 9998.029999
# day 1567, sell 1 unit at price 4.370000, investment 36.990590 %, total balance 10002.399999,
# day 1568: buy 1 unit at price 4.390000, total balance 9998.009999
# day 1571: buy 1 unit at price 4.190000, total balance 9993.819999
# day 1572, sell 1 unit at price 4.260000, investment 27.164190 %, total balance 9998.079999,
# day 1577: buy 1 unit at price 4.160000, total balance 9993.919999
# day 1578: buy 1 unit at price 4.290000, total balance 9989.629999
# day 1581: buy 1 unit at price 4.150000, total balance 9985.479999
# day 1584, sell 1 unit at price 4.250000, investment 15.176150 %, total balance 9989.729999,
# day 1586: buy 1 unit at price 4.420000, total balance 9985.309999
# day 1591, sell 1 unit at price 4.440000, investment 18.085108 %, total balance 9989.749999,
# day 1593, sell 1 unit at price 4.450000, investment 18.983952 %, total balance 9994.199999,
# day 1594, sell 1 unit at price 4.580000, investment 24.456517 %, total balance 9998.779999,
# day 1602: buy 1 unit at price 4.520000, total balance 9994.259999
# day 1605, sell 1 unit at price 4.400000, investment 17.962468 %, total balance 9998.659999,
# day 1608, sell 1 unit at price 4.400000, investment 35.384618 %, total balance 10003.059999,
# day 1610: buy 1 unit at price 4.160000, total balance 9998.899999
# day 1618, sell 1 unit at price 3.970000, investment 17.455618 %, total balance 10002.869999,
# day 1625: buy 1 unit at price 4.200000, total balance 9998.669999
# day 1626, sell 1 unit at price 4.320000, investment 34.161495 %, total balance 10002.990000,
# day 1633: buy 1 unit at price 4.500000, total balance 9998.490000
# day 1634, sell 1 unit at price 4.510000, investment 40.498448 %, total balance 10003.000000,
# day 1644, sell 1 unit at price 4.990000, investment 53.067478 %, total balance 10007.990000,
# day 1645, sell 1 unit at price 4.950000, investment 41.428566 %, total balance 10012.939999,
# day 1648: buy 1 unit at price 4.990000, total balance 10007.950000
# day 1649, sell 1 unit at price 4.970000, investment 56.289298 %, total balance 10012.919999,
# day 1650, sell 1 unit at price 4.960000, investment 45.882350 %, total balance 10017.879999,
# day 1652, sell 1 unit at price 4.980000, investment 46.470585 %, total balance 10022.859999,
# day 1655: buy 1 unit at price 5.150000, total balance 10017.709999
# day 1658, sell 1 unit at price 4.610000, investment 43.613710 %, total balance 10022.319999,
# day 1670: buy 1 unit at price 6.070000, total balance 10016.249999
# day 1674, sell 1 unit at price 6.270000, investment 61.597933 %, total balance 10022.519999,
# day 1675: buy 1 unit at price 6.260000, total balance 10016.259999
# day 1679: buy 1 unit at price 6.390000, total balance 10009.869999
# day 1684: buy 1 unit at price 5.920000, total balance 10003.949999
# day 1687: buy 1 unit at price 5.940000, total balance 9998.009999
# day 1694: buy 1 unit at price 6.260000, total balance 9991.749999
# day 1701, sell 1 unit at price 5.830000, investment 33.105018 %, total balance 9997.579999,
# day 1702, sell 1 unit at price 5.710000, investment 30.068342 %, total balance 10003.289999,
# day 1704, sell 1 unit at price 5.560000, investment 32.696894 %, total balance 10008.849999,
# day 1709, sell 1 unit at price 5.680000, investment 36.538462 %, total balance 10014.529999,
# day 1710: buy 1 unit at price 5.800000, total balance 10008.729998
# day 1715, sell 1 unit at price 5.860000, investment 36.596741 %, total balance 10014.589998,
# day 1718: buy 1 unit at price 5.980000, total balance 10008.609998
# day 1725, sell 1 unit at price 6.500000, investment 56.626502 %, total balance 10015.109998,
# day 1729: buy 1 unit at price 6.500000, total balance 10008.609998
# day 1732, sell 1 unit at price 6.480000, investment 46.606333 %, total balance 10015.089998,
# day 1734, sell 1 unit at price 6.930000, investment 53.318581 %, total balance 10022.019998,
# day 1737, sell 1 unit at price 7.320000, investment 75.961549 %, total balance 10029.339998,
# day 1741: buy 1 unit at price 7.220000, total balance 10022.119999
# day 1747, sell 1 unit at price 7.420000, investment 76.666677 %, total balance 10029.539999,
# day 1753: buy 1 unit at price 7.780000, total balance 10021.759999
# day 1754: buy 1 unit at price 7.430000, total balance 10014.329999
# day 1755, sell 1 unit at price 7.420000, investment 64.888891 %, total balance 10021.749999,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
