# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../agent/cleaned_data/COOP.csv')
df.head()
# Out:
#        Date   Open   High   Low  Close  Adj Close  Volume
# 0  1/2/2013  10.20  10.32  9.48   9.72       9.72   64700
# 1  1/3/2013   9.60   9.84  9.48   9.60       9.60   21600
# 2  1/4/2013   9.48   9.96  9.48   9.48       9.48    8000
# 3  1/7/2013   9.48   9.60  9.00   9.36       9.36  116100
# 4  1/8/2013   9.48   9.48  7.80   8.40       8.40   20800

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAE0A1C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAE0A1C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAE0A1C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAE0A1C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAE0A1C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAE0A1C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAE0A1C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAE0A1C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAF04D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAF04D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAF04D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAF04D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAF04D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAF04D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAF04D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001B9CAF04D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: -75.900013.3, cost: 0.000894, total money: 9782.889987
# epoch: 20, total rewards: 408.500027.3, cost: 0.000369, total money: 10383.540027
# epoch: 30, total rewards: 9.250013.3, cost: 0.000105, total money: 10009.250013
# epoch: 40, total rewards: 211.259970.3, cost: 0.000165, total money: 10095.899969
# epoch: 50, total rewards: 13.060002.3, cost: 0.000774, total money: 9962.450001
# epoch: 60, total rewards: -15.390003.3, cost: 0.000261, total money: 9946.679996
# epoch: 70, total rewards: -71.380014.3, cost: 0.000040, total money: 9928.619986
# epoch: 80, total rewards: 66.929989.3, cost: 0.001426, total money: 9879.959988
# epoch: 90, total rewards: 62.420015.3, cost: 0.000028, total money: 10049.590015
# epoch: 100, total rewards: -32.979971.3, cost: 0.000043, total money: 9967.020029
# epoch: 110, total rewards: 15.849982.3, cost: 0.007380, total money: 10015.849982
# epoch: 120, total rewards: 26.489991.3, cost: 0.000036, total money: 10026.489991
# epoch: 130, total rewards: -0.810020.3, cost: 0.000118, total money: 9999.189980
# epoch: 140, total rewards: 13.349998.3, cost: 0.000051, total money: 10013.349998
# epoch: 150, total rewards: 69.660008.3, cost: 0.003879, total money: 10057.150008
# epoch: 160, total rewards: 6.659989.3, cost: 0.000046, total money: 9981.319989
# epoch: 170, total rewards: 49.820024.3, cost: 0.000009, total money: 10037.350024
# epoch: 180, total rewards: -9.799987.3, cost: 0.000004, total money: 9990.200013
# epoch: 190, total rewards: -2.960005.3, cost: 0.000002, total money: 9997.039995
# epoch: 200, total rewards: 13.299988.3, cost: 0.000169, total money: 10000.789988

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 14: buy 1 unit at price 10.080000, total balance 9989.920000
# day 15: buy 1 unit at price 9.960000, total balance 9979.960000
# day 18: buy 1 unit at price 9.240000, total balance 9970.720000
# day 19: buy 1 unit at price 9.360000, total balance 9961.360001
# day 20, sell 1 unit at price 9.480000, investment -5.952385 %, total balance 9970.840000,
# day 21: buy 1 unit at price 9.000000, total balance 9961.840000
# day 25: buy 1 unit at price 9.840000, total balance 9952.000000
# day 30, sell 1 unit at price 8.880000, investment -10.843373 %, total balance 9960.880000,
# day 32, sell 1 unit at price 9.600000, investment 3.896111 %, total balance 9970.480000,
# day 42, sell 1 unit at price 8.640000, investment -7.692301 %, total balance 9979.120001,
# day 43, sell 1 unit at price 9.000000, investment 0.000000 %, total balance 9988.120001,
# day 49: buy 1 unit at price 8.760000, total balance 9979.360001
# day 50, sell 1 unit at price 8.760000, investment -10.975609 %, total balance 9988.120001,
# day 55, sell 1 unit at price 8.640000, investment -1.369862 %, total balance 9996.760001,
# day 56: buy 1 unit at price 8.400000, total balance 9988.360002
# day 61: buy 1 unit at price 8.280000, total balance 9980.080002
# day 82: buy 1 unit at price 7.200000, total balance 9972.880002
# day 90: buy 1 unit at price 8.040000, total balance 9964.840002
# day 95, sell 1 unit at price 9.840000, investment 17.142864 %, total balance 9974.680002,
# day 104: buy 1 unit at price 10.320000, total balance 9964.360003
# day 107, sell 1 unit at price 9.600000, investment 15.942037 %, total balance 9973.960003,
# day 110: buy 1 unit at price 10.080000, total balance 9963.880003
# day 115, sell 1 unit at price 10.440000, investment 44.999998 %, total balance 9974.320003,
# day 118: buy 1 unit at price 10.440000, total balance 9963.880003
# day 119, sell 1 unit at price 10.200000, investment 26.865670 %, total balance 9974.080003,
# day 120, sell 1 unit at price 10.200000, investment -1.162790 %, total balance 9984.280003,
# day 123: buy 1 unit at price 9.600000, total balance 9974.680002
# day 124, sell 1 unit at price 9.720000, investment -3.571425 %, total balance 9984.400002,
# day 129, sell 1 unit at price 9.960000, investment -4.597697 %, total balance 9994.360003,
# day 135, sell 1 unit at price 10.560000, investment 10.000000 %, total balance 10004.920003,
# day 146: buy 1 unit at price 11.400000, total balance 9993.520003
# day 148, sell 1 unit at price 12.480000, investment 9.473684 %, total balance 10006.000003,
# day 155: buy 1 unit at price 12.120000, total balance 9993.880003
# day 164, sell 1 unit at price 12.360000, investment 1.980196 %, total balance 10006.240003,
# day 168: buy 1 unit at price 12.360000, total balance 9993.880003
# day 169, sell 1 unit at price 12.240000, investment -0.970873 %, total balance 10006.120003,
# day 176: buy 1 unit at price 14.280000, total balance 9991.840003
# day 180: buy 1 unit at price 16.440001, total balance 9975.400002
# day 182: buy 1 unit at price 15.360000, total balance 9960.040003
# day 186: buy 1 unit at price 14.880000, total balance 9945.160003
# day 189: buy 1 unit at price 14.880000, total balance 9930.280003
# day 190, sell 1 unit at price 14.640000, investment 2.521013 %, total balance 9944.920003,
# day 191: buy 1 unit at price 14.640000, total balance 9930.280003
# day 197, sell 1 unit at price 14.640000, investment -10.948906 %, total balance 9944.920003,
# day 206: buy 1 unit at price 14.160000, total balance 9930.760003
# day 208, sell 1 unit at price 13.440000, investment -12.500001 %, total balance 9944.200003,
# day 209, sell 1 unit at price 13.320000, investment -10.483874 %, total balance 9957.520002,
# day 214, sell 1 unit at price 12.600000, investment -15.322579 %, total balance 9970.120003,
# day 218, sell 1 unit at price 14.040000, investment -4.098363 %, total balance 9984.160003,
# day 220: buy 1 unit at price 13.680000, total balance 9970.480002
# day 227, sell 1 unit at price 13.680000, investment -3.389827 %, total balance 9984.160003,
# day 228, sell 1 unit at price 13.680000, investment 0.000000 %, total balance 9997.840003,
# day 229: buy 1 unit at price 13.560000, total balance 9984.280003
# day 235, sell 1 unit at price 13.200000, investment -2.654872 %, total balance 9997.480002,
# day 240: buy 1 unit at price 25.559999, total balance 9971.920003
# day 241, sell 1 unit at price 27.360001, investment 7.042258 %, total balance 9999.280004,
# day 250: buy 1 unit at price 33.240002, total balance 9966.040002
# day 254, sell 1 unit at price 33.000000, investment -0.722027 %, total balance 9999.040002,
# day 258: buy 1 unit at price 32.400002, total balance 9966.640000
# day 262, sell 1 unit at price 29.040001, investment -10.370372 %, total balance 9995.680001,
# day 265: buy 1 unit at price 29.280001, total balance 9966.400001
# day 266, sell 1 unit at price 29.280001, investment 0.000000 %, total balance 9995.680001,
# day 270: buy 1 unit at price 29.879999, total balance 9965.800002
# day 271, sell 1 unit at price 30.000000, investment 0.401609 %, total balance 9995.800002,
# day 281: buy 1 unit at price 32.520000, total balance 9963.280002
# day 284, sell 1 unit at price 32.160000, investment -1.107013 %, total balance 9995.440001,
# day 298: buy 1 unit at price 39.720001, total balance 9955.720000
# day 303, sell 1 unit at price 41.400002, investment 4.229608 %, total balance 9997.120002,
# day 308: buy 1 unit at price 38.880001, total balance 9958.240001
# day 311, sell 1 unit at price 39.000000, investment 0.308639 %, total balance 9997.240001,
# day 316: buy 1 unit at price 39.480000, total balance 9957.760001
# day 327, sell 1 unit at price 37.799999, investment -4.255320 %, total balance 9995.560000,
# day 329: buy 1 unit at price 37.320000, total balance 9958.240001
# day 331, sell 1 unit at price 36.720001, investment -1.607713 %, total balance 9994.960002,
# day 346: buy 1 unit at price 30.719999, total balance 9964.240003
# day 347, sell 1 unit at price 30.959999, investment 0.781249 %, total balance 9995.200002,
# day 349: buy 1 unit at price 34.200001, total balance 9961.000001
# day 351, sell 1 unit at price 34.919998, investment 2.105256 %, total balance 9995.919999,
# day 362: buy 1 unit at price 34.080002, total balance 9961.839997
# day 369, sell 1 unit at price 33.599998, investment -1.408460 %, total balance 9995.439996,
# day 371: buy 1 unit at price 33.599998, total balance 9961.839997
# day 372, sell 1 unit at price 33.599998, investment 0.000000 %, total balance 9995.439996,
# day 387: buy 1 unit at price 33.840000, total balance 9961.599996
# day 388, sell 1 unit at price 33.599998, investment -0.709225 %, total balance 9995.199994,
# day 390: buy 1 unit at price 33.360001, total balance 9961.839993
# day 392, sell 1 unit at price 33.240002, investment -0.359709 %, total balance 9995.079995,
# day 393: buy 1 unit at price 33.000000, total balance 9962.079995
# day 403: buy 1 unit at price 32.520000, total balance 9929.559995
# day 406, sell 1 unit at price 32.520000, investment -1.454544 %, total balance 9962.079995,
# day 409: buy 1 unit at price 32.759998, total balance 9929.319997
# day 413, sell 1 unit at price 34.080002, investment 4.797052 %, total balance 9963.399999,
# day 417, sell 1 unit at price 32.639999, investment -0.366297 %, total balance 9996.039998,
# day 421: buy 1 unit at price 32.880001, total balance 9963.159997
# day 423: buy 1 unit at price 32.639999, total balance 9930.519998
# day 432, sell 1 unit at price 30.840000, investment -6.204382 %, total balance 9961.359998,
# day 433: buy 1 unit at price 30.480000, total balance 9930.879998
# day 434: buy 1 unit at price 29.160000, total balance 9901.719998
# day 438: buy 1 unit at price 32.279999, total balance 9869.440000
# day 441: buy 1 unit at price 29.520000, total balance 9839.919999
# day 442: buy 1 unit at price 30.000000, total balance 9809.919999
# day 443, sell 1 unit at price 29.040001, investment -11.029407 %, total balance 9838.960000,
# day 449, sell 1 unit at price 25.080000, investment -17.716534 %, total balance 9864.040000,
# day 459: buy 1 unit at price 26.520000, total balance 9837.520000
# day 465, sell 1 unit at price 25.440001, investment -12.757199 %, total balance 9862.960000,
# day 467: buy 1 unit at price 24.480000, total balance 9838.480000
# day 468, sell 1 unit at price 24.000000, investment -25.650555 %, total balance 9862.480000,
# day 475: buy 1 unit at price 21.360001, total balance 9841.120000
# day 479: buy 1 unit at price 22.200001, total balance 9818.919999
# day 481: buy 1 unit at price 24.000000, total balance 9794.919999
# day 484, sell 1 unit at price 24.959999, investment -15.447159 %, total balance 9819.879998,
# day 485: buy 1 unit at price 24.480000, total balance 9795.399999
# day 486, sell 1 unit at price 24.360001, investment -18.799998 %, total balance 9819.759999,
# day 495: buy 1 unit at price 21.840000, total balance 9797.919999
# day 499: buy 1 unit at price 25.680000, total balance 9772.239999
# day 500, sell 1 unit at price 25.200001, investment -4.977374 %, total balance 9797.440000,
# day 501: buy 1 unit at price 25.200001, total balance 9772.239999
# day 502: buy 1 unit at price 25.320000, total balance 9746.919999
# day 505: buy 1 unit at price 26.400000, total balance 9720.520000
# day 512, sell 1 unit at price 26.400000, investment 7.843138 %, total balance 9746.919999,
# day 522: buy 1 unit at price 25.799999, total balance 9721.120000
# day 523, sell 1 unit at price 25.799999, investment 20.786510 %, total balance 9746.919999,
# day 524, sell 1 unit at price 25.799999, investment 16.216209 %, total balance 9772.719998,
# day 529, sell 1 unit at price 26.400000, investment 9.999998 %, total balance 9799.119998,
# day 531: buy 1 unit at price 26.400000, total balance 9772.719998
# day 533, sell 1 unit at price 26.400000, investment 7.843138 %, total balance 9799.119998,
# day 534, sell 1 unit at price 26.040001, investment 19.230773 %, total balance 9825.159999,
# day 535: buy 1 unit at price 26.400000, total balance 9798.759999
# day 536: buy 1 unit at price 26.160000, total balance 9772.599999
# day 538: buy 1 unit at price 26.400000, total balance 9746.200000
# day 539, sell 1 unit at price 26.400000, investment 2.803736 %, total balance 9772.599999,
# day 544, sell 1 unit at price 30.600000, investment 21.428569 %, total balance 9803.200000,
# day 545, sell 1 unit at price 30.240000, investment 19.431280 %, total balance 9833.440000,
# day 548, sell 1 unit at price 29.040001, investment 10.000005 %, total balance 9862.480001,
# day 552, sell 1 unit at price 27.840000, investment 7.906981 %, total balance 9890.320001,
# day 556, sell 1 unit at price 27.959999, investment 5.909089 %, total balance 9918.280000,
# day 558: buy 1 unit at price 28.440001, total balance 9889.839999
# day 559, sell 1 unit at price 27.840000, investment 5.454548 %, total balance 9917.679999,
# day 561, sell 1 unit at price 27.360001, investment 4.587159 %, total balance 9945.040000,
# day 562, sell 1 unit at price 27.120001, investment 2.727277 %, total balance 9972.160001,
# day 565: buy 1 unit at price 26.400000, total balance 9945.760001
# day 572, sell 1 unit at price 29.879999, investment 5.063286 %, total balance 9975.640000,
# day 573, sell 1 unit at price 29.639999, investment 12.272727 %, total balance 10005.280000,
# day 576: buy 1 unit at price 29.760000, total balance 9975.520000
# day 579, sell 1 unit at price 30.600000, investment 2.822581 %, total balance 10006.120000,
# day 582: buy 1 unit at price 31.799999, total balance 9974.320001
# day 584, sell 1 unit at price 30.959999, investment -2.641510 %, total balance 10005.280000,
# day 623: buy 1 unit at price 32.759998, total balance 9972.520001
# day 625: buy 1 unit at price 31.680000, total balance 9940.840001
# day 629: buy 1 unit at price 31.080000, total balance 9909.760001
# day 635, sell 1 unit at price 30.719999, investment -6.227104 %, total balance 9940.480000,
# day 639, sell 1 unit at price 34.080002, investment 7.575762 %, total balance 9974.560002,
# day 641, sell 1 unit at price 33.000000, investment 6.177606 %, total balance 10007.560002,
# day 645: buy 1 unit at price 30.600000, total balance 9976.960002
# day 646, sell 1 unit at price 29.879999, investment -2.352945 %, total balance 10006.840001,
# day 650: buy 1 unit at price 29.639999, total balance 9977.200002
# day 654, sell 1 unit at price 28.920000, investment -2.429148 %, total balance 10006.120002,
# day 662: buy 1 unit at price 27.840000, total balance 9978.280002
# day 670, sell 1 unit at price 27.600000, investment -0.862068 %, total balance 10005.880002,
# day 679: buy 1 unit at price 30.240000, total balance 9975.640002
# day 686, sell 1 unit at price 29.040001, investment -3.968250 %, total balance 10004.680003,
# day 688: buy 1 unit at price 32.279999, total balance 9972.400004
# day 691: buy 1 unit at price 31.200001, total balance 9941.200004
# day 692, sell 1 unit at price 30.840000, investment -4.460962 %, total balance 9972.040004,
# day 693: buy 1 unit at price 30.959999, total balance 9941.080005
# day 694: buy 1 unit at price 30.840000, total balance 9910.240005
# day 695, sell 1 unit at price 31.080000, investment -0.384618 %, total balance 9941.320004,
# day 696: buy 1 unit at price 31.080000, total balance 9910.240005
# day 699: buy 1 unit at price 30.959999, total balance 9879.280005
# day 700: buy 1 unit at price 31.080000, total balance 9848.200006
# day 702, sell 1 unit at price 29.520000, investment -4.651158 %, total balance 9877.720006,
# day 703: buy 1 unit at price 30.000000, total balance 9847.720006
# day 705, sell 1 unit at price 29.160000, investment -5.447472 %, total balance 9876.880006,
# day 708: buy 1 unit at price 29.280001, total balance 9847.600005
# day 710, sell 1 unit at price 28.799999, investment -7.335910 %, total balance 9876.400004,
# day 714, sell 1 unit at price 28.200001, investment -8.914724 %, total balance 9904.600005,
# day 720, sell 1 unit at price 27.959999, investment -10.038613 %, total balance 9932.560004,
# day 729, sell 1 unit at price 28.559999, investment -4.800002 %, total balance 9961.120004,
# day 730, sell 1 unit at price 28.440001, investment -2.868853 %, total balance 9989.560004,
# day 735: buy 1 unit at price 29.160000, total balance 9960.400004
# day 741, sell 1 unit at price 33.720001, investment 15.637865 %, total balance 9994.120006,
# day 742: buy 1 unit at price 31.680000, total balance 9962.440005
# day 751: buy 1 unit at price 29.040001, total balance 9933.400004
# day 752: buy 1 unit at price 29.040001, total balance 9904.360003
# day 765: buy 1 unit at price 27.480000, total balance 9876.880004
# day 767: buy 1 unit at price 25.680000, total balance 9851.200004
# day 771, sell 1 unit at price 27.480000, investment -13.257578 %, total balance 9878.680003,
# day 774: buy 1 unit at price 29.040001, total balance 9849.640002
# day 778: buy 1 unit at price 30.240000, total balance 9819.400002
# day 779, sell 1 unit at price 29.760000, investment 2.479336 %, total balance 9849.160003,
# day 785: buy 1 unit at price 28.200001, total balance 9820.960002
# day 786, sell 1 unit at price 28.080000, investment -3.305788 %, total balance 9849.040002,
# day 789, sell 1 unit at price 29.280001, investment 6.550223 %, total balance 9878.320003,
# day 798, sell 1 unit at price 27.600000, investment 7.476636 %, total balance 9905.920003,
# day 799, sell 1 unit at price 27.840000, investment -4.132234 %, total balance 9933.760003,
# day 800, sell 1 unit at price 27.360001, investment -9.523807 %, total balance 9961.120004,
# day 814, sell 1 unit at price 27.959999, investment -0.851070 %, total balance 9989.080003,
# day 817: buy 1 unit at price 27.719999, total balance 9961.360003
# day 821, sell 1 unit at price 27.959999, investment 0.865800 %, total balance 9989.320003,
# day 830: buy 1 unit at price 27.360001, total balance 9961.960002
# day 831, sell 1 unit at price 27.240000, investment -0.438600 %, total balance 9989.200002,
# day 834: buy 1 unit at price 27.240000, total balance 9961.960002
# day 837, sell 1 unit at price 26.760000, investment -1.762113 %, total balance 9988.720002,
# day 838: buy 1 unit at price 27.000000, total balance 9961.720002
# day 842: buy 1 unit at price 27.360001, total balance 9934.360002
# day 847: buy 1 unit at price 27.719999, total balance 9906.640002
# day 850, sell 1 unit at price 28.559999, investment 5.777776 %, total balance 9935.200002,
# day 851, sell 1 unit at price 28.680000, investment 4.824560 %, total balance 9963.880002,
# day 860: buy 1 unit at price 28.080000, total balance 9935.800002
# day 881: buy 1 unit at price 26.879999, total balance 9908.920003
# day 885, sell 1 unit at price 26.760000, investment -3.463200 %, total balance 9935.680003,
# day 887, sell 1 unit at price 27.360001, investment -2.564100 %, total balance 9963.040004,
# day 889, sell 1 unit at price 27.000000, investment 0.446432 %, total balance 9990.040004,
# day 893: buy 1 unit at price 27.600000, total balance 9962.440003
# day 902, sell 1 unit at price 28.799999, investment 4.347822 %, total balance 9991.240003,
# day 908: buy 1 unit at price 27.600000, total balance 9963.640002
# day 911, sell 1 unit at price 28.440001, investment 3.043479 %, total balance 9992.080003,
# day 921: buy 1 unit at price 28.440001, total balance 9963.640002
# day 933: buy 1 unit at price 29.400000, total balance 9934.240003
# day 941, sell 1 unit at price 27.240000, investment -4.219412 %, total balance 9961.480002,
# day 942, sell 1 unit at price 26.879999, investment -8.571430 %, total balance 9988.360002,
# day 960: buy 1 unit at price 24.600000, total balance 9963.760001
# day 962, sell 1 unit at price 25.200001, investment 2.439026 %, total balance 9988.960002,
# day 963: buy 1 unit at price 24.600000, total balance 9964.360002
# day 965, sell 1 unit at price 25.200001, investment 2.439026 %, total balance 9989.560002,
# day 968: buy 1 unit at price 24.000000, total balance 9965.560002
# day 971, sell 1 unit at price 22.799999, investment -5.000003 %, total balance 9988.360002,
# day 981: buy 1 unit at price 20.400000, total balance 9967.960002
# day 982: buy 1 unit at price 20.400000, total balance 9947.560002
# day 983, sell 1 unit at price 21.000000, investment 2.941178 %, total balance 9968.560002,
# day 986, sell 1 unit at price 20.400000, investment 0.000000 %, total balance 9988.960002,
# day 988: buy 1 unit at price 18.600000, total balance 9970.360002
# day 1009: buy 1 unit at price 18.000000, total balance 9952.360002
# day 1016, sell 1 unit at price 18.000000, investment -3.225808 %, total balance 9970.360002,
# day 1017: buy 1 unit at price 17.400000, total balance 9952.960002
# day 1021, sell 1 unit at price 17.400000, investment -3.333335 %, total balance 9970.360002,
# day 1026, sell 1 unit at price 16.799999, investment -3.448278 %, total balance 9987.160001,
# day 1034: buy 1 unit at price 16.799999, total balance 9970.360002
# day 1040, sell 1 unit at price 15.960000, investment -4.999995 %, total balance 9986.320002,
# day 1044: buy 1 unit at price 15.960000, total balance 9970.360002
# day 1045: buy 1 unit at price 16.200001, total balance 9954.160001
# day 1046: buy 1 unit at price 16.200001, total balance 9937.960000
# day 1048: buy 1 unit at price 15.000000, total balance 9922.960000
# day 1049: buy 1 unit at price 15.600000, total balance 9907.360000
# day 1054, sell 1 unit at price 13.200000, investment -17.293234 %, total balance 9920.559999,
# day 1060, sell 1 unit at price 16.799999, investment 3.703694 %, total balance 9937.359999,
# day 1061, sell 1 unit at price 16.200001, investment 0.000000 %, total balance 9953.559999,
# day 1064, sell 1 unit at price 15.600000, investment 4.000003 %, total balance 9969.160000,
# day 1070, sell 1 unit at price 17.160000, investment 9.999996 %, total balance 9986.320000,
# day 1080: buy 1 unit at price 18.600000, total balance 9967.719999
# day 1092: buy 1 unit at price 15.600000, total balance 9952.119999
# day 1103, sell 1 unit at price 14.400000, investment -22.580649 %, total balance 9966.519999,
# day 1104, sell 1 unit at price 14.160000, investment -9.230772 %, total balance 9980.679998,
# day 1108: buy 1 unit at price 13.200000, total balance 9967.479999
# day 1110, sell 1 unit at price 13.200000, investment 0.000000 %, total balance 9980.679998,
# day 1114: buy 1 unit at price 13.800000, total balance 9966.879998
# day 1116: buy 1 unit at price 13.800000, total balance 9953.079998
# day 1117, sell 1 unit at price 13.800000, investment 0.000000 %, total balance 9966.879998,
# day 1119, sell 1 unit at price 14.160000, investment 2.608693 %, total balance 9981.039998,
# day 1153: buy 1 unit at price 14.400000, total balance 9966.639998
# day 1154: buy 1 unit at price 13.800000, total balance 9952.839998
# day 1159, sell 1 unit at price 13.200000, investment -8.333332 %, total balance 9966.039998,
# day 1163, sell 1 unit at price 13.200000, investment -4.347829 %, total balance 9979.239998,
# day 1166: buy 1 unit at price 14.400000, total balance 9964.839998
# day 1171, sell 1 unit at price 15.600000, investment 8.333339 %, total balance 9980.439999,
# day 1182: buy 1 unit at price 13.200000, total balance 9967.239999
# day 1184: buy 1 unit at price 13.200000, total balance 9954.039999
# day 1186, sell 1 unit at price 13.800000, investment 4.545457 %, total balance 9967.839999,
# day 1189: buy 1 unit at price 13.200000, total balance 9954.639999
# day 1190, sell 1 unit at price 13.200000, investment 0.000000 %, total balance 9967.839999,
# day 1192, sell 1 unit at price 12.600000, investment -4.545450 %, total balance 9980.440000,
# day 1193: buy 1 unit at price 13.200000, total balance 9967.240000
# day 1197: buy 1 unit at price 11.400000, total balance 9955.840000
# day 1209: buy 1 unit at price 10.080000, total balance 9945.760000
# day 1212, sell 1 unit at price 8.760000, investment -33.636361 %, total balance 9954.520000,
# day 1223: buy 1 unit at price 8.520000, total balance 9946.000000
# day 1224: buy 1 unit at price 8.400000, total balance 9937.600000
# day 1233, sell 1 unit at price 8.640000, investment -24.210521 %, total balance 9946.240001,
# day 1235, sell 1 unit at price 8.520000, investment -15.476185 %, total balance 9954.760001,
# day 1238, sell 1 unit at price 10.080000, investment 18.309852 %, total balance 9964.840001,
# day 1244: buy 1 unit at price 10.800000, total balance 9954.040001
# day 1247, sell 1 unit at price 9.720000, investment 15.714294 %, total balance 9963.760001,
# day 1249: buy 1 unit at price 8.880000, total balance 9954.880001
# day 1251, sell 1 unit at price 8.640000, investment -19.999998 %, total balance 9963.520001,
# day 1256: buy 1 unit at price 9.360000, total balance 9954.160002
# day 1258: buy 1 unit at price 10.200000, total balance 9943.960002
# day 1259, sell 1 unit at price 10.200000, investment 14.864861 %, total balance 9954.160002,
# day 1260, sell 1 unit at price 9.960000, investment 6.410261 %, total balance 9964.120002,
# day 1262: buy 1 unit at price 10.920000, total balance 9953.200002
# day 1264, sell 1 unit at price 10.680000, investment 4.705887 %, total balance 9963.880002,
# day 1265, sell 1 unit at price 11.280000, investment 3.296700 %, total balance 9975.160002,
# day 1269: buy 1 unit at price 11.760000, total balance 9963.400002
# day 1271: buy 1 unit at price 11.760000, total balance 9951.640001
# day 1274: buy 1 unit at price 11.640000, total balance 9940.000001
# day 1279: buy 1 unit at price 11.280000, total balance 9928.720001
# day 1294: buy 1 unit at price 14.760000, total balance 9913.960001
# day 1295, sell 1 unit at price 15.000000, investment 27.551018 %, total balance 9928.960001,
# day 1296: buy 1 unit at price 15.480000, total balance 9913.480001
# day 1305, sell 1 unit at price 17.040001, investment 44.897964 %, total balance 9930.520002,
# day 1307, sell 1 unit at price 16.200001, investment 39.175260 %, total balance 9946.720003,
# day 1308: buy 1 unit at price 16.440001, total balance 9930.280003
# day 1309: buy 1 unit at price 16.320000, total balance 9913.960003
# day 1315: buy 1 unit at price 17.040001, total balance 9896.920002
# day 1316: buy 1 unit at price 17.160000, total balance 9879.760002
# day 1320, sell 1 unit at price 16.320000, investment 44.680852 %, total balance 9896.080002,
# day 1321: buy 1 unit at price 16.320000, total balance 9879.760002
# day 1327: buy 1 unit at price 17.280001, total balance 9862.480001
# day 1328: buy 1 unit at price 17.400000, total balance 9845.080002
# day 1329: buy 1 unit at price 17.280001, total balance 9827.800001
# day 1338: buy 1 unit at price 16.920000, total balance 9810.880001
# day 1342: buy 1 unit at price 16.680000, total balance 9794.200001
# day 1346, sell 1 unit at price 16.799999, investment 13.821131 %, total balance 9811.000000,
# day 1353, sell 1 unit at price 16.799999, investment 8.527130 %, total balance 9827.799999,
# day 1364: buy 1 unit at price 16.080000, total balance 9811.719999
# day 1368, sell 1 unit at price 15.960000, investment -2.919711 %, total balance 9827.679999,
# day 1371: buy 1 unit at price 16.080000, total balance 9811.599999
# day 1375: buy 1 unit at price 15.480000, total balance 9796.120000
# day 1378: buy 1 unit at price 16.200001, total balance 9779.919999
# day 1381, sell 1 unit at price 15.720000, investment -3.676467 %, total balance 9795.639999,
# day 1382: buy 1 unit at price 16.080000, total balance 9779.559999
# day 1394: buy 1 unit at price 16.559999, total balance 9763.000000
# day 1398: buy 1 unit at price 16.920000, total balance 9746.080000
# day 1399, sell 1 unit at price 17.639999, investment 3.521118 %, total balance 9763.719999,
# day 1401, sell 1 unit at price 18.240000, investment 6.293706 %, total balance 9781.959999,
# day 1407: buy 1 unit at price 15.960000, total balance 9765.999999
# day 1408: buy 1 unit at price 15.840000, total balance 9750.159999
# day 1411, sell 1 unit at price 16.559999, investment 1.470587 %, total balance 9766.719998,
# day 1422: buy 1 unit at price 18.840000, total balance 9747.879998
# day 1436: buy 1 unit at price 18.000000, total balance 9729.879998
# day 1438, sell 1 unit at price 16.799999, investment -2.777786 %, total balance 9746.679997,
# day 1444, sell 1 unit at price 16.559999, investment -4.827587 %, total balance 9763.239997,
# day 1450, sell 1 unit at price 16.680000, investment -3.472224 %, total balance 9779.919997,
# day 1452, sell 1 unit at price 16.200001, investment -4.255315 %, total balance 9796.119998,
# day 1454, sell 1 unit at price 15.720000, investment -5.755396 %, total balance 9811.839998,
# day 1458: buy 1 unit at price 15.220000, total balance 9796.619998
# day 1459, sell 1 unit at price 14.760000, investment -8.208953 %, total balance 9811.379998,
# day 1460: buy 1 unit at price 14.340000, total balance 9797.039998
# day 1461: buy 1 unit at price 14.580000, total balance 9782.459998
# day 1462, sell 1 unit at price 14.440000, investment -10.199007 %, total balance 9796.899998,
# day 1463: buy 1 unit at price 14.530000, total balance 9782.369998
# day 1465, sell 1 unit at price 14.250000, investment -7.945734 %, total balance 9796.619998,
# day 1466: buy 1 unit at price 13.790000, total balance 9782.829998
# day 1467: buy 1 unit at price 13.800000, total balance 9769.029998
# day 1468: buy 1 unit at price 14.220000, total balance 9754.809998
# day 1469: buy 1 unit at price 14.490000, total balance 9740.319998
# day 1476, sell 1 unit at price 15.110000, investment -6.728402 %, total balance 9755.429997,
# day 1477, sell 1 unit at price 14.570000, investment -9.390549 %, total balance 9769.999997,
# day 1485, sell 1 unit at price 14.190000, investment -14.311594 %, total balance 9784.189997,
# day 1488: buy 1 unit at price 14.930000, total balance 9769.259996
# day 1490, sell 1 unit at price 15.130000, investment -10.579196 %, total balance 9784.389997,
# day 1494, sell 1 unit at price 13.460000, investment -15.664160 %, total balance 9797.849997,
# day 1496: buy 1 unit at price 13.940000, total balance 9783.909997
# day 1499, sell 1 unit at price 13.340000, investment -15.782828 %, total balance 9797.249997,
# day 1501, sell 1 unit at price 12.330000, investment -34.554141 %, total balance 9809.579997,
# day 1504, sell 1 unit at price 11.340000, investment -36.999999 %, total balance 9820.919997,
# day 1507: buy 1 unit at price 11.300000, total balance 9809.619997
# day 1512: buy 1 unit at price 12.790000, total balance 9796.829997
# day 1514: buy 1 unit at price 13.480000, total balance 9783.349998
# day 1516: buy 1 unit at price 13.910000, total balance 9769.439998
# day 1519: buy 1 unit at price 13.790000, total balance 9755.649998
# day 1530, sell 1 unit at price 15.390000, investment 1.116952 %, total balance 9771.039998,
# day 1533: buy 1 unit at price 15.150000, total balance 9755.889998
# day 1536, sell 1 unit at price 15.190000, investment 5.927472 %, total balance 9771.079998,
# day 1539: buy 1 unit at price 14.570000, total balance 9756.509998
# day 1542, sell 1 unit at price 14.760000, investment 1.234570 %, total balance 9771.269999,
# day 1545, sell 1 unit at price 14.550000, investment 0.137649 %, total balance 9785.819999,
# day 1546: buy 1 unit at price 14.160000, total balance 9771.659999
# day 1547, sell 1 unit at price 13.990000, investment 1.450325 %, total balance 9785.649999,
# day 1548, sell 1 unit at price 13.880000, investment 0.579710 %, total balance 9799.529999,
# day 1551: buy 1 unit at price 13.290000, total balance 9786.239999
# day 1552, sell 1 unit at price 13.260000, investment -6.751055 %, total balance 9799.499999,
# day 1555, sell 1 unit at price 13.010000, investment -10.213938 %, total balance 9812.509999,
# day 1556, sell 1 unit at price 12.860000, investment -13.864706 %, total balance 9825.369999,
# day 1558, sell 1 unit at price 12.430000, investment -10.832133 %, total balance 9837.799999,
# day 1561: buy 1 unit at price 12.350000, total balance 9825.449999
# day 1564: buy 1 unit at price 10.940000, total balance 9814.509999
# day 1566, sell 1 unit at price 9.610000, investment -14.955757 %, total balance 9824.119999,
# day 1570, sell 1 unit at price 9.590000, investment -25.019545 %, total balance 9833.709999,
# day 1573, sell 1 unit at price 9.340000, investment -30.712163 %, total balance 9843.049999,
# day 1581: buy 1 unit at price 9.010000, total balance 9834.039999
# day 1583: buy 1 unit at price 8.750000, total balance 9825.289999
# day 1587, sell 1 unit at price 8.560000, investment -38.461535 %, total balance 9833.849999,
# day 1588: buy 1 unit at price 8.290000, total balance 9825.560000
# day 1590: buy 1 unit at price 8.880000, total balance 9816.679999
# day 1592, sell 1 unit at price 9.100000, investment -34.010149 %, total balance 9825.780000,
# day 1599: buy 1 unit at price 9.580000, total balance 9816.200000
# day 1600: buy 1 unit at price 8.860000, total balance 9807.340000
# day 1603, sell 1 unit at price 9.100000, investment -39.933989 %, total balance 9816.440001,
# day 1606, sell 1 unit at price 8.880000, investment -39.052846 %, total balance 9825.320001,
# day 1620: buy 1 unit at price 7.380000, total balance 9817.940001
# day 1625, sell 1 unit at price 7.250000, investment -48.799434 %, total balance 9825.190001,
# day 1628, sell 1 unit at price 7.310000, investment -44.996238 %, total balance 9832.500001,
# day 1638: buy 1 unit at price 7.880000, total balance 9824.620000
# day 1640, sell 1 unit at price 7.910000, investment -35.951420 %, total balance 9832.530000,
# day 1643: buy 1 unit at price 7.900000, total balance 9824.630000
# day 1644, sell 1 unit at price 7.910000, investment -27.696525 %, total balance 9832.540000,
# day 1647, sell 1 unit at price 7.590000, investment -15.760267 %, total balance 9840.130000,
# day 1648: buy 1 unit at price 7.260000, total balance 9832.870000
# day 1652, sell 1 unit at price 7.740000, investment -11.542860 %, total balance 9840.610000,
# day 1654: buy 1 unit at price 7.640000, total balance 9832.970000
# day 1658, sell 1 unit at price 8.860000, investment 6.875750 %, total balance 9841.829999,
# day 1663: buy 1 unit at price 9.390000, total balance 9832.439999
# day 1666, sell 1 unit at price 9.060000, investment 2.027030 %, total balance 9841.500000,
# day 1669: buy 1 unit at price 9.540000, total balance 9831.960000
# day 1672, sell 1 unit at price 9.050000, investment -5.532356 %, total balance 9841.010000,
# day 1673: buy 1 unit at price 9.090000, total balance 9831.920000
# day 1674: buy 1 unit at price 8.960000, total balance 9822.960000
# day 1683, sell 1 unit at price 9.690000, investment 9.367945 %, total balance 9832.649999,
# day 1689, sell 1 unit at price 10.800000, investment 46.341464 %, total balance 9843.449999,
# day 1691: buy 1 unit at price 11.150000, total balance 9832.300000
# day 1692, sell 1 unit at price 11.200000, investment 42.131975 %, total balance 9843.500000,
# day 1695, sell 1 unit at price 10.910000, investment 38.101262 %, total balance 9854.409999,
# day 1704: buy 1 unit at price 10.780000, total balance 9843.630000
# day 1705, sell 1 unit at price 10.690000, investment 47.245169 %, total balance 9854.319999,
# day 1706: buy 1 unit at price 10.700000, total balance 9843.619999
# day 1713, sell 1 unit at price 12.140000, investment 58.900531 %, total balance 9855.760000,
# day 1714: buy 1 unit at price 12.070000, total balance 9843.690000
# day 1715, sell 1 unit at price 12.100000, investment 28.860489 %, total balance 9855.790000,
# day 1720: buy 1 unit at price 12.800000, total balance 9842.990000
# day 1721, sell 1 unit at price 12.800000, investment 34.171910 %, total balance 9855.790000,
# day 1726, sell 1 unit at price 12.530000, investment 37.843779 %, total balance 9868.320000,
# day 1730, sell 1 unit at price 12.480000, investment 39.285709 %, total balance 9880.800000,
# day 1732: buy 1 unit at price 12.550000, total balance 9868.250000
# day 1737, sell 1 unit at price 13.400000, investment 20.179373 %, total balance 9881.649999,
# day 1743, sell 1 unit at price 13.300000, investment 23.376628 %, total balance 9894.949999,
# day 1745, sell 1 unit at price 13.350000, investment 24.766361 %, total balance 9908.300000,
# day 1750: buy 1 unit at price 12.640000, total balance 9895.659999
# day 1753, sell 1 unit at price 12.650000, investment 4.805302 %, total balance 9908.309999,
# day 1755, sell 1 unit at price 12.740000, investment -0.468753 %, total balance 9921.049999,
# day 1759, sell 1 unit at price 12.830000, investment 2.231074 %, total balance 9933.879999,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
