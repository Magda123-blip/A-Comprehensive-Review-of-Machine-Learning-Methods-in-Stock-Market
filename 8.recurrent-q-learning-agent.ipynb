# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../Kaggle_dataset/AADR1.csv')
df.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close  Volume
# 0  1/2/2013  31.650000  31.650000  31.500000  31.500000  30.171495    1500
# 1  1/3/2013  31.530001  31.730000  31.430000  31.639999  30.305590    3400
# 2  1/4/2013  31.490000  31.700001  31.490000  31.549999  30.219389    2600
# 3  1/7/2013  31.730000  31.799999  31.730000  31.799999  30.458843     600
# 4  1/8/2013  31.440001  31.629999  31.440001  31.450001  30.123606    5500

# %%
from collections import deque
import random
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.X = tf.placeholder(tf.float32, (None, None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, self.OUTPUT_SIZE))
        cell = tf.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
        self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * self.LAYER_SIZE))
        self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
        self.logits = tf.layers.dense(self.rnn[:,-1], self.OUTPUT_SIZE)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.logits, feed_dict={self.X:states, self.hidden_layer:init_values})
        Q_new = self.sess.run(self.logits, feed_dict={self.X:new_states, self.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * np.amax(Q_new[i])
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.logits,self.last_state],
                                                feed_dict={self.X:[self.INITIAL_FEATURES],
                                                            self.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.logits,
                                                  self.last_state],
                                                  feed_dict={self.X:[self.INITIAL_FEATURES],
                                                             self.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.cost, self.optimizer], 
                                        feed_dict={self.X: X, self.Y:Y,
                                                  self.hidden_layer: INIT_VAL})
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
                
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-deb04c5fc6f6>:27: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000198AC0E3048>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:From <ipython-input-3-deb04c5fc6f6>:31: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py:961: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000198AC0E3048>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000198AC0E3048>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000198AC0E3048>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000198AC0E3048>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From <ipython-input-3-deb04c5fc6f6>:32: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000198AE8F2908>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000198AE8F2908>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000198AE8F2908>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000198AE8F2908>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: 252.720020.3, cost: 0.008482, total money: 9733.340019
# epoch: 20, total rewards: 171.499968.3, cost: 0.023713, total money: 9903.919970
# epoch: 30, total rewards: 128.640001.3, cost: 0.015582, total money: 9566.510004
# epoch: 40, total rewards: 183.660038.3, cost: 0.026016, total money: 8926.390041
# epoch: 50, total rewards: 49.060032.3, cost: 0.019266, total money: 9886.530033
# epoch: 60, total rewards: 35.589930.3, cost: 0.099529, total money: 7890.279924
# epoch: 70, total rewards: 642.260050.3, cost: 0.172643, total money: 8807.580057
# epoch: 80, total rewards: -26.529991.3, cost: 0.003094, total money: 9757.350010
# epoch: 90, total rewards: 86.719942.3, cost: 0.345874, total money: 9981.619940
# epoch: 100, total rewards: 211.700039.3, cost: 3.488708, total money: 10157.190041
# epoch: 110, total rewards: 84.750021.3, cost: 0.010581, total money: 10030.750021
# epoch: 120, total rewards: 339.830032.3, cost: 0.116290, total money: 10286.670032
# epoch: 130, total rewards: 651.310028.3, cost: 0.293102, total money: 9625.200028
# epoch: 140, total rewards: 78.650044.3, cost: 0.194411, total money: 10078.650044
# epoch: 150, total rewards: 333.989975.3, cost: 0.038979, total money: 8933.859974
# epoch: 160, total rewards: 92.670056.3, cost: 0.007188, total money: 9828.440052
# epoch: 170, total rewards: 117.590000.3, cost: 0.022903, total money: 9454.619999
# epoch: 180, total rewards: 1.350019.3, cost: 0.007283, total money: 9582.330015
# epoch: 190, total rewards: 12.429962.3, cost: 0.145007, total money: 10012.429962
# epoch: 200, total rewards: 37.509983.3, cost: 0.053236, total money: 9984.969982

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 883: buy 1 unit at price 38.930000, total balance 9961.070000
# day 884: buy 1 unit at price 38.930000, total balance 9922.139999
# day 885: buy 1 unit at price 39.189999, total balance 9882.950001
# day 886: buy 1 unit at price 39.279999, total balance 9843.670002
# day 887: buy 1 unit at price 40.000000, total balance 9803.670002
# day 888: buy 1 unit at price 39.779999, total balance 9763.890003
# day 889: buy 1 unit at price 39.889999, total balance 9724.000004
# day 890: buy 1 unit at price 39.509998, total balance 9684.490005
# day 891: buy 1 unit at price 40.599998, total balance 9643.890007
# day 892: buy 1 unit at price 40.290001, total balance 9603.600006
# day 893: buy 1 unit at price 40.450001, total balance 9563.150005
# day 894: buy 1 unit at price 40.599998, total balance 9522.550007
# day 895: buy 1 unit at price 40.330002, total balance 9482.220005
# day 896: buy 1 unit at price 40.590000, total balance 9441.630005
# day 897: buy 1 unit at price 40.950001, total balance 9400.680004
# day 898: buy 1 unit at price 40.959999, total balance 9359.720005
# day 899: buy 1 unit at price 40.689999, total balance 9319.030006
# day 900: buy 1 unit at price 40.590000, total balance 9278.440006
# day 901: buy 1 unit at price 40.590000, total balance 9237.850006
# day 902: buy 1 unit at price 40.590000, total balance 9197.260006
# day 903: buy 1 unit at price 40.580002, total balance 9156.680004
# day 904: buy 1 unit at price 40.580002, total balance 9116.100002
# day 905: buy 1 unit at price 40.580002, total balance 9075.520000
# day 906: buy 1 unit at price 40.500000, total balance 9035.020000
# day 907: buy 1 unit at price 40.500000, total balance 8994.520000
# day 908: buy 1 unit at price 40.389999, total balance 8954.130001
# day 909: buy 1 unit at price 41.200001, total balance 8912.930000
# day 910: buy 1 unit at price 40.880001, total balance 8872.049999
# day 911: buy 1 unit at price 41.049999, total balance 8831.000000
# day 912: buy 1 unit at price 41.340000, total balance 8789.660000
# day 913: buy 1 unit at price 41.340000, total balance 8748.320000
# day 914: buy 1 unit at price 41.119999, total balance 8707.200001
# day 915: buy 1 unit at price 40.849998, total balance 8666.350002
# day 916: buy 1 unit at price 40.849998, total balance 8625.500004
# day 917: buy 1 unit at price 41.000000, total balance 8584.500004
# day 918: buy 1 unit at price 40.759998, total balance 8543.740006
# day 919: buy 1 unit at price 40.759998, total balance 8502.980007
# day 920: buy 1 unit at price 40.599998, total balance 8462.380009
# day 921: buy 1 unit at price 40.669998, total balance 8421.710011
# day 922: buy 1 unit at price 40.709999, total balance 8381.000011
# day 923: buy 1 unit at price 40.160000, total balance 8340.840012
# day 924: buy 1 unit at price 40.330002, total balance 8300.510010
# day 925: buy 1 unit at price 40.630001, total balance 8259.880009
# day 926: buy 1 unit at price 40.910000, total balance 8218.970009
# day 927: buy 1 unit at price 41.060001, total balance 8177.910008
# day 928: buy 1 unit at price 40.810001, total balance 8137.100006
# day 929: buy 1 unit at price 39.650002, total balance 8097.450005
# day 930: buy 1 unit at price 39.720001, total balance 8057.730003
# day 931: buy 1 unit at price 39.000000, total balance 8018.730003
# day 932: buy 1 unit at price 39.060001, total balance 7979.670002
# day 933: buy 1 unit at price 39.650002, total balance 7940.020000
# day 934: buy 1 unit at price 39.110001, total balance 7900.910000
# day 935: buy 1 unit at price 39.110001, total balance 7861.799999
# day 936: buy 1 unit at price 39.770000, total balance 7822.029999
# day 937: buy 1 unit at price 40.299999, total balance 7781.730000
# day 938: buy 1 unit at price 41.009998, total balance 7740.720001
# day 939: buy 1 unit at price 40.669998, total balance 7700.050003
# day 940: buy 1 unit at price 39.950001, total balance 7660.100002
# day 941: buy 1 unit at price 39.700001, total balance 7620.400002
# day 942: buy 1 unit at price 40.130001, total balance 7580.270000
# day 943: buy 1 unit at price 40.400002, total balance 7539.869999
# day 944: buy 1 unit at price 40.580002, total balance 7499.289997
# day 945: buy 1 unit at price 40.580002, total balance 7458.709995
# day 946: buy 1 unit at price 40.119999, total balance 7418.589996
# day 947: buy 1 unit at price 40.330002, total balance 7378.259995
# day 948: buy 1 unit at price 40.330002, total balance 7337.929993
# day 949: buy 1 unit at price 40.410000, total balance 7297.519993
# day 950: buy 1 unit at price 40.410000, total balance 7257.109993
# day 951: buy 1 unit at price 40.080002, total balance 7217.029991
# day 952: buy 1 unit at price 40.139999, total balance 7176.889992
# day 953: buy 1 unit at price 39.990002, total balance 7136.899990
# day 954: buy 1 unit at price 40.189999, total balance 7096.709991
# day 955: buy 1 unit at price 40.220001, total balance 7056.489990
# day 956: buy 1 unit at price 40.889999, total balance 7015.599991
# day 957: buy 1 unit at price 41.349998, total balance 6974.249992
# day 958: buy 1 unit at price 41.080002, total balance 6933.169991
# day 959: buy 1 unit at price 41.830002, total balance 6891.339989
# day 960: buy 1 unit at price 41.919998, total balance 6849.419991
# day 961: buy 1 unit at price 42.490002, total balance 6806.929989
# day 962: buy 1 unit at price 41.759998, total balance 6765.169991
# day 963: buy 1 unit at price 41.840000, total balance 6723.329990
# day 964: buy 1 unit at price 41.540001, total balance 6681.789990
# day 965: buy 1 unit at price 41.680000, total balance 6640.109989
# day 966: buy 1 unit at price 40.980000, total balance 6599.129990
# day 967: buy 1 unit at price 40.619999, total balance 6558.509991
# day 968: buy 1 unit at price 40.610001, total balance 6517.899990
# day 969: buy 1 unit at price 40.560001, total balance 6477.339989
# day 970: buy 1 unit at price 41.060001, total balance 6436.279987
# day 971: buy 1 unit at price 41.599998, total balance 6394.679989
# day 972: buy 1 unit at price 41.439999, total balance 6353.239990
# day 973: buy 1 unit at price 40.549999, total balance 6312.689991
# day 974: buy 1 unit at price 39.090000, total balance 6273.599991
# day 975: buy 1 unit at price 38.500000, total balance 6235.099991
# day 976: buy 1 unit at price 39.380001, total balance 6195.719990
# day 977: buy 1 unit at price 39.099998, total balance 6156.619991
# day 978: buy 1 unit at price 39.139999, total balance 6117.479992
# day 979: buy 1 unit at price 39.540001, total balance 6077.939991
# day 980: buy 1 unit at price 40.160000, total balance 6037.779991
# day 981: buy 1 unit at price 40.910000, total balance 5996.869991
# day 982: buy 1 unit at price 40.790001, total balance 5956.079990
# day 983: buy 1 unit at price 40.740002, total balance 5915.339989
# day 984: buy 1 unit at price 41.040001, total balance 5874.299988
# day 985: buy 1 unit at price 40.540001, total balance 5833.759987
# day 986: buy 1 unit at price 40.680000, total balance 5793.079987
# day 987: buy 1 unit at price 39.750000, total balance 5753.329987
# day 988: buy 1 unit at price 39.810001, total balance 5713.519985
# day 989: buy 1 unit at price 40.119999, total balance 5673.399986
# day 990: buy 1 unit at price 40.669998, total balance 5632.729988
# day 991: buy 1 unit at price 40.849998, total balance 5591.879990
# day 992: buy 1 unit at price 40.799999, total balance 5551.079990
# day 993: buy 1 unit at price 40.680000, total balance 5510.399990
# day 994: buy 1 unit at price 40.459999, total balance 5469.939991
# day 995: buy 1 unit at price 40.830002, total balance 5429.109989
# day 996: buy 1 unit at price 40.040001, total balance 5389.069988
# day 997: buy 1 unit at price 40.119999, total balance 5348.949989
# day 998: buy 1 unit at price 39.660000, total balance 5309.289989
# day 999: buy 1 unit at price 39.110001, total balance 5270.179989
# day 1000: buy 1 unit at price 39.369999, total balance 5230.809990
# day 1001: buy 1 unit at price 39.650002, total balance 5191.159988
# day 1002: buy 1 unit at price 39.540001, total balance 5151.619987
# day 1003: buy 1 unit at price 39.759998, total balance 5111.859989
# day 1004: buy 1 unit at price 39.889999, total balance 5071.969990
# day 1005: buy 1 unit at price 40.650002, total balance 5031.319988
# day 1006: buy 1 unit at price 40.220001, total balance 4991.099987
# day 1007: buy 1 unit at price 40.180000, total balance 4950.919987
# day 1008: buy 1 unit at price 41.250000, total balance 4909.669987
# day 1009: buy 1 unit at price 41.959999, total balance 4867.709988
# day 1010: buy 1 unit at price 42.410000, total balance 4825.299988
# day 1011: buy 1 unit at price 42.270000, total balance 4783.029987
# day 1012: buy 1 unit at price 42.419998, total balance 4740.609989
# day 1013: buy 1 unit at price 42.820000, total balance 4697.789989
# day 1014: buy 1 unit at price 43.400002, total balance 4654.389988
# day 1015: buy 1 unit at price 43.369999, total balance 4611.019989
# day 1016: buy 1 unit at price 43.419998, total balance 4567.599991
# day 1017: buy 1 unit at price 43.770000, total balance 4523.829990
# day 1018: buy 1 unit at price 43.450001, total balance 4480.379990
# day 1019: buy 1 unit at price 43.430000, total balance 4436.949989
# day 1020: buy 1 unit at price 43.709999, total balance 4393.239990
# day 1021: buy 1 unit at price 44.470001, total balance 4348.769989
# day 1022: buy 1 unit at price 44.130001, total balance 4304.639988
# day 1023: buy 1 unit at price 44.849998, total balance 4259.789989
# day 1024: buy 1 unit at price 44.470001, total balance 4215.319988
# day 1025: buy 1 unit at price 44.330002, total balance 4170.989986
# day 1026: buy 1 unit at price 43.939999, total balance 4127.049988
# day 1027: buy 1 unit at price 44.220001, total balance 4082.829987
# day 1028: buy 1 unit at price 44.459999, total balance 4038.369987
# day 1029: buy 1 unit at price 45.000000, total balance 3993.369987
# day 1030: buy 1 unit at price 44.959999, total balance 3948.409988
# day 1031: buy 1 unit at price 44.619999, total balance 3903.789989
# day 1032: buy 1 unit at price 44.220001, total balance 3859.569988
# day 1033: buy 1 unit at price 44.369999, total balance 3815.199989
# day 1034: buy 1 unit at price 44.330002, total balance 3770.869988
# day 1035: buy 1 unit at price 45.070000, total balance 3725.799988
# day 1036: buy 1 unit at price 45.619999, total balance 3680.179989
# day 1037: buy 1 unit at price 45.450001, total balance 3634.729988
# day 1038: buy 1 unit at price 45.779999, total balance 3588.949989
# day 1039: buy 1 unit at price 45.779999, total balance 3543.169991
# day 1040: buy 1 unit at price 45.430000, total balance 3497.739990
# day 1041: buy 1 unit at price 46.049999, total balance 3451.689991
# day 1042: buy 1 unit at price 46.130001, total balance 3405.559990
# day 1043: buy 1 unit at price 45.820000, total balance 3359.739990
# day 1044: buy 1 unit at price 45.049999, total balance 3314.689991
# day 1045: buy 1 unit at price 45.160000, total balance 3269.529991
# day 1046: buy 1 unit at price 44.910000, total balance 3224.619991
# day 1047: buy 1 unit at price 46.020000, total balance 3178.599991
# day 1048: buy 1 unit at price 45.330002, total balance 3133.269989
# day 1049: buy 1 unit at price 45.910000, total balance 3087.359989
# day 1050: buy 1 unit at price 45.540001, total balance 3041.819988
# day 1051: buy 1 unit at price 45.320000, total balance 2996.499989
# day 1052: buy 1 unit at price 44.730000, total balance 2951.769989
# day 1053: buy 1 unit at price 44.240002, total balance 2907.529987
# day 1054: buy 1 unit at price 44.799999, total balance 2862.729988
# day 1055: buy 1 unit at price 45.310001, total balance 2817.419987
# day 1056: buy 1 unit at price 44.889999, total balance 2772.529987
# day 1057: buy 1 unit at price 45.810001, total balance 2726.719986
# day 1058: buy 1 unit at price 46.169998, total balance 2680.549988
# day 1059: buy 1 unit at price 45.990002, total balance 2634.559986
# day 1060: buy 1 unit at price 46.470001, total balance 2588.089985
# day 1061: buy 1 unit at price 45.900002, total balance 2542.189983
# day 1062: buy 1 unit at price 46.029999, total balance 2496.159985
# day 1063: buy 1 unit at price 46.119999, total balance 2450.039986
# day 1064: buy 1 unit at price 46.599998, total balance 2403.439987
# day 1065: buy 1 unit at price 46.320000, total balance 2357.119988
# day 1066: buy 1 unit at price 46.480000, total balance 2310.639988
# day 1067: buy 1 unit at price 46.869999, total balance 2263.769989
# day 1068: buy 1 unit at price 46.730000, total balance 2217.039989
# day 1069: buy 1 unit at price 46.709999, total balance 2170.329990
# day 1070: buy 1 unit at price 46.700001, total balance 2123.629990
# day 1071: buy 1 unit at price 47.049999, total balance 2076.579990
# day 1072: buy 1 unit at price 46.619999, total balance 2029.959991
# day 1073: buy 1 unit at price 46.689999, total balance 1983.269993
# day 1074: buy 1 unit at price 46.599998, total balance 1936.669994
# day 1075: buy 1 unit at price 46.580002, total balance 1890.089993
# day 1076: buy 1 unit at price 46.299999, total balance 1843.789993
# day 1077: buy 1 unit at price 46.080002, total balance 1797.709991
# day 1078: buy 1 unit at price 45.759998, total balance 1751.949993
# day 1079: buy 1 unit at price 46.450001, total balance 1705.499992
# day 1080: buy 1 unit at price 46.130001, total balance 1659.369991
# day 1081: buy 1 unit at price 45.820000, total balance 1613.549992
# day 1082: buy 1 unit at price 46.310001, total balance 1567.239990
# day 1083: buy 1 unit at price 46.400002, total balance 1520.839989
# day 1084: buy 1 unit at price 47.310001, total balance 1473.529987
# day 1085: buy 1 unit at price 47.900002, total balance 1425.629986
# day 1086: buy 1 unit at price 47.500000, total balance 1378.129986
# day 1087: buy 1 unit at price 47.060001, total balance 1331.069984
# day 1088: buy 1 unit at price 47.340000, total balance 1283.729984
# day 1089: buy 1 unit at price 47.340000, total balance 1236.389984
# day 1090: buy 1 unit at price 47.840000, total balance 1188.549984
# day 1091: buy 1 unit at price 47.720001, total balance 1140.829983
# day 1092: buy 1 unit at price 47.369999, total balance 1093.459984
# day 1093: buy 1 unit at price 47.810001, total balance 1045.649983
# day 1094: buy 1 unit at price 47.799999, total balance 997.849983
# day 1095: buy 1 unit at price 47.820000, total balance 950.029984
# day 1096: buy 1 unit at price 48.490002, total balance 901.539982
# day 1097: buy 1 unit at price 48.709999, total balance 852.829983
# day 1098: buy 1 unit at price 48.840000, total balance 803.989983
# day 1099: buy 1 unit at price 49.169998, total balance 754.819984
# day 1100: buy 1 unit at price 49.799999, total balance 705.019985
# day 1101: buy 1 unit at price 48.349998, total balance 656.669987
# day 1102: buy 1 unit at price 46.330002, total balance 610.339985
# day 1103: buy 1 unit at price 47.520000, total balance 562.819984
# day 1104: buy 1 unit at price 47.320000, total balance 515.499985
# day 1105: buy 1 unit at price 47.490002, total balance 468.009983
# day 1106: buy 1 unit at price 47.580002, total balance 420.429981
# day 1107: buy 1 unit at price 47.660000, total balance 372.769981
# day 1108: buy 1 unit at price 48.009998, total balance 324.759983
# day 1109: buy 1 unit at price 47.580002, total balance 277.179981
# day 1110: buy 1 unit at price 47.459999, total balance 229.719982
# day 1111: buy 1 unit at price 47.779999, total balance 181.939983
# day 1112: buy 1 unit at price 48.029999, total balance 133.909985
# day 1113: buy 1 unit at price 48.040001, total balance 85.869984
# day 1114: buy 1 unit at price 47.950001, total balance 37.919983

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
