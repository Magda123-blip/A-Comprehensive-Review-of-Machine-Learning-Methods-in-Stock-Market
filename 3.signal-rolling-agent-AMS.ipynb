# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../agent/cleaned_data/AMS.csv')
df.head()
# Out:
#        Date  Open  High   Low  Close  Adj Close  Volume
# 0  1/2/2013  2.70  2.80  2.70    2.8        2.8    5600
# 1  1/3/2013  2.75  2.81  2.74    2.8        2.8    4500
# 2  1/4/2013  2.80  2.80  2.80    2.8        2.8       0
# 3  1/7/2013  2.75  2.75  2.70    2.7        2.7     400
# 4  1/8/2013  2.70  2.70  2.60    2.6        2.6     500

# %%
def buy_stock(
    real_movement,
    delay = 5,
    initial_state = 1,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    delay_change_decision = delay
    current_decision = 0
    state = initial_state
    current_val = real_movement[0]
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    if state == 1:
        initial_money, current_inventory = buy(
            0, initial_money, current_inventory
        )

    for i in range(1, real_movement.shape[0], 1):
        if real_movement[i] < current_val and state == 0:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 1
                initial_money, current_inventory = buy(
                    i, initial_money, current_inventory
                )
                current_decision = 0
                states_buy.append(i)
        if real_movement[i] > current_val and state == 1:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 0

                if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
                else:
                    if current_inventory > max_sell:
                        sell_units = max_sell
                    else:
                        sell_units = current_inventory
                    current_inventory -= sell_units
                    total_sell = sell_units * real_movement[i]
                    initial_money += total_sell
                    try:
                        invest = (
                            (real_movement[i] - real_movement[states_buy[-1]])
                            / real_movement[states_buy[-1]]
                        ) * 100
                    except:
                        invest = 0
                    print(
                        'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                        % (i, sell_units, total_sell, invest, initial_money)
                    )

                current_decision = 0
                states_sell.append(i)
        current_val = real_movement[i]
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, initial_state = 1, 
                                                         delay = 4, initial_money = 10000)
# Out:
# day 0: buy 1 units at price 2.800000, total balance 9997.200000
# day 19, sell 1 units at price 2.230000, investment -20.357141 %, total balance 9999.430000,
# day 28: buy 1 units at price 2.060000, total balance 9997.370000
# day 39, sell 1 units at price 2.100000, investment 1.941746 %, total balance 9999.470000,
# day 47: buy 1 units at price 2.010000, total balance 9997.460000
# day 56, sell 1 units at price 2.050000, investment 1.990048 %, total balance 9999.510000,
# day 64: buy 1 units at price 1.760000, total balance 9997.750000
# day 77, sell 1 units at price 1.660000, investment -5.681820 %, total balance 9999.410000,
# day 90: buy 1 units at price 1.610000, total balance 9997.800000
# day 97, sell 1 units at price 1.990000, investment 23.602484 %, total balance 9999.790000,
# day 111: buy 1 units at price 2.130000, total balance 9997.660000
# day 120, sell 1 units at price 2.270000, investment 6.572763 %, total balance 9999.930000,
# day 134: buy 1 units at price 3.000000, total balance 9996.930000
# day 144, sell 1 units at price 2.920000, investment -2.666664 %, total balance 9999.850000,
# day 153: buy 1 units at price 2.770000, total balance 9997.080000
# day 174, sell 1 units at price 2.710000, investment -2.166063 %, total balance 9999.790000,
# day 186: buy 1 units at price 2.630000, total balance 9997.160000
# day 199, sell 1 units at price 2.540000, investment -3.422059 %, total balance 9999.700000,
# day 207: buy 1 units at price 2.420000, total balance 9997.280000
# day 219, sell 1 units at price 2.450000, investment 1.239668 %, total balance 9999.730000,
# day 231: buy 1 units at price 2.700000, total balance 9997.030000
# day 238, sell 1 units at price 2.730000, investment 1.111110 %, total balance 9999.760000,
# day 249: buy 1 units at price 2.630000, total balance 9997.130000
# day 258, sell 1 units at price 2.800000, investment 6.463872 %, total balance 9999.930000,
# day 271: buy 1 units at price 2.850000, total balance 9997.080000
# day 278, sell 1 units at price 3.190000, investment 11.929830 %, total balance 10000.270000,
# day 288: buy 1 units at price 3.110000, total balance 9997.160000
# day 296, sell 1 units at price 3.270000, investment 5.144697 %, total balance 10000.430000,
# day 306: buy 1 units at price 3.300000, total balance 9997.130000
# day 318, sell 1 units at price 3.020000, investment -8.484848 %, total balance 10000.150000,
# day 325: buy 1 units at price 2.770000, total balance 9997.380000
# day 336, sell 1 units at price 2.770000, investment 0.000000 %, total balance 10000.150000,
# day 348: buy 1 units at price 2.600000, total balance 9997.550000
# day 360, sell 1 units at price 2.450000, investment -5.769225 %, total balance 10000.000000,
# day 368: buy 1 units at price 2.610000, total balance 9997.390000
# day 378, sell 1 units at price 2.630000, investment 0.766292 %, total balance 10000.020000,
# day 388: buy 1 units at price 2.700000, total balance 9997.320000
# day 396, sell 1 units at price 2.830000, investment 4.814810 %, total balance 10000.150000,
# day 410: buy 1 units at price 2.430000, total balance 9997.720000
# day 422, sell 1 units at price 2.170000, investment -10.699588 %, total balance 9999.890000,
# day 439: buy 1 units at price 2.200000, total balance 9997.690000
# day 453, sell 1 units at price 2.180000, investment -0.909090 %, total balance 9999.870000,
# day 467: buy 1 units at price 2.660000, total balance 9997.210000
# day 481, sell 1 units at price 2.540000, investment -4.511283 %, total balance 9999.750000,
# day 489: buy 1 units at price 2.520000, total balance 9997.230000
# day 498, sell 1 units at price 2.520000, investment 0.000000 %, total balance 9999.750000,
# day 509: buy 1 units at price 2.750000, total balance 9997.000000
# day 520, sell 1 units at price 2.450000, investment -10.909089 %, total balance 9999.450000,
# day 531: buy 1 units at price 2.420000, total balance 9997.030000
# day 539, sell 1 units at price 2.520000, investment 4.132227 %, total balance 9999.550000,
# day 547: buy 1 units at price 2.350000, total balance 9997.200000
# day 559, sell 1 units at price 2.500000, investment 6.382983 %, total balance 9999.700000,
# day 572: buy 1 units at price 2.720000, total balance 9996.980000
# day 582, sell 1 units at price 2.780000, investment 2.205880 %, total balance 9999.760000,
# day 590: buy 1 units at price 2.580000, total balance 9997.180000
# day 606, sell 1 units at price 2.500000, investment -3.100772 %, total balance 9999.680000,
# day 618: buy 1 units at price 2.690000, total balance 9996.990000
# day 637, sell 1 units at price 2.580000, investment -4.089224 %, total balance 9999.570000,
# day 648: buy 1 units at price 2.680000, total balance 9996.890000
# day 665, sell 1 units at price 2.210000, investment -17.537314 %, total balance 9999.100000,
# day 671: buy 1 units at price 2.060000, total balance 9997.040000
# day 686, sell 1 units at price 1.870000, investment -9.223298 %, total balance 9998.910000,
# day 700: buy 1 units at price 1.760000, total balance 9997.150000
# day 713, sell 1 units at price 1.670000, investment -5.113638 %, total balance 9998.820000,
# day 732: buy 1 units at price 2.000000, total balance 9996.820000
# day 752, sell 1 units at price 1.600000, investment -19.999999 %, total balance 9998.420000,
# day 761: buy 1 units at price 1.600000, total balance 9996.820000
# day 770, sell 1 units at price 1.980000, investment 23.749999 %, total balance 9998.800000,
# day 780: buy 1 units at price 1.790000, total balance 9997.010000
# day 791, sell 1 units at price 1.900000, investment 6.145252 %, total balance 9998.910000,
# day 804: buy 1 units at price 1.970000, total balance 9996.940000
# day 812, sell 1 units at price 1.970000, investment 0.000000 %, total balance 9998.910000,
# day 828: buy 1 units at price 2.370000, total balance 9996.540000
# day 840, sell 1 units at price 2.480000, investment 4.641356 %, total balance 9999.020000,
# day 847: buy 1 units at price 1.990000, total balance 9997.030000
# day 858, sell 1 units at price 2.010000, investment 1.005024 %, total balance 9999.040000,
# day 871: buy 1 units at price 2.250000, total balance 9996.790000
# day 885, sell 1 units at price 2.170000, investment -3.555552 %, total balance 9998.960000,
# day 893: buy 1 units at price 1.920000, total balance 9997.040000
# day 901, sell 1 units at price 2.460000, investment 28.125005 %, total balance 9999.500000,
# day 911: buy 1 units at price 2.070000, total balance 9997.430000
# day 920, sell 1 units at price 2.710000, investment 30.917880 %, total balance 10000.140000,
# day 931: buy 1 units at price 2.680000, total balance 9997.460000
# day 940, sell 1 units at price 3.080000, investment 14.925367 %, total balance 10000.540000,
# day 951: buy 1 units at price 3.050000, total balance 9997.490000
# day 964, sell 1 units at price 3.000000, investment -1.639343 %, total balance 10000.490000,
# day 974: buy 1 units at price 3.250000, total balance 9997.240000
# day 986, sell 1 units at price 3.400000, investment 4.615388 %, total balance 10000.640000,
# day 995: buy 1 units at price 3.050000, total balance 9997.590000
# day 1005, sell 1 units at price 3.300000, investment 8.196721 %, total balance 10000.890000,
# day 1018: buy 1 units at price 3.900000, total balance 9996.990000
# day 1030, sell 1 units at price 4.400000, investment 12.820513 %, total balance 10001.390000,
# day 1039: buy 1 units at price 4.050000, total balance 9997.340000
# day 1048, sell 1 units at price 4.100000, investment 1.234561 %, total balance 10001.440000,
# day 1061: buy 1 units at price 3.950000, total balance 9997.490000
# day 1071, sell 1 units at price 4.700000, investment 18.987335 %, total balance 10002.190000,
# day 1080: buy 1 units at price 4.400000, total balance 9997.790000
# day 1089, sell 1 units at price 4.450000, investment 1.136357 %, total balance 10002.240000,
# day 1099: buy 1 units at price 3.850000, total balance 9998.390000
# day 1109, sell 1 units at price 4.250000, investment 10.389613 %, total balance 10002.640000,
# day 1117: buy 1 units at price 4.150000, total balance 9998.490000
# day 1133, sell 1 units at price 3.920000, investment -5.542169 %, total balance 10002.410000,
# day 1149: buy 1 units at price 4.000000, total balance 9998.410000
# day 1175, sell 1 units at price 2.900000, investment -27.499998 %, total balance 10001.310000,
# day 1191: buy 1 units at price 2.950000, total balance 9998.360000
# day 1204, sell 1 units at price 3.000000, investment 1.694914 %, total balance 10001.360000,
# day 1218: buy 1 units at price 3.050000, total balance 9998.310000
# day 1234, sell 1 units at price 2.700000, investment -11.475407 %, total balance 10001.010000,
# day 1244: buy 1 units at price 2.540000, total balance 9998.470000
# day 1255, sell 1 units at price 2.670000, investment 5.118115 %, total balance 10001.140000,
# day 1264: buy 1 units at price 2.750000, total balance 9998.390000
# day 1279, sell 1 units at price 2.700000, investment -1.818180 %, total balance 10001.090000,
# day 1288: buy 1 units at price 2.550000, total balance 9998.540000
# day 1308, sell 1 units at price 2.600000, investment 1.960783 %, total balance 10001.140000,
# day 1324: buy 1 units at price 2.400000, total balance 9998.740000
# day 1338, sell 1 units at price 2.400000, investment 0.000000 %, total balance 10001.140000,
# day 1350: buy 1 units at price 2.700000, total balance 9998.440000
# day 1363, sell 1 units at price 2.800000, investment 3.703700 %, total balance 10001.240000,
# day 1374: buy 1 units at price 2.750000, total balance 9998.490000
# day 1387, sell 1 units at price 2.800000, investment 1.818180 %, total balance 10001.290000,
# day 1409: buy 1 units at price 3.010000, total balance 9998.280000
# day 1417, sell 1 units at price 3.100000, investment 2.990030 %, total balance 10001.380000,
# day 1429: buy 1 units at price 3.040000, total balance 9998.340000
# day 1442, sell 1 units at price 3.030000, investment -0.328947 %, total balance 10001.370000,
# day 1456: buy 1 units at price 3.370000, total balance 9998.000000
# day 1467, sell 1 units at price 3.150000, investment -6.528184 %, total balance 10001.150000,
# day 1478: buy 1 units at price 2.690000, total balance 9998.460000
# day 1494, sell 1 units at price 2.420000, investment -10.037174 %, total balance 10000.880000,
# day 1506: buy 1 units at price 2.350000, total balance 9998.530000
# day 1517, sell 1 units at price 2.380000, investment 1.276605 %, total balance 10000.910000,
# day 1537: buy 1 units at price 2.500000, total balance 9998.410000
# day 1545, sell 1 units at price 2.580000, investment 3.199997 %, total balance 10000.990000,
# day 1554: buy 1 units at price 2.790000, total balance 9998.200000
# day 1566, sell 1 units at price 2.860000, investment 2.508958 %, total balance 10001.060000,
# day 1572: buy 1 units at price 2.650000, total balance 9998.410000
# day 1581, sell 1 units at price 2.680000, investment 1.132074 %, total balance 10001.090000,
# day 1594: buy 1 units at price 2.760000, total balance 9998.330000
# day 1602, sell 1 units at price 2.910000, investment 5.434786 %, total balance 10001.240000,
# day 1612: buy 1 units at price 2.880000, total balance 9998.360000
# day 1623, sell 1 units at price 2.900000, investment 0.694444 %, total balance 10001.260000,
# day 1631: buy 1 units at price 2.950000, total balance 9998.310000
# day 1642, sell 1 units at price 2.910000, investment -1.355931 %, total balance 10001.220000,
# day 1652: buy 1 units at price 3.010000, total balance 9998.210000
# day 1669, sell 1 units at price 2.590000, investment -13.953491 %, total balance 10000.800000,
# day 1682: buy 1 units at price 2.510000, total balance 9998.290000
# day 1697, sell 1 units at price 2.510000, investment 0.000000 %, total balance 10000.800000,
# day 1709: buy 1 units at price 2.410000, total balance 9998.390000
# day 1723, sell 1 units at price 2.420000, investment 0.414937 %, total balance 10000.810000,
# day 1734: buy 1 units at price 2.340000, total balance 9998.470000
# day 1742, sell 1 units at price 2.530000, investment 8.119661 %, total balance 10001.000000,
# day 1756: buy 1 units at price 2.520000, total balance 9998.480000

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
