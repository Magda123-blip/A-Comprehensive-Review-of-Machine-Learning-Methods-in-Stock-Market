# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../agent/cleaned_data/NQP.csv')
df.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close  Volume
# 0  1/2/2013  15.620000  15.990000  15.620000  15.980000  10.681674   13800
# 1  1/3/2013  15.850000  16.110001  15.850000  16.110001  10.768575   26400
# 2  1/4/2013  16.030001  16.219999  16.030001  16.170000  10.808681   33500
# 3  1/7/2013  16.200001  16.280001  16.070000  16.110001  10.768575   22500
# 4  1/8/2013  16.200001  16.209999  16.040001  16.139999  10.788628   18500

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59CE7F348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59CE7F348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59CE7F348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59CE7F348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59CE7F348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59CE7F348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59CE7F348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59CE7F348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59ED6EE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59ED6EE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59ED6EE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59ED6EE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59ED6EE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59ED6EE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59ED6EE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000002B59ED6EE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: -6.009999.3, cost: 0.000705, total money: 9824.170000
# epoch: 20, total rewards: 6.740006.3, cost: 0.000695, total money: 9836.850007
# epoch: 30, total rewards: -12.589990.3, cost: 0.000457, total money: 9973.210011
# epoch: 40, total rewards: -29.240003.3, cost: 0.000600, total money: 9857.279996
# epoch: 50, total rewards: -0.840000.3, cost: 0.000341, total money: 9999.160000
# epoch: 60, total rewards: -10.220008.3, cost: 0.000069, total money: 9933.109992
# epoch: 70, total rewards: -0.599991.3, cost: 0.000108, total money: 9928.480009
# epoch: 80, total rewards: -8.159996.3, cost: 0.000309, total money: 9991.840004
# epoch: 90, total rewards: -3.299995.3, cost: 0.000052, total money: 9996.700005
# epoch: 100, total rewards: -11.990016.3, cost: 0.000069, total money: 9973.859984
# epoch: 110, total rewards: -2.909998.3, cost: 0.000064, total money: 9968.750003
# epoch: 120, total rewards: -12.929986.3, cost: 0.000057, total money: 9987.070014
# epoch: 130, total rewards: -3.670007.3, cost: 0.000058, total money: 9968.039993
# epoch: 140, total rewards: 14.659993.3, cost: 0.000334, total money: 9957.949993
# epoch: 150, total rewards: -4.159999.3, cost: 0.000013, total money: 9995.840001
# epoch: 160, total rewards: 3.750008.3, cost: 0.000173, total money: 9975.360008
# epoch: 170, total rewards: 10.749997.3, cost: 0.000226, total money: 10010.749997
# epoch: 180, total rewards: -1.270006.3, cost: 0.000017, total money: 9970.339994
# epoch: 190, total rewards: -1.649986.3, cost: 0.000007, total money: 9998.350014
# epoch: 200, total rewards: 2.859996.3, cost: 0.000043, total money: 10002.859996

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 4: buy 1 unit at price 16.139999, total balance 9983.860001
# day 5, sell 1 unit at price 16.230000, investment 0.557622 %, total balance 10000.090000,
# day 13: buy 1 unit at price 16.190001, total balance 9983.900000
# day 14, sell 1 unit at price 16.309999, investment 0.741192 %, total balance 10000.209999,
# day 18: buy 1 unit at price 15.960000, total balance 9984.249999
# day 19, sell 1 unit at price 15.940000, investment -0.125316 %, total balance 10000.189999,
# day 24: buy 1 unit at price 15.940000, total balance 9984.249999
# day 25, sell 1 unit at price 16.049999, investment 0.690086 %, total balance 10000.299998,
# day 29: buy 1 unit at price 15.900000, total balance 9984.399999
# day 30, sell 1 unit at price 15.730000, investment -1.069183 %, total balance 10000.129998,
# day 36: buy 1 unit at price 15.800000, total balance 9984.329998
# day 37, sell 1 unit at price 15.700000, investment -0.632914 %, total balance 10000.029998,
# day 41: buy 1 unit at price 15.560000, total balance 9984.469997
# day 43, sell 1 unit at price 15.580000, investment 0.128531 %, total balance 10000.049997,
# day 48: buy 1 unit at price 14.870000, total balance 9985.179997
# day 49, sell 1 unit at price 14.800000, investment -0.470744 %, total balance 9999.979998,
# day 50: buy 1 unit at price 14.800000, total balance 9985.179997
# day 51: buy 1 unit at price 15.010000, total balance 9970.169997
# day 52: buy 1 unit at price 14.930000, total balance 9955.239997
# day 53: buy 1 unit at price 15.150000, total balance 9940.089997
# day 54, sell 1 unit at price 15.070000, investment 1.824321 %, total balance 9955.159997,
# day 56, sell 1 unit at price 15.000000, investment -0.066624 %, total balance 9970.159997,
# day 57, sell 1 unit at price 14.910000, investment -0.133962 %, total balance 9985.069997,
# day 59, sell 1 unit at price 15.000000, investment -0.990097 %, total balance 10000.069997,
# day 77: buy 1 unit at price 15.070000, total balance 9984.999997
# day 78, sell 1 unit at price 15.100000, investment 0.199076 %, total balance 10000.099998,
# day 82: buy 1 unit at price 15.290000, total balance 9984.809998
# day 83: buy 1 unit at price 15.320000, total balance 9969.489998
# day 84, sell 1 unit at price 15.240000, investment -0.327012 %, total balance 9984.729998,
# day 85, sell 1 unit at price 15.100000, investment -1.436027 %, total balance 9999.829998,
# day 86: buy 1 unit at price 15.140000, total balance 9984.689998
# day 89, sell 1 unit at price 15.120000, investment -0.132103 %, total balance 9999.809998,
# day 97: buy 1 unit at price 14.810000, total balance 9984.999997
# day 98, sell 1 unit at price 14.690000, investment -0.810269 %, total balance 9999.689997,
# day 99: buy 1 unit at price 14.690000, total balance 9984.999997
# day 100: buy 1 unit at price 14.580000, total balance 9970.419997
# day 101: buy 1 unit at price 14.310000, total balance 9956.109997
# day 102, sell 1 unit at price 14.260000, investment -2.927157 %, total balance 9970.369997,
# day 104: buy 1 unit at price 14.290000, total balance 9956.079997
# day 105, sell 1 unit at price 14.200000, investment -2.606311 %, total balance 9970.279997,
# day 106, sell 1 unit at price 14.300000, investment -0.069883 %, total balance 9984.579997,
# day 107, sell 1 unit at price 14.360000, investment 0.489851 %, total balance 9998.939997,
# day 113: buy 1 unit at price 14.180000, total balance 9984.759996
# day 114: buy 1 unit at price 14.060000, total balance 9970.699996
# day 115, sell 1 unit at price 14.020000, investment -1.128349 %, total balance 9984.719996,
# day 116, sell 1 unit at price 13.940000, investment -0.853491 %, total balance 9998.659996,
# day 132: buy 1 unit at price 13.330000, total balance 9985.329996
# day 133, sell 1 unit at price 13.250000, investment -0.600149 %, total balance 9998.579996,
# day 136: buy 1 unit at price 13.190000, total balance 9985.389997
# day 137, sell 1 unit at price 13.140000, investment -0.379069 %, total balance 9998.529997,
# day 152: buy 1 unit at price 12.470000, total balance 9986.059997
# day 154, sell 1 unit at price 12.330000, investment -1.122697 %, total balance 9998.389997,
# day 166: buy 1 unit at price 12.300000, total balance 9986.089996
# day 167, sell 1 unit at price 12.370000, investment 0.569103 %, total balance 9998.459996,
# day 176: buy 1 unit at price 12.110000, total balance 9986.349997
# day 177, sell 1 unit at price 12.260000, investment 1.238650 %, total balance 9998.609997,
# day 187: buy 1 unit at price 12.620000, total balance 9985.989997
# day 188: buy 1 unit at price 12.600000, total balance 9973.389997
# day 189, sell 1 unit at price 12.620000, investment 0.000000 %, total balance 9986.009996,
# day 190, sell 1 unit at price 12.500000, investment -0.793654 %, total balance 9998.509996,
# day 192: buy 1 unit at price 12.410000, total balance 9986.099997
# day 193, sell 1 unit at price 12.420000, investment 0.080582 %, total balance 9998.519997,
# day 198: buy 1 unit at price 12.210000, total balance 9986.309997
# day 199, sell 1 unit at price 12.280000, investment 0.573298 %, total balance 9998.589996,
# day 218: buy 1 unit at price 12.390000, total balance 9986.199996
# day 219, sell 1 unit at price 12.390000, investment 0.000000 %, total balance 9998.589996,
# day 223: buy 1 unit at price 12.500000, total balance 9986.089996
# day 224, sell 1 unit at price 12.320000, investment -1.440002 %, total balance 9998.409996,
# day 229: buy 1 unit at price 12.450000, total balance 9985.959996
# day 230, sell 1 unit at price 12.510000, investment 0.481931 %, total balance 9998.469996,
# day 232: buy 1 unit at price 12.470000, total balance 9985.999996
# day 233, sell 1 unit at price 12.300000, investment -1.363272 %, total balance 9998.299996,
# day 236: buy 1 unit at price 12.320000, total balance 9985.979997
# day 237, sell 1 unit at price 12.390000, investment 0.568187 %, total balance 9998.369997,
# day 238: buy 1 unit at price 12.210000, total balance 9986.159997
# day 240, sell 1 unit at price 12.140000, investment -0.573298 %, total balance 9998.299997,
# day 253: buy 1 unit at price 12.520000, total balance 9985.779997
# day 254, sell 1 unit at price 12.600000, investment 0.638977 %, total balance 9998.379997,
# day 259: buy 1 unit at price 12.820000, total balance 9985.559998
# day 260, sell 1 unit at price 12.820000, investment 0.000000 %, total balance 9998.379997,
# day 261: buy 1 unit at price 12.840000, total balance 9985.539997
# day 262, sell 1 unit at price 12.790000, investment -0.389410 %, total balance 9998.329997,
# day 286: buy 1 unit at price 12.830000, total balance 9985.499997
# day 287, sell 1 unit at price 12.810000, investment -0.155881 %, total balance 9998.309998,
# day 290: buy 1 unit at price 12.960000, total balance 9985.349998
# day 291, sell 1 unit at price 12.950000, investment -0.077162 %, total balance 9998.299997,
# day 304: buy 1 unit at price 13.090000, total balance 9985.209997
# day 305: buy 1 unit at price 12.970000, total balance 9972.239997
# day 306, sell 1 unit at price 13.060000, investment -0.229181 %, total balance 9985.299997,
# day 307, sell 1 unit at price 13.200000, investment 1.773319 %, total balance 9998.499997,
# day 310: buy 1 unit at price 13.400000, total balance 9985.099998
# day 312, sell 1 unit at price 13.330000, investment -0.522386 %, total balance 9998.429997,
# day 317: buy 1 unit at price 13.360000, total balance 9985.069998
# day 318, sell 1 unit at price 13.330000, investment -0.224549 %, total balance 9998.399998,
# day 320: buy 1 unit at price 13.400000, total balance 9984.999998
# day 321, sell 1 unit at price 13.390000, investment -0.074621 %, total balance 9998.389998,
# day 328: buy 1 unit at price 13.710000, total balance 9984.679998
# day 329, sell 1 unit at price 13.760000, investment 0.364699 %, total balance 9998.439999,
# day 334: buy 1 unit at price 13.790000, total balance 9984.649999
# day 335, sell 1 unit at price 13.760000, investment -0.217547 %, total balance 9998.409999,
# day 348: buy 1 unit at price 13.910000, total balance 9984.499999
# day 349, sell 1 unit at price 13.960000, investment 0.359455 %, total balance 9998.459999,
# day 356: buy 1 unit at price 13.800000, total balance 9984.659999
# day 357, sell 1 unit at price 13.680000, investment -0.869564 %, total balance 9998.339999,
# day 359: buy 1 unit at price 13.810000, total balance 9984.529999
# day 360, sell 1 unit at price 13.850000, investment 0.289645 %, total balance 9998.379999,
# day 364: buy 1 unit at price 13.800000, total balance 9984.579999
# day 365, sell 1 unit at price 13.780000, investment -0.144931 %, total balance 9998.359999,
# day 380: buy 1 unit at price 13.840000, total balance 9984.519999
# day 382: buy 1 unit at price 13.850000, total balance 9970.669998
# day 384, sell 1 unit at price 13.790000, investment -0.361273 %, total balance 9984.459998,
# day 385, sell 1 unit at price 13.750000, investment -0.722024 %, total balance 9998.209998,
# day 387: buy 1 unit at price 13.790000, total balance 9984.419998
# day 388: buy 1 unit at price 13.790000, total balance 9970.629998
# day 389, sell 1 unit at price 13.770000, investment -0.145029 %, total balance 9984.399999,
# day 390, sell 1 unit at price 13.710000, investment -0.580130 %, total balance 9998.109999,
# day 412: buy 1 unit at price 13.820000, total balance 9984.289999
# day 413, sell 1 unit at price 13.840000, investment 0.144721 %, total balance 9998.129999,
# day 416: buy 1 unit at price 13.800000, total balance 9984.329999
# day 417, sell 1 unit at price 13.890000, investment 0.652175 %, total balance 9998.219999,
# day 430: buy 1 unit at price 13.530000, total balance 9984.690000
# day 431, sell 1 unit at price 13.580000, investment 0.369551 %, total balance 9998.269999,
# day 443: buy 1 unit at price 13.690000, total balance 9984.580000
# day 445: buy 1 unit at price 13.740000, total balance 9970.840000
# day 446, sell 1 unit at price 13.730000, investment 0.292184 %, total balance 9984.570000,
# day 447, sell 1 unit at price 13.640000, investment -0.727798 %, total balance 9998.210000,
# day 454: buy 1 unit at price 13.750000, total balance 9984.460000
# day 455: buy 1 unit at price 13.760000, total balance 9970.700000
# day 456, sell 1 unit at price 13.760000, investment 0.072729 %, total balance 9984.460000,
# day 458, sell 1 unit at price 13.750000, investment -0.072676 %, total balance 9998.210000,
# day 460: buy 1 unit at price 13.750000, total balance 9984.460000
# day 461, sell 1 unit at price 13.730000, investment -0.145458 %, total balance 9998.190000,
# day 470: buy 1 unit at price 13.730000, total balance 9984.460000
# day 471, sell 1 unit at price 13.620000, investment -0.801163 %, total balance 9998.080000,
# day 472: buy 1 unit at price 13.670000, total balance 9984.410000
# day 473, sell 1 unit at price 13.580000, investment -0.658377 %, total balance 9997.990000,
# day 508: buy 1 unit at price 14.060000, total balance 9983.929999
# day 509: buy 1 unit at price 14.080000, total balance 9969.849999
# day 510, sell 1 unit at price 14.170000, investment 0.782359 %, total balance 9984.019999,
# day 511: buy 1 unit at price 14.180000, total balance 9969.839999
# day 512, sell 1 unit at price 14.230000, investment 1.065338 %, total balance 9984.069999,
# day 513: buy 1 unit at price 14.270000, total balance 9969.799998
# day 514, sell 1 unit at price 14.320000, investment 0.987302 %, total balance 9984.119998,
# day 515: buy 1 unit at price 14.260000, total balance 9969.859998
# day 518, sell 1 unit at price 14.180000, investment -0.630695 %, total balance 9984.039998,
# day 519: buy 1 unit at price 14.210000, total balance 9969.829998
# day 520, sell 1 unit at price 14.280000, investment 0.140249 %, total balance 9984.109998,
# day 521: buy 1 unit at price 14.400000, total balance 9969.709998
# day 522, sell 1 unit at price 14.420000, investment 1.477833 %, total balance 9984.129998,
# day 524, sell 1 unit at price 14.640000, investment 1.666672 %, total balance 9998.769999,
# day 546: buy 1 unit at price 14.260000, total balance 9984.509998
# day 548: buy 1 unit at price 13.910000, total balance 9970.599998
# day 549, sell 1 unit at price 14.000000, investment -1.823283 %, total balance 9984.599998,
# day 550: buy 1 unit at price 13.910000, total balance 9970.689999
# day 552, sell 1 unit at price 13.870000, investment -0.287563 %, total balance 9984.559998,
# day 553, sell 1 unit at price 13.840000, investment -0.503233 %, total balance 9998.399999,
# day 558: buy 1 unit at price 14.010000, total balance 9984.389998
# day 559, sell 1 unit at price 14.010000, investment 0.000000 %, total balance 9998.399999,
# day 569: buy 1 unit at price 13.930000, total balance 9984.469998
# day 570, sell 1 unit at price 13.900000, investment -0.215367 %, total balance 9998.369998,
# day 580: buy 1 unit at price 13.920000, total balance 9984.449998
# day 582, sell 1 unit at price 13.910000, investment -0.071841 %, total balance 9998.359998,
# day 586: buy 1 unit at price 13.840000, total balance 9984.519998
# day 587: buy 1 unit at price 13.780000, total balance 9970.739998
# day 588, sell 1 unit at price 13.710000, investment -0.939307 %, total balance 9984.449998,
# day 589, sell 1 unit at price 13.630000, investment -1.088531 %, total balance 9998.079998,
# day 606: buy 1 unit at price 13.520000, total balance 9984.559998
# day 607, sell 1 unit at price 13.460000, investment -0.443790 %, total balance 9998.019998,
# day 612: buy 1 unit at price 13.230000, total balance 9984.789998
# day 615, sell 1 unit at price 13.120000, investment -0.831441 %, total balance 9997.909998,
# day 617: buy 1 unit at price 13.180000, total balance 9984.729998
# day 618, sell 1 unit at price 13.230000, investment 0.379357 %, total balance 9997.959997,
# day 619: buy 1 unit at price 13.190000, total balance 9984.769998
# day 620, sell 1 unit at price 13.220000, investment 0.227450 %, total balance 9997.989998,
# day 637: buy 1 unit at price 13.080000, total balance 9984.909998
# day 638, sell 1 unit at price 13.120000, investment 0.305810 %, total balance 9998.029998,
# day 641: buy 1 unit at price 13.080000, total balance 9984.949998
# day 642: buy 1 unit at price 13.120000, total balance 9971.829998
# day 644: buy 1 unit at price 13.150000, total balance 9958.679998
# day 645, sell 1 unit at price 13.220000, investment 1.070339 %, total balance 9971.899999,
# day 646: buy 1 unit at price 13.230000, total balance 9958.669999
# day 647, sell 1 unit at price 13.220000, investment 0.762198 %, total balance 9971.889999,
# day 648, sell 1 unit at price 13.170000, investment 0.152095 %, total balance 9985.059999,
# day 649, sell 1 unit at price 13.250000, investment 0.151175 %, total balance 9998.309999,
# day 651: buy 1 unit at price 13.240000, total balance 9985.070000
# day 652, sell 1 unit at price 13.220000, investment -0.151054 %, total balance 9998.290000,
# day 677: buy 1 unit at price 13.050000, total balance 9985.240000
# day 678, sell 1 unit at price 13.000000, investment -0.383143 %, total balance 9998.240000,
# day 686: buy 1 unit at price 13.050000, total balance 9985.190000
# day 687, sell 1 unit at price 13.030000, investment -0.153260 %, total balance 9998.219999,
# day 691: buy 1 unit at price 13.120000, total balance 9985.099999
# day 692, sell 1 unit at price 13.120000, investment 0.000000 %, total balance 9998.219999,
# day 695: buy 1 unit at price 13.090000, total balance 9985.129999
# day 697, sell 1 unit at price 13.100000, investment 0.076396 %, total balance 9998.230000,
# day 704: buy 1 unit at price 13.100000, total balance 9985.129999
# day 705, sell 1 unit at price 13.150000, investment 0.381674 %, total balance 9998.279999,
# day 707: buy 1 unit at price 13.270000, total balance 9985.009998
# day 708, sell 1 unit at price 13.220000, investment -0.376791 %, total balance 9998.229999,
# day 712: buy 1 unit at price 13.290000, total balance 9984.939999
# day 713: buy 1 unit at price 13.380000, total balance 9971.559999
# day 714, sell 1 unit at price 13.430000, investment 1.053426 %, total balance 9984.989999,
# day 715, sell 1 unit at price 13.370000, investment -0.074740 %, total balance 9998.359999,
# day 738: buy 1 unit at price 13.390000, total balance 9984.969998
# day 739, sell 1 unit at price 13.460000, investment 0.522776 %, total balance 9998.429998,
# day 751: buy 1 unit at price 13.640000, total balance 9984.789998
# day 752, sell 1 unit at price 13.670000, investment 0.219939 %, total balance 9998.459998,
# day 757: buy 1 unit at price 13.880000, total balance 9984.579998
# day 758, sell 1 unit at price 13.920000, investment 0.288184 %, total balance 9998.499998,
# day 793: buy 1 unit at price 14.220000, total balance 9984.279998
# day 794, sell 1 unit at price 14.250000, investment 0.210969 %, total balance 9998.529998,
# day 795: buy 1 unit at price 14.280000, total balance 9984.249998
# day 796, sell 1 unit at price 14.350000, investment 0.490201 %, total balance 9998.599998,
# day 812: buy 1 unit at price 14.220000, total balance 9984.379998
# day 813: buy 1 unit at price 14.240000, total balance 9970.139998
# day 814: buy 1 unit at price 14.260000, total balance 9955.879998
# day 815, sell 1 unit at price 14.290000, investment 0.492262 %, total balance 9970.169998,
# day 816, sell 1 unit at price 14.350000, investment 0.772476 %, total balance 9984.519999,
# day 817, sell 1 unit at price 14.370000, investment 0.771386 %, total balance 9998.889998,
# day 818: buy 1 unit at price 14.440000, total balance 9984.449999
# day 819: buy 1 unit at price 14.550000, total balance 9969.899999
# day 820: buy 1 unit at price 14.720000, total balance 9955.179998
# day 821, sell 1 unit at price 14.750000, investment 2.146817 %, total balance 9969.929998,
# day 822, sell 1 unit at price 14.780000, investment 1.580753 %, total balance 9984.709998,
# day 823, sell 1 unit at price 14.940000, investment 1.494561 %, total balance 9999.649998,
# day 825: buy 1 unit at price 14.870000, total balance 9984.779998
# day 826, sell 1 unit at price 14.810000, investment -0.403493 %, total balance 9999.589998,
# day 828: buy 1 unit at price 14.890000, total balance 9984.699998
# day 829, sell 1 unit at price 14.850000, investment -0.268636 %, total balance 9999.549998,
# day 832: buy 1 unit at price 14.880000, total balance 9984.669998
# day 833, sell 1 unit at price 14.840000, investment -0.268817 %, total balance 9999.509998,
# day 841: buy 1 unit at price 14.910000, total balance 9984.599998
# day 842, sell 1 unit at price 14.910000, investment 0.000000 %, total balance 9999.509998,
# day 844: buy 1 unit at price 14.920000, total balance 9984.589998
# day 845, sell 1 unit at price 14.880000, investment -0.268096 %, total balance 9999.469998,
# day 850: buy 1 unit at price 14.770000, total balance 9984.699998
# day 852, sell 1 unit at price 14.720000, investment -0.338525 %, total balance 9999.419998,
# day 857: buy 1 unit at price 15.000000, total balance 9984.419998
# day 858, sell 1 unit at price 15.010000, investment 0.066668 %, total balance 9999.429998,
# day 870: buy 1 unit at price 15.220000, total balance 9984.209998
# day 871, sell 1 unit at price 15.230000, investment 0.065698 %, total balance 9999.439998,
# day 876: buy 1 unit at price 15.170000, total balance 9984.269998
# day 877, sell 1 unit at price 15.250000, investment 0.527356 %, total balance 9999.519998,
# day 878: buy 1 unit at price 15.340000, total balance 9984.179997
# day 879: buy 1 unit at price 15.380000, total balance 9968.799997
# day 881: buy 1 unit at price 15.500000, total balance 9953.299997
# day 882, sell 1 unit at price 15.550000, investment 1.368970 %, total balance 9968.849998,
# day 883, sell 1 unit at price 15.640000, investment 1.690509 %, total balance 9984.489998,
# day 884, sell 1 unit at price 15.660000, investment 1.032257 %, total balance 10000.149998,
# day 893: buy 1 unit at price 15.390000, total balance 9984.759997
# day 894, sell 1 unit at price 15.560000, investment 1.104614 %, total balance 10000.319998,
# day 901: buy 1 unit at price 15.400000, total balance 9984.919998
# day 903, sell 1 unit at price 15.450000, investment 0.324677 %, total balance 10000.369998,
# day 909: buy 1 unit at price 15.210000, total balance 9985.159998
# day 910, sell 1 unit at price 15.280000, investment 0.460221 %, total balance 10000.439998,
# day 915: buy 1 unit at price 15.190000, total balance 9985.249998
# day 917: buy 1 unit at price 15.220000, total balance 9970.029998
# day 918, sell 1 unit at price 15.210000, investment 0.131669 %, total balance 9985.239998,
# day 919, sell 1 unit at price 15.160000, investment -0.394221 %, total balance 10000.399998,
# day 922: buy 1 unit at price 15.270000, total balance 9985.129997
# day 924, sell 1 unit at price 15.170000, investment -0.654881 %, total balance 10000.299997,
# day 930: buy 1 unit at price 15.050000, total balance 9985.249997
# day 931, sell 1 unit at price 14.930000, investment -0.797341 %, total balance 10000.179997,
# day 944: buy 1 unit at price 14.910000, total balance 9985.269998
# day 945, sell 1 unit at price 14.950000, investment 0.268276 %, total balance 10000.219997,
# day 947: buy 1 unit at price 14.750000, total balance 9985.469997
# day 948, sell 1 unit at price 14.640000, investment -0.745760 %, total balance 10000.109998,
# day 952: buy 1 unit at price 14.330000, total balance 9985.779998
# day 954, sell 1 unit at price 14.080000, investment -1.744592 %, total balance 9999.859998,
# day 959: buy 1 unit at price 14.120000, total balance 9985.739998
# day 961, sell 1 unit at price 14.150000, investment 0.212463 %, total balance 9999.889997,
# day 963: buy 1 unit at price 13.990000, total balance 9985.899998
# day 964, sell 1 unit at price 13.920000, investment -0.500355 %, total balance 9999.819998,
# day 976: buy 1 unit at price 13.350000, total balance 9986.469997
# day 977, sell 1 unit at price 13.240000, investment -0.823975 %, total balance 9999.709997,
# day 985: buy 1 unit at price 13.230000, total balance 9986.479998
# day 986, sell 1 unit at price 13.270000, investment 0.302350 %, total balance 9999.749998,
# day 989: buy 1 unit at price 13.080000, total balance 9986.669998
# day 991, sell 1 unit at price 13.230000, investment 1.146786 %, total balance 9999.899998,
# day 994: buy 1 unit at price 13.030000, total balance 9986.869998
# day 995: buy 1 unit at price 13.060000, total balance 9973.809998
# day 996, sell 1 unit at price 13.090000, investment 0.460479 %, total balance 9986.899998,
# day 998, sell 1 unit at price 12.940000, investment -0.918843 %, total balance 9999.839997,
# day 1004: buy 1 unit at price 12.910000, total balance 9986.929997
# day 1005, sell 1 unit at price 12.970000, investment 0.464759 %, total balance 9999.899998,
# day 1014: buy 1 unit at price 13.200000, total balance 9986.699998
# day 1015, sell 1 unit at price 13.270000, investment 0.530308 %, total balance 9999.969998,
# day 1018: buy 1 unit at price 13.320000, total balance 9986.649999
# day 1019, sell 1 unit at price 13.230000, investment -0.675677 %, total balance 9999.879998,
# day 1023: buy 1 unit at price 13.240000, total balance 9986.639998
# day 1024, sell 1 unit at price 13.220000, investment -0.151054 %, total balance 9999.859999,
# day 1029: buy 1 unit at price 13.300000, total balance 9986.559999
# day 1030, sell 1 unit at price 13.290000, investment -0.075190 %, total balance 9999.849998,
# day 1039: buy 1 unit at price 13.150000, total balance 9986.699999
# day 1040, sell 1 unit at price 13.120000, investment -0.228135 %, total balance 9999.819999,
# day 1042: buy 1 unit at price 13.190000, total balance 9986.629999
# day 1043: buy 1 unit at price 13.210000, total balance 9973.419999
# day 1044, sell 1 unit at price 13.290000, investment 0.758153 %, total balance 9986.709999,
# day 1045, sell 1 unit at price 13.250000, investment 0.302801 %, total balance 9999.959999,
# day 1057: buy 1 unit at price 12.820000, total balance 9987.139999
# day 1058, sell 1 unit at price 12.760000, investment -0.468015 %, total balance 9999.900000,
# day 1063: buy 1 unit at price 13.000000, total balance 9986.900000
# day 1065, sell 1 unit at price 13.080000, investment 0.615384 %, total balance 9999.980000,
# day 1068: buy 1 unit at price 13.090000, total balance 9986.889999
# day 1069, sell 1 unit at price 13.130000, investment 0.305576 %, total balance 10000.020000,
# day 1073: buy 1 unit at price 13.150000, total balance 9986.870000
# day 1075, sell 1 unit at price 13.260000, investment 0.836507 %, total balance 10000.130000,
# day 1096: buy 1 unit at price 13.230000, total balance 9986.900001
# day 1098, sell 1 unit at price 13.320000, investment 0.680273 %, total balance 10000.220000,
# day 1099: buy 1 unit at price 13.390000, total balance 9986.830000
# day 1100, sell 1 unit at price 13.380000, investment -0.074684 %, total balance 10000.210000,
# day 1108: buy 1 unit at price 13.400000, total balance 9986.810000
# day 1109, sell 1 unit at price 13.410000, investment 0.074629 %, total balance 10000.220000,
# day 1110: buy 1 unit at price 13.500000, total balance 9986.720000
# day 1111: buy 1 unit at price 13.510000, total balance 9973.210000
# day 1112, sell 1 unit at price 13.510000, investment 0.074076 %, total balance 9986.720000,
# day 1113, sell 1 unit at price 13.470000, investment -0.296077 %, total balance 10000.190001,
# day 1125: buy 1 unit at price 13.560000, total balance 9986.630000
# day 1126, sell 1 unit at price 13.540000, investment -0.147496 %, total balance 10000.170000,
# day 1130: buy 1 unit at price 13.510000, total balance 9986.660000
# day 1131, sell 1 unit at price 13.400000, investment -0.814216 %, total balance 10000.059999,
# day 1132: buy 1 unit at price 13.380000, total balance 9986.679999
# day 1133: buy 1 unit at price 13.460000, total balance 9973.219999
# day 1134, sell 1 unit at price 13.450000, investment 0.523167 %, total balance 9986.669999,
# day 1135, sell 1 unit at price 13.380000, investment -0.594353 %, total balance 10000.049999,
# day 1142: buy 1 unit at price 13.450000, total balance 9986.599999
# day 1143, sell 1 unit at price 13.530000, investment 0.594795 %, total balance 10000.129999,
# day 1163: buy 1 unit at price 13.420000, total balance 9986.709999
# day 1164, sell 1 unit at price 13.450000, investment 0.223545 %, total balance 10000.159999,
# day 1174: buy 1 unit at price 13.650000, total balance 9986.509999
# day 1175, sell 1 unit at price 13.700000, investment 0.366302 %, total balance 10000.209999,
# day 1182: buy 1 unit at price 13.730000, total balance 9986.480000
# day 1183, sell 1 unit at price 13.730000, investment 0.000000 %, total balance 10000.209999,
# day 1196: buy 1 unit at price 13.560000, total balance 9986.649999
# day 1197, sell 1 unit at price 13.530000, investment -0.221244 %, total balance 10000.179998,
# day 1209: buy 1 unit at price 13.620000, total balance 9986.559999
# day 1211, sell 1 unit at price 13.590000, investment -0.220262 %, total balance 10000.149999,
# day 1222: buy 1 unit at price 13.590000, total balance 9986.559999
# day 1223: buy 1 unit at price 13.550000, total balance 9973.009998
# day 1226, sell 1 unit at price 13.580000, investment -0.073585 %, total balance 9986.589998,
# day 1227: buy 1 unit at price 13.460000, total balance 9973.129998
# day 1228, sell 1 unit at price 13.450000, investment -0.738010 %, total balance 9986.579998,
# day 1229, sell 1 unit at price 13.440000, investment -0.148592 %, total balance 10000.019998,
# day 1236: buy 1 unit at price 13.380000, total balance 9986.639997
# day 1237, sell 1 unit at price 13.360000, investment -0.149480 %, total balance 9999.999997,
# day 1241: buy 1 unit at price 13.400000, total balance 9986.599998
# day 1242: buy 1 unit at price 13.470000, total balance 9973.129997
# day 1243, sell 1 unit at price 13.490000, investment 0.671643 %, total balance 9986.619997,
# day 1244, sell 1 unit at price 13.470000, investment 0.000000 %, total balance 10000.089997,
# day 1259: buy 1 unit at price 13.140000, total balance 9986.949997
# day 1260, sell 1 unit at price 13.200000, investment 0.456617 %, total balance 10000.149997,
# day 1283: buy 1 unit at price 12.650000, total balance 9987.499997
# day 1285, sell 1 unit at price 12.670000, investment 0.158106 %, total balance 10000.169997,
# day 1290: buy 1 unit at price 12.650000, total balance 9987.519998
# day 1291: buy 1 unit at price 12.620000, total balance 9974.899998
# day 1292: buy 1 unit at price 12.620000, total balance 9962.279998
# day 1293, sell 1 unit at price 12.630000, investment -0.158099 %, total balance 9974.909998,
# day 1294, sell 1 unit at price 12.640000, investment 0.158482 %, total balance 9987.549998,
# day 1295: buy 1 unit at price 12.630000, total balance 9974.919998
# day 1296, sell 1 unit at price 12.640000, investment 0.158482 %, total balance 9987.559999,
# day 1297, sell 1 unit at price 12.590000, investment -0.316706 %, total balance 10000.149999,
# day 1304: buy 1 unit at price 12.570000, total balance 9987.579999
# day 1305, sell 1 unit at price 12.540000, investment -0.238661 %, total balance 10000.119999,
# day 1310: buy 1 unit at price 12.420000, total balance 9987.699999
# day 1311, sell 1 unit at price 12.420000, investment 0.000000 %, total balance 10000.119999,
# day 1312: buy 1 unit at price 12.420000, total balance 9987.699999
# day 1313, sell 1 unit at price 12.370000, investment -0.402578 %, total balance 10000.069999,
# day 1320: buy 1 unit at price 12.470000, total balance 9987.599998
# day 1321: buy 1 unit at price 12.500000, total balance 9975.099998
# day 1322: buy 1 unit at price 12.580000, total balance 9962.519999
# day 1323, sell 1 unit at price 12.560000, investment 0.721733 %, total balance 9975.079999,
# day 1324, sell 1 unit at price 12.600000, investment 0.800003 %, total balance 9987.679999,
# day 1325, sell 1 unit at price 12.570000, investment -0.079493 %, total balance 10000.249999,
# day 1329: buy 1 unit at price 12.500000, total balance 9987.749999
# day 1331, sell 1 unit at price 12.470000, investment -0.239998 %, total balance 10000.219999,
# day 1332: buy 1 unit at price 12.450000, total balance 9987.770000
# day 1333, sell 1 unit at price 12.420000, investment -0.240962 %, total balance 10000.190000,
# day 1337: buy 1 unit at price 12.370000, total balance 9987.820000
# day 1338: buy 1 unit at price 12.370000, total balance 9975.450000
# day 1339, sell 1 unit at price 12.440000, investment 0.565883 %, total balance 9987.889999,
# day 1340, sell 1 unit at price 12.430000, investment 0.485048 %, total balance 10000.320000,
# day 1355: buy 1 unit at price 12.440000, total balance 9987.880000
# day 1356, sell 1 unit at price 12.460000, investment 0.160775 %, total balance 10000.340000,
# day 1371: buy 1 unit at price 12.590000, total balance 9987.750000
# day 1372: buy 1 unit at price 12.590000, total balance 9975.160000
# day 1373, sell 1 unit at price 12.480000, investment -0.873714 %, total balance 9987.639999,
# day 1374, sell 1 unit at price 12.500000, investment -0.714854 %, total balance 10000.139999,
# day 1376: buy 1 unit at price 12.570000, total balance 9987.570000
# day 1377, sell 1 unit at price 12.610000, investment 0.318218 %, total balance 10000.179999,
# day 1383: buy 1 unit at price 12.630000, total balance 9987.549999
# day 1384, sell 1 unit at price 12.630000, investment 0.000000 %, total balance 10000.179999,
# day 1395: buy 1 unit at price 12.740000, total balance 9987.440000
# day 1396, sell 1 unit at price 12.760000, investment 0.156989 %, total balance 10000.200000,
# day 1401: buy 1 unit at price 12.720000, total balance 9987.480000
# day 1402: buy 1 unit at price 12.690000, total balance 9974.790000
# day 1404, sell 1 unit at price 12.690000, investment -0.235854 %, total balance 9987.480000,
# day 1405, sell 1 unit at price 12.720000, investment 0.236412 %, total balance 10000.200000,
# day 1426: buy 1 unit at price 12.750000, total balance 9987.450000
# day 1427: buy 1 unit at price 12.770000, total balance 9974.679999
# day 1429: buy 1 unit at price 12.860000, total balance 9961.820000
# day 1430, sell 1 unit at price 12.850000, investment 0.784317 %, total balance 9974.670000,
# day 1431, sell 1 unit at price 12.680000, investment -0.704778 %, total balance 9987.350000,
# day 1432, sell 1 unit at price 12.760000, investment -0.777601 %, total balance 10000.110001,
# day 1436: buy 1 unit at price 12.570000, total balance 9987.540001
# day 1438, sell 1 unit at price 12.570000, investment 0.000000 %, total balance 10000.110001,
# day 1445: buy 1 unit at price 12.450000, total balance 9987.660001
# day 1446, sell 1 unit at price 12.450000, investment 0.000000 %, total balance 10000.110001,
# day 1451: buy 1 unit at price 12.330000, total balance 9987.780001
# day 1452, sell 1 unit at price 12.360000, investment 0.243307 %, total balance 10000.140000,
# day 1481: buy 1 unit at price 12.190000, total balance 9987.950001
# day 1482, sell 1 unit at price 12.200000, investment 0.082036 %, total balance 10000.150001,
# day 1492: buy 1 unit at price 12.400000, total balance 9987.750001
# day 1493: buy 1 unit at price 12.470000, total balance 9975.280001
# day 1494: buy 1 unit at price 12.420000, total balance 9962.860001
# day 1495, sell 1 unit at price 12.410000, investment 0.080647 %, total balance 9975.270000,
# day 1496, sell 1 unit at price 12.380000, investment -0.721733 %, total balance 9987.650001,
# day 1497, sell 1 unit at price 12.390000, investment -0.241544 %, total balance 10000.040001,
# day 1511: buy 1 unit at price 12.430000, total balance 9987.610001
# day 1513, sell 1 unit at price 12.520000, investment 0.724056 %, total balance 10000.130001,
# day 1519: buy 1 unit at price 12.550000, total balance 9987.580001
# day 1521, sell 1 unit at price 12.550000, investment 0.000000 %, total balance 10000.130001,
# day 1527: buy 1 unit at price 12.560000, total balance 9987.570001
# day 1528, sell 1 unit at price 12.630000, investment 0.557322 %, total balance 10000.200001,
# day 1551: buy 1 unit at price 13.050000, total balance 9987.150001
# day 1552, sell 1 unit at price 13.050000, investment 0.000000 %, total balance 10000.200001,
# day 1553: buy 1 unit at price 13.030000, total balance 9987.170001
# day 1554: buy 1 unit at price 13.080000, total balance 9974.090001
# day 1555, sell 1 unit at price 13.050000, investment 0.153495 %, total balance 9987.140001,
# day 1556, sell 1 unit at price 13.060000, investment -0.152901 %, total balance 10000.200002,
# day 1576: buy 1 unit at price 13.270000, total balance 9986.930001
# day 1577, sell 1 unit at price 13.290000, investment 0.150712 %, total balance 10000.220001,
# day 1587: buy 1 unit at price 13.250000, total balance 9986.970001
# day 1588, sell 1 unit at price 13.280000, investment 0.226413 %, total balance 10000.250001,
# day 1612: buy 1 unit at price 13.550000, total balance 9986.700001
# day 1613, sell 1 unit at price 13.570000, investment 0.147598 %, total balance 10000.270000,
# day 1624: buy 1 unit at price 13.680000, total balance 9986.590000
# day 1625, sell 1 unit at price 13.670000, investment -0.073101 %, total balance 10000.260000,
# day 1631: buy 1 unit at price 13.650000, total balance 9986.610001
# day 1632, sell 1 unit at price 13.710000, investment 0.439564 %, total balance 10000.320001,
# day 1643: buy 1 unit at price 13.800000, total balance 9986.520000
# day 1644, sell 1 unit at price 13.750000, investment -0.362320 %, total balance 10000.270000,
# day 1652: buy 1 unit at price 13.910000, total balance 9986.360001
# day 1653, sell 1 unit at price 13.950000, investment 0.287563 %, total balance 10000.310000,
# day 1656: buy 1 unit at price 14.110000, total balance 9986.200001
# day 1657, sell 1 unit at price 14.090000, investment -0.141740 %, total balance 10000.290001,
# day 1662: buy 1 unit at price 14.200000, total balance 9986.090001
# day 1663, sell 1 unit at price 14.220000, investment 0.140848 %, total balance 10000.310001,
# day 1666: buy 1 unit at price 14.140000, total balance 9986.170001
# day 1667, sell 1 unit at price 14.170000, investment 0.212162 %, total balance 10000.340001,
# day 1677: buy 1 unit at price 14.170000, total balance 9986.170001
# day 1678, sell 1 unit at price 14.220000, investment 0.352859 %, total balance 10000.390001,
# day 1682: buy 1 unit at price 14.150000, total balance 9986.240002
# day 1683: buy 1 unit at price 14.110000, total balance 9972.130002
# day 1685: buy 1 unit at price 13.940000, total balance 9958.190002
# day 1686: buy 1 unit at price 13.800000, total balance 9944.390002
# day 1687, sell 1 unit at price 13.830000, investment -2.261482 %, total balance 9958.220002,
# day 1688: buy 1 unit at price 13.820000, total balance 9944.400002
# day 1689, sell 1 unit at price 13.810000, investment -2.126146 %, total balance 9958.210003,
# day 1690: buy 1 unit at price 13.910000, total balance 9944.300003
# day 1691, sell 1 unit at price 13.860000, investment -0.573888 %, total balance 9958.160003,
# day 1692, sell 1 unit at price 13.940000, investment 1.014488 %, total balance 9972.100002,
# day 1693, sell 1 unit at price 13.980000, investment 1.157741 %, total balance 9986.080002,
# day 1694, sell 1 unit at price 14.010000, investment 0.718910 %, total balance 10000.090002,
# day 1711: buy 1 unit at price 14.090000, total balance 9986.000002
# day 1712: buy 1 unit at price 13.950000, total balance 9972.050002
# day 1713, sell 1 unit at price 14.020000, investment -0.496804 %, total balance 9986.070003,
# day 1714, sell 1 unit at price 14.020000, investment 0.501797 %, total balance 10000.090003,
# day 1724: buy 1 unit at price 14.160000, total balance 9985.930003
# day 1725, sell 1 unit at price 14.040000, investment -0.847457 %, total balance 9999.970003,
# day 1738: buy 1 unit at price 14.160000, total balance 9985.810003
# day 1739: buy 1 unit at price 14.110000, total balance 9971.700004
# day 1740, sell 1 unit at price 14.030000, investment -0.918080 %, total balance 9985.730003,
# day 1741, sell 1 unit at price 14.040000, investment -0.496100 %, total balance 9999.770003,
# day 1748: buy 1 unit at price 14.200000, total balance 9985.570003
# day 1749: buy 1 unit at price 14.210000, total balance 9971.360003
# day 1750, sell 1 unit at price 14.260000, investment 0.422538 %, total balance 9985.620004,
# day 1752, sell 1 unit at price 14.230000, investment 0.140742 %, total balance 9999.850003,
# day 1754: buy 1 unit at price 14.180000, total balance 9985.670003
# day 1755: buy 1 unit at price 14.140000, total balance 9971.530003
# day 1756, sell 1 unit at price 14.160000, investment -0.141047 %, total balance 9985.690002,
# day 1757, sell 1 unit at price 14.140000, investment 0.000000 %, total balance 9999.830003,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
