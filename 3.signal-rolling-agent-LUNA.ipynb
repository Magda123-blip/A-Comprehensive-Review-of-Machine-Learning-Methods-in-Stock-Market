# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../agent/cleaned_data/LUNA.csv')
df.head()
# Out:
#        Date  Open  High   Low  Close  Adj Close  Volume
# 0  1/2/2013  1.18  1.32  1.18   1.25       1.25   11700
# 1  1/3/2013  1.22  1.24  1.16   1.17       1.17   15800
# 2  1/4/2013  1.18  1.23  1.18   1.22       1.22    5600
# 3  1/7/2013  1.22  1.22  1.20   1.22       1.22    2500
# 4  1/8/2013  1.24  1.32  1.20   1.30       1.30    8500

# %%
def buy_stock(
    real_movement,
    delay = 5,
    initial_state = 1,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    delay_change_decision = delay
    current_decision = 0
    state = initial_state
    current_val = real_movement[0]
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    if state == 1:
        initial_money, current_inventory = buy(
            0, initial_money, current_inventory
        )

    for i in range(1, real_movement.shape[0], 1):
        if real_movement[i] < current_val and state == 0:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 1
                initial_money, current_inventory = buy(
                    i, initial_money, current_inventory
                )
                current_decision = 0
                states_buy.append(i)
        if real_movement[i] > current_val and state == 1:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 0

                if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
                else:
                    if current_inventory > max_sell:
                        sell_units = max_sell
                    else:
                        sell_units = current_inventory
                    current_inventory -= sell_units
                    total_sell = sell_units * real_movement[i]
                    initial_money += total_sell
                    try:
                        invest = (
                            (real_movement[i] - real_movement[states_buy[-1]])
                            / real_movement[states_buy[-1]]
                        ) * 100
                    except:
                        invest = 0
                    print(
                        'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                        % (i, sell_units, total_sell, invest, initial_money)
                    )

                current_decision = 0
                states_sell.append(i)
        current_val = real_movement[i]
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, initial_state = 1, 
                                                         delay = 4, initial_money = 10000)
# Out:
# day 0: buy 1 units at price 1.250000, total balance 9998.750000
# day 10, sell 1 units at price 1.270000, investment 1.599998 %, total balance 10000.020000,
# day 24: buy 1 units at price 1.250000, total balance 9998.770000
# day 43, sell 1 units at price 1.250000, investment 0.000000 %, total balance 10000.020000,
# day 59: buy 1 units at price 1.260000, total balance 9998.760000
# day 71, sell 1 units at price 1.250000, investment -0.793650 %, total balance 10000.010000,
# day 80: buy 1 units at price 1.180000, total balance 9998.830000
# day 87, sell 1 units at price 1.330000, investment 12.711873 %, total balance 10000.160000,
# day 98: buy 1 units at price 1.260000, total balance 9998.900000
# day 107, sell 1 units at price 1.340000, investment 6.349210 %, total balance 10000.240000,
# day 121: buy 1 units at price 1.300000, total balance 9998.940000
# day 131, sell 1 units at price 1.650000, investment 26.923080 %, total balance 10000.590000,
# day 138: buy 1 units at price 1.430000, total balance 9999.160000
# day 148, sell 1 units at price 1.500000, investment 4.895109 %, total balance 10000.660000,
# day 154: buy 1 units at price 1.270000, total balance 9999.390000
# day 170, sell 1 units at price 1.220000, investment -3.937004 %, total balance 10000.610000,
# day 181: buy 1 units at price 1.210000, total balance 9999.400000
# day 189, sell 1 units at price 1.370000, investment 13.223137 %, total balance 10000.770000,
# day 204: buy 1 units at price 1.410000, total balance 9999.360000
# day 214, sell 1 units at price 1.450000, investment 2.836885 %, total balance 10000.810000,
# day 221: buy 1 units at price 1.210000, total balance 9999.600000
# day 238, sell 1 units at price 1.290000, investment 6.611564 %, total balance 10000.890000,
# day 249: buy 1 units at price 1.360000, total balance 9999.530000
# day 258, sell 1 units at price 1.470000, investment 8.088236 %, total balance 10001.000000,
# day 264: buy 1 units at price 1.320000, total balance 9999.680000
# day 280, sell 1 units at price 1.720000, investment 30.303027 %, total balance 10001.400000,
# day 288: buy 1 units at price 1.530000, total balance 9999.870000
# day 299, sell 1 units at price 1.720000, investment 12.418305 %, total balance 10001.590000,
# day 310: buy 1 units at price 1.470000, total balance 10000.120000
# day 318, sell 1 units at price 1.510000, investment 2.721086 %, total balance 10001.630000,
# day 323: buy 1 units at price 1.330000, total balance 10000.300000
# day 332, sell 1 units at price 1.480000, investment 11.278193 %, total balance 10001.780000,
# day 340: buy 1 units at price 1.420000, total balance 10000.360000
# day 350, sell 1 units at price 1.410000, investment -0.704225 %, total balance 10001.770000,
# day 360: buy 1 units at price 1.380000, total balance 10000.390000
# day 375, sell 1 units at price 1.370000, investment -0.724637 %, total balance 10001.760000,
# day 387: buy 1 units at price 1.360000, total balance 10000.400000
# day 393, sell 1 units at price 1.430000, investment 5.147054 %, total balance 10001.830000,
# day 404: buy 1 units at price 1.230000, total balance 10000.600000
# day 410, sell 1 units at price 1.330000, investment 8.130083 %, total balance 10001.930000,
# day 418: buy 1 units at price 1.310000, total balance 10000.620000
# day 426, sell 1 units at price 1.660000, investment 26.717560 %, total balance 10002.280000,
# day 432: buy 1 units at price 1.380000, total balance 10000.900000
# day 445, sell 1 units at price 1.390000, investment 0.724637 %, total balance 10002.290000,
# day 450: buy 1 units at price 1.240000, total balance 10001.050000
# day 457, sell 1 units at price 1.310000, investment 5.645156 %, total balance 10002.360000,
# day 473: buy 1 units at price 1.420000, total balance 10000.940000
# day 483, sell 1 units at price 1.450000, investment 2.112683 %, total balance 10002.390000,
# day 493: buy 1 units at price 1.390000, total balance 10001.000000
# day 500, sell 1 units at price 1.450000, investment 4.316551 %, total balance 10002.450000,
# day 512: buy 1 units at price 1.580000, total balance 10000.870000
# day 522, sell 1 units at price 1.640000, investment 3.797465 %, total balance 10002.510000,
# day 532: buy 1 units at price 1.490000, total balance 10001.020000
# day 546, sell 1 units at price 1.450000, investment -2.684561 %, total balance 10002.470000,
# day 555: buy 1 units at price 1.370000, total balance 10001.100000
# day 576, sell 1 units at price 1.370000, investment 0.000000 %, total balance 10002.470000,
# day 590: buy 1 units at price 1.330000, total balance 10001.140000
# day 610, sell 1 units at price 1.120000, investment -15.789476 %, total balance 10002.260000,
# day 618: buy 1 units at price 1.030000, total balance 10001.230000
# day 634, sell 1 units at price 1.010000, investment -1.941746 %, total balance 10002.240000,
# day 642: buy 1 units at price 1.090000, total balance 10001.150000
# day 651, sell 1 units at price 1.190000, investment 9.174314 %, total balance 10002.340000,
# day 663: buy 1 units at price 1.180000, total balance 10001.160000
# day 682, sell 1 units at price 1.090000, investment -7.627112 %, total balance 10002.250000,
# day 690: buy 1 units at price 0.920000, total balance 10001.330000
# day 702, sell 1 units at price 0.990000, investment 7.608695 %, total balance 10002.320000,
# day 718: buy 1 units at price 1.130000, total balance 10001.190000
# day 732, sell 1 units at price 1.090000, investment -3.539820 %, total balance 10002.280000,
# day 740: buy 1 units at price 1.000000, total balance 10001.280000
# day 751, sell 1 units at price 1.150000, investment 14.999998 %, total balance 10002.430000,
# day 759: buy 1 units at price 1.040000, total balance 10001.390000
# day 771, sell 1 units at price 0.970000, investment -6.730763 %, total balance 10002.360000,
# day 777: buy 1 units at price 0.900000, total balance 10001.460000
# day 789, sell 1 units at price 1.020000, investment 13.333334 %, total balance 10002.480000,
# day 796: buy 1 units at price 0.900000, total balance 10001.580000
# day 806, sell 1 units at price 0.970000, investment 7.777784 %, total balance 10002.550000,
# day 816: buy 1 units at price 1.050000, total balance 10001.500001
# day 830, sell 1 units at price 1.080000, investment 2.857152 %, total balance 10002.580001,
# day 838: buy 1 units at price 0.980000, total balance 10001.600001
# day 845, sell 1 units at price 1.060000, investment 8.163257 %, total balance 10002.660001,
# day 857: buy 1 units at price 1.040000, total balance 10001.620001
# day 868, sell 1 units at price 1.180000, investment 13.461538 %, total balance 10002.800000,
# day 877: buy 1 units at price 1.130000, total balance 10001.670000
# day 887, sell 1 units at price 1.250000, investment 10.619470 %, total balance 10002.920000,
# day 899: buy 1 units at price 1.330000, total balance 10001.590000
# day 907, sell 1 units at price 1.500000, investment 12.781951 %, total balance 10003.090000,
# day 918: buy 1 units at price 1.170000, total balance 10001.920000
# day 927, sell 1 units at price 1.260000, investment 7.692311 %, total balance 10003.180000,
# day 942: buy 1 units at price 1.470000, total balance 10001.710000
# day 956, sell 1 units at price 1.310000, investment -10.884359 %, total balance 10003.020000,
# day 966: buy 1 units at price 1.270000, total balance 10001.750000
# day 978, sell 1 units at price 1.400000, investment 10.236220 %, total balance 10003.150000,
# day 988: buy 1 units at price 1.390000, total balance 10001.760000
# day 999, sell 1 units at price 1.450000, investment 4.316551 %, total balance 10003.210000,
# day 1014: buy 1 units at price 1.530000, total balance 10001.680000
# day 1021, sell 1 units at price 1.820000, investment 18.954254 %, total balance 10003.500001,
# day 1034: buy 1 units at price 1.940000, total balance 10001.560000
# day 1050, sell 1 units at price 1.890000, investment -2.577323 %, total balance 10003.450000,
# day 1060: buy 1 units at price 1.760000, total balance 10001.690000
# day 1072, sell 1 units at price 1.730000, investment -1.704544 %, total balance 10003.420000,
# day 1080: buy 1 units at price 1.530000, total balance 10001.890001
# day 1090, sell 1 units at price 1.530000, investment 0.000000 %, total balance 10003.420000,
# day 1105: buy 1 units at price 1.510000, total balance 10001.910001
# day 1112, sell 1 units at price 1.520000, investment 0.662251 %, total balance 10003.430000,
# day 1121: buy 1 units at price 1.580000, total balance 10001.850000
# day 1137, sell 1 units at price 1.410000, investment -10.759498 %, total balance 10003.260000,
# day 1149: buy 1 units at price 1.360000, total balance 10001.900000
# day 1160, sell 1 units at price 1.420000, investment 4.411760 %, total balance 10003.320000,
# day 1169: buy 1 units at price 1.380000, total balance 10001.940000
# day 1176, sell 1 units at price 1.590000, investment 15.217394 %, total balance 10003.530000,
# day 1189: buy 1 units at price 1.630000, total balance 10001.900000
# day 1197, sell 1 units at price 1.720000, investment 5.521474 %, total balance 10003.620000,
# day 1205: buy 1 units at price 1.630000, total balance 10001.990000
# day 1217, sell 1 units at price 1.680000, investment 3.067482 %, total balance 10003.670000,
# day 1238: buy 1 units at price 2.350000, total balance 10001.320000
# day 1249, sell 1 units at price 2.450000, investment 4.255325 %, total balance 10003.770001,
# day 1262: buy 1 units at price 2.730000, total balance 10001.040001
# day 1282, sell 1 units at price 2.200000, investment -19.413918 %, total balance 10003.240001,
# day 1298: buy 1 units at price 2.660000, total balance 10000.580000
# day 1310, sell 1 units at price 2.560000, investment -3.759404 %, total balance 10003.140000,
# day 1328: buy 1 units at price 3.390000, total balance 9999.750000
# day 1341, sell 1 units at price 3.400000, investment 0.294985 %, total balance 10003.150000,
# day 1350: buy 1 units at price 2.870000, total balance 10000.280001
# day 1356, sell 1 units at price 3.260000, investment 13.588854 %, total balance 10003.540001,
# day 1367: buy 1 units at price 3.080000, total balance 10000.460001
# day 1378, sell 1 units at price 2.970000, investment -3.571425 %, total balance 10003.430001,
# day 1392: buy 1 units at price 3.350000, total balance 10000.080001
# day 1398, sell 1 units at price 3.540000, investment 5.671644 %, total balance 10003.620001,
# day 1409: buy 1 units at price 3.680000, total balance 9999.940001
# day 1424, sell 1 units at price 3.570000, investment -2.989134 %, total balance 10003.510001,
# day 1433: buy 1 units at price 3.530000, total balance 9999.980001
# day 1449, sell 1 units at price 3.250000, investment -7.932011 %, total balance 10003.230001,
# day 1456: buy 1 units at price 2.930000, total balance 10000.300000
# day 1465, sell 1 units at price 3.220000, investment 9.897609 %, total balance 10003.520001,
# day 1473: buy 1 units at price 3.150000, total balance 10000.370000
# day 1478, sell 1 units at price 3.570000, investment 13.333328 %, total balance 10003.940000,
# day 1485: buy 1 units at price 3.400000, total balance 10000.540000
# day 1502, sell 1 units at price 3.000000, investment -11.764708 %, total balance 10003.540000,
# day 1511: buy 1 units at price 3.220000, total balance 10000.320000
# day 1519, sell 1 units at price 3.330000, investment 3.416146 %, total balance 10003.650000,
# day 1533: buy 1 units at price 3.290000, total balance 10000.360000
# day 1548, sell 1 units at price 3.300000, investment 0.303951 %, total balance 10003.660000,
# day 1558: buy 1 units at price 3.890000, total balance 9999.770000
# day 1566, sell 1 units at price 4.380000, investment 12.596401 %, total balance 10004.150000,
# day 1574: buy 1 units at price 4.180000, total balance 9999.970000
# day 1582, sell 1 units at price 4.160000, investment -0.478468 %, total balance 10004.130000,
# day 1597: buy 1 units at price 4.600000, total balance 9999.530000
# day 1611, sell 1 units at price 4.180000, investment -9.130437 %, total balance 10003.710000,
# day 1621: buy 1 units at price 3.990000, total balance 9999.720000
# day 1626, sell 1 units at price 4.320000, investment 8.270681 %, total balance 10004.040000,
# day 1642: buy 1 units at price 5.120000, total balance 9998.920000
# day 1654, sell 1 units at price 5.210000, investment 1.757816 %, total balance 10004.130000,
# day 1659: buy 1 units at price 4.550000, total balance 9999.580000
# day 1667, sell 1 units at price 5.930000, investment 30.329661 %, total balance 10005.510000,
# day 1682: buy 1 units at price 6.040000, total balance 9999.470000
# day 1691, sell 1 units at price 6.140000, investment 1.655628 %, total balance 10005.610000,
# day 1701: buy 1 units at price 5.830000, total balance 9999.780000
# day 1712, sell 1 units at price 5.830000, investment 0.000000 %, total balance 10005.610000,
# day 1728: buy 1 units at price 6.500000, total balance 9999.110000
# day 1737, sell 1 units at price 7.320000, investment 12.615387 %, total balance 10006.430000,
# day 1747: buy 1 units at price 7.420000, total balance 9999.010000
# day 1756, sell 1 units at price 7.430000, investment 0.134768 %, total balance 10006.440000,

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
