# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../agent/cleaned_data/COOP.csv')
df.head()
# Out:
#        Date   Open   High   Low  Close  Adj Close  Volume
# 0  1/2/2013  10.20  10.32  9.48   9.72       9.72   64700
# 1  1/3/2013   9.60   9.84  9.48   9.60       9.60   21600
# 2  1/4/2013   9.48   9.96  9.48   9.48       9.48    8000
# 3  1/7/2013   9.48   9.60  9.00   9.36       9.36  116100
# 4  1/8/2013   9.48   9.48  7.80   8.40       8.40   20800

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE1C55548>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE1C55548>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE1C55548>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE1C55548>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE1C55548>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE1C55548>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE1C55548>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE1C55548>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE3F16E48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE3F16E48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE3F16E48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE3F16E48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE3F16E48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE3F16E48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE3F16E48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001EFE3F16E48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: -386.780018.3, cost: 0.001310, total money: 9343.119982
# epoch: 20, total rewards: -148.540004.3, cost: 0.002500, total money: 9673.069996
# epoch: 30, total rewards: 702.970029.3, cost: 0.000189, total money: 10652.670029
# epoch: 40, total rewards: -108.280008.3, cost: 0.000443, total money: 9854.049992
# epoch: 50, total rewards: 77.819970.3, cost: 0.000853, total money: 10052.319970
# epoch: 60, total rewards: 26.630001.3, cost: 0.000194, total money: 10014.160001
# epoch: 70, total rewards: 5.389977.3, cost: 0.000074, total money: 10005.389977
# epoch: 80, total rewards: 63.690011.3, cost: 0.003705, total money: 10038.670011
# epoch: 90, total rewards: -4.799979.3, cost: 0.000025, total money: 9995.200021
# epoch: 100, total rewards: -33.360003.3, cost: 0.000023, total money: 9966.639997
# epoch: 110, total rewards: 19.060008.3, cost: 0.000057, total money: 10019.060008
# epoch: 120, total rewards: -2.280029.3, cost: 0.000016, total money: 9997.719971
# epoch: 130, total rewards: 42.229982.3, cost: 0.000009, total money: 10042.229982
# epoch: 140, total rewards: 56.430015.3, cost: 0.000536, total money: 10006.120016
# epoch: 150, total rewards: 33.709985.3, cost: 0.000285, total money: 10033.709985
# epoch: 160, total rewards: -16.859971.3, cost: 0.000012, total money: 9983.140029
# epoch: 170, total rewards: 31.539995.3, cost: 0.000268, total money: 10019.029994
# epoch: 180, total rewards: 16.810005.3, cost: 0.000494, total money: 10004.300005
# epoch: 190, total rewards: -5.799990.3, cost: 0.000020, total money: 9981.690010
# epoch: 200, total rewards: 57.360011.3, cost: 0.000045, total money: 10057.360011

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 9.720000, total balance 9990.280000
# day 1: buy 1 unit at price 9.600000, total balance 9980.679999
# day 2, sell 1 unit at price 9.480000, investment -2.469143 %, total balance 9990.159999,
# day 3, sell 1 unit at price 9.360000, investment -2.500007 %, total balance 9999.519999,
# day 9: buy 1 unit at price 9.600000, total balance 9989.919998
# day 10: buy 1 unit at price 9.600000, total balance 9980.319998
# day 12, sell 1 unit at price 9.960000, investment 3.749996 %, total balance 9990.279998,
# day 13, sell 1 unit at price 9.600000, investment 0.000000 %, total balance 9999.879998,
# day 21: buy 1 unit at price 9.000000, total balance 9990.879998
# day 22: buy 1 unit at price 9.000000, total balance 9981.879998
# day 23, sell 1 unit at price 9.000000, investment 0.000000 %, total balance 9990.879998,
# day 24: buy 1 unit at price 9.360000, total balance 9981.519999
# day 25, sell 1 unit at price 9.840000, investment 9.333335 %, total balance 9991.359999,
# day 26, sell 1 unit at price 9.360000, investment 0.000000 %, total balance 10000.719998,
# day 31: buy 1 unit at price 9.480000, total balance 9991.239999
# day 32, sell 1 unit at price 9.600000, investment 1.265832 %, total balance 10000.839999,
# day 41: buy 1 unit at price 9.120000, total balance 9991.719999
# day 42: buy 1 unit at price 8.640000, total balance 9983.079999
# day 43: buy 1 unit at price 9.000000, total balance 9974.079999
# day 44, sell 1 unit at price 8.760000, investment -3.947365 %, total balance 9982.839999,
# day 45, sell 1 unit at price 8.880000, investment 2.777775 %, total balance 9991.719999,
# day 46, sell 1 unit at price 8.760000, investment -2.666664 %, total balance 10000.480000,
# day 62: buy 1 unit at price 8.040000, total balance 9992.440000
# day 63: buy 1 unit at price 7.680000, total balance 9984.760000
# day 65, sell 1 unit at price 7.800000, investment -2.985072 %, total balance 9992.560000,
# day 66, sell 1 unit at price 7.680000, investment 0.000000 %, total balance 10000.240000,
# day 68: buy 1 unit at price 7.560000, total balance 9992.680000
# day 69, sell 1 unit at price 7.560000, investment 0.000000 %, total balance 10000.240000,
# day 79: buy 1 unit at price 7.200000, total balance 9993.040000
# day 80: buy 1 unit at price 7.080000, total balance 9985.960000
# day 81, sell 1 unit at price 7.200000, investment 0.000000 %, total balance 9993.160000,
# day 82, sell 1 unit at price 7.200000, investment 1.694914 %, total balance 10000.360000,
# day 87: buy 1 unit at price 7.200000, total balance 9993.160000
# day 88, sell 1 unit at price 7.200000, investment 0.000000 %, total balance 10000.360000,
# day 105: buy 1 unit at price 10.320000, total balance 9990.040000
# day 106, sell 1 unit at price 9.240000, investment -10.465116 %, total balance 9999.280000,
# day 122: buy 1 unit at price 9.600000, total balance 9989.679999
# day 123, sell 1 unit at price 9.600000, investment 0.000000 %, total balance 9999.280000,
# day 135: buy 1 unit at price 10.560000, total balance 9988.719999
# day 136, sell 1 unit at price 10.560000, investment 0.000000 %, total balance 9999.280000,
# day 150: buy 1 unit at price 12.600000, total balance 9986.679999
# day 151, sell 1 unit at price 12.600000, investment 0.000000 %, total balance 9999.280000,
# day 158: buy 1 unit at price 12.240000, total balance 9987.040000
# day 159, sell 1 unit at price 12.240000, investment 0.000000 %, total balance 9999.280000,
# day 171: buy 1 unit at price 12.480000, total balance 9986.800000
# day 173: buy 1 unit at price 12.360000, total balance 9974.440001
# day 174, sell 1 unit at price 13.560000, investment 8.653854 %, total balance 9988.000001,
# day 175, sell 1 unit at price 13.920000, investment 12.621363 %, total balance 10001.920001,
# day 183: buy 1 unit at price 15.240000, total balance 9986.680001
# day 184, sell 1 unit at price 15.000000, investment -1.574802 %, total balance 10001.680001,
# day 195: buy 1 unit at price 14.160000, total balance 9987.520001
# day 196, sell 1 unit at price 14.160000, investment 0.000000 %, total balance 10001.680001,
# day 201: buy 1 unit at price 14.280000, total balance 9987.400002
# day 202, sell 1 unit at price 14.040000, investment -1.680671 %, total balance 10001.440001,
# day 204: buy 1 unit at price 14.040000, total balance 9987.400002
# day 205, sell 1 unit at price 14.160000, investment 0.854700 %, total balance 10001.560001,
# day 208: buy 1 unit at price 13.440000, total balance 9988.120002
# day 210, sell 1 unit at price 13.200000, investment -1.785713 %, total balance 10001.320002,
# day 214: buy 1 unit at price 12.600000, total balance 9988.720001
# day 215, sell 1 unit at price 12.120000, investment -3.809528 %, total balance 10000.840001,
# day 226: buy 1 unit at price 13.560000, total balance 9987.280001
# day 227, sell 1 unit at price 13.680000, investment 0.884955 %, total balance 10000.960001,
# day 230: buy 1 unit at price 13.800000, total balance 9987.160001
# day 232, sell 1 unit at price 13.560000, investment -1.739129 %, total balance 10000.720001,
# day 237: buy 1 unit at price 20.160000, total balance 9980.560001
# day 238, sell 1 unit at price 21.120001, investment 4.761910 %, total balance 10001.680002,
# day 252: buy 1 unit at price 34.439999, total balance 9967.240004
# day 253, sell 1 unit at price 35.279999, investment 2.439025 %, total balance 10002.520002,
# day 278: buy 1 unit at price 30.360001, total balance 9972.160002
# day 279, sell 1 unit at price 32.400002, investment 6.719370 %, total balance 10004.560003,
# day 283: buy 1 unit at price 32.279999, total balance 9972.280005
# day 284, sell 1 unit at price 32.160000, investment -0.371744 %, total balance 10004.440004,
# day 301: buy 1 unit at price 40.200001, total balance 9964.240004
# day 302, sell 1 unit at price 41.160000, investment 2.388057 %, total balance 10005.400003,
# day 304: buy 1 unit at price 40.799999, total balance 9964.600004
# day 306, sell 1 unit at price 39.000000, investment -4.411763 %, total balance 10003.600004,
# day 311: buy 1 unit at price 39.000000, total balance 9964.600004
# day 312, sell 1 unit at price 39.000000, investment 0.000000 %, total balance 10003.600004,
# day 330: buy 1 unit at price 36.840000, total balance 9966.760004
# day 332, sell 1 unit at price 36.480000, investment -0.977200 %, total balance 10003.240004,
# day 339: buy 1 unit at price 32.759998, total balance 9970.480005
# day 341, sell 1 unit at price 32.160000, investment -1.831497 %, total balance 10002.640005,
# day 351: buy 1 unit at price 34.919998, total balance 9967.720007
# day 352, sell 1 unit at price 34.799999, investment -0.343640 %, total balance 10002.520006,
# day 355: buy 1 unit at price 34.799999, total balance 9967.720007
# day 357, sell 1 unit at price 33.480000, investment -3.793103 %, total balance 10001.200007,
# day 368: buy 1 unit at price 33.959999, total balance 9967.240007
# day 369, sell 1 unit at price 33.599998, investment -1.060072 %, total balance 10000.840006,
# day 388: buy 1 unit at price 33.599998, total balance 9967.240007
# day 389, sell 1 unit at price 33.240002, investment -1.071419 %, total balance 10000.480009,
# day 393: buy 1 unit at price 33.000000, total balance 9967.480009
# day 394, sell 1 unit at price 33.000000, investment 0.000000 %, total balance 10000.480009,
# day 403: buy 1 unit at price 32.520000, total balance 9967.960009
# day 404, sell 1 unit at price 32.639999, investment 0.369000 %, total balance 10000.600008,
# day 405: buy 1 unit at price 32.639999, total balance 9967.960009
# day 406: buy 1 unit at price 32.520000, total balance 9935.440008
# day 407, sell 1 unit at price 32.639999, investment 0.000000 %, total balance 9968.080008,
# day 408, sell 1 unit at price 32.520000, investment 0.000000 %, total balance 10000.600008,
# day 414: buy 1 unit at price 33.720001, total balance 9966.880007
# day 415, sell 1 unit at price 32.400002, investment -3.914590 %, total balance 9999.280008,
# day 418: buy 1 unit at price 33.000000, total balance 9966.280008
# day 419, sell 1 unit at price 33.000000, investment 0.000000 %, total balance 9999.280008,
# day 421: buy 1 unit at price 32.880001, total balance 9966.400007
# day 422, sell 1 unit at price 32.400002, investment -1.459853 %, total balance 9998.800009,
# day 423: buy 1 unit at price 32.639999, total balance 9966.160009
# day 425, sell 1 unit at price 32.279999, investment -1.102943 %, total balance 9998.440008,
# day 428: buy 1 unit at price 32.160000, total balance 9966.280008
# day 429, sell 1 unit at price 31.799999, investment -1.119405 %, total balance 9998.080008,
# day 430: buy 1 unit at price 31.680000, total balance 9966.400007
# day 432: buy 1 unit at price 30.840000, total balance 9935.560007
# day 434, sell 1 unit at price 29.160000, investment -7.954547 %, total balance 9964.720007,
# day 435, sell 1 unit at price 27.840000, investment -9.727626 %, total balance 9992.560007,
# day 436: buy 1 unit at price 28.200001, total balance 9964.360006
# day 437, sell 1 unit at price 32.279999, investment 14.468078 %, total balance 9996.640005,
# day 453: buy 1 unit at price 26.520000, total balance 9970.120005
# day 454: buy 1 unit at price 26.400000, total balance 9943.720005
# day 455, sell 1 unit at price 25.920000, investment -2.262445 %, total balance 9969.640005,
# day 456, sell 1 unit at price 26.760000, investment 1.363639 %, total balance 9996.400005,
# day 457: buy 1 unit at price 27.000000, total balance 9969.400005
# day 458, sell 1 unit at price 27.000000, investment 0.000000 %, total balance 9996.400005,
# day 459: buy 1 unit at price 26.520000, total balance 9969.880005
# day 460, sell 1 unit at price 26.400000, investment -0.452492 %, total balance 9996.280005,
# day 461: buy 1 unit at price 25.440001, total balance 9970.840004
# day 463: buy 1 unit at price 24.360001, total balance 9946.480003
# day 465: buy 1 unit at price 25.440001, total balance 9921.040003
# day 466, sell 1 unit at price 24.959999, investment -1.886798 %, total balance 9946.000002,
# day 468, sell 1 unit at price 24.000000, investment -1.477835 %, total balance 9970.000002,
# day 469, sell 1 unit at price 24.000000, investment -5.660379 %, total balance 9994.000002,
# day 471: buy 1 unit at price 22.799999, total balance 9971.200003
# day 472, sell 1 unit at price 21.959999, investment -3.684211 %, total balance 9993.160002,
# day 473: buy 1 unit at price 21.000000, total balance 9972.160002
# day 474, sell 1 unit at price 21.000000, investment 0.000000 %, total balance 9993.160002,
# day 477: buy 1 unit at price 20.879999, total balance 9972.280003
# day 478, sell 1 unit at price 21.840000, investment 4.597706 %, total balance 9994.120003,
# day 484: buy 1 unit at price 24.959999, total balance 9969.160004
# day 485, sell 1 unit at price 24.480000, investment -1.923075 %, total balance 9993.640003,
# day 493: buy 1 unit at price 22.799999, total balance 9970.840004
# day 494, sell 1 unit at price 21.959999, investment -3.684211 %, total balance 9992.800003,
# day 502: buy 1 unit at price 25.320000, total balance 9967.480003
# day 503, sell 1 unit at price 24.600000, investment -2.843599 %, total balance 9992.080004,
# day 509: buy 1 unit at price 26.280001, total balance 9965.800003
# day 510, sell 1 unit at price 26.280001, investment 0.000000 %, total balance 9992.080004,
# day 527: buy 1 unit at price 25.799999, total balance 9966.280005
# day 528, sell 1 unit at price 26.280001, investment 1.860471 %, total balance 9992.560005,
# day 536: buy 1 unit at price 26.160000, total balance 9966.400005
# day 537, sell 1 unit at price 26.400000, investment 0.917430 %, total balance 9992.800005,
# day 541: buy 1 unit at price 30.600000, total balance 9962.200005
# day 542, sell 1 unit at price 30.600000, investment 0.000000 %, total balance 9992.800005,
# day 545: buy 1 unit at price 30.240000, total balance 9962.560005
# day 546: buy 1 unit at price 29.760000, total balance 9932.800005
# day 547, sell 1 unit at price 29.280001, investment -3.174600 %, total balance 9962.080006,
# day 548: buy 1 unit at price 29.040001, total balance 9933.040005
# day 550, sell 1 unit at price 28.680000, investment -3.629032 %, total balance 9961.720005,
# day 551, sell 1 unit at price 28.559999, investment -1.652898 %, total balance 9990.280005,
# day 556: buy 1 unit at price 27.959999, total balance 9962.320005
# day 558, sell 1 unit at price 28.440001, investment 1.716743 %, total balance 9990.760006,
# day 585: buy 1 unit at price 30.959999, total balance 9959.800007
# day 587, sell 1 unit at price 32.520000, investment 5.038764 %, total balance 9992.320007,
# day 599: buy 1 unit at price 35.880001, total balance 9956.440006
# day 600, sell 1 unit at price 35.279999, investment -1.672247 %, total balance 9991.720005,
# day 602: buy 1 unit at price 34.080002, total balance 9957.640003
# day 603, sell 1 unit at price 33.360001, investment -2.112680 %, total balance 9991.000004,
# day 621: buy 1 unit at price 33.000000, total balance 9958.000004
# day 623, sell 1 unit at price 32.759998, investment -0.727278 %, total balance 9990.760002,
# day 637: buy 1 unit at price 30.959999, total balance 9959.800003
# day 638, sell 1 unit at price 33.000000, investment 6.589150 %, total balance 9992.800003,
# day 639: buy 1 unit at price 34.080002, total balance 9958.720001
# day 640, sell 1 unit at price 34.439999, investment 1.056329 %, total balance 9993.160000,
# day 651: buy 1 unit at price 29.639999, total balance 9963.520001
# day 652, sell 1 unit at price 29.879999, investment 0.809716 %, total balance 9993.400000,
# day 670: buy 1 unit at price 27.600000, total balance 9965.799999
# day 671, sell 1 unit at price 27.600000, investment 0.000000 %, total balance 9993.400000,
# day 685: buy 1 unit at price 29.760000, total balance 9963.639999
# day 686, sell 1 unit at price 29.040001, investment -2.419353 %, total balance 9992.680000,
# day 688: buy 1 unit at price 32.279999, total balance 9960.400002
# day 689, sell 1 unit at price 32.279999, investment 0.000000 %, total balance 9992.680000,
# day 690: buy 1 unit at price 31.799999, total balance 9960.880001
# day 692: buy 1 unit at price 30.840000, total balance 9930.040001
# day 693, sell 1 unit at price 30.959999, investment -2.641510 %, total balance 9961.000000,
# day 694, sell 1 unit at price 30.840000, investment 0.000000 %, total balance 9991.840000,
# day 714: buy 1 unit at price 28.200001, total balance 9963.639999
# day 715: buy 1 unit at price 27.959999, total balance 9935.680000
# day 716, sell 1 unit at price 28.080000, investment -0.425535 %, total balance 9963.760000,
# day 717, sell 1 unit at price 28.320000, investment 1.287556 %, total balance 9992.080000,
# day 721: buy 1 unit at price 28.200001, total balance 9963.879999
# day 722, sell 1 unit at price 27.719999, investment -1.702133 %, total balance 9991.599999,
# day 730: buy 1 unit at price 28.440001, total balance 9963.159998
# day 731, sell 1 unit at price 29.280001, investment 2.953587 %, total balance 9992.439999,
# day 741: buy 1 unit at price 33.720001, total balance 9958.719997
# day 742, sell 1 unit at price 31.680000, investment -6.049825 %, total balance 9990.399998,
# day 768: buy 1 unit at price 25.920000, total balance 9964.479998
# day 769, sell 1 unit at price 27.000000, investment 4.166666 %, total balance 9991.479998,
# day 783: buy 1 unit at price 27.959999, total balance 9963.519999
# day 784: buy 1 unit at price 28.200001, total balance 9935.319998
# day 785, sell 1 unit at price 28.200001, investment 0.858375 %, total balance 9963.519999,
# day 786, sell 1 unit at price 28.080000, investment -0.425535 %, total balance 9991.599999,
# day 788: buy 1 unit at price 28.680000, total balance 9962.919998
# day 789, sell 1 unit at price 29.280001, investment 2.092052 %, total balance 9992.199999,
# day 794: buy 1 unit at price 29.280001, total balance 9962.919998
# day 795, sell 1 unit at price 28.440001, investment -2.868853 %, total balance 9991.359999,
# day 796: buy 1 unit at price 28.320000, total balance 9963.039999
# day 797, sell 1 unit at price 27.959999, investment -1.271189 %, total balance 9990.999998,
# day 805: buy 1 unit at price 27.840000, total balance 9963.159998
# day 806, sell 1 unit at price 27.840000, investment 0.000000 %, total balance 9990.999998,
# day 813: buy 1 unit at price 28.200001, total balance 9962.799997
# day 814, sell 1 unit at price 27.959999, investment -0.851070 %, total balance 9990.759996,
# day 821: buy 1 unit at price 27.959999, total balance 9962.799997
# day 822, sell 1 unit at price 27.959999, investment 0.000000 %, total balance 9990.759996,
# day 823: buy 1 unit at price 27.719999, total balance 9963.039997
# day 824, sell 1 unit at price 28.200001, investment 1.731607 %, total balance 9991.239998,
# day 832: buy 1 unit at price 27.360001, total balance 9963.879997
# day 833: buy 1 unit at price 27.600000, total balance 9936.279997
# day 835, sell 1 unit at price 26.280001, investment -3.947368 %, total balance 9962.559998,
# day 836, sell 1 unit at price 25.920000, investment -6.086958 %, total balance 9988.479998,
# day 845: buy 1 unit at price 27.600000, total balance 9960.879997
# day 846, sell 1 unit at price 27.480000, investment -0.434786 %, total balance 9988.359997,
# day 855: buy 1 unit at price 28.320000, total balance 9960.039997
# day 856, sell 1 unit at price 28.200001, investment -0.423725 %, total balance 9988.239998,
# day 871: buy 1 unit at price 25.559999, total balance 9962.679998
# day 872, sell 1 unit at price 25.920000, investment 1.408453 %, total balance 9988.599999,
# day 881: buy 1 unit at price 26.879999, total balance 9961.719999
# day 883, sell 1 unit at price 27.000000, investment 0.446432 %, total balance 9988.719999,
# day 884: buy 1 unit at price 26.639999, total balance 9962.080000
# day 886: buy 1 unit at price 26.760000, total balance 9935.320000
# day 887, sell 1 unit at price 27.360001, investment 2.702707 %, total balance 9962.680000,
# day 888, sell 1 unit at price 27.240000, investment 1.793720 %, total balance 9989.920000,
# day 893: buy 1 unit at price 27.600000, total balance 9962.320000
# day 895, sell 1 unit at price 27.480000, investment -0.434786 %, total balance 9989.799999,
# day 905: buy 1 unit at price 27.959999, total balance 9961.840000
# day 906, sell 1 unit at price 27.959999, investment 0.000000 %, total balance 9989.799999,
# day 907: buy 1 unit at price 27.719999, total balance 9962.080000
# day 908: buy 1 unit at price 27.600000, total balance 9934.480000
# day 910, sell 1 unit at price 27.959999, investment 0.865800 %, total balance 9962.439999,
# day 911, sell 1 unit at price 28.440001, investment 3.043479 %, total balance 9990.879999,
# day 914: buy 1 unit at price 27.840000, total balance 9963.039999
# day 915, sell 1 unit at price 27.600000, investment -0.862068 %, total balance 9990.639999,
# day 917: buy 1 unit at price 28.080000, total balance 9962.560000
# day 918: buy 1 unit at price 27.719999, total balance 9934.840000
# day 921: buy 1 unit at price 28.440001, total balance 9906.400000
# day 922, sell 1 unit at price 28.680000, investment 2.136754 %, total balance 9935.080000,
# day 923: buy 1 unit at price 29.879999, total balance 9905.200001
# day 924, sell 1 unit at price 29.760000, investment 7.359311 %, total balance 9934.960001,
# day 925, sell 1 unit at price 29.400000, investment 3.375524 %, total balance 9964.360001,
# day 926, sell 1 unit at price 29.879999, investment 0.000000 %, total balance 9994.240000,
# day 930: buy 1 unit at price 29.760000, total balance 9964.480000
# day 931, sell 1 unit at price 29.400000, investment -1.209679 %, total balance 9993.879999,
# day 934: buy 1 unit at price 28.559999, total balance 9965.320000
# day 936, sell 1 unit at price 28.080000, investment -1.680671 %, total balance 9993.400000,
# day 941: buy 1 unit at price 27.240000, total balance 9966.160000
# day 942, sell 1 unit at price 26.879999, investment -1.321588 %, total balance 9993.039999,
# day 946: buy 1 unit at price 26.879999, total balance 9966.160000
# day 947, sell 1 unit at price 26.280001, investment -2.232137 %, total balance 9992.440001,
# day 951: buy 1 unit at price 26.160000, total balance 9966.280001
# day 952, sell 1 unit at price 26.160000, investment 0.000000 %, total balance 9992.440001,
# day 962: buy 1 unit at price 25.200001, total balance 9967.240000
# day 963, sell 1 unit at price 24.600000, investment -2.380954 %, total balance 9991.840000,
# day 972: buy 1 unit at price 20.400000, total balance 9971.440001
# day 973, sell 1 unit at price 19.799999, investment -2.941178 %, total balance 9991.240000,
# day 984: buy 1 unit at price 20.400000, total balance 9970.840000
# day 985, sell 1 unit at price 19.799999, investment -2.941178 %, total balance 9990.639999,
# day 990: buy 1 unit at price 19.799999, total balance 9970.840000
# day 991, sell 1 unit at price 18.600000, investment -6.060601 %, total balance 9989.440001,
# day 1014: buy 1 unit at price 17.400000, total balance 9972.040001
# day 1015, sell 1 unit at price 17.400000, investment 0.000000 %, total balance 9989.440001,
# day 1018: buy 1 unit at price 17.400000, total balance 9972.040001
# day 1019, sell 1 unit at price 16.799999, investment -3.448278 %, total balance 9988.840000,
# day 1021: buy 1 unit at price 17.400000, total balance 9971.440001
# day 1023, sell 1 unit at price 18.000000, investment 3.448278 %, total balance 9989.440001,
# day 1028: buy 1 unit at price 17.400000, total balance 9972.040001
# day 1030, sell 1 unit at price 17.400000, investment 0.000000 %, total balance 9989.440001,
# day 1036: buy 1 unit at price 16.200001, total balance 9973.240000
# day 1037, sell 1 unit at price 15.600000, investment -3.703706 %, total balance 9988.840000,
# day 1038: buy 1 unit at price 16.200001, total balance 9972.639999
# day 1039, sell 1 unit at price 15.600000, investment -3.703706 %, total balance 9988.240000,
# day 1040: buy 1 unit at price 15.960000, total balance 9972.280000
# day 1041: buy 1 unit at price 16.200001, total balance 9956.079999
# day 1042, sell 1 unit at price 15.600000, investment -2.255637 %, total balance 9971.679999,
# day 1043, sell 1 unit at price 15.600000, investment -3.703706 %, total balance 9987.280000,
# day 1045: buy 1 unit at price 16.200001, total balance 9971.079999
# day 1047, sell 1 unit at price 15.600000, investment -3.703706 %, total balance 9986.679999,
# day 1048: buy 1 unit at price 15.000000, total balance 9971.679999
# day 1049, sell 1 unit at price 15.600000, investment 4.000003 %, total balance 9987.280000,
# day 1053: buy 1 unit at price 14.160000, total balance 9973.120000
# day 1054, sell 1 unit at price 13.200000, investment -6.779661 %, total balance 9986.320000,
# day 1066: buy 1 unit at price 15.600000, total balance 9970.719999
# day 1067, sell 1 unit at price 15.960000, investment 2.307690 %, total balance 9986.679999,
# day 1078: buy 1 unit at price 18.000000, total balance 9968.679999
# day 1079, sell 1 unit at price 18.000000, investment 0.000000 %, total balance 9986.679999,
# day 1088: buy 1 unit at price 18.000000, total balance 9968.679999
# day 1089, sell 1 unit at price 17.760000, investment -1.333332 %, total balance 9986.440000,
# day 1093: buy 1 unit at price 15.600000, total balance 9970.839999
# day 1096, sell 1 unit at price 15.600000, investment 0.000000 %, total balance 9986.440000,
# day 1099: buy 1 unit at price 15.240000, total balance 9971.200000
# day 1100, sell 1 unit at price 15.600000, investment 2.362209 %, total balance 9986.800000,
# day 1108: buy 1 unit at price 13.200000, total balance 9973.600000
# day 1110, sell 1 unit at price 13.200000, investment 0.000000 %, total balance 9986.800000,
# day 1120: buy 1 unit at price 13.800000, total balance 9973.000000
# day 1121, sell 1 unit at price 13.800000, investment 0.000000 %, total balance 9986.800000,
# day 1123: buy 1 unit at price 14.400000, total balance 9972.400001
# day 1125, sell 1 unit at price 15.000000, investment 4.166669 %, total balance 9987.400001,
# day 1127: buy 1 unit at price 15.600000, total balance 9971.800000
# day 1128, sell 1 unit at price 16.200001, investment 3.846156 %, total balance 9988.000001,
# day 1132: buy 1 unit at price 15.000000, total balance 9973.000001
# day 1133: buy 1 unit at price 15.000000, total balance 9958.000001
# day 1134, sell 1 unit at price 14.400000, investment -4.000003 %, total balance 9972.400001,
# day 1135, sell 1 unit at price 14.400000, investment -4.000003 %, total balance 9986.800000,
# day 1147: buy 1 unit at price 15.000000, total balance 9971.800000
# day 1148, sell 1 unit at price 15.000000, investment 0.000000 %, total balance 9986.800000,
# day 1155: buy 1 unit at price 13.800000, total balance 9973.000000
# day 1158, sell 1 unit at price 13.800000, investment 0.000000 %, total balance 9986.800000,
# day 1166: buy 1 unit at price 14.400000, total balance 9972.400001
# day 1167, sell 1 unit at price 13.800000, investment -4.166663 %, total balance 9986.200001,
# day 1182: buy 1 unit at price 13.200000, total balance 9973.000001
# day 1183, sell 1 unit at price 12.600000, investment -4.545450 %, total balance 9985.600001,
# day 1186: buy 1 unit at price 13.800000, total balance 9971.800001
# day 1187, sell 1 unit at price 13.800000, investment 0.000000 %, total balance 9985.600001,
# day 1188: buy 1 unit at price 13.200000, total balance 9972.400002
# day 1189: buy 1 unit at price 13.200000, total balance 9959.200002
# day 1190, sell 1 unit at price 13.200000, investment 0.000000 %, total balance 9972.400002,
# day 1191, sell 1 unit at price 12.960000, investment -1.818180 %, total balance 9985.360002,
# day 1206: buy 1 unit at price 10.800000, total balance 9974.560001
# day 1207: buy 1 unit at price 10.560000, total balance 9964.000001
# day 1208, sell 1 unit at price 10.560000, investment -2.222220 %, total balance 9974.560001,
# day 1209, sell 1 unit at price 10.080000, investment -4.545459 %, total balance 9984.640001,
# day 1210: buy 1 unit at price 9.960000, total balance 9974.680001
# day 1211, sell 1 unit at price 9.480000, investment -4.819282 %, total balance 9984.160001,
# day 1215: buy 1 unit at price 9.840000, total balance 9974.320001
# day 1216: buy 1 unit at price 10.080000, total balance 9964.240001
# day 1217, sell 1 unit at price 9.960000, investment 1.219511 %, total balance 9974.200001,
# day 1218, sell 1 unit at price 9.720000, investment -3.571425 %, total balance 9983.920001,
# day 1222: buy 1 unit at price 8.760000, total balance 9975.160001
# day 1224, sell 1 unit at price 8.400000, investment -4.109596 %, total balance 9983.560000,
# day 1225: buy 1 unit at price 8.160000, total balance 9975.400001
# day 1226, sell 1 unit at price 7.800000, investment -4.411761 %, total balance 9983.200001,
# day 1243: buy 1 unit at price 10.680000, total balance 9972.520001
# day 1244, sell 1 unit at price 10.800000, investment 1.123594 %, total balance 9983.320001,
# day 1252: buy 1 unit at price 8.520000, total balance 9974.800000
# day 1253, sell 1 unit at price 8.160000, investment -4.225359 %, total balance 9982.960000,
# day 1257: buy 1 unit at price 9.600000, total balance 9973.360000
# day 1258, sell 1 unit at price 10.200000, investment 6.249994 %, total balance 9983.560000,
# day 1271: buy 1 unit at price 11.760000, total balance 9971.799999
# day 1272, sell 1 unit at price 11.880000, investment 1.020407 %, total balance 9983.679999,
# day 1273: buy 1 unit at price 12.120000, total balance 9971.560000
# day 1274, sell 1 unit at price 11.640000, investment -3.960392 %, total balance 9983.200000,
# day 1275: buy 1 unit at price 11.640000, total balance 9971.560000
# day 1276, sell 1 unit at price 11.880000, investment 2.061854 %, total balance 9983.440000,
# day 1280: buy 1 unit at price 10.560000, total balance 9972.879999
# day 1281, sell 1 unit at price 10.080000, investment -4.545459 %, total balance 9982.959999,
# day 1285: buy 1 unit at price 9.000000, total balance 9973.959999
# day 1286: buy 1 unit at price 9.240000, total balance 9964.719999
# day 1287, sell 1 unit at price 9.600000, investment 6.666671 %, total balance 9974.320000,
# day 1288, sell 1 unit at price 14.760000, investment 59.740266 %, total balance 9989.080000,
# day 1293: buy 1 unit at price 14.880000, total balance 9974.200000
# day 1294, sell 1 unit at price 14.760000, investment -0.806451 %, total balance 9988.960000,
# day 1309: buy 1 unit at price 16.320000, total balance 9972.640000
# day 1310: buy 1 unit at price 18.240000, total balance 9954.400001
# day 1311, sell 1 unit at price 18.240000, investment 11.764707 %, total balance 9972.640000,
# day 1312, sell 1 unit at price 18.360001, investment 0.657899 %, total balance 9991.000001,
# day 1316: buy 1 unit at price 17.160000, total balance 9973.840001
# day 1317, sell 1 unit at price 16.920000, investment -1.398600 %, total balance 9990.760001,
# day 1318: buy 1 unit at price 16.920000, total balance 9973.840001
# day 1319, sell 1 unit at price 17.040001, investment 0.709225 %, total balance 9990.880002,
# day 1329: buy 1 unit at price 17.280001, total balance 9973.600001
# day 1330, sell 1 unit at price 17.400000, investment 0.694438 %, total balance 9991.000001,
# day 1331: buy 1 unit at price 17.040001, total balance 9973.960000
# day 1332, sell 1 unit at price 17.280001, investment 1.408449 %, total balance 9991.240001,
# day 1366: buy 1 unit at price 16.080000, total balance 9975.160001
# day 1367, sell 1 unit at price 16.200001, investment 0.746274 %, total balance 9991.360002,
# day 1376: buy 1 unit at price 16.080000, total balance 9975.280002
# day 1377, sell 1 unit at price 15.720000, investment -2.238804 %, total balance 9991.000002,
# day 1383: buy 1 unit at price 16.080000, total balance 9974.920002
# day 1384, sell 1 unit at price 16.559999, investment 2.985072 %, total balance 9991.480002,
# day 1389: buy 1 unit at price 16.680000, total balance 9974.800001
# day 1390: buy 1 unit at price 16.799999, total balance 9958.000002
# day 1391: buy 1 unit at price 16.440001, total balance 9941.560001
# day 1393, sell 1 unit at price 16.680000, investment 0.000000 %, total balance 9958.240002,
# day 1395, sell 1 unit at price 16.559999, investment -1.428570 %, total balance 9974.800001,
# day 1396, sell 1 unit at price 16.320000, investment -0.729932 %, total balance 9991.120001,
# day 1426: buy 1 unit at price 19.200001, total balance 9971.920000
# day 1427, sell 1 unit at price 18.120001, investment -5.624999 %, total balance 9990.040001,
# day 1428: buy 1 unit at price 18.480000, total balance 9971.560001
# day 1429, sell 1 unit at price 17.879999, investment -3.246755 %, total balance 9989.440001,
# day 1436: buy 1 unit at price 18.000000, total balance 9971.440001
# day 1437, sell 1 unit at price 17.400000, investment -3.333335 %, total balance 9988.840000,
# day 1448: buy 1 unit at price 16.440001, total balance 9972.400000
# day 1449, sell 1 unit at price 16.920000, investment 2.919705 %, total balance 9989.320000,
# day 1459: buy 1 unit at price 14.760000, total balance 9974.560000
# day 1461, sell 1 unit at price 14.580000, investment -1.219514 %, total balance 9989.139999,
# day 1469: buy 1 unit at price 14.490000, total balance 9974.650000
# day 1470, sell 1 unit at price 14.290000, investment -1.380261 %, total balance 9988.940000,
# day 1485: buy 1 unit at price 14.190000, total balance 9974.750000
# day 1486, sell 1 unit at price 14.840000, investment 4.580695 %, total balance 9989.590000,
# day 1499: buy 1 unit at price 13.340000, total balance 9976.250000
# day 1500, sell 1 unit at price 12.430000, investment -6.821588 %, total balance 9988.680000,
# day 1505: buy 1 unit at price 11.440000, total balance 9977.240001
# day 1506, sell 1 unit at price 11.440000, investment 0.000000 %, total balance 9988.680000,
# day 1508: buy 1 unit at price 11.720000, total balance 9976.960000
# day 1509, sell 1 unit at price 11.670000, investment -0.426623 %, total balance 9988.630000,
# day 1511: buy 1 unit at price 12.000000, total balance 9976.630000
# day 1513, sell 1 unit at price 13.290000, investment 10.750000 %, total balance 9989.920000,
# day 1517: buy 1 unit at price 13.750000, total balance 9976.170000
# day 1518, sell 1 unit at price 13.600000, investment -1.090906 %, total balance 9989.770001,
# day 1525: buy 1 unit at price 14.320000, total balance 9975.450001
# day 1527, sell 1 unit at price 14.990000, investment 4.678772 %, total balance 9990.440001,
# day 1532: buy 1 unit at price 15.010000, total balance 9975.430000
# day 1533, sell 1 unit at price 15.150000, investment 0.932707 %, total balance 9990.580000,
# day 1535: buy 1 unit at price 15.220000, total balance 9975.360000
# day 1536, sell 1 unit at price 15.190000, investment -0.197114 %, total balance 9990.549999,
# day 1545: buy 1 unit at price 14.550000, total balance 9975.999999
# day 1546, sell 1 unit at price 14.160000, investment -2.680415 %, total balance 9990.159999,
# day 1551: buy 1 unit at price 13.290000, total balance 9976.869999
# day 1552: buy 1 unit at price 13.260000, total balance 9963.609999
# day 1553, sell 1 unit at price 13.460000, investment 1.279158 %, total balance 9977.069999,
# day 1554, sell 1 unit at price 13.320000, investment 0.452485 %, total balance 9990.389999,
# day 1555: buy 1 unit at price 13.010000, total balance 9977.379998
# day 1556, sell 1 unit at price 12.860000, investment -1.152964 %, total balance 9990.239998,
# day 1563: buy 1 unit at price 11.000000, total balance 9979.239998
# day 1565, sell 1 unit at price 10.070000, investment -8.454548 %, total balance 9989.309998,
# day 1569: buy 1 unit at price 9.780000, total balance 9979.529998
# day 1570, sell 1 unit at price 9.590000, investment -1.942736 %, total balance 9989.119998,
# day 1571: buy 1 unit at price 9.510000, total balance 9979.609998
# day 1572, sell 1 unit at price 9.280000, investment -2.418512 %, total balance 9988.889998,
# day 1580: buy 1 unit at price 8.770000, total balance 9980.119997
# day 1581, sell 1 unit at price 9.010000, investment 2.736599 %, total balance 9989.129997,
# day 1582: buy 1 unit at price 9.210000, total balance 9979.919997
# day 1583, sell 1 unit at price 8.750000, investment -4.994572 %, total balance 9988.669997,
# day 1585: buy 1 unit at price 8.380000, total balance 9980.289997
# day 1586, sell 1 unit at price 8.580000, investment 2.386633 %, total balance 9988.869997,
# day 1589: buy 1 unit at price 8.560000, total balance 9980.309997
# day 1590, sell 1 unit at price 8.880000, investment 3.738314 %, total balance 9989.189997,
# day 1593: buy 1 unit at price 9.150000, total balance 9980.039997
# day 1594, sell 1 unit at price 9.140000, investment -0.109282 %, total balance 9989.179998,
# day 1596: buy 1 unit at price 9.230000, total balance 9979.949998
# day 1597, sell 1 unit at price 9.430000, investment 2.166856 %, total balance 9989.379998,
# day 1602: buy 1 unit at price 9.050000, total balance 9980.329998
# day 1604, sell 1 unit at price 9.010000, investment -0.441989 %, total balance 9989.339998,
# day 1605: buy 1 unit at price 8.910000, total balance 9980.429998
# day 1606, sell 1 unit at price 8.880000, investment -0.336697 %, total balance 9989.309999,
# day 1615: buy 1 unit at price 7.610000, total balance 9981.699998
# day 1616: buy 1 unit at price 7.150000, total balance 9974.549998
# day 1617, sell 1 unit at price 6.910000, investment -9.198427 %, total balance 9981.459998,
# day 1619, sell 1 unit at price 7.240000, investment 1.258737 %, total balance 9988.699998,
# day 1620: buy 1 unit at price 7.380000, total balance 9981.319998
# day 1621, sell 1 unit at price 7.180000, investment -2.710031 %, total balance 9988.499998,
# day 1622: buy 1 unit at price 7.370000, total balance 9981.129998
# day 1624, sell 1 unit at price 7.000000, investment -5.020351 %, total balance 9988.129998,
# day 1629: buy 1 unit at price 7.160000, total balance 9980.969998
# day 1630, sell 1 unit at price 7.220000, investment 0.837988 %, total balance 9988.189998,
# day 1640: buy 1 unit at price 7.910000, total balance 9980.279998
# day 1641, sell 1 unit at price 8.070000, investment 2.022754 %, total balance 9988.349998,
# day 1648: buy 1 unit at price 7.260000, total balance 9981.089997
# day 1649, sell 1 unit at price 7.270000, investment 0.137738 %, total balance 9988.359997,
# day 1650: buy 1 unit at price 7.530000, total balance 9980.829997
# day 1651: buy 1 unit at price 7.410000, total balance 9973.419997
# day 1652, sell 1 unit at price 7.740000, investment 2.788839 %, total balance 9981.159997,
# day 1653, sell 1 unit at price 7.660000, investment 3.373819 %, total balance 9988.819997,
# day 1660: buy 1 unit at price 8.780000, total balance 9980.039997
# day 1661, sell 1 unit at price 9.090000, investment 3.530757 %, total balance 9989.129997,
# day 1664: buy 1 unit at price 9.380000, total balance 9979.749997
# day 1665, sell 1 unit at price 9.050000, investment -3.518123 %, total balance 9988.799997,
# day 1670: buy 1 unit at price 9.520000, total balance 9979.279997
# day 1673, sell 1 unit at price 9.090000, investment -4.516810 %, total balance 9988.369997,
# day 1675: buy 1 unit at price 8.700000, total balance 9979.669997
# day 1676, sell 1 unit at price 8.840000, investment 1.609199 %, total balance 9988.509997,
# day 1684: buy 1 unit at price 10.050000, total balance 9978.459997
# day 1685, sell 1 unit at price 10.310000, investment 2.587067 %, total balance 9988.769998,
# day 1689: buy 1 unit at price 10.800000, total balance 9977.969997
# day 1690, sell 1 unit at price 10.910000, investment 1.018515 %, total balance 9988.879997,
# day 1695: buy 1 unit at price 10.910000, total balance 9977.969997
# day 1696, sell 1 unit at price 10.820000, investment -0.824933 %, total balance 9988.789997,
# day 1703: buy 1 unit at price 10.400000, total balance 9978.389998
# day 1704, sell 1 unit at price 10.780000, investment 3.653847 %, total balance 9989.169997,
# day 1705: buy 1 unit at price 10.690000, total balance 9978.479998
# day 1708, sell 1 unit at price 11.160000, investment 4.396635 %, total balance 9989.639998,
# day 1712: buy 1 unit at price 11.800000, total balance 9977.839997
# day 1713, sell 1 unit at price 12.140000, investment 2.881357 %, total balance 9989.979998,
# day 1714: buy 1 unit at price 12.070000, total balance 9977.909998
# day 1715, sell 1 unit at price 12.100000, investment 0.248556 %, total balance 9990.009998,
# day 1717: buy 1 unit at price 12.390000, total balance 9977.619998
# day 1718, sell 1 unit at price 12.270000, investment -0.968522 %, total balance 9989.889999,
# day 1721: buy 1 unit at price 12.800000, total balance 9977.089998
# day 1722: buy 1 unit at price 12.680000, total balance 9964.409998
# day 1723, sell 1 unit at price 12.650000, investment -1.171879 %, total balance 9977.059998,
# day 1724, sell 1 unit at price 12.650000, investment -0.236598 %, total balance 9989.709997,
# day 1725: buy 1 unit at price 12.770000, total balance 9976.939997
# day 1726: buy 1 unit at price 12.530000, total balance 9964.409997
# day 1727, sell 1 unit at price 12.550000, investment -1.722790 %, total balance 9976.959997,
# day 1728, sell 1 unit at price 12.650000, investment 0.957701 %, total balance 9989.609997,
# day 1733: buy 1 unit at price 12.680000, total balance 9976.929997
# day 1734: buy 1 unit at price 12.660000, total balance 9964.269997
# day 1735, sell 1 unit at price 12.500000, investment -1.419561 %, total balance 9976.769997,
# day 1739, sell 1 unit at price 13.380000, investment 5.687206 %, total balance 9990.149997,
# day 1744: buy 1 unit at price 13.110000, total balance 9977.039997
# day 1745, sell 1 unit at price 13.350000, investment 1.830669 %, total balance 9990.389998,
# day 1758: buy 1 unit at price 12.510000, total balance 9977.879997
# day 1759, sell 1 unit at price 12.830000, investment 2.557951 %, total balance 9990.709997,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
