# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Magda\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../Kaggle_dataset/AAXJ2.csv')
df.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close  Volume
# 0  1/2/2013  61.439999  61.939999  61.340000  61.759998  53.829903  520200
# 1  1/3/2013  61.320000  61.660000  61.230000  61.290001  53.420250  416900
# 2  1/4/2013  61.060001  61.330002  60.950001  61.290001  53.420250  296400
# 3  1/7/2013  60.880001  60.880001  60.639999  60.810001  53.001884  249900
# 4  1/8/2013  60.590000  60.599998  60.119999  60.299999  52.557358  219100

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\Users\Magda\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E846285D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E846285D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E846285D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E846285D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E846285D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E846285D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E846285D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E846285D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E81E0CDC48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E81E0CDC48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E81E0CDC48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E81E0CDC48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E81E0CDC48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E81E0CDC48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E81E0CDC48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001E81E0CDC48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# epoch: 10, total rewards: -64.550022.3, cost: 0.055267, total money: 9862.189976
# epoch: 20, total rewards: 12.259895.3, cost: 0.003144, total money: 10012.259895
# epoch: 30, total rewards: -48.289990.3, cost: 0.012065, total money: 9586.220020
# epoch: 40, total rewards: 22.960087.3, cost: 0.003322, total money: 10022.960087
# epoch: 50, total rewards: -6.569939.3, cost: 0.002053, total money: 9637.800064
# epoch: 60, total rewards: -46.209938.3, cost: 0.000636, total money: 9515.910065
# epoch: 70, total rewards: 97.809979.3, cost: 0.006862, total money: 10024.549976
# epoch: 80, total rewards: -66.879963.3, cost: 0.000600, total money: 9787.090038
# epoch: 90, total rewards: 60.459946.3, cost: 0.079040, total money: 8735.799942
# epoch: 100, total rewards: -5.800007.3, cost: 0.001571, total money: 9921.389996
# epoch: 110, total rewards: -6.060043.3, cost: 0.000927, total money: 9846.979958
# epoch: 120, total rewards: 33.489960.3, cost: 0.000670, total money: 10033.489960
# epoch: 130, total rewards: -16.989994.3, cost: 0.000883, total money: 9983.010006
# epoch: 140, total rewards: -10.360054.3, cost: 0.000524, total money: 9989.639946
# epoch: 150, total rewards: -29.389992.3, cost: 0.000114, total money: 9824.090004
# epoch: 160, total rewards: 50.220036.3, cost: 0.001833, total money: 9903.260037
# epoch: 170, total rewards: 20.939995.3, cost: 0.006035, total money: 10020.939995
# epoch: 180, total rewards: 13.819965.3, cost: 0.000401, total money: 10013.819965
# epoch: 190, total rewards: 7.930027.3, cost: 0.000079, total money: 10007.930027
# epoch: 200, total rewards: 6.200020.3, cost: 0.000086, total money: 10006.200020

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 11: buy 1 unit at price 61.060001, total balance 9938.939999
# day 12, sell 1 unit at price 61.060001, investment 0.000000 %, total balance 10000.000000,
# day 19: buy 1 unit at price 60.630001, total balance 9939.369999
# day 20, sell 1 unit at price 60.470001, investment -0.263896 %, total balance 9999.840000,
# day 24: buy 1 unit at price 60.099998, total balance 9939.740002
# day 26, sell 1 unit at price 60.130001, investment 0.049921 %, total balance 9999.870003,
# day 30: buy 1 unit at price 60.740002, total balance 9939.130001
# day 31, sell 1 unit at price 60.630001, investment -0.181101 %, total balance 9999.760002,
# day 34: buy 1 unit at price 59.790001, total balance 9939.970001
# day 35: buy 1 unit at price 59.950001, total balance 9880.020000
# day 36, sell 1 unit at price 59.160000, investment -1.053690 %, total balance 9939.180000,
# day 37, sell 1 unit at price 59.369999, investment -0.967476 %, total balance 9998.549999,
# day 38: buy 1 unit at price 60.180000, total balance 9938.369999
# day 39, sell 1 unit at price 60.119999, investment -0.099703 %, total balance 9998.489998,
# day 40: buy 1 unit at price 60.130001, total balance 9938.359997
# day 41, sell 1 unit at price 59.660000, investment -0.781642 %, total balance 9998.019997,
# day 50: buy 1 unit at price 58.900002, total balance 9939.119995
# day 51: buy 1 unit at price 58.169998, total balance 9880.949997
# day 53: buy 1 unit at price 58.349998, total balance 9822.599998
# day 54, sell 1 unit at price 57.830002, investment -1.816638 %, total balance 9880.430000,
# day 55, sell 1 unit at price 58.110001, investment -0.103142 %, total balance 9938.540001,
# day 56, sell 1 unit at price 58.090000, investment -0.445584 %, total balance 9996.630001,
# day 65: buy 1 unit at price 57.270000, total balance 9939.360001
# day 66: buy 1 unit at price 57.689999, total balance 9881.670002
# day 67, sell 1 unit at price 58.310001, investment 1.815961 %, total balance 9939.980003,
# day 68: buy 1 unit at price 58.340000, total balance 9881.640003
# day 69, sell 1 unit at price 57.580002, investment -0.190669 %, total balance 9939.220005,
# day 70, sell 1 unit at price 56.619999, investment -2.948237 %, total balance 9995.840004,
# day 81: buy 1 unit at price 60.419998, total balance 9935.420006
# day 82, sell 1 unit at price 59.740002, investment -1.125449 %, total balance 9995.160007,
# day 84: buy 1 unit at price 60.430000, total balance 9934.730007
# day 85, sell 1 unit at price 60.650002, investment 0.364060 %, total balance 9995.380009,
# day 128: buy 1 unit at price 53.700001, total balance 9941.680008
# day 129: buy 1 unit at price 54.290001, total balance 9887.390007
# day 130, sell 1 unit at price 54.169998, investment 0.875228 %, total balance 9941.560005,
# day 131, sell 1 unit at price 56.730000, investment 4.494379 %, total balance 9998.290005,
# day 145: buy 1 unit at price 55.889999, total balance 9942.400005
# day 146: buy 1 unit at price 56.779999, total balance 9885.620007
# day 147, sell 1 unit at price 56.770000, investment 1.574523 %, total balance 9942.390007,
# day 148, sell 1 unit at price 56.389999, investment -0.686861 %, total balance 9998.780006,
# day 154: buy 1 unit at price 56.930000, total balance 9941.850006
# day 155, sell 1 unit at price 57.090000, investment 0.281047 %, total balance 9998.940006,
# day 159: buy 1 unit at price 54.910000, total balance 9944.030006
# day 160, sell 1 unit at price 53.779999, investment -2.057915 %, total balance 9997.810005,
# day 164: buy 1 unit at price 53.369999, total balance 9944.440006
# day 165, sell 1 unit at price 53.599998, investment 0.430953 %, total balance 9998.040005,
# day 166: buy 1 unit at price 54.259998, total balance 9943.780006
# day 167: buy 1 unit at price 54.650002, total balance 9889.130005
# day 168: buy 1 unit at price 55.209999, total balance 9833.920006
# day 169, sell 1 unit at price 56.169998, investment 3.520088 %, total balance 9890.090004,
# day 171, sell 1 unit at price 57.119999, investment 4.519666 %, total balance 9947.210003,
# day 172, sell 1 unit at price 58.360001, investment 5.705491 %, total balance 10005.570003,
# day 186: buy 1 unit at price 58.900002, total balance 9946.670002
# day 187, sell 1 unit at price 58.279999, investment -1.052636 %, total balance 10004.950001,
# day 193: buy 1 unit at price 59.169998, total balance 9945.780003
# day 194, sell 1 unit at price 59.610001, investment 0.743624 %, total balance 10005.390003,
# day 198: buy 1 unit at price 60.419998, total balance 9944.970005
# day 200, sell 1 unit at price 61.200001, investment 1.290968 %, total balance 10006.170006,
# day 206: buy 1 unit at price 60.209999, total balance 9945.960007
# day 207, sell 1 unit at price 60.240002, investment 0.049830 %, total balance 10006.200008,
# day 214: buy 1 unit at price 59.900002, total balance 9946.300007
# day 215, sell 1 unit at price 58.970001, investment -1.552588 %, total balance 10005.270008,
# day 223: buy 1 unit at price 60.840000, total balance 9944.430008
# day 224: buy 1 unit at price 60.169998, total balance 9884.260010
# day 225: buy 1 unit at price 59.980000, total balance 9824.280010
# day 226, sell 1 unit at price 60.250000, investment -0.969757 %, total balance 9884.530010,
# day 227, sell 1 unit at price 59.639999, investment -0.880836 %, total balance 9944.170010,
# day 228: buy 1 unit at price 60.040001, total balance 9884.130009
# day 229, sell 1 unit at price 60.619999, investment 1.067021 %, total balance 9944.750008,
# day 230, sell 1 unit at price 61.130001, investment 1.815457 %, total balance 10005.880009,
# day 235: buy 1 unit at price 60.840000, total balance 9945.040009
# day 236, sell 1 unit at price 61.240002, investment 0.657465 %, total balance 10006.280010,
# day 240: buy 1 unit at price 59.439999, total balance 9946.840012
# day 243, sell 1 unit at price 59.830002, investment 0.656129 %, total balance 10006.670013,
# day 264: buy 1 unit at price 58.029999, total balance 9948.640015
# day 265, sell 1 unit at price 58.660000, investment 1.085647 %, total balance 10007.300014,
# day 273: buy 1 unit at price 54.750000, total balance 9952.550014
# day 274: buy 1 unit at price 55.470001, total balance 9897.080013
# day 275, sell 1 unit at price 55.070000, investment 0.584474 %, total balance 9952.150013,
# day 276, sell 1 unit at price 56.090000, investment 1.117719 %, total balance 10008.240013,
# day 283: buy 1 unit at price 57.509998, total balance 9950.730015
# day 285, sell 1 unit at price 57.540001, investment 0.052169 %, total balance 10008.270016,
# day 287: buy 1 unit at price 57.669998, total balance 9950.600018
# day 288, sell 1 unit at price 57.209999, investment -0.797640 %, total balance 10007.810017,
# day 300: buy 1 unit at price 56.590000, total balance 9951.220016
# day 301, sell 1 unit at price 56.730000, investment 0.247392 %, total balance 10007.950016,
# day 315: buy 1 unit at price 59.779999, total balance 9948.170017
# day 317, sell 1 unit at price 59.529999, investment -0.418200 %, total balance 10007.700016,
# day 318: buy 1 unit at price 60.419998, total balance 9947.280018
# day 319, sell 1 unit at price 60.970001, investment 0.910300 %, total balance 10008.250019,
# day 320: buy 1 unit at price 60.799999, total balance 9947.450020
# day 321, sell 1 unit at price 60.669998, investment -0.213818 %, total balance 10008.120018,
# day 326: buy 1 unit at price 60.590000, total balance 9947.530018
# day 327, sell 1 unit at price 60.400002, investment -0.313581 %, total balance 10007.930019,
# day 334: buy 1 unit at price 59.799999, total balance 9948.130020
# day 335, sell 1 unit at price 59.849998, investment 0.083611 %, total balance 10007.980019,
# day 340: buy 1 unit at price 59.580002, total balance 9948.400017
# day 341, sell 1 unit at price 60.540001, investment 1.611277 %, total balance 10008.940018,
# day 342: buy 1 unit at price 60.759998, total balance 9948.180019
# day 343, sell 1 unit at price 61.009998, investment 0.411455 %, total balance 10009.190018,
# day 344: buy 1 unit at price 60.830002, total balance 9948.360016
# day 345, sell 1 unit at price 61.770000, investment 1.545288 %, total balance 10010.130016,
# day 348: buy 1 unit at price 61.759998, total balance 9948.370018
# day 349, sell 1 unit at price 62.099998, investment 0.550518 %, total balance 10010.470016,
# day 353: buy 1 unit at price 62.189999, total balance 9948.280018
# day 354: buy 1 unit at price 61.799999, total balance 9886.480019
# day 355, sell 1 unit at price 62.080002, investment -0.176872 %, total balance 9948.560020,
# day 356, sell 1 unit at price 62.480000, investment 1.100324 %, total balance 10011.040020,
# day 365: buy 1 unit at price 62.639999, total balance 9948.400021
# day 366, sell 1 unit at price 62.720001, investment 0.127717 %, total balance 10011.120022,
# day 375: buy 1 unit at price 62.689999, total balance 9948.430023
# day 376: buy 1 unit at price 63.220001, total balance 9885.210022
# day 377, sell 1 unit at price 63.830002, investment 1.818477 %, total balance 9949.040024,
# day 378, sell 1 unit at price 64.080002, investment 1.360330 %, total balance 10013.120026,
# day 396: buy 1 unit at price 65.550003, total balance 9947.570023
# day 397, sell 1 unit at price 64.489998, investment -1.617094 %, total balance 10012.060020,
# day 402: buy 1 unit at price 63.950001, total balance 9948.110020
# day 403, sell 1 unit at price 64.349998, investment 0.625485 %, total balance 10012.460018,
# day 410: buy 1 unit at price 66.080002, total balance 9946.380016
# day 411, sell 1 unit at price 66.050003, investment -0.045398 %, total balance 10012.430019,
# day 417: buy 1 unit at price 65.699997, total balance 9946.730022
# day 418, sell 1 unit at price 65.720001, investment 0.030448 %, total balance 10012.450024,
# day 420: buy 1 unit at price 66.230003, total balance 9946.220020
# day 421, sell 1 unit at price 66.379997, investment 0.226474 %, total balance 10012.600017,
# day 426: buy 1 unit at price 64.949997, total balance 9947.650021
# day 427, sell 1 unit at price 64.570000, investment -0.585061 %, total balance 10012.220020,
# day 436: buy 1 unit at price 62.279999, total balance 9949.940021
# day 437, sell 1 unit at price 62.570000, investment 0.465641 %, total balance 10012.510021,
# day 439: buy 1 unit at price 61.320000, total balance 9951.190021
# day 440, sell 1 unit at price 60.330002, investment -1.614478 %, total balance 10011.520023,
# day 441: buy 1 unit at price 60.529999, total balance 9950.990024
# day 442, sell 1 unit at price 61.060001, investment 0.875603 %, total balance 10012.050026,
# day 443: buy 1 unit at price 61.380001, total balance 9950.670025
# day 444, sell 1 unit at price 60.869999, investment -0.830893 %, total balance 10011.540024,
# day 456: buy 1 unit at price 61.430000, total balance 9950.110023
# day 457, sell 1 unit at price 61.490002, investment 0.097674 %, total balance 10011.600025,
# day 459: buy 1 unit at price 62.110001, total balance 9949.490024
# day 460, sell 1 unit at price 62.259998, investment 0.241503 %, total balance 10011.750023,
# day 470: buy 1 unit at price 62.230000, total balance 9949.520023
# day 471: buy 1 unit at price 62.430000, total balance 9887.090023
# day 472: buy 1 unit at price 62.779999, total balance 9824.310024
# day 473, sell 1 unit at price 62.169998, investment -0.096419 %, total balance 9886.480022,
# day 474, sell 1 unit at price 62.099998, investment -0.528595 %, total balance 9948.580021,
# day 475, sell 1 unit at price 61.830002, investment -1.513216 %, total balance 10010.410023,
# day 479: buy 1 unit at price 62.580002, total balance 9947.830021
# day 480: buy 1 unit at price 63.450001, total balance 9884.380020
# day 481, sell 1 unit at price 62.889999, investment 0.495362 %, total balance 9947.270019,
# day 482, sell 1 unit at price 61.880001, investment -2.474389 %, total balance 10009.150021,
# day 486: buy 1 unit at price 62.770000, total balance 9946.380020
# day 487, sell 1 unit at price 62.150002, investment -0.987731 %, total balance 10008.530022,
# day 496: buy 1 unit at price 60.139999, total balance 9948.390022
# day 497, sell 1 unit at price 60.880001, investment 1.230465 %, total balance 10009.270023,
# day 499: buy 1 unit at price 60.369999, total balance 9948.900024
# day 500: buy 1 unit at price 61.020000, total balance 9887.880024
# day 501, sell 1 unit at price 60.950001, investment 0.960745 %, total balance 9948.830025,
# day 502, sell 1 unit at price 60.669998, investment -0.573586 %, total balance 10009.500023,
# day 519: buy 1 unit at price 64.000000, total balance 9945.500023
# day 520, sell 1 unit at price 63.549999, investment -0.703126 %, total balance 10009.050022,
# day 529: buy 1 unit at price 62.520000, total balance 9946.530022
# day 530, sell 1 unit at price 62.639999, investment 0.191937 %, total balance 10009.170021,
# day 537: buy 1 unit at price 63.660000, total balance 9945.510021
# day 538: buy 1 unit at price 63.209999, total balance 9882.300022
# day 539, sell 1 unit at price 63.869999, investment 0.329876 %, total balance 9946.170021,
# day 540, sell 1 unit at price 63.759998, investment 0.870114 %, total balance 10009.930019,
# day 545: buy 1 unit at price 63.270000, total balance 9946.660019
# day 546, sell 1 unit at price 63.110001, investment -0.252884 %, total balance 10009.770019,
# day 547: buy 1 unit at price 62.520000, total balance 9947.250019
# day 548, sell 1 unit at price 62.459999, investment -0.095971 %, total balance 10009.710018,
# day 574: buy 1 unit at price 68.449997, total balance 9941.260021
# day 575, sell 1 unit at price 69.029999, investment 0.847337 %, total balance 10010.290020,
# day 577: buy 1 unit at price 67.949997, total balance 9942.340023
# day 578: buy 1 unit at price 68.430000, total balance 9873.910023
# day 579, sell 1 unit at price 69.129997, investment 1.736572 %, total balance 9943.040020,
# day 580, sell 1 unit at price 69.419998, investment 1.446731 %, total balance 10012.460018,
# day 598: buy 1 unit at price 67.879997, total balance 9944.580021
# day 599, sell 1 unit at price 67.769997, investment -0.162052 %, total balance 10012.350017,
# day 614: buy 1 unit at price 64.459999, total balance 9947.890018
# day 615, sell 1 unit at price 64.660004, investment 0.310277 %, total balance 10012.550022,
# day 624: buy 1 unit at price 64.500000, total balance 9948.050022
# day 625, sell 1 unit at price 63.730000, investment -1.193799 %, total balance 10011.780022,
# day 626: buy 1 unit at price 62.299999, total balance 9949.480022
# day 627, sell 1 unit at price 63.000000, investment 1.123597 %, total balance 10012.480022,
# day 632: buy 1 unit at price 58.139999, total balance 9954.340023
# day 633, sell 1 unit at price 59.599998, investment 2.511178 %, total balance 10013.940021,
# day 635: buy 1 unit at price 61.549999, total balance 9952.390022
# day 636, sell 1 unit at price 61.430000, investment -0.194962 %, total balance 10013.820022,
# day 638: buy 1 unit at price 61.529999, total balance 9952.290024
# day 640, sell 1 unit at price 61.240002, investment -0.471310 %, total balance 10013.530025,
# day 646: buy 1 unit at price 59.139999, total balance 9954.390026
# day 647: buy 1 unit at price 59.590000, total balance 9894.800026
# day 648, sell 1 unit at price 59.009998, investment -0.219819 %, total balance 9953.810024,
# day 649, sell 1 unit at price 59.270000, investment -0.537002 %, total balance 10013.080025,
# day 661: buy 1 unit at price 55.669998, total balance 9957.410026
# day 662, sell 1 unit at price 54.990002, investment -1.221477 %, total balance 10012.400028,
# day 687: buy 1 unit at price 52.270000, total balance 9960.130028
# day 688, sell 1 unit at price 52.180000, investment -0.172183 %, total balance 10012.310028,
# day 694: buy 1 unit at price 55.330002, total balance 9956.980026
# day 696, sell 1 unit at price 56.570000, investment 2.241095 %, total balance 10013.550026,
# day 698: buy 1 unit at price 57.130001, total balance 9956.420025
# day 699, sell 1 unit at price 56.950001, investment -0.315071 %, total balance 10013.370026,
# day 719: buy 1 unit at price 55.910000, total balance 9957.460026
# day 720: buy 1 unit at price 55.470001, total balance 9901.990024
# day 721, sell 1 unit at price 55.560001, investment -0.626003 %, total balance 9957.550026,
# day 722, sell 1 unit at price 55.299999, investment -0.306476 %, total balance 10012.850025,
# day 729: buy 1 unit at price 56.060001, total balance 9956.790024
# day 730, sell 1 unit at price 56.330002, investment 0.481628 %, total balance 10013.120026,
# day 732: buy 1 unit at price 55.169998, total balance 9957.950027
# day 733, sell 1 unit at price 55.480000, investment 0.561902 %, total balance 10013.430027,
# day 735: buy 1 unit at price 55.430000, total balance 9958.000027
# day 736, sell 1 unit at price 54.970001, investment -0.829874 %, total balance 10012.970028,
# day 740: buy 1 unit at price 53.919998, total balance 9959.050030
# day 741, sell 1 unit at price 53.799999, investment -0.222550 %, total balance 10012.850029,
# day 751: buy 1 unit at price 54.480000, total balance 9958.370029
# day 753, sell 1 unit at price 54.139999, investment -0.624083 %, total balance 10012.510029,
# day 754: buy 1 unit at price 53.560001, total balance 9958.950027
# day 755, sell 1 unit at price 53.410000, investment -0.280063 %, total balance 10012.360027,
# day 758: buy 1 unit at price 50.939999, total balance 9961.420029
# day 759: buy 1 unit at price 49.520000, total balance 9911.900028
# day 761: buy 1 unit at price 49.139999, total balance 9862.760029
# day 762, sell 1 unit at price 49.259998, investment -3.297998 %, total balance 9912.020027,
# day 763, sell 1 unit at price 48.689999, investment -1.676094 %, total balance 9960.710026,
# day 765, sell 1 unit at price 47.369999, investment -3.601955 %, total balance 10008.080025,
# day 774: buy 1 unit at price 49.750000, total balance 9958.330025
# day 775, sell 1 unit at price 49.299999, investment -0.904524 %, total balance 10007.630024,
# day 776: buy 1 unit at price 48.090000, total balance 9959.540024
# day 777: buy 1 unit at price 48.869999, total balance 9910.670025
# day 778, sell 1 unit at price 49.040001, investment 1.975464 %, total balance 9959.710026,
# day 779, sell 1 unit at price 48.650002, investment -0.450169 %, total balance 10008.360027,
# day 793: buy 1 unit at price 49.090000, total balance 9959.270027
# day 794, sell 1 unit at price 49.310001, investment 0.448159 %, total balance 10008.580028,
# day 795: buy 1 unit at price 50.849998, total balance 9957.730030
# day 797, sell 1 unit at price 51.849998, investment 1.966568 %, total balance 10009.580028,
# day 810: buy 1 unit at price 54.250000, total balance 9955.330028
# day 811: buy 1 unit at price 53.549999, total balance 9901.780029
# day 812, sell 1 unit at price 53.459999, investment -1.456223 %, total balance 9955.240028,
# day 813, sell 1 unit at price 53.450001, investment -0.186739 %, total balance 10008.690029,
# day 817: buy 1 unit at price 54.310001, total balance 9954.380028
# day 819, sell 1 unit at price 52.900002, investment -2.596207 %, total balance 10007.280029,
# day 845: buy 1 unit at price 52.090000, total balance 9955.190029
# day 846, sell 1 unit at price 51.919998, investment -0.326362 %, total balance 10007.110027,
# day 848: buy 1 unit at price 51.910000, total balance 9955.200027
# day 849, sell 1 unit at price 51.709999, investment -0.385284 %, total balance 10006.910026,
# day 859: buy 1 unit at price 53.189999, total balance 9953.720028
# day 860, sell 1 unit at price 53.619999, investment 0.808423 %, total balance 10007.340027,
# day 864: buy 1 unit at price 55.259998, total balance 9952.080028
# day 865, sell 1 unit at price 54.779999, investment -0.868620 %, total balance 10006.860027,
# day 878: buy 1 unit at price 53.060001, total balance 9953.800026
# day 879, sell 1 unit at price 54.060001, investment 1.884659 %, total balance 10007.860027,
# day 893: buy 1 unit at price 57.000000, total balance 9950.860027
# day 894, sell 1 unit at price 56.919998, investment -0.140354 %, total balance 10007.780025,
# day 911: buy 1 unit at price 60.020000, total balance 9947.760025
# day 913, sell 1 unit at price 59.380001, investment -1.066310 %, total balance 10007.140026,
# day 931: buy 1 unit at price 58.320000, total balance 9948.820026
# day 933, sell 1 unit at price 59.639999, investment 2.263374 %, total balance 10008.460026,
# day 936: buy 1 unit at price 59.720001, total balance 9948.740024
# day 937, sell 1 unit at price 61.209999, investment 2.494973 %, total balance 10009.950024,
# day 942: buy 1 unit at price 61.099998, total balance 9948.850025
# day 943, sell 1 unit at price 60.209999, investment -1.456628 %, total balance 10009.060024,
# day 963: buy 1 unit at price 59.119999, total balance 9949.940025
# day 965, sell 1 unit at price 58.919998, investment -0.338296 %, total balance 10008.860023,
# day 969: buy 1 unit at price 57.639999, total balance 9951.220024
# day 971, sell 1 unit at price 59.389999, investment 3.036086 %, total balance 10010.610023,
# day 973: buy 1 unit at price 56.720001, total balance 9953.890022
# day 974, sell 1 unit at price 55.730000, investment -1.745419 %, total balance 10009.620022,
# day 979: buy 1 unit at price 55.750000, total balance 9953.870022
# day 980: buy 1 unit at price 55.910000, total balance 9897.960022
# day 981, sell 1 unit at price 56.529999, investment 1.399101 %, total balance 9954.490021,
# day 982, sell 1 unit at price 56.230000, investment 0.572348 %, total balance 10010.720020,
# day 983: buy 1 unit at price 56.560001, total balance 9954.160019
# day 984, sell 1 unit at price 56.700001, investment 0.247524 %, total balance 10010.860020,
# day 993: buy 1 unit at price 57.490002, total balance 9953.370018
# day 994: buy 1 unit at price 56.919998, total balance 9896.450020
# day 995, sell 1 unit at price 57.570000, investment 0.139151 %, total balance 9954.020019,
# day 997, sell 1 unit at price 56.130001, investment -1.387908 %, total balance 10010.150020,
# day 999: buy 1 unit at price 55.549999, total balance 9954.600021
# day 1000, sell 1 unit at price 55.560001, investment 0.018006 %, total balance 10010.160023,
# day 1005: buy 1 unit at price 54.400002, total balance 9955.760021
# day 1006: buy 1 unit at price 55.110001, total balance 9900.650020
# day 1009, sell 1 unit at price 56.020000, investment 2.977939 %, total balance 9956.670021,
# day 1010, sell 1 unit at price 56.810001, investment 3.084741 %, total balance 10013.480022,
# day 1015: buy 1 unit at price 57.740002, total balance 9955.740021
# day 1016: buy 1 unit at price 57.770000, total balance 9897.970020
# day 1017, sell 1 unit at price 57.720001, investment -0.034639 %, total balance 9955.690021,
# day 1018, sell 1 unit at price 57.570000, investment -0.346202 %, total balance 10013.260021,
# day 1026: buy 1 unit at price 58.799999, total balance 9954.460022
# day 1027, sell 1 unit at price 58.990002, investment 0.323133 %, total balance 10013.450024,
# day 1028: buy 1 unit at price 59.090000, total balance 9954.360023
# day 1029, sell 1 unit at price 59.240002, investment 0.253853 %, total balance 10013.600025,
# day 1035: buy 1 unit at price 60.220001, total balance 9953.380024
# day 1036, sell 1 unit at price 60.419998, investment 0.332111 %, total balance 10013.800022,
# day 1038: buy 1 unit at price 60.810001, total balance 9952.990021
# day 1041: buy 1 unit at price 61.060001, total balance 9891.930019
# day 1042, sell 1 unit at price 61.320000, investment 0.838675 %, total balance 9953.250019,
# day 1043, sell 1 unit at price 61.389999, investment 0.540449 %, total balance 10014.640018,
# day 1046: buy 1 unit at price 60.619999, total balance 9954.020019
# day 1048: buy 1 unit at price 60.349998, total balance 9893.670021
# day 1049, sell 1 unit at price 60.349998, investment -0.445398 %, total balance 9954.020019,
# day 1050, sell 1 unit at price 60.380001, investment 0.049714 %, total balance 10014.400020,
# day 1055: buy 1 unit at price 61.310001, total balance 9953.090019
# day 1056, sell 1 unit at price 61.119999, investment -0.309904 %, total balance 10014.210018,
# day 1062: buy 1 unit at price 63.200001, total balance 9951.010017
# day 1063, sell 1 unit at price 63.240002, investment 0.063293 %, total balance 10014.250019,
# day 1064: buy 1 unit at price 63.310001, total balance 9950.940018
# day 1065, sell 1 unit at price 63.330002, investment 0.031591 %, total balance 10014.270019,
# day 1067: buy 1 unit at price 63.509998, total balance 9950.760021
# day 1068, sell 1 unit at price 63.250000, investment -0.409382 %, total balance 10014.010021,
# day 1074: buy 1 unit at price 63.139999, total balance 9950.870022
# day 1075, sell 1 unit at price 62.860001, investment -0.443457 %, total balance 10013.730022,
# day 1080: buy 1 unit at price 62.360001, total balance 9951.370022
# day 1081: buy 1 unit at price 62.070000, total balance 9889.300022
# day 1082, sell 1 unit at price 62.810001, investment 0.721618 %, total balance 9952.110023,
# day 1084, sell 1 unit at price 63.410000, investment 2.158853 %, total balance 10015.520023,
# day 1087: buy 1 unit at price 64.239998, total balance 9951.280025
# day 1088, sell 1 unit at price 64.209999, investment -0.046698 %, total balance 10015.490024,
# day 1092: buy 1 unit at price 64.150002, total balance 9951.340023
# day 1093: buy 1 unit at price 64.269997, total balance 9887.070026
# day 1095, sell 1 unit at price 65.309998, investment 1.808256 %, total balance 9952.380024,
# day 1096, sell 1 unit at price 65.540001, investment 1.976045 %, total balance 10017.920025,
# day 1101: buy 1 unit at price 65.419998, total balance 9952.500027
# day 1102, sell 1 unit at price 65.500000, investment 0.122290 %, total balance 10018.000027,
# day 1109: buy 1 unit at price 67.050003, total balance 9950.950024
# day 1110, sell 1 unit at price 66.760002, investment -0.432514 %, total balance 10017.710026,
# day 1114: buy 1 unit at price 67.839996, total balance 9949.870029
# day 1115, sell 1 unit at price 67.769997, investment -0.103184 %, total balance 10017.640026,
# day 1117: buy 1 unit at price 67.849998, total balance 9949.790028
# day 1118, sell 1 unit at price 67.370003, investment -0.707437 %, total balance 10017.160030,
# day 1121: buy 1 unit at price 67.099998, total balance 9950.060032
# day 1122, sell 1 unit at price 67.180000, investment 0.119228 %, total balance 10017.240032,
# day 1125: buy 1 unit at price 67.389999, total balance 9949.850033
# day 1126, sell 1 unit at price 67.669998, investment 0.415490 %, total balance 10017.520031,
# day 1133: buy 1 unit at price 67.629997, total balance 9949.890034
# day 1134, sell 1 unit at price 67.589996, investment -0.059147 %, total balance 10017.480030,
# day 1146: buy 1 unit at price 70.510002, total balance 9946.970028
# day 1147, sell 1 unit at price 70.900002, investment 0.553112 %, total balance 10017.870029,
# day 1149: buy 1 unit at price 71.230003, total balance 9946.640026
# day 1150, sell 1 unit at price 70.750000, investment -0.673878 %, total balance 10017.390026,
# day 1157: buy 1 unit at price 71.500000, total balance 9945.890026
# day 1158, sell 1 unit at price 71.610001, investment 0.153847 %, total balance 10017.500027,
# day 1179: buy 1 unit at price 72.220001, total balance 9945.280025
# day 1180, sell 1 unit at price 71.949997, investment -0.373864 %, total balance 10017.230022,
# day 1195: buy 1 unit at price 72.220001, total balance 9945.010021
# day 1198: buy 1 unit at price 73.349998, total balance 9871.660023
# day 1200, sell 1 unit at price 73.559998, investment 1.855437 %, total balance 9945.220020,
# day 1201: buy 1 unit at price 73.769997, total balance 9871.450024
# day 1202, sell 1 unit at price 74.480003, investment 1.540566 %, total balance 9945.930027,
# day 1204, sell 1 unit at price 74.559998, investment 1.070897 %, total balance 10020.490024,
# day 1227: buy 1 unit at price 75.669998, total balance 9944.820026
# day 1228, sell 1 unit at price 75.239998, investment -0.568257 %, total balance 10020.060024,
# day 1229: buy 1 unit at price 76.720001, total balance 9943.340023
# day 1230, sell 1 unit at price 76.699997, investment -0.026074 %, total balance 10020.040020,
# day 1240: buy 1 unit at price 75.000000, total balance 9945.040020
# day 1242, sell 1 unit at price 73.860001, investment -1.519999 %, total balance 10018.900021,
# day 1266: buy 1 unit at price 79.400002, total balance 9939.500019
# day 1267, sell 1 unit at price 80.150002, investment 0.944584 %, total balance 10019.650021,
# day 1275: buy 1 unit at price 82.250000, total balance 9937.400021
# day 1277, sell 1 unit at price 82.309998, investment 0.072945 %, total balance 10019.710018,
# day 1282: buy 1 unit at price 76.370003, total balance 9943.340015
# day 1283, sell 1 unit at price 78.360001, investment 2.605732 %, total balance 10021.700016,
# day 1284: buy 1 unit at price 75.739998, total balance 9945.960018
# day 1285, sell 1 unit at price 73.320000, investment -3.195139 %, total balance 10019.280018,
# day 1291: buy 1 unit at price 78.930000, total balance 9940.350017
# day 1292, sell 1 unit at price 77.860001, investment -1.355631 %, total balance 10018.210018,
# day 1300: buy 1 unit at price 76.900002, total balance 9941.310017
# day 1302, sell 1 unit at price 77.540001, investment 0.832249 %, total balance 10018.850017,
# day 1317: buy 1 unit at price 76.559998, total balance 9942.290020
# day 1318, sell 1 unit at price 76.160004, investment -0.522458 %, total balance 10018.450024,
# day 1330: buy 1 unit at price 77.010002, total balance 9941.440021
# day 1332, sell 1 unit at price 77.430000, investment 0.545381 %, total balance 10018.870022,
# day 1342: buy 1 unit at price 75.690002, total balance 9943.180019
# day 1343, sell 1 unit at price 75.529999, investment -0.211393 %, total balance 10018.710018,
# day 1349: buy 1 unit at price 77.489998, total balance 9941.220020
# day 1350, sell 1 unit at price 77.699997, investment 0.271002 %, total balance 10018.920017,
# day 1351: buy 1 unit at price 76.250000, total balance 9942.670017
# day 1352, sell 1 unit at price 77.370003, investment 1.468856 %, total balance 10020.040020,
# day 1354: buy 1 unit at price 75.989998, total balance 9944.050022
# day 1355, sell 1 unit at price 76.709999, investment 0.947495 %, total balance 10020.760021,
# day 1361: buy 1 unit at price 75.779999, total balance 9944.980022
# day 1363, sell 1 unit at price 76.870003, investment 1.438380 %, total balance 10021.850025,
# day 1366: buy 1 unit at price 78.690002, total balance 9943.160023
# day 1367, sell 1 unit at price 77.919998, investment -0.978529 %, total balance 10021.080021,
# day 1368: buy 1 unit at price 77.510002, total balance 9943.570019
# day 1370, sell 1 unit at price 77.470001, investment -0.051607 %, total balance 10021.040020,
# day 1383: buy 1 unit at price 71.669998, total balance 9949.370022
# day 1384, sell 1 unit at price 70.779999, investment -1.241802 %, total balance 10020.150021,
# day 1387: buy 1 unit at price 71.099998, total balance 9949.050022
# day 1388, sell 1 unit at price 72.430000, investment 1.870607 %, total balance 10021.480022,
# day 1390: buy 1 unit at price 70.919998, total balance 9950.560024
# day 1391, sell 1 unit at price 71.910004, investment 1.395947 %, total balance 10022.470028,
# day 1394: buy 1 unit at price 71.900002, total balance 9950.570026
# day 1395: buy 1 unit at price 71.839996, total balance 9878.730030
# day 1396, sell 1 unit at price 71.000000, investment -1.251741 %, total balance 9949.730030,
# day 1397, sell 1 unit at price 72.010002, investment 0.236645 %, total balance 10021.740032,
# day 1408: buy 1 unit at price 71.290001, total balance 9950.450031
# day 1409, sell 1 unit at price 72.190002, investment 1.262451 %, total balance 10022.640034,
# day 1420: buy 1 unit at price 71.389999, total balance 9951.250034
# day 1421, sell 1 unit at price 70.500000, investment -1.246672 %, total balance 10021.750034,
# day 1428: buy 1 unit at price 70.599998, total balance 9951.150036
# day 1429, sell 1 unit at price 69.379997, investment -1.728047 %, total balance 10020.530033,
# day 1435: buy 1 unit at price 69.660004, total balance 9950.870029
# day 1436, sell 1 unit at price 69.589996, investment -0.100499 %, total balance 10020.460026,
# day 1439: buy 1 unit at price 70.300003, total balance 9950.160023
# day 1440, sell 1 unit at price 70.949997, investment 0.924600 %, total balance 10021.110020,
# day 1447: buy 1 unit at price 70.459999, total balance 9950.650021
# day 1448, sell 1 unit at price 69.250000, investment -1.717285 %, total balance 10019.900021,
# day 1454: buy 1 unit at price 63.900002, total balance 9956.000019
# day 1455, sell 1 unit at price 63.259998, investment -1.001570 %, total balance 10019.260017,
# day 1457: buy 1 unit at price 64.110001, total balance 9955.150017
# day 1458, sell 1 unit at price 65.529999, investment 2.214940 %, total balance 10020.680015,
# day 1460: buy 1 unit at price 63.259998, total balance 9957.420017
# day 1461, sell 1 unit at price 63.959999, investment 1.106546 %, total balance 10021.380016,
# day 1462: buy 1 unit at price 64.730003, total balance 9956.650013
# day 1463, sell 1 unit at price 63.810001, investment -1.421291 %, total balance 10020.460014,
# day 1468: buy 1 unit at price 62.160000, total balance 9958.300014
# day 1470, sell 1 unit at price 65.239998, investment 4.954952 %, total balance 10023.540012,
# day 1475: buy 1 unit at price 65.349998, total balance 9958.190014
# day 1477: buy 1 unit at price 63.230000, total balance 9894.960014
# day 1478: buy 1 unit at price 64.419998, total balance 9830.540016
# day 1479, sell 1 unit at price 64.680000, investment -1.025246 %, total balance 9895.220016,
# day 1480: buy 1 unit at price 66.150002, total balance 9829.070015
# day 1481, sell 1 unit at price 66.199997, investment 4.697133 %, total balance 9895.270012,
# day 1482, sell 1 unit at price 65.139999, investment 1.117667 %, total balance 9960.410011,
# day 1483: buy 1 unit at price 63.910000, total balance 9896.500011
# day 1485, sell 1 unit at price 64.449997, investment -2.569924 %, total balance 9960.950008,
# day 1486, sell 1 unit at price 65.820000, investment 2.988577 %, total balance 10026.770008,
# day 1494: buy 1 unit at price 64.830002, total balance 9961.940006
# day 1495, sell 1 unit at price 64.379997, investment -0.694130 %, total balance 10026.320003,
# day 1502: buy 1 unit at price 62.860001, total balance 9963.460003
# day 1503, sell 1 unit at price 63.200001, investment 0.540885 %, total balance 10026.660004,
# day 1505: buy 1 unit at price 62.119999, total balance 9964.540005
# day 1506, sell 1 unit at price 63.480000, investment 2.189312 %, total balance 10028.020004,
# day 1507: buy 1 unit at price 63.310001, total balance 9964.710003
# day 1508, sell 1 unit at price 63.709999, investment 0.631808 %, total balance 10028.420002,
# day 1510: buy 1 unit at price 63.090000, total balance 9965.330002
# day 1511, sell 1 unit at price 61.599998, investment -2.361708 %, total balance 10026.930000,
# day 1512: buy 1 unit at price 63.630001, total balance 9963.299999
# day 1514: buy 1 unit at price 64.180000, total balance 9899.119999
# day 1516, sell 1 unit at price 65.739998, investment 3.316041 %, total balance 9964.859997,
# day 1518, sell 1 unit at price 64.730003, investment 0.856970 %, total balance 10029.590000,
# day 1520: buy 1 unit at price 66.169998, total balance 9963.420002
# day 1521, sell 1 unit at price 66.480003, investment 0.468498 %, total balance 10029.900005,
# day 1523: buy 1 unit at price 65.669998, total balance 9964.230007
# day 1524, sell 1 unit at price 66.190002, investment 0.791845 %, total balance 10030.420010,
# day 1528: buy 1 unit at price 67.089996, total balance 9963.330013
# day 1531, sell 1 unit at price 68.500000, investment 2.101660 %, total balance 10031.830013,
# day 1532: buy 1 unit at price 68.809998, total balance 9963.020016
# day 1533, sell 1 unit at price 69.760002, investment 1.380620 %, total balance 10032.780018,
# day 1539: buy 1 unit at price 68.599998, total balance 9964.180019
# day 1541, sell 1 unit at price 68.260002, investment -0.495621 %, total balance 10032.440021,
# day 1542: buy 1 unit at price 68.849998, total balance 9963.590023
# day 1543, sell 1 unit at price 69.379997, investment 0.769788 %, total balance 10032.970020,
# day 1550: buy 1 unit at price 69.480003, total balance 9963.490017
# day 1551, sell 1 unit at price 69.639999, investment 0.230276 %, total balance 10033.130016,
# day 1554: buy 1 unit at price 68.779999, total balance 9964.350017
# day 1555, sell 1 unit at price 68.129997, investment -0.945044 %, total balance 10032.480015,
# day 1570: buy 1 unit at price 70.690002, total balance 9961.790012
# day 1571, sell 1 unit at price 71.709999, investment 1.442915 %, total balance 10033.500011,
# day 1572: buy 1 unit at price 71.589996, total balance 9961.910015
# day 1573: buy 1 unit at price 72.269997, total balance 9889.640018
# day 1574, sell 1 unit at price 72.610001, investment 1.424786 %, total balance 9962.250019,
# day 1575, sell 1 unit at price 73.160004, investment 1.231503 %, total balance 10035.410023,
# day 1576: buy 1 unit at price 72.970001, total balance 9962.440021
# day 1577: buy 1 unit at price 72.940002, total balance 9889.500019
# day 1580, sell 1 unit at price 73.199997, investment 0.315192 %, total balance 9962.700016,
# day 1581: buy 1 unit at price 72.599998, total balance 9890.100017
# day 1582, sell 1 unit at price 73.099998, investment 0.219353 %, total balance 9963.200016,
# day 1583, sell 1 unit at price 73.400002, investment 1.101933 %, total balance 10036.600017,
# day 1585: buy 1 unit at price 72.709999, total balance 9963.890018
# day 1586, sell 1 unit at price 72.940002, investment 0.316330 %, total balance 10036.830021,
# day 1587: buy 1 unit at price 72.110001, total balance 9964.720020
# day 1588, sell 1 unit at price 71.889999, investment -0.305091 %, total balance 10036.610020,
# day 1591: buy 1 unit at price 72.260002, total balance 9964.350017
# day 1592, sell 1 unit at price 72.000000, investment -0.359815 %, total balance 10036.350017,
# day 1594: buy 1 unit at price 73.010002, total balance 9963.340015
# day 1596, sell 1 unit at price 69.889999, investment -4.273391 %, total balance 10033.230015,
# day 1611: buy 1 unit at price 65.650002, total balance 9967.580013
# day 1612, sell 1 unit at price 65.769997, investment 0.182780 %, total balance 10033.350010,
# day 1631: buy 1 unit at price 69.260002, total balance 9964.090008
# day 1632, sell 1 unit at price 69.959999, investment 1.010680 %, total balance 10034.050007,
# day 1646: buy 1 unit at price 69.870003, total balance 9964.180004
# day 1647, sell 1 unit at price 69.669998, investment -0.286252 %, total balance 10033.850002,
# day 1656: buy 1 unit at price 66.459999, total balance 9967.390003
# day 1657, sell 1 unit at price 65.650002, investment -1.218775 %, total balance 10033.040005,
# day 1659: buy 1 unit at price 63.919998, total balance 9969.120006
# day 1660, sell 1 unit at price 64.150002, investment 0.359830 %, total balance 10033.270008,
# day 1666: buy 1 unit at price 63.400002, total balance 9969.870006
# day 1667, sell 1 unit at price 64.500000, investment 1.735013 %, total balance 10034.370006,
# day 1682: buy 1 unit at price 67.459999, total balance 9966.910007
# day 1683, sell 1 unit at price 67.500000, investment 0.059296 %, total balance 10034.410007,
# day 1688: buy 1 unit at price 68.050003, total balance 9966.360004
# day 1690, sell 1 unit at price 67.550003, investment -0.734754 %, total balance 10033.910007,
# day 1695: buy 1 unit at price 66.830002, total balance 9967.080006
# day 1696, sell 1 unit at price 65.879997, investment -1.421524 %, total balance 10032.960003,
# day 1705: buy 1 unit at price 66.699997, total balance 9966.260006
# day 1706, sell 1 unit at price 67.690002, investment 1.484266 %, total balance 10033.950008,
# day 1708: buy 1 unit at price 68.199997, total balance 9965.750011
# day 1709, sell 1 unit at price 68.330002, investment 0.190623 %, total balance 10034.080013,
# day 1724: buy 1 unit at price 71.550003, total balance 9962.530010
# day 1725, sell 1 unit at price 72.010002, investment 0.642906 %, total balance 10034.540012,
# day 1727: buy 1 unit at price 70.820000, total balance 9963.720013
# day 1728, sell 1 unit at price 70.470001, investment -0.494209 %, total balance 10034.190014,
# day 1729: buy 1 unit at price 69.800003, total balance 9964.390011
# day 1730, sell 1 unit at price 69.669998, investment -0.186253 %, total balance 10034.060009,
# day 1731: buy 1 unit at price 70.099998, total balance 9963.960010
# day 1734, sell 1 unit at price 70.029999, investment -0.099857 %, total balance 10033.990009,
# day 1735: buy 1 unit at price 69.820000, total balance 9964.170010
# day 1736, sell 1 unit at price 69.800003, investment -0.028640 %, total balance 10033.970013,
# day 1746: buy 1 unit at price 69.820000, total balance 9964.150013
# day 1747: buy 1 unit at price 70.129997, total balance 9894.020016
# day 1749, sell 1 unit at price 72.400002, investment 3.695219 %, total balance 9966.420017,
# day 1750, sell 1 unit at price 72.419998, investment 3.265366 %, total balance 10038.840015,
# day 1752: buy 1 unit at price 72.610001, total balance 9966.230015
# day 1753, sell 1 unit at price 72.949997, investment 0.468250 %, total balance 10039.180012,
# day 1755: buy 1 unit at price 73.000000, total balance 9966.180012
# day 1756, sell 1 unit at price 73.029999, investment 0.041094 %, total balance 10039.210010,
# day 1758: buy 1 unit at price 73.260002, total balance 9965.950008
# day 1759: buy 1 unit at price 73.699997, total balance 9892.250011
# day 1760, sell 1 unit at price 73.260002, investment 0.000000 %, total balance 9965.510014,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
